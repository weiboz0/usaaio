# %% [markdown]
# # B2-020 — Book 1 and B2-019 Bridge Diagnostic
#
# *30 minutes.*
#
# **Program layer:** Round 2 extension
# **Compute:** `compute.policy: cpu` · seed `20260812`
# **Qualified prerequisites:** `book1:F1-scientific-python`, `book1:F3-matrices`, `book1:C6-pytorch`, `book1:C7-cnn-transfer`, `book1:C11-neural-training`, `B2-019-attention-transformers`
# **Remediation links actually used:** [book1:F1-scientific-python](../../../../book1/units/F1-scientific-python/lesson.ipynb), [book1:F3-matrices](../../../../book1/units/F3-matrices/lesson.ipynb), [book1:C6-pytorch](../../../../book1/units/C6-pytorch/lesson.ipynb), [book1:C7-cnn-transfer](../../../../book1/units/C7-cnn-transfer/lesson.ipynb), [book1:C11-neural-training](../../../../book1/units/C11-neural-training/lesson.ipynb), [B2-019-attention-transformers](../../B2-019-attention-transformers/lesson.ipynb).
#
# This bridge distinguishes optional fixed-vector/token-to-index remediation from the required B2-019 attention and causal-mask prerequisite.

# %% [markdown]
# ## 1. Token-to-index and fixed-vector boundary
#
# Map `['red','circle']` through a literal dictionary and distinguish the resulting IDs from fixed vectors. If this is not fluent, use the optional qualified remediation link [book1:C8-embeddings](../../../../book1/units/C8-embeddings/lesson.ipynb). C8 is remediation, not a B2-020 owned or consumed concept.
#
# **Checkpoint 1A.** What is token-to-index?
#
# **Checkpoint 1B.** Why is loading a fixed-vector table not training?

# %% [markdown]
# ## 2. Matrix and tensor shapes
#
# Trace one-hot `(B,12) @ (12,8)`, integer IDs `(B,N)`, hidden states `(B,N,8)`, and logits `(B,N,12)`. Use book1:F3 and book1:C6 if matrix multiplication or Torch dtype rules are not fluent.
#
# **Checkpoint 2A.** Which inputs are int64?
#
# **Checkpoint 2B.** Which outputs are float32?

# %% [markdown]
# ## 3. Autograd and optimizers
#
# State the order zero-grad, forward, loss, backward, step and identify `requires_grad` parameters. Use book1:C11 for remediation when snapshots or optimizer membership are unclear.
#
# **Checkpoint 3A.** Why clear gradients?
#
# **Checkpoint 3B.** What does step mutate?

# %% [markdown]
# ## 4. B2-019 attention prerequisite
#
# Draw the lower-triangular causal mask and trace a pre-norm Transformer block. This is required prerequisite knowledge from B2-019-attention-transformers, not optional Book 1 remediation.
#
# **Checkpoint 4A.** Can row 2 attend to key 3?
#
# **Checkpoint 4B.** Where is the mask applied?

# %% [markdown]
# ## 5. Readiness decision
#
# A learner is ready only if token IDs, tensor shapes, gradient order, Transformer block, attention mask, and causal mask are all fluent. Otherwise follow the named remediation surface before Session 1.
#
# **Checkpoint 5A.** Name one Book 1 remediation.
#
# **Checkpoint 5B.** Name the required B2-019 remediation.

# %%
bridge_feedback = 'ready for B2-020'
assert bridge_feedback == 'ready for B2-020'
