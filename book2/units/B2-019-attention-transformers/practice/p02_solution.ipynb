# %% [markdown]
# # B2-019-attention-transformers — Practice p02 — Solution
#
# **Type:** mc-normal-form · **Difficulty:** intro · **Concepts:** matrix-transpose, query-key-value-attention, scaled-dot-product-attention
#
# **Program layer:** Round 2 extension
# **Compute:** `compute.policy: cpu` · seed `20260808`
# **Qualified Book 1 prerequisites:** `book1:F1-scientific-python`, `book1:F3-matrices`, `book1:C6-pytorch`, `book1:C11-neural-training`
# **Remediation:** review the linked Book 1 units before continuing: [book1:F1-scientific-python](../../../../book1/units/F1-scientific-python/lesson.ipynb), [book1:F3-matrices](../../../../book1/units/F3-matrices/lesson.ipynb), [book1:C6-pytorch](../../../../book1/units/C6-pytorch/lesson.ipynb), [book1:C11-neural-training](../../../../book1/units/C11-neural-training/lesson.ipynb).

# %% [markdown]
# ## Independent solution
#
# The dot product is 2. Scaling by sqrt(2) gives 2/sqrt(2) = sqrt(2), so the coprime pair is (a,b)=(1,1). For the score row (sqrt(2),0), the first softmax weight is exp(sqrt(2))/(exp(sqrt(2))+1). Therefore option A is correct.

# %%
import math
import numpy as np
SEED = 20260808
ATOL = 1e-12
RTOL = 1e-12
ANSWER = "A"
NORMAL_FORM = (1, 1)
q = np.array([1.0, 1.0], dtype=np.float64)
k = np.array([2.0, 0.0], dtype=np.float64)
d_k = 2
scaled_score = (q @ k) / math.sqrt(d_k)
first_weight = math.exp(scaled_score) / (math.exp(scaled_score) + 1.0)

# %% [markdown]
# ### Answer check

# %%
assert ANSWER == "A"
assert NORMAL_FORM == (1, 1)
assert np.isclose(scaled_score, math.sqrt(2.0), atol=ATOL, rtol=RTOL)
assert np.isclose(first_weight, 0.8044296825069569, atol=ATOL, rtol=RTOL)
