# %% [markdown]
# # B2-019 — Practice p05
#
# **Set:** A · **Type:** mc · **Difficulty:** core · **Minutes:** 20
#
# **Concepts:** sinusoidal-positional-encoding
#
# **Program layer:** Round 2 extension
# **Compute:** `compute.policy: cpu` · seed `20260808`
# **Qualified Book 1 prerequisites:** `book1:F1-scientific-python`, `book1:F3-matrices`, `book1:C6-pytorch`, `book1:C11-neural-training`
# **Remediation:** review the linked Book 1 units before continuing: [book1:F1-scientific-python](../../../book1/units/F1-scientific-python/lesson.ipynb), [book1:F3-matrices](../../../book1/units/F3-matrices/lesson.ipynb), [book1:C6-pytorch](../../../book1/units/C6-pytorch/lesson.ipynb), [book1:C11-neural-training](../../../book1/units/C11-neural-training/lesson.ipynb).
#
# ## Task
#
# Self-attention without a positional signal is permutation equivariant. Which statement is correct?
#
# A. Sinusoidal position is multiplied into the score after softmax.
#
# B. At position zero, every sinusoidal coordinate equals one.
#
# C. Adding distinct positional rows to numeric token inputs lets the same content at different positions produce different Q/K/V projections.
#
# D. Positional encoding changes sequence length.
#
# E. Permutation equivariance means output is invariant rather than permuted.
#
# Reasoning is required; distinguish invariance from equivariance.

# %% [markdown]
# ## Your response
#
# Show the requested derivation, implementation, audit, or justification here.
