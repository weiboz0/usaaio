# %% [markdown]
# # B2-019 — Practice p01
#
# **Set:** A · **Type:** mc · **Difficulty:** intro · **Minutes:** 20
#
# **Concepts:** query-key-value-attention
#
# **Program layer:** Round 2 extension
# **Compute:** `compute.policy: cpu` · seed `20260808`
# **Qualified Book 1 prerequisites:** `book1:F1-scientific-python`, `book1:F3-matrices`, `book1:C6-pytorch`, `book1:C11-neural-training`
# **Remediation:** review the linked Book 1 units before continuing: [book1:F1-scientific-python](../../../book1/units/F1-scientific-python/lesson.ipynb), [book1:F3-matrices](../../../book1/units/F3-matrices/lesson.ipynb), [book1:C6-pytorch](../../../book1/units/C6-pytorch/lesson.ipynb), [book1:C11-neural-training](../../../book1/units/C11-neural-training/lesson.ipynb).
#
# ## Task
#
# A query vector represents a destination's request, keys represent candidate matches, and values carry mixed content. Which option is correct when one attention row is `(0.2, 0.3, 0.5)`?
#
# A. The row is invalid because keys must sum to one.
#
# B. It is a valid attention row and the output is `0.2 V0 + 0.3 V1 + 0.5 V2`.
#
# C. Values choose the softmax denominator.
#
# D. Queries determine the value feature width.
#
# E. The largest weight forces all other weights to zero.
#
# Reasoning is required: identify the role of Q, K, and V and justify the row test.

# %% [markdown]
# ## Your response
#
# Show the requested derivation, implementation, audit, or justification here.
