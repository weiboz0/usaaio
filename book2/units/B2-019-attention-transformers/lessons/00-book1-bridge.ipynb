# %% [markdown]
# # B2-019 — Book 1 Bridge Diagnostic
#
# *30 minutes.*
#
# **Program layer:** Round 2 extension
# **Compute:** `compute.policy: cpu` · seed `20260808`
# **Qualified Book 1 prerequisites:** `book1:F1-scientific-python`, `book1:F2-vectors`, `book1:F3-matrices`, `book1:F5-probability`, `book1:C6-pytorch`, `book1:C7-cnn-transfer`, `book1:C8-embeddings`, `book1:C11-neural-training`
# **Remediation:** review the linked Book 1 units before continuing: [book1:F1-scientific-python](../../../../book1/units/F1-scientific-python/lesson.ipynb), [book1:F2-vectors](../../../../book1/units/F2-vectors/lesson.ipynb), [book1:F3-matrices](../../../../book1/units/F3-matrices/lesson.ipynb), [book1:F5-probability](../../../../book1/units/F5-probability/lesson.ipynb), [book1:C6-pytorch](../../../../book1/units/C6-pytorch/lesson.ipynb), [book1:C7-cnn-transfer](../../../../book1/units/C7-cnn-transfer/lesson.ipynb), [book1:C8-embeddings](../../../../book1/units/C8-embeddings/lesson.ipynb), [book1:C11-neural-training](../../../../book1/units/C11-neural-training/lesson.ipynb).
#
# This diagnostic checks imported skills; it teaches no new Book 2 concept.

# %% [markdown]
# ## 1. NumPy reductions and vectorization
#
# **Imports diagnosed:** `book1:numpy-arrays`, `book1:broadcasting`, `book1:vectorization`, `book1:elementwise-ops`, `book1:aggregation-axis`, `book1:random-seeding`.
#
# Given a (2,3,4) array, identify the axis that reduces tokens while preserving batch and feature axes; then predict the result shape with keepdims=True.
#
# **If this is not fluent:** stop and use [book1:F1-scientific-python](../../../../book1/units/F1-scientific-python/lesson.ipynb) for remediation.

# %% [markdown]
# ## 2. dot products and matrix multiplication
#
# **Imports diagnosed:** `book1:dot-product`, `book1:matrix-multiplication`.
#
# Compute one row-column dot product and state why transposing the key matrix makes all pairwise query-key scores at once.
#
# **If this is not fluent:** stop and use [book1:F2-vectors](../../../../book1/units/F2-vectors/lesson.ipynb) for remediation.

# %% [markdown]
# ## 3. expectation and variance
#
# **Imports diagnosed:** `book1:expectation`, `book1:variance`, `book1:independence`, `book1:variance-of-sums`.
#
# For independent zero-mean coordinates with unit variance, derive the variance of a d-term dot product.
#
# **If this is not fluent:** stop and use [book1:F5-probability](../../../../book1/units/F5-probability/lesson.ipynb) for remediation.

# %% [markdown]
# ## 4. tensor shapes
#
# **Imports diagnosed:** `book1:torch-tensors`, `book1:tensor-shape-tracing`, `book1:requires-grad`.
#
# Trace (B,N,D) through transpose(-2,-1), matrix multiplication, and a scalar loss; state which tensors may receive gradients.
#
# **If this is not fluent:** stop and use [book1:C6-pytorch](../../../../book1/units/C6-pytorch/lesson.ipynb) for remediation.

# %% [markdown]
# ## 5. cross-entropy, nn.Module, autograd, and optimizer fluency
#
# **Imports diagnosed:** `book1:nn-module`, `book1:softmax`, `book1:cross-entropy-loss`, `book1:torch-optimizers`, `book1:autograd-training`.
#
# Order zero_grad, forward, cross-entropy, backward, and step; explain why cross_entropy receives logits rather than probabilities.
#
# **If this is not fluent:** stop and use [book1:C11-neural-training](../../../../book1/units/C11-neural-training/lesson.ipynb) for remediation.

# %% [markdown]
# ## Additional qualified remediation routes
#
# - `book1:F3-matrices`: [transpose and matrix products](../../../../book1/units/F3-matrices/lesson.ipynb).
# - `book1:C7-cnn-transfer`: [batched tensor shape discipline](../../../../book1/units/C7-cnn-transfer/lesson.ipynb).
# - `book1:C8-embeddings`: [roadmap continuity only](../../../../book1/units/C8-embeddings/lesson.ipynb); it is evidence context, not a teaching prerequisite here.
# - `book1:C11-neural-training`: [cross-entropy, autograd, and optimizer loop](../../../../book1/units/C11-neural-training/lesson.ipynb).
#
# Proceed only when every group can be completed without looking up syntax.
