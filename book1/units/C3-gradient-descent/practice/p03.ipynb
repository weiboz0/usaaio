# %% [markdown]
# # C3-gradient-descent — Practice p03
#
# **Type:** multiple choice · **Difficulty:** core · **Concepts:** learning-rate
#
# Three descent runs were made on the same quadratic loss
# $L(w) = (w - 5)^2$, each with a different learning rate
# $\eta \in \{0.001,\; 0.2,\; 1.2\}$ (one run per value).
# The observed behaviors:
#
# - **Run 1:** the distance $|w_t - 5|$ shrinks by about $0.2\%$ per step — a slow crawl.
# - **Run 2:** the iterates alternate sides of $5$, and the distance $|w_t - 5|$ **grows** every step.
# - **Run 3:** the distance shrinks by a factor of $0.6$ every step, never overshooting $5$.
#
# Which assignment of learning rates to runs is correct?
#
# A. Run 1 → $0.2$, Run 2 → $1.2$, Run 3 → $0.001$
#
# B. Run 1 → $0.001$, Run 2 → $1.2$, Run 3 → $0.2$
#
# C. Run 1 → $0.001$, Run 2 → $0.2$, Run 3 → $1.2$
#
# D. Run 1 → $1.2$, Run 2 → $0.001$, Run 3 → $0.2$
#
# E. Run 1 → $0.2$, Run 2 → $0.001$, Run 3 → $1.2$
#
# Reasoning is not required. Record your choice below.

# %%
import numpy as np

answer_p03 = "?"  # replace with "A".."E"
