# %% [markdown]
# # C3-gradient-descent — Practice p02
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** gradient-descent
#
# Let $L(w) = w^2 + 2w$ (a single-number parameter $w$).
#
# Starting from $w = 1$, one gradient-descent step
# $w \leftarrow w - \eta\, L'(w)$ is taken with learning rate $\eta = 0.25$.
#
# What is the new value of $w$?
#
# A. $0$
#
# B. $2$
#
# C. $1$
#
# D. $-1$
#
# E. $0.5$
#
# Reasoning is not required. Record your choice below.

# %%
import numpy as np

answer_p02 = "?"  # replace with "A".."E"
