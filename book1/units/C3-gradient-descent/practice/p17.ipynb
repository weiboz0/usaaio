# %% [markdown]
# # C3-gradient-descent — Practice p17
#
# **Type:** challenge · **Difficulty:** advanced · **Concepts:** gradient-descent, loss-surfaces
#
# Beyond the bowl: a surface with two valleys.
#
# Consider the (non-quadratic) loss
# $$L(w) = (w^2 - 1)^2, \qquad L'(w) = 4w^3 - 4w .$$
#
# **(a)** By hand (Calc AB): find all three critical points of $L$, classify each with the second derivative $L''(w) = 12w^2 - 4$, and give the loss value at each.
# Write the work in the markdown cell.
#
# **(b)** Run 300 descent steps with $\eta = 0.05$ from each starting point in `starts`, and store the four final iterates in `finals` (shape `(4,)`, same order).
# Compare with (a) in the markdown cell: which minimum does each run find, and what single property of the start decides it?
#
# **(c)** Near a minimum $w^\star = \pm 1$, small errors evolve with the local update factor
# $1 - \eta\, L''(w^\star) = 1 - 8\eta$ (Session 1's bowl analysis, with the curvature at that minimum).
# Derive the resulting local convergence condition on $\eta$.
# Then run 60 steps from $w_0 = 0.5$ with $\eta = 0.2$ and with $\eta = 0.3$; store
# `settled_02 = bool(abs(w60_at_02 - 1) < 1e-6)`,
# `settled_03 = bool(abs(w60_at_03 - 1) < 1e-6)`, and `first6_03` = the first six iterates of the $\eta = 0.3$ run (starting with $0.5$).
# Check that the two outcomes match your condition.
#
# **(d)** In the markdown cell (2–3 sentences): two things quadratic bowls never showed — what descent converges **to** now depends on where it starts, and the usable $\eta$ is governed by the **local** curvature at the minimum being approached.
#
# The **only** loops allowed are over descent steps and over the four starts.
# **Banned (zero points): `@`, `np.matmul`, `np.dot`, `np.einsum`, `.T`.**

# %%
import numpy as np

starts = np.array([-2.0, -0.5, 0.5, 2.0])

# (b) YOUR CODE HERE
finals = ...

# (c) YOUR CODE HERE
settled_02 = ...
settled_03 = ...
first6_03 = ...

# %% [markdown]
# *Your (a) hand analysis, (b) comparison, (c) derivation, and (d) synthesis here.*
