# %% [markdown]
# # C3-gradient-descent — Practice p05
#
# **Type:** constrained coding · **Difficulty:** intro · **Concepts:** gradient-descent
#
# The descent step as one line of array arithmetic.
#
# **(a)** Write `descent_step(w, grad, eta)` that takes a parameter array `w` of shape `(d,)`, a gradient array `grad` of shape `(d,)`, and a learning rate `eta`, and returns the updated array
# $w - \eta\,\cdot\mathrm{grad}$ (do not modify the input in place).
# Apply it once to the arrays below to produce `w_new`.
#
# **(b)** For the loss $L(w) = \sum_k w_k^2$ the gradient is $\nabla L(w) = 2w$.
# Starting again from the same `w`, apply `descent_step` **twice** with `eta = 0.25`, recomputing the gradient between the two steps.
# Store the result in `w_after_two`.
#
# **Banned (zero points): `@`, `np.matmul`, `np.dot`, `np.einsum`, `.T`.**
# Elementwise array arithmetic only; calling `descent_step` twice by hand (or in a 2-iteration loop) is allowed.

# %%
import numpy as np

w = np.array([1.0, -2.0, 0.5])
grad = np.array([4.0, -2.0, 0.0])
eta = 0.1


def descent_step(w, grad, eta):
    # YOUR CODE HERE (banned: @, np.matmul, np.dot, np.einsum, .T)
    ...


w_new = ...        # YOUR CODE HERE — one step with the arrays above

# (b) two steps on L(w) = sum(w_k^2), eta = 0.25, starting from w
w_after_two = ...  # YOUR CODE HERE
