# %% [markdown]
# # C3-gradient-descent — Practice p06
#
# **Type:** constrained coding · **Difficulty:** intro · **Concepts:** loss-surfaces, linear-regression, mse-loss, broadcasting, aggregation-axis
#
# Build a loss surface on a grid — no loops.
#
# For the one-feature dataset below, the model is
# $\hat y_i = w\, x_i + b$ and the loss is
# $$L(w, b) = \frac{1}{n} \sum_{i=1}^{n} (\hat y_i - y_i)^2 ,$$
# as covered in C2-linear-models.
#
# Using the grids `w_vals` (81 values) and `b_vals` (81 values) below, build `L_grid` of shape `(81, 81)` where **row $i$, column $j$** holds $L$ evaluated at $w = $ `w_vals[j]`, $b = $ `b_vals[i]` — rows walk along $b$, columns along $w$.
#
# Then compute:
# - `min_loss` — the smallest value in `L_grid`;
# - `best_w`, `best_b` — the grid values of $w$ and $b$ where it occurs
#   (hint: with `k = L_grid.argmin()`, the row index is `k // 81` and the column index is `k % 81`).
#
# **Banned (zero points): any loop, `@`, `np.matmul`, `np.dot`, `np.einsum`, `.T`.**
# Build the whole grid by broadcasting (e.g. shapes `(81, 1, 1)`, `(1, 81, 1)`, `(1, 1, 3)`) and one axis-mean.

# %%
import numpy as np

x = np.array([0.0, 1.0, 2.0])
y = np.array([1.0, 3.0, 5.0])
w_vals = np.linspace(0, 4, 81)
b_vals = np.linspace(-1, 3, 81)

L_grid = ...    # YOUR CODE HERE — shape (81, 81), rows = b, columns = w
min_loss = ...  # YOUR CODE HERE
best_w = ...    # YOUR CODE HERE
best_b = ...    # YOUR CODE HERE
