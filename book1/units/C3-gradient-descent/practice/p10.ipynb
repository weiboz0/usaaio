# %% [markdown]
# # C3-gradient-descent — Practice p10
#
# **Type:** constrained coding · **Difficulty:** advanced · **Concepts:** learning-rate
#
# Mapping the convergence boundary.
#
# Take the quadratic loss $L(w) = 3\,(w - 2)^2$, so $L'(w) = 6\,(w - 2)$.
#
# **(a)** For every learning rate in `etas` below, run 200 descent steps from $w_0 = 0$ and record the final iterate in `final_w` (shape `(10,)`, same order as `etas`).
# Set `converged = np.abs(final_w - 2) < 1e-3` and `n_converged = int(converged.sum())`.
#
# **(b)** By hand, from the update factor: each step multiplies the error $w_t - 2$ by $1 - 6\eta$.
# Derive the **exact** range of $\eta > 0$ for which descent converges, and store the boundary value in `eta_crit` (as an exact expression, e.g. a fraction).
# Check the derived range against your `converged` mask, and write the derivation in the markdown cell.
#
# **(c)** The entry `etas[6]` **is** `eta_crit` exactly.
# Store the first five iterates of that run in `first_five` (shape `(5,)`, starting with $w_0 = 0$), and describe in the markdown cell what the iterates do forever at this boundary learning rate.
#
# Loops over `etas` and over descent steps are allowed.
# **Banned (zero points): `@`, `np.matmul`, `np.dot`, `np.einsum`, `.T`.**

# %%
import numpy as np

etas = np.array([0.01, 0.02, 0.05, 0.1, 0.2, 0.3, 1 / 3, 0.34, 0.4, 0.5])

final_w = ...      # YOUR CODE HERE — shape (10,)
converged = ...    # YOUR CODE HERE
n_converged = ...  # YOUR CODE HERE

eta_crit = ...     # YOUR CODE HERE — exact value from (b)

first_five = ...   # YOUR CODE HERE — first five iterates at etas[6]

# %% [markdown]
# *Your (b) derivation and (c) description here.*
