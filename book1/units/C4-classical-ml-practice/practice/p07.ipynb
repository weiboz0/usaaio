# %% [markdown]
# # C4-classical-ml-practice — Practice p07
#
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** knn, distance-metrics, accuracy-precision-recall, broadcasting, aggregation-axis
#
# k-nearest neighbors from first principles.
#
# Implement `knn_predict(X_tr, y_tr, X_q, k)` returning the 0/1 label
# for each row of `X_q` by **majority vote among the `k` nearest rows
# of `X_tr`** under squared Euclidean distance (odd `k` only, so no
# ties).
#
# Then, for the seeded data below:
#
# - `d2` — the full squared-distance matrix between the 4 query rows
#   and the 40 training rows, shape `(4, 40)`;
# - `preds` — `knn_predict(X_train, y_train, X_query, 5)`, shape
#   `(4,)`, dtype int;
# - `train_acc_k1` — the training accuracy of 1-NN evaluated **on the
#   training set itself** (a `float`), plus a one-sentence written
#   answer below: why does this value come out the way it does, by
#   construction?
#
# **Banned (zero points): importing `sklearn` (any part of it — this
# problem is the no-library register), `scipy`, `for`/`while` loops,
# `np.linalg`.** Route: broadcasting with inserted axes
# (`X_tr[None, :, :] - X_q[:, None, :]`), `np.argsort`, and a
# mean-of-labels vote.

# %%
import numpy as np

SEED = 20260804
rng = np.random.default_rng(SEED)
X_train = np.vstack([rng.normal((2.0, 3.0), 0.9, (20, 2)),   # class 0
                     rng.normal((5.0, 1.0), 0.9, (20, 2))])  # class 1
y_train = np.array([0] * 20 + [1] * 20)
X_query = np.array([[2.5, 2.5], [4.5, 1.5], [3.5, 2.0], [1.5, 4.0]])


def knn_predict(X_tr, y_tr, X_q, k):
    # YOUR CODE HERE (banned: sklearn, scipy, loops, np.linalg)
    ...


d2 = ...            # YOUR CODE HERE  (4, 40)
preds = ...         # YOUR CODE HERE
train_acc_k1 = ...  # YOUR CODE HERE

# %% [markdown]
# *Your one-sentence answer about `train_acc_k1` here.*
