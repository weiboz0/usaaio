# %% [markdown]
# # C4-classical-ml-practice — Practice p17
#
#
# **Type:** scenario · **Difficulty:** core · **Concepts:** cross-validation, sklearn-pipelines
#
# Three students cross-validate 5-NN on the full `data/sensors.csv`
# table (features `temp_c`, `vibration_mm_s`, `pressure_pa`; labels
# `status`), all with `cv=5`, and get three different numbers.
#
# - **Student A**: `cross_val_score(KNeighborsClassifier(5), X, y)` on
#   the raw features.
# - **Student B**: standardizes the **whole table once**
#   (`StandardScaler().fit_transform(X)`), then cross-validates a bare
#   kNN on the scaled matrix.
# - **Student C**: passes a scaler+kNN `Pipeline` to
#   `cross_val_score` on the raw features.
#
# **(a)** Reproduce all three: `acc_A`, `acc_B`, `acc_C` (each the
# mean of the 5 fold scores).
#
# **(b)** Written: explain A's number — which column sabotages the
# distances, and why does no fold escape it?
#
# **(c)** Written: B and C differ by less than 0.02 here — yet exactly
# one of them is a legitimate estimate.
# Which one, what information leaked in the other, and why does the
# small size of the gap *not* rehabilitate the leaky protocol?
#
# **(d)** Written: one sentence — which single number goes into the
# report, and with what caveat about what CV estimates (rather than
# guarantees)?
#
# **Banned (zero points): any additional preprocessing; models other
# than `KNeighborsClassifier`.**

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

SEED = 20260804
FEATURES = ["temp_c", "vibration_mm_s", "pressure_pa"]

sensors = pd.read_csv("data/sensors.csv")
X = sensors[FEATURES].to_numpy()
y = sensors["status"].to_numpy()

acc_A = ...  # YOUR CODE HERE
acc_B = ...  # YOUR CODE HERE
acc_C = ...  # YOUR CODE HERE

# %% [markdown]
# *Your (b)–(d) answers here.*
