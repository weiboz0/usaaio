# %% [markdown]
# # C4-classical-ml-practice — Practice p01
#
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** pandas-basics
#
# A DataFrame `df` holds the table
#
# | | species | mass_g |
# |---|---|---|
# | 0 | alba | 0.42 |
# | 1 | cava | 0.85 |
# | 2 | alba | 0.39 |
# | 3 | brio | 0.61 |
# | 4 | cava | 0.79 |
#
# Which expression correctly computes **the number of rows with species
# `"cava"` AND `mass_g` greater than 0.7**?
#
# A. `df[df["species"] == "cava" & df["mass_g"] > 0.7].shape[0]`
#
# B. `((df["species"] == "cava") & (df["mass_g"] > 0.7)).sum()`
#
# C. `df["species"] == "cava" and df["mass_g"] > 0.7`
#
# D. `df.loc[df["species"] == "cava" or df["mass_g"] > 0.7].count()`
#
# E. `(df["species"] == "cava").sum() & (df["mass_g"] > 0.7).sum()`
#
# Record your choice below.

# %%
import pandas as pd

answer_p01 = "?"  # replace with "A".."E"
