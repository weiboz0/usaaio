# %% [markdown]
# # C4-classical-ml-practice — Practice p21
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** tabular-feature-engineering
#
# *Coding is required.*
#
# The supplied table has three measured predictors. Build a leakage-safe recipe that creates one rowwise interaction **inside** the pipeline.
#
# Implement `add_interaction(frame)`: return a copy with a new column named exactly `"temp_x_moisture"`, equal to `ridge_temp_c * soil_moisture_pct`. Then build `pipe` with these exact steps in order:
#
# 1. `("derive", FunctionTransformer(add_interaction, validate=False))`
# 2. `("scale", StandardScaler())`
# 3. `("knn", KNeighborsClassifier(n_neighbors=7))`
#
# Use the supplied seeded split. Fit only on `X_tr, y_tr`; set `n_features_after` to the number of columns produced by the fitted pipeline's `derive` step on `X_tr.iloc[:2]`, and `val_acc` to a plain `float`.
#
# **Banned (zero points): adding the interaction to `X`, `X_tr`, or `X_val` outside `pipe`; fitting any preprocessing object on all rows; manually transforming the validation rows; or placing preprocessing after kNN.** A helper that performs a banned out-of-pipeline transform is still banned.

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer, StandardScaler

SEED = 20260804
rng = np.random.default_rng(SEED)
n_rows = 233
X = pd.DataFrame({
    "ridge_temp_c": rng.normal(14.3, 3.7, n_rows),
    "soil_moisture_pct": rng.normal(46.1, 8.3, n_rows),
    "slope_deg": rng.normal(17.9, 4.1, n_rows),
})
latent = X["ridge_temp_c"] * X["soil_moisture_pct"] - 9.7 * X["slope_deg"]
y = (latent + rng.normal(0.0, 41.0, n_rows) > np.median(latent)).astype(int).to_numpy()
X_tr, X_val, y_tr, y_val = train_test_split(
    X, y, test_size=0.27, random_state=SEED, stratify=y
)


def add_interaction(frame):
    # YOUR CODE HERE
    ...


pipe = ...              # YOUR CODE HERE
n_features_after = ...  # YOUR CODE HERE (int)
val_acc = ...           # YOUR CODE HERE (float)
