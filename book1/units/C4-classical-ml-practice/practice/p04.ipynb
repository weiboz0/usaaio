# %% [markdown]
# # C4-classical-ml-practice — Practice p04
#
#
# **Type:** multiple choice (numeric, normal form) · **Difficulty:** core · **Concepts:** knn
#
# Training set (features $x_0, x_1$; labels 0/1) and query
# $q = (2, 2)$:
#
# | row | point | label |
# |---|---|---|
# | 0 | (1, 1) | 0 |
# | 1 | (2, 3) | 0 |
# | 2 | (4, 1) | 1 |
# | 3 | (3, 2) | 1 |
# | 4 | (0, 2) | 0 |
#
# Run **3-nearest-neighbors** on $q$ using squared Euclidean distance:
# find the three nearest rows, the majority label $c$, and the **mean**
# of the three nearest squared distances, written in lowest terms as
# $p/q$ with $\gcd(p, q) = 1$, $p, q > 0$.
#
# Report $S = p + q$ **if $c = 0$**, or $S = p + q - 2$ **if $c = 1$**.
#
# A. 3
#
# B. 4
#
# C. 5
#
# D. 7
#
# E. 9
#
# Reasoning is not required. Record your choice below.

# %%
import numpy as np

answer_p04 = "?"  # replace with "A".."E"
