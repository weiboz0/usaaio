# %% [markdown]
# # C4-classical-ml-practice — Practice p13
#
#
# **Type:** proof · **Difficulty:** core · **Concepts:** cross-validation
#
# **Reasoning is required.**
#
# $K$-fold cross-validation on $n$ rows; fold $f$ has $m_f$ rows of
# which the fold's model gets $c_f$ correct, so its fold accuracy is
# $a_f = c_f / m_f$.
#
# **(a)** For $K = 5$ folds of equal size on $n = 30$ rows: how many
# rows does each model train on, and why is every row validated
# *exactly once* across the 5 folds?
# (Argue from the definition of the folds, not by example.)
#
# **(b)** Prove: if all folds have equal size $m$, then the **mean of
# the fold accuracies** equals the **pooled accuracy**
# $\bigl(\sum_f c_f\bigr) / n$.
# (Write both quantities in terms of $c_f$, $m$, $K$ and simplify.)
#
# **(c)** Show the equal-size hypothesis is necessary: exhibit fold
# sizes and correct-counts for $K = 2$, $n = 30$ where the two
# quantities differ, and compute both numbers.
#
# **(d) Concrete anchor:** verify (a)–(c) in code with
# `correct = np.array([5, 4, 6, 5, 4])` on folds of size 6:
#
# - `fold_accs` — shape `(5,)`;
# - `mean_acc` — mean of `fold_accs`;
# - `pooled_acc` — total correct / 30 (must equal `mean_acc`);
# - `mean_uneq`, `pooled_uneq` — the two (different) numbers from your
#   counterexample in (c).

# %% [markdown]
# *Your reasoning for (a)–(c) here.*

# %%
import numpy as np

correct = np.array([5, 4, 6, 5, 4])   # correct counts, folds of size 6

fold_accs = ...    # YOUR CODE HERE
mean_acc = ...     # YOUR CODE HERE
pooled_acc = ...   # YOUR CODE HERE
mean_uneq = ...    # YOUR CODE HERE (from your (c) numbers)
pooled_uneq = ...  # YOUR CODE HERE
