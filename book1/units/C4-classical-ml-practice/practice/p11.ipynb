# %% [markdown]
# # C4-classical-ml-practice — Practice p11
#
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** knn, sklearn-pipelines
#
# Choosing k on a validation split — with the test set touched once.
#
# Load `data/beans.csv`, build `X` from
# `["length_mm", "width_mm", "mass_g", "moisture_pct"]` (that order)
# and `y` from `species`, then:
#
# 1. split off 18 **test** rows:
#    `train_test_split(X, y, test_size=18, random_state=SEED, stratify=y)`;
# 2. from the remaining 72, split off 18 **validation** rows:
#    `train_test_split(X_tmp, y_tmp, test_size=18, random_state=SEED, stratify=y_tmp)`
#    — leaving 54 training rows;
# 3. for each `k` in `ks = [1, 3, 5, 7, 9, 11]`: fit a
#    scaler+kNN `Pipeline` on the 54 training rows and score it on the
#    validation rows → `val_accs` (shape `(6,)`);
# 4. `best_k` — the `k` with the highest validation accuracy,
#    **smallest `k` winning ties** (an `int`);
# 5. refit a `best_k` pipeline on the 72 train+validation rows
#    (`np.vstack` / `np.concatenate`) and evaluate **once** on the test
#    rows → `test_acc` (a `float`).
#
# **Banned (zero points): scoring any candidate on the test rows;
# fitting any scaler outside a pipeline; models other than
# `KNeighborsClassifier`.** A loop over `ks` is permitted.

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

SEED = 20260804
FEATURES = ["length_mm", "width_mm", "mass_g", "moisture_pct"]
ks = np.array([1, 3, 5, 7, 9, 11])

# YOUR CODE HERE (load, bridge, two splits, sweep, refit)

val_accs = ...  # YOUR CODE HERE (shape (6,))
best_k = ...    # YOUR CODE HERE
test_acc = ...  # YOUR CODE HERE
