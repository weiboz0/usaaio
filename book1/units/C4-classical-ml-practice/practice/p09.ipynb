# %% [markdown]
# # C4-classical-ml-practice — Practice p09
#
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** sklearn-pipelines
#
# The scaler+kNN pipeline, and what it buys on real data.
#
# Using sklearn's built-in wine dataset
# (`from sklearn.datasets import load_wine`; 178 rows, 13 features on
# wildly different scales, 3 classes):
#
# - split with
#   `train_test_split(X, y, test_size=0.25, random_state=SEED, stratify=y)`
#   into `X_tr, X_te, y_tr, y_te`;
# - `pipe` — a `Pipeline` with steps named exactly `"scaler"`
#   (`StandardScaler()`) and `"knn"`
#   (`KNeighborsClassifier(n_neighbors=5)`);
# - `test_acc` — `pipe`'s accuracy on the held-out rows after fitting
#   on the training rows only (a `float`);
# - `bare_acc` — the accuracy of a plain
#   `KNeighborsClassifier(n_neighbors=5)` fitted on the **raw**
#   training rows and scored on the raw held-out rows;
# - a one-sentence written answer: what single fact about the wine
#   features explains the gap between the two numbers?
#
# **Banned (zero points): fitting any scaler outside the pipeline;
# calling `fit` or `fit_transform` on any object with data containing
# test rows; models other than `KNeighborsClassifier`; loops.**

# %%
import numpy as np
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

SEED = 20260804
X, y = load_wine(return_X_y=True)

X_tr, X_te, y_tr, y_te = ...  # YOUR CODE HERE
pipe = ...                    # YOUR CODE HERE
test_acc = ...                # YOUR CODE HERE
bare_acc = ...                # YOUR CODE HERE

# %% [markdown]
# *Your one-sentence answer here.*
