# %% [markdown]
# # C4-classical-ml-practice — Practice p03
#
#
# **Type:** multiple choice · **Difficulty:** core · **Concepts:** cross-validation
#
# A student runs **5-fold cross-validation** on a training set of 40
# labeled rows (folds of equal size).
#
# Which statement is true?
#
# A. One model is trained on all 40 rows, and its accuracy is measured
# 5 times on 5 random subsets.
#
# B. 5 models are trained, each on 32 rows; each of the 40 rows is used
# for validation exactly once.
#
# C. 5 models are trained, each on 8 rows; each model is validated on
# the remaining 32 rows.
#
# D. 40 models are trained, each leaving out a single row for
# validation.
#
# E. 5 models are trained, each on 32 rows; rows may appear in several
# validation folds, depending on the shuffle.
#
# Record your choice below.

# %%
import numpy as np

answer_p03 = "?"  # replace with "A".."E"
