# %% [markdown]
# # F6-svd-spectral — Practice p03
#
# **Type:** multiple choice · **Difficulty:** core · **Concepts:** svd
#
# `U, s, Vt = np.linalg.svd(W, full_matrices=False)` is called on a matrix `W` of shape $(7, 3)$.
# Exactly one of the following statements is true — which?
#
# A. `U` has shape $(3, 3)$
#
# B. `s` has $7$ entries
#
# C. Calling with `full_matrices=True` instead would change `s` to have $7$ entries
#
# D. `U.T @ U` equals $I_3$ (to machine precision) and `s` is sorted in descending order
#
# E. The *columns* of `Vt` are the right singular vectors of `W`
#
# **Allowed `np.linalg` calls: none needed — answer from the output contract and the shape table** (checking with `np.linalg.svd` afterwards is fine).
#
# Reasoning is not required. Record your choice below.

# %%
import numpy as np

answer_p03 = "?"  # replace with "A".."E"
