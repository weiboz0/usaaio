# %% [markdown]
# # F6-svd-spectral — Practice p03 — Solution

# %% [markdown]
# For a tall $(7,3)$ matrix, the thin shapes are $U:(7,3)$, $s:(3,)$, and $V^{\mathsf T}:(3,3)$. The columns of $U$ are orthonormal and `svd` already returns descending singular values, so the answer is **D**.
#
# A swaps dimensions; B and C incorrectly give `s` the tall dimension; E confuses the rows of `Vt` with its columns.

# %%
import numpy as np

thin_shapes = ((7, 3), (3,), (3, 3))
full_shapes = ((7, 7), (3,), (3, 3))
answer_p03 = "D"

# %% [markdown]
# ### Answer check

# %%
assert thin_shapes == ((7, 3), (3,), (3, 3))
assert full_shapes == ((7, 7), (3,), (3, 3))
assert answer_p03 == "D"
