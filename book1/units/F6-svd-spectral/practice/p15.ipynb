# %% [markdown]
# # F6-svd-spectral — Practice p15
#
# **Type:** proof / derivation · **Difficulty:** core · **Concepts:** frobenius-norm
#
# **Reasoning is required.**
#
# Derive the master identity: for any matrix $W$ with SVD $W = \sum_k \sigma_k u_k v_k^{\mathsf T}$,
#
# $$\lVert W \rVert_F^2 = \sum_k \sigma_k^2.$$
#
# Structure your derivation as three claims (the component route — no other route is accepted):
#
# **(a)** Entry formula: show $W_{ij} = \sum_k \sigma_k\, u_k[i]\, v_k[j]$ from the atom sum.
#
# **(b)** Square-and-swap: expand $\sum_{i,j} W_{ij}^2$ and reorganize the finite sums to obtain
# $\sum_{k,\ell} \sigma_k \sigma_\ell\,(u_k \cdot u_\ell)(v_k \cdot v_\ell)$, saying explicitly why the swap is legitimate and how the entry sums become dot products.
#
# **(c)** Orthonormality: state the values of $u_k \cdot u_\ell$ and $v_k \cdot v_\ell$ for $k = \ell$ and $k \ne \ell$, and conclude the identity.
#
# **(d) Numeric anchor:** for the seeded `W (5, 4)` below, compute `frob_sq` (from entries), `sig_sq_sum` (from the singular values), and `anchor_gap` = their absolute difference; the final cell's assertion must pass.
#
# **Allowed `np.linalg` calls (part d only): `np.linalg.svd`.**

# %% [markdown]
# *Your reasoning for (a)–(c) here.*

# %%
import numpy as np

SEED = 20260804
rng = np.random.default_rng(SEED)
W = rng.normal(0, 1, (5, 4))

# (d) YOUR CODE HERE
frob_sq = ...
sig_sq_sum = ...
anchor_gap = ...

assert np.isclose(frob_sq, sig_sq_sum, rtol=0, atol=1e-8)
