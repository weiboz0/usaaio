# %% [markdown]
# # F6-svd-spectral — Practice p06 — Solution

# %% [markdown]
# Linearity and the eigen-equations give $Sx=S q_1-2S q_3=6q_1-2(-q_3)=6q_1+2q_3$, so the answer is **B**.
#
# A misses the sign change from $\lambda_3=-1$; C scales the $q_3$ component incorrectly; D leaves the vector unchanged; E ignores that the eigen-equations already determine the action.

# %%
import numpy as np

coeff_x = np.array([1., 0., -2.])
lam = np.array([6., 2., -1.])
coeff_Sx = lam * coeff_x
answer_p06 = "B"
coeff_Sx

# %% [markdown]
# ### Answer check

# %%
assert np.array_equal(coeff_Sx, np.array([6., 0., 2.]))
assert answer_p06 == "B"
