# %% [markdown]
# # F6-svd-spectral — Practice p11
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** singular-values
#
# The thin-form bridge, verified numerically.
# For the seeded `W (6, 3)` below and $S = WW^{\mathsf T}$:
#
# 1. `lam_desc (6,)` = the eigenvalues of $S$ via `np.linalg.eigh` + the pinned descending reorder.
# 2. `s (3,)` = the singular values of `W` (the `compute_uv=False` variant is convenient).
# 3. `bridge_gap` = max absolute difference between `lam_desc[:3]` and `s**2` — the nonzero spectrum is exactly the squared singular values.
# 4. `tail_max` = max absolute value of `lam_desc[3:]` — the remaining eigenvalues are (machine) zero.
#
# **Allowed `np.linalg` calls: `np.linalg.svd` and `np.linalg.eigh` only. Any other `np.linalg` call scores zero.**
#
# Contract: `bridge_gap < 1e-8` and `tail_max < 1e-10`.

# %%
import numpy as np

SEED = 20260804
rng = np.random.default_rng(SEED)
W = rng.normal(0, 1, (6, 3))
S = W @ W.T

lam_desc = ...    # YOUR CODE HERE
s = ...           # YOUR CODE HERE
bridge_gap = ...  # YOUR CODE HERE
tail_max = ...    # YOUR CODE HERE
