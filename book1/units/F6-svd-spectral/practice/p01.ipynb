# %% [markdown]
# # F6-svd-spectral — Practice p01
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** eigenvalues-eigenvectors
#
# Let $S = \begin{pmatrix} 5 & 2 \\ 2 & 5 \end{pmatrix}$.
# Exactly one of the following statements is true — which?
#
# A. $(1, 1)$ is an eigenvector of $S$ with eigenvalue $3$
#
# B. $(1, 0)$ is an eigenvector of $S$ with eigenvalue $5$
#
# C. $(2, 2)$ is an eigenvector of $S$ with eigenvalue $14$
#
# D. $(1, -1)$ is an eigenvector of $S$ with eigenvalue $3$
#
# E. $(1, -1)$ is not an eigenvector of $S$
#
# **Allowed `np.linalg` calls: none needed — answer by hand** (multiply each candidate through $S$ and apply the multiple-of test).
#
# Reasoning is not required. Record your choice below.

# %%
import numpy as np

answer_p01 = "?"  # replace with "A".."E"
