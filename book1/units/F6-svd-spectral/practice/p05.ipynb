# %% [markdown]
# # F6-svd-spectral — Practice p05
#
# **Type:** multiple choice · **Difficulty:** core · **Concepts:** low-rank-approximation
#
# A matrix $W$ has singular values $\sigma = (10, 6, 3, 1)$.
# What is the rank-2 truncation error $\lVert W - W_2 \rVert_F$?
#
# A. $4$
#
# B. $\sqrt{10}$
#
# C. $10$
#
# D. $\sqrt{46}$
#
# E. $\sqrt{136}$
#
# **Allowed `np.linalg` calls: none needed — answer by hand from the error identity.**
#
# Reasoning is not required. Record your choice below.

# %%
import numpy as np

answer_p05 = "?"  # replace with "A".."E"
