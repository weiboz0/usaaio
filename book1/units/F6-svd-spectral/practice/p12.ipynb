# %% [markdown]
# # F6-svd-spectral — Practice p12
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** low-rank-approximation
#
# For the seeded `W (8, 5)` below:
#
# 1. Write `truncate(U, s, Vt, r)` returning the rank-`r` truncation $W_r = U[:, :r]\,\mathrm{diag}(s[:r])\,V^{\mathsf T}[:r, :]$.
# 2. `errs_direct (6,)` = $\lVert W - W_r \rVert_F$ for $r = 0, 1, \dots, 5$, each measured directly with `np.linalg.norm`.
# 3. `errs_formula (6,)` = the same errors from the error identity $\sqrt{\sum_{i>r} s_i^2}$ — **no truncations built**.
# 4. `identity_gap` = max absolute difference between the two arrays.
# 5. `err_r2 = errs_direct[2]` (recorded as its own variable).
#
# **Allowed `np.linalg` calls: `np.linalg.svd` and `np.linalg.norm` only. Any other `np.linalg` call scores zero.**
#
# Contract: `identity_gap < 1e-8`; `errs_direct[0]` must equal $\lVert W \rVert_F$ and `errs_direct[5]` must be $< 10^{-10}$ (the two end anchors).

# %%
import numpy as np

SEED = 20260804
rng = np.random.default_rng(SEED)
W = rng.normal(0, 1, (8, 5))


def truncate(U, s, Vt, r):
    # YOUR CODE HERE
    ...


errs_direct = ...   # YOUR CODE HERE (shape (6,))
errs_formula = ...  # YOUR CODE HERE (shape (6,))
identity_gap = ...  # YOUR CODE HERE
err_r2 = ...        # YOUR CODE HERE
