# %% [markdown]
# # F6-svd-spectral — Practice p24
#
# **Type:** drill · **Difficulty:** intro · **Concepts:** eigenvalues-eigenvectors
#
# Quick eigen reads — by inspection, no quadratics needed.
# Record numeric answers in the code cell; two items also want one written line each in the markdown cell.
#
# 1. $D = \mathrm{diag}(4, -1)$: `vals_a (2,)` = its eigenvalues in the course's descending order, and `e_a (2,)` = an eigenvector for the *larger* eigenvalue.
# 2. A lab note reads "$S q = -2q$ for our probe vector $q \ne 0$": `lam_b` = the eigenvalue this certifies.
# 3. $M = 3 I_3$ (three-dimensional identity, scaled): `vals_c (3,)` = its eigenvalues.
#    *Markdown line 1:* which nonzero vectors are its eigenvectors, and why?
# 4. The quarter-turn $R = \begin{pmatrix} 0 & -1 \\ 1 & 0 \end{pmatrix}$: `n_real_eigvecs` = the number of real eigen-directions it has.
#    *Markdown line 2:* the one-sentence geometric reason.
#
# **Allowed `np.linalg` calls: none needed — these are inspection reads** (checking afterwards with `np.linalg.eig` is fine).

# %%
import numpy as np

vals_a = ...          # YOUR ANSWER (np.array, descending)
e_a = ...             # YOUR ANSWER (np.array)
lam_b = ...           # YOUR ANSWER
vals_c = ...          # YOUR ANSWER (np.array)
n_real_eigvecs = ...  # YOUR ANSWER (int)

# %% [markdown]
# *Your two lines here.*
