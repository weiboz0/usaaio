# %% [markdown]
# # F6-svd-spectral — Practice p04
#
# **Type:** multiple choice (numeric, normal form) · **Difficulty:** core · **Concepts:** singular-values
#
# Let $W = \begin{pmatrix} 2 & 2 \\ -1 & 2 \end{pmatrix}$, with singular values $\sigma_1 \ge \sigma_2$.
#
# Find the singular values **by hand**: form $W^{\mathsf T} W$, find its eigenvalues via the dependent-rows quadratic, and use the mirror bridge ($\lambda_i$ of $W^{\mathsf T}W$ $= \sigma_i^2$).
#
# Compute $s = \sigma_1^2 - \sigma_2^2$.
# Your answer can be written as $s = \pm m$ with $m$ a non-negative integer. What is the value of $2m + 1$ if $s \ge 0$, or $2m$ if $s < 0$?
#
# A. 3
#
# B. 10
#
# C. 11
#
# D. 13
#
# E. 21
#
# **Allowed `np.linalg` calls: none — the hand route is the task** (a plain calculator is fine).
#
# Reasoning is not required. Record your choice below.

# %%
import numpy as np

answer_p04 = "?"  # replace with "A".."E"
