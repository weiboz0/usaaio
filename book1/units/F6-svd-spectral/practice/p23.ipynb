# %% [markdown]
# # F6-svd-spectral — Practice p23
#
# **Type:** drill · **Difficulty:** intro · **Concepts:** singular-values
#
# Quick reads — every answer comes off the given data BY INSPECTION (no SVD computation).
# Record each in the code cell.
#
# 1. A matrix has singular values $\sigma = (9, 3, 0, 0)$.
#    `rank_a` = its rank; `frob_a` = its Frobenius norm (exact arithmetic, then `np.sqrt` is fine); `top_stretch` = the largest stretch factor the matrix applies to any unit input.
# 2. The same matrix is scaled: what is the largest singular value of $3W$?
#    → `sig_scale`.
# 3. `sig_d (3,)` = the singular values, **in the conventional order**, of $D = \mathrm{diag}(-2, 5, 1)$.
#    (Careful with the sign — Session 3 §2's convention.)
# 4. `len_s` = the number of entries `np.linalg.svd` returns in `s` for a $(3, 7)$ matrix.
#
# **Allowed `np.linalg` calls: none needed — these are inspection reads** (checking afterwards with `np.linalg.svd` is fine).

# %%
import numpy as np

rank_a = ...       # YOUR ANSWER (int)
frob_a = ...       # YOUR ANSWER
top_stretch = ...  # YOUR ANSWER
sig_scale = ...    # YOUR ANSWER
sig_d = ...        # YOUR ANSWER (np.array, length 3)
len_s = ...        # YOUR ANSWER (int)
