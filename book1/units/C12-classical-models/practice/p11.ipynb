# %% [markdown]
# # C12-classical-models — Practice p11
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** decision-trees
#
# **Time budget:** 55 minutes
#
# Implement
# `fit_depth_limited_tree(X, y, max_depth=2, min_samples_split=2)` and `predict_tree(tree, X)`.
# Validate finite `float64 X (N,D)`, integer `y (N,)`, positive `min_samples_split`, and nonnegative
# integer `max_depth`. Reuse the Session-4 Gini candidate/tie rules. A leaf is
# `{"prediction": int}`; an internal node has exactly `feature`, `threshold`, `left`, `right`.
#
# Stop at purity, `depth == max_depth`, too few rows, or no positive-gain split. Leaf ties choose
# the smaller class label. Prediction uses `<=` left. The grader fits the fixed probe below and
# hidden boundary/tie cases, checks exact structure, `predict_tree` output integer shape `(M,)`,
# training accuracy/movement beyond a root-only leaf, and predictions against an independent tree
# within `atol=0, rtol=0`.
#
# **Banned (zero points): `sklearn`, `scipy`, pandas, random splitting, global mutable tree state,
# or memorizing the public rows.**

# %%
import numpy as np

X_p11 = np.array([[0.,0.],[0.,1.],[1.,0.],[1.,1.],
                  [2.,0.],[2.,1.],[3.,0.],[3.,1.]], dtype=np.float64)
y_p11 = np.array([0,0,0,1,1,1,1,0], dtype=np.int64)


def fit_depth_limited_tree(X, y, max_depth=2, min_samples_split=2):
    # YOUR CODE HERE
    raise NotImplementedError


def predict_tree(tree, X):
    # YOUR CODE HERE
    raise NotImplementedError


tree_p11 = fit_depth_limited_tree(X_p11, y_p11)
predictions_p11 = predict_tree(tree_p11, X_p11)
