# %% [markdown]
# # C12-classical-models — Practice p07
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** logistic-regression
#
# **Time budget:** 55 minutes
#
# Implement
# `train_logistic(X, y, learning_rate=0.2, steps=300)`. `X` is finite `float64` shape `(N,D)` with
# `N>=2,D>=1`; `y` is `float64` shape `(N,)` containing only 0 and 1. Initialize `w` as zeros
# shape `(D,)` and `b=0.0`. At each full-batch step, record stable mean BCE **before** updating,
# then use `p = stable_sigmoid(X @ w + b)`,
# `grad_w = X.T @ (p-y) / N`, and `grad_b = mean(p-y)`.
#
# Return exactly `{"w": w, "b": float(b), "losses": losses}` where `losses` is `float64` shape
# `(steps,)`. Raise `ValueError` for invalid shapes/dtypes/values or nonpositive hyperparameters.
# The fixed probe is the six-row array below. The grader checks exact initialization and loop order,
# the first gradient against an independent reference, finite loss, final loss below initial loss,
# parameter movement, final labels under threshold `p>=0.5`, and final values within
# `atol=1e-10, rtol=1e-8`.
#
# **Banned (zero points): `sklearn`, `scipy`, `torch`, numerical differentiation, stochastic
# sampling, clipping, or omitting/dividing twice by the mean-loss factor.**

# %%
import numpy as np

X_p07 = np.array([[-2.0, -1.0], [-1.0, -1.5], [-0.5, 0.0],
                  [0.5, 0.2], [1.0, 1.5], [2.0, 1.0]], dtype=np.float64)
y_p07 = np.array([0.0, 0.0, 0.0, 1.0, 1.0, 1.0], dtype=np.float64)


def train_logistic(X, y, learning_rate=0.2, steps=300):
    # YOUR CODE HERE
    raise NotImplementedError


result_p07 = train_logistic(X_p07, y_p07)
