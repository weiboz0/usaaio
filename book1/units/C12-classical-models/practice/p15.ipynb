# %% [markdown]
# # C12-classical-models — Practice p15
#
# **Type:** proof · **Difficulty:** advanced · **Concepts:** svm, margin-and-hinge-loss
#
# **Time budget:** 45 minutes
#
# Using labels $t_i\in\{-1,+1\}$ and the F7 minimization convention $g\le0$ with nonnegative
# multipliers, build the complete margin-to-dual-support chain.
#
# 1. Explain functional versus geometric margin and derive the canonical hard-margin constraints.
# 2. Introduce $\xi_i\ge0$ and show that the smallest feasible slack equals hinge loss.
# 3. State the sum-loss soft-margin primal
#    $\frac12\|w\|^2+C\sum_i\xi_i$ with both inequality families.
# 4. Form the Lagrangian with multipliers $\alpha_i$ and $\beta_i$ using correct signs.
# 5. Derive stationarity in $w,b,\xi$, yielding $w=\sum_i\alpha_it_ix_i$,
#    $\sum_i\alpha_it_i=0$, and $0\le\alpha_i\le C$.
# 6. Substitute to obtain the dual objective and replace dot products by a valid kernel.
# 7. Use complementary slackness to justify the support-vector decision function, stating precisely
#    what $\alpha_i=0$, $0<\alpha_i<C$, and $\alpha_i=C$ imply or do not imply.
#
# Reasoning is required. Unsupported memorized formulas or mixed inequality conventions receive no
# credit.

# %% [markdown]
# ## Your proof
#
# Write the signed primal, Lagrangian, stationary equations, dual, and support-vector argument here.
