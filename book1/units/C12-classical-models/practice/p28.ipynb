# %% [markdown]
# # C12-classical-models — Practice p28
#
# **Type:** challenge · **Difficulty:** core · **Concepts:** decision-trees, tree-split-criteria
#
# **Time budget:** 50 minutes
#
# Construct and certify a tiny depth-2 tree for the fixed dataset below using Gini impurity,
# midpoint thresholds, `<=` left, and lexicographic `(weighted_impurity, feature, threshold)` ties.
# Leaf class ties choose the smaller label.
#
# 1. Enumerate every valid root candidate with exact child counts, weighted impurity, and gain.
# 2. Select the root and enumerate candidates in each nonpure child.
# 3. Assign `tree_p28` to the final nested dictionary. Every internal node has exactly
#    `feature` (Python `int`), `threshold` (Python `float`), `left`, and `right`; every leaf has
#    exactly `prediction` (Python `int`).
# 4. Assign `split_ledger_p28` to a pre-order tuple with one dictionary per visited internal node.
#    Each dictionary has exactly `node_path` (tuple of `"left"`/`"right"`, empty at root) and
#    `candidates` (feature-index order, then increasing threshold within each feature). Each candidate has exactly `feature` (int), `threshold`
#    (float), `left_counts` and `right_counts` (tuples in sorted class-label order),
#    `weighted_impurity` (float), and `gain` (float).
# 5. Implement `predict_certified_tree(tree, X)` returning `int64 (M,)`. Implement
#    `trace_tree_paths(tree, X)` returning a tuple of `M` dictionaries, each with exactly `steps`
#    (tuple of `(feature, threshold, direction)` using literal direction `"left"` or `"right"`)
#    and `prediction` (Python int). Assign its output to `paths_p28`.
# 6. Assign `certificates_p28` to exactly `max_depth` (int), `nonempty_children` (bool),
#    `positive_gains` (bool), `deterministic_ties` (bool), and `training_predictions` (`int64
#    (8,)`). Numeric checks use `atol=1e-12, rtol=1e-10`.
#
# **Banned (zero points): `sklearn`, random ties, fitting a different tree than the written ledger,
# or listing only the final predictions without split certificates.**

# %%
import numpy as np

X_p28 = np.array([[0.,0.],[0.,1.],[1.,0.],[1.,1.],
                  [2.,0.],[2.,1.],[3.,0.],[3.,1.]], dtype=np.float64)
y_p28 = np.array([0,0,1,0,1,1,0,1], dtype=np.int64)


tree_p28 = None  # REPLACE WITH YOUR CERTIFIED NESTED-DICTIONARY TREE
split_ledger_p28 = None  # REPLACE WITH THE EXACT PRE-ORDER TUPLE


def predict_certified_tree(tree, X):
    # YOUR CODE HERE
    raise NotImplementedError


def trace_tree_paths(tree, X):
    # YOUR CODE HERE
    raise NotImplementedError


predictions_p28 = predict_certified_tree(tree_p28, X_p28)
paths_p28 = trace_tree_paths(tree_p28, X_p28)
certificates_p28 = None  # REPLACE WITH THE EXACT CERTIFICATE DICTIONARY
