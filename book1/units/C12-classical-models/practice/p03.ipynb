# %% [markdown]
# # C12-classical-models — Practice p03
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** decision-trees, tree-split-criteria
#
# **Time budget:** 20 minutes
#
# A binary node has eight rows. Candidate split S sends labels `(0,0,0,1)` left and
# `(0,1,1,1)` right. Candidate split T sends `(0,0)` left and `(0,0,1,1,1,1)` right.
# Using Gini impurity and sample-count-weighted child impurity, which claim is correct?
#
# A. S is better because its unweighted average child Gini is smaller.
#
# B. T is better because its weighted child impurity is $1/3$, below S's $3/8$.
#
# C. S and T tie at weighted impurity $3/8$, so the larger threshold must win.
#
# D. T is worse because a pure child is forbidden.
#
# E. S is better because information gain is maximized by maximizing child impurity.
#
# Reasoning is required. Show both child Gini values, both weights, and the chosen split direction.

# %% [markdown]
# ## Your response
#
# **Choice:**
#
# **Impurity calculation:**
