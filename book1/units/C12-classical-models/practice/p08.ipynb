# %% [markdown]
# # C12-classical-models — Practice p08
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** svm, margin-and-hinge-loss
#
# **Time budget:** 55 minutes
#
# Implement
# `hinge_step(X, t, w, b, C, learning_rate)`. Inputs are finite `float64`: `X (N,D)`, labels `t (N,)`
# exactly `-1` or `+1`, `w (D,)`, scalar `b`, and positive scalars `C`, `learning_rate`. Use
#
# `margins = t * (X @ w + b)`, `active = margins < 1.0`,
# $J=\frac12w^Tw+C\operatorname{mean}(\max(0,1-margins))$, and the Session-2 subgradient with zero
# hinge contribution at equality. Return a dictionary with keys `objective` (float), `margins
# (N,)`, `active (N,)` bool, `grad_w (D,)`, `grad_b` (float), `w_next (D,)`, and `b_next` (float).
#
# Raise `ValueError` for invalid contracts. The grader uses the fixed probe below plus a kink row,
# checks the signed active branch, objective and subgradient against independent constants, exact
# nonmutation of inputs, and update values within `atol=1e-12, rtol=1e-10`.
#
# **Banned (zero points): loops over rows/features, `sklearn`, `scipy`, `torch`, numerical
# differentiation, testing `scores < 1`, regularizing `b`, or changing the kink convention.**

# %%
import numpy as np

X_p08 = np.array([[-2.0, -1.0], [-0.5, 1.0], [0.75, -1.0], [2.0, 0.5]], dtype=np.float64)
t_p08 = np.array([-1.0, -1.0, 1.0, 1.0], dtype=np.float64)
w_p08 = np.array([0.6, -0.2], dtype=np.float64)
b_p08 = 0.1


def hinge_step(X, t, w, b, C, learning_rate):
    # YOUR CODE HERE
    raise NotImplementedError


result_p08 = hinge_step(X_p08, t_p08, w_p08, b_p08, C=1.5, learning_rate=0.1)
