# %% [markdown]
# # C12-classical-models — Practice p29
#
# **Type:** challenge · **Difficulty:** core · **Concepts:** ensemble-learning, bagging-and-boosting
#
# **Time budget:** 50 minutes
#
# Complete an exact two-round AdaBoost ledger. Labels are
# $t=(-1,-1,+1,+1)$ and initial weights are $q^{(1)}=(1/4,1/4,1/4,1/4)$. Round-1 predictions are
# $h_1=(-1,+1,+1,+1)$. After applying and normalizing the exact round-1 weight update, round-2
# predictions are $h_2=(-1,-1,-1,+1)$.
#
# 1. Compute $\varepsilon_1$, $\alpha_1$, every unnormalized weight, normalization $Z_1$, and
#    reduced exact $q^{(2)}$.
# 2. Using **updated** $q^{(2)}$, compute $\varepsilon_2$, $\alpha_2$, all unnormalized round-2
#    weights, $Z_2$, and reduced $q^{(3)}$.
# 3. For each training row, compute additive score $F_i=\alpha_1h_{1i}+\alpha_2h_{2i}$ and final
#    sign, using `+1` on exact zero.
# 4. Implement `adaboost_two_rounds(t, h1, h2)` returning exactly one dictionary with exactly
#    these keys: `q1`, `unnormalized_q2`, `q2`, `unnormalized_q3`, and `q3` as `float64 (4,)`;
#    `error1`, `alpha1`, `Z1`, `error2`, `alpha2`, and `Z2` as Python `float`; `scores` as
#    `float64 (4,)`; and `predictions` as `int64 (4,)`. The grader compares independent references
#    within `atol=1e-12, rtol=1e-10` and requires `q2,q3` to sum to one.
# 5. Store the exact-logarithm work in top-level string `symbolic_ledger_p29` and the explanation of
#    why uniform round-2 weights break sequential correction in `interpretation_p29`.
#
# Reasoning is required. Preserve logarithms symbolically before decimal evaluation.
#
# **Banned (zero points): `sklearn`, skipping either normalized weight update, using unweighted
# round-2 error, or reporting only final labels.**

# %%
import numpy as np

t_p29 = np.array([-1, -1, 1, 1], dtype=np.int64)
h1_p29 = np.array([-1, 1, 1, 1], dtype=np.int64)
h2_p29 = np.array([-1, -1, -1, 1], dtype=np.int64)


def adaboost_two_rounds(t, h1, h2):
    # YOUR CODE HERE
    raise NotImplementedError


ledger_p29 = adaboost_two_rounds(t_p29, h1_p29, h2_p29)
symbolic_ledger_p29 = ""  # WRITE THE EXACT-LOGARITHM LEDGER
interpretation_p29 = ""  # EXPLAIN THE ROUND-2 WEIGHT DEPENDENCE
