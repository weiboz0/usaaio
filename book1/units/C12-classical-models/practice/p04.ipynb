# %% [markdown]
# # C12-classical-models — Practice p04
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** ensemble-learning, bagging-and-boosting
#
# **Time budget:** 20 minutes
#
# Which description correctly distinguishes bagging, random forests, and AdaBoost?
#
# A. Bagging fits learners sequentially to reweighted rows; a random forest removes row sampling; AdaBoost fits all learners independently.
#
# B. Bagging draws bootstrap samples and can fit members independently; a random forest also subsamples candidate features at splits; AdaBoost fits sequentially and changes row weights after mistakes.
#
# C. Bagging and boosting differ only in their final voting tie rule.
#
# D. A random forest is exactly soft voting over logistic regressions, while AdaBoost is hard voting over k-means fits.
#
# E. AdaBoost keeps uniform row weights and differs from bagging only by training fewer members.
#
# Reasoning is required. Your justification must address sampling, feature randomness, sequential
# dependence, and the principal bias/variance motivation.

# %% [markdown]
# ## Your response
#
# **Choice:**
#
# **Comparison:**
