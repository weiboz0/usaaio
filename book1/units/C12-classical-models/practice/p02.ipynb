# %% [markdown]
# # C12-classical-models — Practice p02
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** svm, margin-and-hinge-loss
#
# **Time budget:** 20 minutes
#
# A linear SVM uses labels
# $t\in\{-1,+1\}$. Four fitted scores are $(-2,\,0.5,\,1,\,-3)$ and their labels are
# $(-1,\,-1,\,+1,\,+1)$. This unit uses hinge activity $t_if_i<1$ and zero subgradient
# contribution at equality. Which statement is correct?
#
# A. Signed margins are $(2,-0.5,1,-3)$; rows 2 and 4 are hinge-active, while row 3 is on the margin.
#
# B. Signed margins are $(-2,0.5,1,-3)$; rows 1 and 4 are hinge-active.
#
# C. Signed margins are $(2,-0.5,1,3)$; only row 2 is hinge-active and row 4 is misclassified.
#
# D. Signed margins are $(2,0.5,1,-3)$; rows 2 and 4 are support vectors because every active row is a support vector before optimization.
#
# E. Signed margins are $(2,-0.5,1,-3)$; rows 2, 3, and 4 are hinge-active because equality counts as active.
#
# Reasoning is required. Compute all signed margins and hinge losses, and distinguish a
# hinge-active row from a certified support vector.

# %% [markdown]
# ## Your response
#
# **Choice:**
#
# **Margin and hinge ledger:**
