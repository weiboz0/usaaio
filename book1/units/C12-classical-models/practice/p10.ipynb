# %% [markdown]
# # C12-classical-models — Practice p10
#
# **Type:** constrained coding · **Difficulty:** intro · **Concepts:** decision-trees, tree-split-criteria
#
# **Time budget:** 55 minutes
#
# Implement
# `best_gini_split(X, y)`. `X` is finite `float64 (N,D)`, `y` is integer `(N,)` with at least two
# classes, and `N>=2,D>=1`. Candidate thresholds are midpoints between adjacent distinct values.
# Rows with `X[:, feature] <= threshold` go left. Exclude empty children. Return `None` if no valid
# positive-gain split; otherwise return exactly a dictionary with `feature` (int), `threshold`
# (float), `weighted_impurity` (float), and `gain` (float).
#
# Choose minimum `(weighted_impurity, feature, threshold)` lexicographically. The fixed probe is
# below; hidden probes include constant columns, multiclass labels, and exact ties. The grader checks
# weighted (not unweighted) impurity, maximum gain/minimum child impurity, nonmutation, and values
# within `atol=1e-12, rtol=1e-10`.
#
# **Banned (zero points): `sklearn`, `scipy`, pandas, entropy in place of Gini, observed-value-only
# thresholds, random tie-breaking, or choosing maximum child impurity.**

# %%
import numpy as np

X_p10 = np.array([[0.0,0.0],[1.0,1.0],[2.0,0.0],[3.0,1.0],
                  [4.0,0.0],[5.0,1.0]], dtype=np.float64)
y_p10 = np.array([0,0,0,1,1,1], dtype=np.int64)


def best_gini_split(X, y):
    # YOUR CODE HERE
    raise NotImplementedError


split_p10 = best_gini_split(X_p10, y_p10)
