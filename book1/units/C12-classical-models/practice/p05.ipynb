# %% [markdown]
# # C12-classical-models — Practice p05
#
# **Type:** multiple choice (numeric, normal form) · **Difficulty:** intro · **Concepts:** k-means, lloyd-algorithm
#
# **Time budget:** 20 minutes
#
# Run one Lloyd assignment-and-update step on one-dimensional points
# $X=(0,1,5,8)$ from initial centroids $\mu_0=0$ and $\mu_1=6$. Squared-distance ties go to the
# smaller cluster index. After updating each nonempty centroid to its assigned-point mean, compute
# the WCSS of the resulting assignments and updated centroids.
#
# Write the WCSS as $a/b$ in lowest terms with **b > 0** and **gcd(|a|, b) = 1**, then report
# $a+b$. Which option is correct?
#
# A. 6
#
# B. 9
#
# C. 11
#
# D. 13
#
# E. 15
#
# Reasoning is required. Show the assignment, both updated centroids, every squared residual, the
# reduced fraction, and the sign/gcd normal-form check.

# %% [markdown]
# ## Your response
#
# **Choice:**
#
# **Exact Lloyd ledger:**
