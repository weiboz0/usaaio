# %% [markdown]
# # C12-classical-models — Practice p01
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** logistic-regression
#
# **Time budget:** 20 minutes
#
# A binary logistic model uses score
# $z=\log 3$ for one row, so $p=\sigma(z)$. It predicts class 1 when $p\ge 0.5$.
# Which option correctly gives the odds, probability, predicted class, and derivative
# $dp/dz$?
#
# A. Odds $3$, probability $3/4$, class 1, derivative $3/16$.
#
# B. Odds $\log3$, probability $\log3/(1+\log3)$, class 1, derivative $1/4$.
#
# C. Odds $1/3$, probability $1/4$, class 0, derivative $3/16$.
#
# D. Odds $3$, probability $3/4$, class 1, derivative $1/4$.
#
# E. Odds $e^3$, probability $e^3/(1+e^3)$, class 1, derivative $3/16$.
#
# Reasoning is required. Derive the probability from the odds equation and evaluate
# $p(1-p)$; a bare letter receives no credit.

# %% [markdown]
# ## Your response
#
# **Choice:**
#
# **Derivation:**
