# %% [markdown]
# # C12-classical-models — Practice p04 — Solution

# %% [markdown]
# **B** is correct. Bagging independently fits learners on bootstrap samples and mainly
# reduces variance. A random forest adds random feature subsets at splits to decorrelate its
# bootstrapped trees. AdaBoost is sequential: each learner sees the current row weights, mistakes
# receive more emphasis, and weighted member votes aim to reduce systematic error. Excessively
# correlated bagged members limit variance reduction, while boosting can chase noisy labels.

# %%
answer_p04 = "B"
properties_p04 = {
    "bagging": ("bootstrap", "independent", "variance"),
    "random_forest": ("bootstrap", "feature_subsets", "decorrelation"),
    "adaboost": ("sequential", "row_reweighting", "weighted_vote"),
}

# %% [markdown]
# ### Answer check

# %%
assert answer_p04 == "B"
assert properties_p04["bagging"] == ("bootstrap", "independent", "variance")
assert properties_p04["random_forest"][1] == "feature_subsets"
assert properties_p04["adaboost"][:2] == ("sequential", "row_reweighting")
