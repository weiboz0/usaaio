# %% [markdown]
# # C12-classical-models — Practice p14
#
# **Type:** proof · **Difficulty:** core · **Concepts:** logistic-regression
#
# **Time budget:** 45 minutes
#
# Derive the stable mean-gradient formula for binary logistic regression without quoting a
# multiclass or neural-network loss result.
#
# 1. Begin from odds $p/(1-p)=e^z$ and derive $p=\sigma(z)$ and $dp/dz=p(1-p)$.
# 2. From the observed-event probability $p^y(1-p)^{1-y}$, derive
#    $\ell=-[y\log p+(1-y)\log(1-p)]$.
# 3. Use the scalar chain rule to prove $d\ell/dz=p-y$, handling both $y=0$ and $y=1$.
# 4. For $X\in\mathbb R^{N\times D}$, $z=Xw+b\mathbf1$, derive
#    $\nabla_wL=X^T(p-y)/N$ and $\partial L/\partial b=\sum_i(p_i-y_i)/N$.
# 5. Annotate every vector/matrix shape and explain why the factor is $1/N$ exactly once.
# 6. Derive the stable logit form $\max(z,0)-yz+\log(1+e^{-|z|})$ by separate signs of $z$.
#
# Reasoning is required. Every algebraic equivalence and chain-rule step is graded.

# %% [markdown]
# ## Your derivation
#
# Write the complete derivation and shape ledger here.
