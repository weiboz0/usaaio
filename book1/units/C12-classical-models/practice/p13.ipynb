# %% [markdown]
# # C12-classical-models — Practice p13
#
# **Type:** constrained coding · **Difficulty:** intro · **Concepts:** k-means, lloyd-algorithm
#
# **Time budget:** 55 minutes
#
# Implement
# `lloyd_kmeans(X, initial_centroids, max_iter=100, tol=1e-10)`. Validate finite `float64 X (N,D)`
# and centroids `(k,D)`, `1<=k<=N`, positive integer `max_iter`, and nonnegative `tol`. Assignment
# uses squared Euclidean distance and smaller cluster index on ties. Update each centroid to its
# assigned arithmetic mean.
#
# If clusters are empty, process smallest empty index first: among rows whose current cluster has
# at least two members, move the row with largest assignment-step squared distance, breaking ties by
# smaller row index. Preserve those pre-repair distances, but recompute membership counts after
# every move. Return `labels (N,)` `int64`, `centroids (k,D)`
# `float64`, and `objective_trace` one-dimensional `float64`, with each objective computed from the
# same repaired-label/updated-centroid state. Stop on unchanged labels or max centroid movement
# `<=tol`.
#
# The fixed probe below plus tie/empty-cluster probes check exact updates, nonincreasing objective,
# nonempty clusters, and final references within `atol=1e-10, rtol=1e-8`.
#
# **Banned (zero points): `sklearn`, `scipy`, random reinitialization, keeping an old centroid for
# an empty cluster, non-centroid updates, or computing the trace from mixed old/new state.**

# %%
import numpy as np

X_p13 = np.array([[0.,0.],[0.,2.],[1.,1.],[8.,8.],[8.,10.],[9.,9.]], dtype=np.float64)
initial_centroids_p13 = np.array([[0.,0.],[0.,0.],[9.,9.]], dtype=np.float64)


def lloyd_kmeans(X, initial_centroids, max_iter=100, tol=1e-10):
    # YOUR CODE HERE
    raise NotImplementedError


labels_p13, centroids_p13, objective_trace_p13 = lloyd_kmeans(
    X_p13, initial_centroids_p13
)
