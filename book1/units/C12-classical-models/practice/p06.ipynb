# %% [markdown]
# # C12-classical-models — Practice p06
#
# **Type:** constrained coding · **Difficulty:** intro · **Concepts:** logistic-regression
#
# **Time budget:** 55 minutes
#
# Implement both functions below.
#
# - `stable_sigmoid(z)` accepts a finite numeric array of any shape and returns a `np.float64`
#   array of the same shape. Use the sign-aware two-branch formula.
# - `mean_bce_from_logits(z, y)` accepts finite float arrays with identical nonempty shape, with
#   every `y` entry exactly 0 or 1, and returns a plain Python `float`. Use
#   `maximum(z,0) - y*z + log1p(exp(-abs(z)))`, averaged over all entries.
#
# Raise `ValueError` for nonnumeric input, shape mismatch, empty input, nonfinite values, or invalid
# labels. The grader probes scalars-as-0D arrays, vectors, and matrices including logits
# `[-10000.0, -3.0, 0.0, 3.0, 10000.0]`. It checks shape/dtype, finiteness, sigmoid symmetry,
# monotonicity, and independent high-precision references within `atol=1e-12, rtol=1e-10`.
#
# **Banned (zero points): `scipy`, `sklearn`, `torch`, clipping, adding epsilon, or forming BCE by
# taking logs of returned probabilities.**

# %%
import numpy as np


def stable_sigmoid(z: np.ndarray) -> np.ndarray:
    # YOUR CODE HERE
    raise NotImplementedError


def mean_bce_from_logits(z: np.ndarray, y: np.ndarray) -> float:
    # YOUR CODE HERE
    raise NotImplementedError


probe_z_p06 = np.array([-10000.0, -3.0, 0.0, 3.0, 10000.0], dtype=np.float64)
probe_y_p06 = np.array([0.0, 1.0, 0.0, 1.0, 1.0], dtype=np.float64)
probabilities_p06 = stable_sigmoid(probe_z_p06)
loss_p06 = mean_bce_from_logits(probe_z_p06, probe_y_p06)
