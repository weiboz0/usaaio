# %% [markdown]
# # F3-matrices — Practice p04
#
# **Type:** multiple choice (numeric, normal form) · **Difficulty:** core · **Concepts:** matrix-from-action, matrix-multiplication
#
# A matrix $B \in \mathbb{R}^{2\times 3}$ acts on any $x = (x_0, x_1, x_2)$ by
# $$B x = (x_2 - 2x_0,\; 3x_1 + x_2).$$
#
# Reconstruct $B$, then compute $s$ = the sum of ALL entries of $B$.
# Your answer can be written as $s = \pm m$ with $m$ a non-negative integer. What is the value of $m + 2$ if $s \ge 0$, or $m + 1$ if $s < 0$?
#
# A. 3
#
# B. 4
#
# C. 5
#
# D. 6
#
# E. 7
#
# Reasoning is not required. Record your choice below.

# %%
import numpy as np

answer_p04 = "?"  # replace with "A".."E"
