# %% [markdown]
# # F3-matrices — Practice p20 — Solution

# %% [markdown]
# Matrix (a) has proportional rows, (b) has two independent columns, and (c) has a zero third coordinate in every column with its third column dependent on the first two. For (d), $AB$ has rank at most 2 because its outputs pass through a 2-D intermediate space, so no such $3\times3$ product can be invertible.

# %%
import numpy as np

inv_a = False
inv_b = True
inv_c = False
inv_d = False

# %% [markdown]
# ### Answer check

# %%
assert inv_a is False
assert inv_b is True
assert inv_c is False
assert inv_d is False
