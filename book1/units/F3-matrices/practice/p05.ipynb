# %% [markdown]
# # F3-matrices — Practice p05
#
# **Type:** constrained coding · **Difficulty:** intro · **Concepts:** matrices-as-linear-maps, vectors-and-norms, broadcasting, aggregation-axis
#
# Apply a map, three ways of thinking — one implementation.
#
# Write `apply_map(M, points)`:
#
# 1. Inputs: matrix `M` of shape `(2, 2)`; `points` of shape `(n, 2)` — each ROW a 2-D point.
# 2. Return the shape-`(n, 2)` array of mapped points.
#
# **Banned (zero points): `@`, `np.matmul`, `np.dot`, `.T`, loops.** Use broadcasting + axis sums (hint: `M[None, :, :] * points[:, None, :]`).
#
# Apply the quarter-turn matrix `M = np.array([[0., -1.], [1., 0.]])` to the seeded points below; store as `turned`. Also compute `lengths_before`, `lengths_after` (row lengths) and `max_length_change`.

# %%
import numpy as np

SEED = 20260804
rng = np.random.default_rng(SEED)
points = rng.normal(0, 2, (200, 2))
M = np.array([[0., -1.], [1., 0.]])

def apply_map(M, points):
    # YOUR CODE HERE (banned: @, np.matmul, np.dot, .T, loops)
    ...

turned = ...            # YOUR CODE HERE
lengths_before = ...    # YOUR CODE HERE
lengths_after = ...     # YOUR CODE HERE
max_length_change = ... # YOUR CODE HERE
