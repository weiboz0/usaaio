# %% [markdown]
# # F3-matrices — Practice p18
#
# **Type:** challenge · **Difficulty:** advanced · **Concepts:** linear-independence-span, rank, invertibility-via-rank, broadcasting, aggregation-axis
#
# How much probing pins down invertibility?
#
# An unknown $3\times 3$ matrix $Z$ is probed with chosen input vectors; you see only input→output pairs.
#
# **(a)** Someone probes with $p_1 = (1, 1, 0)$, $p_2 = (2, 2, 0)$, $p_3 = (0, 0, 1)$ and gets outputs $q_1, q_2, q_3$. Explain in 2-3 sentences why this probe set can NEVER determine `Z` fully — no matter the outputs — using independence of the probes.
#
# **(b)** Now the probes are $p_1 = (1, 1, 0)$, $p_2 = (0, 1, 1)$, $p_3 = (1, 0, 1)$ with outputs $q_1 = (2, 0, 1)$, $q_2 = (1, 1, 0)$, $q_3 = (3, 1, 1)$. First verify the probes are independent (reason via combinations or a small computation). Then reconstruct `Z` — express each standard basis vector as a combination of the probes, and combine the outputs accordingly (hand algebra in markdown; assemble in code; no `np.linalg.solve` — zero points).
#
# **(c)** With YOUR `Z`: are its columns independent? State `rank_Z` and whether $Z$ is invertible (rank argument only), then verify your reconstruction: `recon_gap` = max deviation over the three probes (broadcasting only, no `@`).

# %% [markdown]
# *Your (a)/(b) algebra here.*

# %%
import numpy as np

# YOUR CODE HERE
Z = ...
rank_Z = ...
recon_gap = ...
