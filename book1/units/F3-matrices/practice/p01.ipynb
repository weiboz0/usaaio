# %% [markdown]
# # F3-matrices — Practice p01
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** matrices-as-linear-maps
#
# A matrix $M$ acts on 2-D vectors. You are told only that $M$ applied to $(1, 0)$ gives $(3, 1)$ and $M$ applied to $(0, 1)$ gives $(-2, 4)$.
#
# What does $M$ applied to $(2, 1)$ give?
#
# A. $(4, 6)$
#
# B. $(6, 2)$
#
# C. $(1, 5)$
#
# D. $(4, 5)$
#
# E. It cannot be determined from the information given.
#
# Record your choice below.

# %%
import numpy as np

answer_p01 = "?"  # replace with "A".."E"
