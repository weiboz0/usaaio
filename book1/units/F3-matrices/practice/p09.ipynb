# %% [markdown]
# # F3-matrices — Practice p09
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** outer-products, broadcasting
#
# Rank-1 building blocks.
#
# Write `outer(u, v)` returning the outer product of `u (n,)` and `v (m,)` — the `(n, m)` grid with entries $u_i v_j$. **Banned (zero points): `np.outer`, `@`, `np.matmul`, `np.dot`, loops** — pure broadcasting.
#
# Then: with `u = np.array([1., 2., -1.])`, `v = np.array([3., 0., 1., -2.])`, compute `P = outer(u, v)`; demonstrate the rank-1 property by computing `row_ratios` — every nonzero row of `P` divided elementwise by `v` (shape `(3, 4)` array; rows should be constant) — and `col_of_ratios` = the per-row constant (shape `(3,)`, compare to `u`: `ratio_gap`).

# %%
import numpy as np

def outer(u, v):
    # YOUR CODE HERE
    ...

u = np.array([1., 2., -1.])
v = np.array([3., 0., 1., -2.])
P = ...            # YOUR CODE HERE
row_ratios = ...   # YOUR CODE HERE (careful with the zero in v — mask or use nonzero positions)
col_of_ratios = ...# YOUR CODE HERE
ratio_gap = ...    # YOUR CODE HERE
