# %% [markdown]
# # F3-matrices — Practice p16
#
# **Type:** scenario analysis · **Difficulty:** core · **Concepts:** rank, gram-matrices
#
# A survey team collected 6 sensor channels over 400 time steps: seeded `D (400, 6)` below (channels are COLUMNS). Two channels were accidentally wired to combinations of others.
#
# **(a)** Compute the channel Gram matrix `Gc` — all pairwise dot products of the 6 COLUMN channels — under the p07 bans (hint: work with `D`'s columns via slicing/broadcasting; no transpose-style calls: `Gc = (D[:, :, None] * D[:, None, :]).sum(axis=0)`).
#
# **(b)** Normalize to cosines `Cc` and list `suspect_pairs` — all pairs (i<j) with |cosine| > 0.999.
#
# **(c)** 2-3 sentences: what is the effective number of independent channels (the rank of the channel collection), which physical wiring fault does each suspect pair suggest, and why does high |cosine| (rather than high covariance) make the right detector here?

# %%
import numpy as np

SEED = 20260804
rng = np.random.default_rng(SEED)
D = rng.normal(0, 1, (400, 6))
D[:, 4] = 0.6 * D[:, 1]
D[:, 5] = -2.0 * D[:, 2]

# YOUR CODE HERE
Gc = ...
Cc = ...
suspect_pairs = ...

# %% [markdown]
# *Your (c) analysis here.*
