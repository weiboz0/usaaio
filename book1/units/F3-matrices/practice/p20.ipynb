# %% [markdown]
# # F3-matrices — Practice p20
#
# **Type:** drill · **Difficulty:** intro · **Concepts:** invertibility-via-rank, matrix-multiplication
#
# Invertibility triage. For each matrix, decide from rank reasoning whether it is invertible (True/False), recording booleans:
#
# 1. `inv_a`: $\begin{pmatrix} 1 & 2 \\ 2 & 4 \end{pmatrix}$
# 2. `inv_b`: $\begin{pmatrix} 1 & 2 \\ 0 & 1 \end{pmatrix}$
# 3. `inv_c`: the 3×3 matrix whose columns are (1,0,0), (0,1,0), (1,1,0).
# 4. `inv_d`: the product $AB$ where $A$ is 3×2 and $B$ is 2×3 (ANY such $A, B$ — decide from rank bounds and explain in one markdown sentence why the answer holds for every choice).

# %%
import numpy as np

# YOUR ANSWERS HERE (booleans)
inv_a = ...
inv_b = ...
inv_c = ...
inv_d = ...

# %% [markdown]
# *Your one-sentence argument for 4 here.*
