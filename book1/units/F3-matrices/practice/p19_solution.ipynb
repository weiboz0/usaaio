# %% [markdown]
# # F3-matrices — Practice p19 — Solution

# %% [markdown]
# Collections (a) through (d) have ranks 2, 1, 1, and 3 respectively: the dependent rows are immediate scalar combinations, while the triangular pattern in (d) supplies three directions. In collection 1, three vectors cannot all be independent because the ambient space has only two coordinate directions.

# %%
import numpy as np

r_a = 2
r_b = 1
r_c = 1
r_d = 3

# %% [markdown]
# ### Answer check

# %%
assert (r_a, r_b, r_c, r_d) == (2, 1, 1, 3)
