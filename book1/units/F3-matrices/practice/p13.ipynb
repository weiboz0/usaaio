# %% [markdown]
# # F3-matrices — Practice p13
#
# **Type:** integrative · **Difficulty:** advanced · **Concepts:** matrix-from-action, matrix-multiplication, outer-products, broadcasting
#
# Reconstruct, then decompose.
#
# A linear map on $\mathbb{R}^3$ is described by its action: for any $x = (x_0, x_1, x_2)$,
# $$T x = (x_0 + 2x_1,\ 3x_0 + 6x_1,\ -x_0 - 2x_1).$$
#
# **(a)** Reconstruct the matrix `T` (3×3) from the action (by reading coefficients or basis-probing — your choice; show the method).
#
# **(b)** Using YOUR `T` from (a): observe the columns and rows, and determine `rank_T` by independent-direction reasoning (state it in markdown; no `np.linalg`).
#
# **(c)** Using (b): write `T` as a SINGLE outer product — find `u3, v3` with outer(u3, v3) = T (broadcasting only, no np.outer) and verify `decomp_gap` ≈ 0.
#
# **(d)** One sentence: connect the single-outer-product form to your rank answer.

# %% [markdown]
# *Your (a) method and (b) reasoning here.*

# %%
import numpy as np

# YOUR CODE HERE
T = ...
rank_T = ...   # an integer, from reasoning
u3 = ...
v3 = ...
decomp_gap = ...

# %% [markdown]
# *Your (d) sentence here.*
