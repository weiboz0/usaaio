# %% [markdown]
# # F3-matrices — Practice p19
#
# **Type:** drill · **Difficulty:** intro · **Concepts:** rank, linear-independence-span
#
# Quick rank reads. For each collection of vectors, decide the number of independent directions (the rank of the stacked matrix) BY INSPECTION and record it:
#
# 1. `r_a`: rows (1, 0), (0, 1), (1, 1).
# 2. `r_b`: rows (2, 4), (-1, -2).
# 3. `r_c`: rows (1, 1, 1), (2, 2, 2), (3, 3, 3).
# 4. `r_d`: rows (1, 0, 0), (1, 1, 0), (1, 1, 1).
#
# Then one sentence in markdown: for collection 1, WHY can three 2-D vectors never be independent?

# %%
import numpy as np

# YOUR ANSWERS HERE (integers)
r_a = ...
r_b = ...
r_c = ...
r_d = ...

# %% [markdown]
# *Your one-sentence answer here.*
