# %% [markdown]
# # F3-matrices — Practice p11
#
# **Type:** proof · **Difficulty:** advanced · **Concepts:** outer-products, rank, broadcasting
#
# **Reasoning is required.**
#
# Let $u \in \mathbb{R}^n$ and $v \in \mathbb{R}^m$ be nonzero vectors and $P = $ outer product of $u$ and $v$ (entries $P_{ij} = u_i v_j$).
#
# **(a)** Show that every row of $P$ is a scalar multiple of $v$ (name the scalar).
#
# **(b)** Conclude that the independent-direction count of $P$'s rows — its rank — is exactly 1 (why not 0?).
#
# **(c)** Show the converse direction on a concrete case: the matrix $Q = \begin{pmatrix} 2 & 4 & -2 \\ 3 & 6 & -3 \end{pmatrix}$ has rank 1; exhibit vectors $u, v$ with $Q = $ outer($u$, $v$), and explain in one sentence why such a factorization certifies rank 1.
#
# **(d) Concrete anchor:** verify your (c) factorization numerically (`factor_gap` = max abs difference, broadcasting only — no np.outer).

# %% [markdown]
# *Your reasoning for (a)–(c) here.*

# %%
import numpy as np

Q = np.array([[2., 4., -2.], [3., 6., -3.]])
# (d) YOUR CODE HERE
u = ...
v = ...
factor_gap = ...
