# %% [markdown]
# # F3-matrices — Practice p03
#
# **Type:** multiple choice · **Difficulty:** core · **Concepts:** rank, linear-independence-span
#
# Consider the three vectors $v_1 = (1, 2, 0)$, $v_2 = (2, 4, 0)$, $v_3 = (0, 0, 5)$, stacked as the rows of a $3\times 3$ matrix $V$.
#
# Which statement is true?
#
# A. The rows are linearly independent, so $\mathrm{rank}(V) = 3$.
#
# B. $v_2 = 2v_1$, so the independent directions number 2 and $\mathrm{rank}(V) = 2$.
#
# C. $v_3$ is orthogonal to $v_1$, so $\mathrm{rank}(V) = 1$.
#
# D. Rank cannot be determined without computing determinants.
#
# E. The span of the three rows is all of 3-D space.
#
# Record your choice below.

# %%
import numpy as np

answer_p03 = "?"  # replace with "A".."E"
