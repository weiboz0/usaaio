# %% [markdown]
# # F1-scientific-python — Practice p09
#
# **Type:** multiple choice (numeric, normal form) · **Difficulty:** intro · **Concepts:** array-indexing-slicing, elementwise-ops
#
# **Set B (exam
# register)** — numeric multiple choice in **normal form**: the answer is a
# fraction $p/q$ in lowest terms with $q > 0$ and $\gcd(p, q) = 1$.
#
# Let
#
# ```python
# g = np.arange(12).reshape(3, 4)
# sel = g[g > 5]
# ```
#
# Define $f$ = (number of **even** values in `sel`) ÷ (total number of values in
# `sel`), written in lowest terms. What is $f$?
#
# A. $1/3$
#
# B. $5/12$
#
# C. $1/2$
#
# D. $7/12$
#
# E. $2/3$
#
# Work it by hand: list `g`'s values, apply the mask, count.
#
# Reasoning is not required.

# %%
import numpy as np

# %% [markdown]
# **Your answer.** Replace the `"?"` with a single letter `"A"`–`"E"`.

# %%
answer_p09 = "?"

# %% [markdown]
# **Verify in code**: compute the fraction with masks (no loops) and confirm it
# equals your chosen option.

# %%
# YOUR CODE HERE
