# %% [markdown]
# # F1-scientific-python — Practice p14
#
# **Type:** proof · **Difficulty:** advanced · **Concepts:** broadcasting, numpy-arrays
#
# **Set B (exam register)** —
# **Reasoning is required.** Answer every part *by hand first*, writing your
# step-by-step justification in the markdown cells; code is only for checking
# afterwards.
#
# Recall the shape-compatibility rules: compare shapes from the right; pad the
# shorter shape with size-1 axes on the left; sizes are compatible when equal or
# when one is 1; every size-1 axis stretches; otherwise ERROR.

# %%
import numpy as np

# %% [markdown]
# **Part 1.** Determine, with a rule-by-rule justification, the result shape of
#
# ```python
# np.ones((6, 1, 4)) + np.ones((3, 1))
# ```
#
# Set **`shape1`** to the resulting shape as a tuple (or the string `"ERROR"`).
#
# *(Write your derivation here: pad which shape, compare which sizes, stretch
# which axes?)*

# %%
shape1 = None   # replace with a tuple or "ERROR"

# %% [markdown]
# **Part 2.** Same drill for
#
# ```python
# np.arange(8).reshape(2, 4) + np.arange(4)
# ```
#
# Set **`shape2`** to the resulting shape as a tuple (or `"ERROR"`), with
# justification.
#
# *(Write your derivation here.)*

# %%
shape2 = None   # replace with a tuple or "ERROR"

# %% [markdown]
# **Part 3.** Same drill for
#
# ```python
# np.ones((2, 3)) + np.ones((3, 2))
# ```
#
# Set **`shape3`** to the resulting shape as a tuple (or `"ERROR"`), with
# justification.
#
# *(Write your derivation here.)*

# %%
shape3 = None   # replace with a tuple or "ERROR"

# %% [markdown]
# **Part 4.** By hand, using the stretching picture: what **value** sits at
# position `[2, 1]` of
#
# ```python
# np.arange(3)[:, None] * np.arange(1, 5)[None, :]
# ```
#
# Set **`value4`** to that number, with justification (which element of each
# array meets at `[2, 1]`?).
#
# *(Write your derivation here.)*

# %%
value4 = None   # replace with a number

# %% [markdown]
# **Part 5 — verify everything in code.** Confirm each shape (wrap the ERROR
# case in `try`/`except`) and the value from Part 4.

# %%
# YOUR CODE HERE
