# %% [markdown]
# # F1-scientific-python — Practice p16
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** random-seeding
#
# **Set B (exam register)** — five-option
# multiple choice. Decide *before* running anything.
#
# Exactly one of the following statements is true:
#
# A. `np.random.default_rng(5)` produces different numbers on different
# computers, even running identical code.
#
# B. Two generators built from the same seed produce identical sequences
# of draws.
#
# C. A seeded generator returns the same value every time you call
# `rng.random()` within one run.
#
# D. `rng.shuffle(a)` returns a shuffled copy and leaves `a` unchanged.
#
# E. Building a generator without a seed makes its first draw always 0.
#
# Reasoning is required.

# %%
import numpy as np

# %% [markdown]
# **Your answer.** Replace the `"?"` with a single letter `"A"`–`"E"`, then
# justify your elimination of the other four in the markdown cell below.
#
# *(Write your eliminations here.)*

# %%
answer_p16 = "?"

# %% [markdown]
# **Verify in code**: demonstrate that the true statement holds and that at
# least one false statement fails (for example, show two calls to `rng.random()`
# differ, refuting (C)).

# %%
# YOUR CODE HERE
