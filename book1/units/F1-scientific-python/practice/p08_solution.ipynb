# %% [markdown]
# # F1-scientific-python — Practice p08 — Solution

# %%
import numpy as np

SEED = 20260804
rng = np.random.default_rng(SEED)

# %% [markdown]
# **Your answer.** Replace the `"?"` with a single letter `"A"`–`"E"`. (Reason it
# out first: apply the shape-compatibility rules, then think about what dtype
# `int64 + float64` produces.)

# %%
answer_p08 = "B"

# %% [markdown]
# Shapes compare from the right: `(3,)` pads to `(1, 3)`, the 3s match, and the 1 stretches to 2 — result shape `(2, 3)`, so (A), (D), (E) are out. `A` is `int64` but `np.ones` is `float64`, and mixing promotes to the more general type, so `C` is `float64` — (B), not (C).

# %% [markdown]
# **Verify in code** (after committing to an answer): build `C`, print its shape
# and dtype.

# %%
A = np.arange(6).reshape(2, 3)
B = np.ones(3)
C = A + B
print(C.shape, C.dtype)
print(C)

# %% [markdown]
# ### Answer check

# %%
assert answer_p08 == "B"
A = np.arange(6).reshape(2, 3)
C = A + np.ones(3)
assert C.shape == (2, 3) and C.dtype == np.float64
print("all checks passed")
