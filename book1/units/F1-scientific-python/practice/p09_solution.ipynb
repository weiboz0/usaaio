# %% [markdown]
# # F1-scientific-python — Practice p09 — Solution

# %%
import numpy as np

SEED = 20260804
rng = np.random.default_rng(SEED)

# %% [markdown]
# **Your answer.** Replace the `"?"` with a single letter `"A"`–`"E"`.

# %%
answer_p09 = "C"

# %% [markdown]
# `g` holds 0–11; the mask `g > 5` keeps 6, 7, 8, 9, 10, 11 — six values. The even ones are 6, 8, 10 — three values. $f = 3/6$, and lowest terms divides out $\gcd(3, 6) = 3$: $f = 1/2$, answer (C).

# %% [markdown]
# **Verify in code**: compute the fraction with masks (no loops) and confirm it
# equals your chosen option.

# %%
g = np.arange(12).reshape(3, 4)
sel = g[g > 5]
frac = (sel % 2 == 0).mean()
print(sel, frac)

# %% [markdown]
# ### Answer check

# %%
assert answer_p09 == "C"
g = np.arange(12).reshape(3, 4)
sel = g[g > 5]
assert np.isclose((sel % 2 == 0).mean(), 1 / 2, atol=1e-9, rtol=0)
print("all checks passed")
