# %% [markdown]
# # C7-cnn-transfer — Practice p04
#
# **Type:** multiple choice (numeric, normal form) · **Difficulty:** core · **Concepts:** bottleneck-blocks
#
# An interior (no-downsample) bottleneck block of a ResNet has this
# printed anatomy:
#
# ```text
# Bottleneck(
#   (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn1):   BatchNorm2d(128, ...)
#   (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2):   BatchNorm2d(128, ...)
#   (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn3):   BatchNorm2d(512, ...)
# )
# ```
#
# Let $F$ be the fraction of the block's **convolution** parameters
# (weights only — the convs have no bias; BatchNorm excluded) that live
# in the $3\times3$ convolution `conv2`.
# Write $F$ in lowest terms as $p/q$ with $\gcd(p, q) = 1$, $q > 0$.
# What is $p + q$?
#
# A. 4
#
# B. 22
#
# C. 25
#
# D. 26
#
# E. 52
#
# Reasoning is not required; no code is needed (**`numel`,
# `torchsummary`, and `state_dict`-size reads score zero here — this is
# hand arithmetic**). Record your choice below.

# %%
answer_p04 = "?"  # replace with "A".."E"
