# %% [markdown]
# # C7-cnn-transfer — Practice p25
#
# **Type:** integrative · **Difficulty:** advanced · **Concepts:** tensor-shape-tracing
#
# *Reasoning is required. No model execution is allowed; the code cell records your hand-derived deliverables.*
#
# A residual block receives \((4,13,197,233)\).
#
# **Main path**
#
# - `conv1`: \(13\to29\), kernel 3, stride \((2,1)\), padding 1;
# - `conv2`: \(29\to37\), kernel \((5,3)\), stride \((1,2)\), padding \((2,0)\).
#
# **Skip path**
#
# - `project`: \(13\to37\), kernel 1, stride \((2,2)\), padding 0.
#
# Use floor arithmetic independently on height and width.
#
# Set `main_shapes` to the two main-path output tuples, `skip_shape` to the projection output tuple, and `mismatch_axis` to `"height"`, `"width"`, or `"none"`. The addition currently fails. Repair it by changing **only** `conv2`'s padding; set `repaired_padding` to the required \((p_h,p_w)\), and explain in 2–4 sentences why the repaired paths can be added.
#
# **Banned (zero points): constructing or running layers/models, forward hooks, model-summary tools, or automated shape calculators.**

# %%
main_shapes = ...
skip_shape = ...
mismatch_axis = ...
repaired_padding = ...

# %% [markdown]
# *Your 2–4 sentence explanation here.*
