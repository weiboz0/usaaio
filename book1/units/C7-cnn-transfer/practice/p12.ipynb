# %% [markdown]
# # C7-cnn-transfer — Practice p12
#
# **Type:** constrained coding · **Difficulty:** intro · **Concepts:** resnet-architecture, parameter-counting
#
# First contact: load the model the course way and read its surface.
# The starter cell resolves the weight cache; you write the load.
#
# **(a)** Load ResNet-50 with the **explicitly named** weights
# `ResNet50_Weights.IMAGENET1K_V1` into `model`, and put it in
# evaluation mode immediately.
#
# **(b)** Set:
#
# - `w_dtype` — the dtype of the model's first parameter (expect
#   `torch.float32`: the artifact's dtype);
# - `is_eval` — `True` iff the model is in evaluation mode (read
#   `model.training`);
# - `child_names` — the ten top-level child names in order;
# - `n_children` — their count (plain `int`);
# - `n_params_total` — total parameter scalars (`numel` allowed);
# - `fc_weight_shape` — the shape of `model.fc.weight` as a plain
#   tuple.
#
# **Banned (zero points): `pretrained=True` (the deprecated implicit
# form); `torchsummary`.**

# %%
# Cache pin (course convention, plan 009): pretrained weights live in the repo's
# gitignored reference/cache/ -- resolve it from the repo root BEFORE importing torch.
import os, pathlib
_env_root = os.environ.get("USAAIO_BOOK_ROOT")
if _env_root:
    _root = pathlib.Path(_env_root).resolve()
else:
    _start = pathlib.Path.cwd().resolve()
    _root = next(
        p for p in [_start, *_start.parents]
        if (p / "syllabus.md").is_file() and (p / "curriculum").is_dir()
    )
os.environ["TORCH_HOME"] = str(_root / "reference" / "cache" / "torch")

import torch
import torch.nn as nn
from torchvision.models import resnet50, ResNet50_Weights

# float32 register (course exception): pretrained resnet50 is a float32 artifact.
SEED = 20260804

# (a) YOUR CODE HERE -- load into `model`, eval mode immediately
model = ...

# (b)
w_dtype = ...          # YOUR CODE HERE
is_eval = ...          # YOUR CODE HERE
child_names = ...      # YOUR CODE HERE
n_children = ...       # YOUR CODE HERE
n_params_total = ...   # YOUR CODE HERE
fc_weight_shape = ...  # YOUR CODE HERE
