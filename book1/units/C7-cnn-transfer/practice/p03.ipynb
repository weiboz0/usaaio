# %% [markdown]
# # C7-cnn-transfer — Practice p03
#
# **Type:** multiple choice · **Difficulty:** core · **Concepts:** feature-hierarchy
#
# For a trained deep convolutional image classifier, which description
# of its layers is correct?
#
# A. Early layers respond to whole objects and object categories because
# they sit closest to the raw image; depth then decomposes those objects
# into parts and finally edges, so the final layers of a trained network
# are edge and texture detectors operating at the finest scale.
#
# B. Early layers have small receptive fields and respond to local,
# high-frequency patterns (edges, simple textures); deeper layers have
# large receptive fields and respond to parts and object categories,
# while the spatial grids typically shrink and the channel counts grow.
#
# C. Every layer responds to essentially the same patterns as every
# other; depth changes only the spatial resolution at which those
# patterns are reported, with the channel counts held fixed so that no
# layer is more semantic than any other.
#
# D. Deeper layers have *smaller* receptive fields, because the feature
# maps they operate on are spatially smaller.
#
# E. Early-layer maps are sparse and slowly varying; deep-layer maps
# are dense and rough — activation statistics grow busier with depth.
#
# Reasoning is not required. Record your choice below.

# %%
answer_p03 = "?"  # replace with "A".."E"
