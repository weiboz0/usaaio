# %% [markdown]
# # C7-cnn-transfer — Practice p04 — Solution

# %% [markdown]
# By hand, the three convolution counts are
# $512\cdot128=65{,}536$, $128\cdot128\cdot9=147{,}456$, and
# $128\cdot512=65{,}536$. Thus
# $F=147{,}456/278{,}528=9/17$, so $p+q=26$: **D**.
#
# A ($4$) counts *layers* instead of parameters: the $3\times3$ is one
# of three convolutions, $1/3 \to p+q = 4$. B uses $13$ as the
# total coefficient, which drops one $4m^2$ pointwise convolution. C
# incorrectly changes the true denominator 17 to 16. E doubles the
# correct numerator-plus-denominator. No model-size API is needed.

# %%
answer_p04 = "D"

# %% [markdown]
# ### Answer check

# %%
assert answer_p04 == "D"
