# %% [markdown]
# # C7-cnn-transfer — Practice p23
#
# **Type:** multiple choice (numeric, normal form) · **Difficulty:** intro · **Concepts:** tensor-shape-tracing
#
# *Reasoning is not required. No coding is needed; the code cell only records your choice.*
#
# A batch has shape \((3, 11, 223, 227)\) in \((B,C,H,W)\) order. A convolution maps 11 input channels to 19 output channels with `kernel_size=(7, 5)`, `stride=(3, 2)`, and `padding=(2, 1)`. Dilation is 1.
#
# Compute the output height \(h\) and width \(w\) using
# \[
# \left\lfloor\frac{n+2p-k}{s}\right\rfloor+1.
# \]
# Write \(h/w=p/q\) in lowest terms with \(q>0\), then report \(p+q\).
#
# A. 185
#
# B. 186
#
# C. 187
#
# D. 188
#
# E. 337
#
# **Banned (zero points): constructing or running a convolution, using a shape-calculator package, or reading a model summary.** This is a hand trace.

# %%
answer_p23 = "?"  # replace with one capital letter A-E
