# %% [markdown]
# # C7-cnn-transfer — Practice p23 — Solution

# %% [markdown]
# The convolution gives
# \[
# h=\left\lfloor\frac{223+2(2)-7}{3}\right\rfloor+1
#  =\lfloor220/3\rfloor+1=74
# \]
# and
# \[
# w=\left\lfloor\frac{227+2(1)-5}{2}\right\rfloor+1
#  =112+1=113.
# \]
# Thus $h/w=74/113$, already in lowest terms, and $p+q=187$, so the answer is **C**.
#
# Trap by trap: A (185) and B (186) are below the correctly decoded sum and signal lost +1 or floor arithmetic; D (188) is the corresponding one-too-large result. E (337) is incompatible with the reduced output ratio and comes from combining unrelated raw dimensions rather than its numerator and denominator. Only C matches both independently traced axes and the normal-form decode.

# %%
h = 74
w = 113
p = 74
q = 113
decoded = p + q
answer_p23 = "C"

# %% [markdown]
# ### Answer check

# %%
assert (h, w) == (74, 113)
assert (p, q) == (74, 113)
assert decoded == 187
assert answer_p23 == "C"
