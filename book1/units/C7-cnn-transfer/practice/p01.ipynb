# %% [markdown]
# # C7-cnn-transfer — Practice p01
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** convolution
#
# Using this unit's convention (no kernel flip, valid mode), the 1-D
# convolution of
#
# $$x = (1, 2, 0, -1, 3) \qquad \text{with} \qquad k = (1, 0, -1)$$
#
# is:
#
# A. $(-1, -3, 3)$
#
# B. $(1, 3, -3)$
#
# C. $(3, 1, -3)$
#
# D. $(1, -3, 3)$
#
# E. $(1, 3, -3, 4)$
#
# Reasoning is not required. Record your choice below.

# %%
answer_p01 = "?"  # replace with "A".."E"
