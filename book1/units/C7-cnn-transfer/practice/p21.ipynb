# %% [markdown]
# # C7-cnn-transfer — Practice p21
#
# **Type:** drill · **Difficulty:** intro · **Concepts:** feature-maps, torch-tensors, nn-module, parameter-counting
#
# Rapid-fire one-liners on a fixed convolutional layer.
# Each deliverable is a single expression; **no loops or comprehensions
# anywhere (zero points)**; `n_params` and `out_h_s2` must be integer
# *arithmetic* (literals with `*`, `+`, `//`), not `numel` or a forward
# pass.
#
# - `w_shape` — the weight tensor's shape as a plain tuple;
# - `b_shape` — the bias tensor's shape as a plain tuple;
# - `n_maps` — how many feature maps one input yields (plain `int`);
# - `y_shape` — the output shape for the batch `x` below, as a plain
#   tuple (running `conv` on `x` is allowed for this one);
# - `n_params` — the layer's total parameter count, weights **and**
#   bias, as integer arithmetic;
# - `out_h_s2` — the output height if the same layer ran at
#   `stride=2`, as integer arithmetic from the output-size formula;
# - `n_positions` — how many spatial positions one output map of `y`
#   holds (plain `int` arithmetic).

# %%
import torch
import torch.nn as nn

torch.set_default_dtype(torch.float64)   # course convention (no pretrained weights here)
SEED = 20260804

torch.manual_seed(SEED)
conv = nn.Conv2d(3, 12, kernel_size=5, stride=1, padding=2)
x = torch.randn(4, 3, 30, 30)

w_shape = ...      # YOUR CODE HERE
b_shape = ...      # YOUR CODE HERE
n_maps = ...       # YOUR CODE HERE
y_shape = ...      # YOUR CODE HERE
n_params = ...     # YOUR CODE HERE -- integer arithmetic, no numel
out_h_s2 = ...     # YOUR CODE HERE -- integer arithmetic from the formula
n_positions = ...  # YOUR CODE HERE
