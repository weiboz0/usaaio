# %% [markdown]
# # C7-cnn-transfer — Practice p01 — Solution

# %% [markdown]
# The three valid windows give $1\cdot1+2\cdot0+0\cdot(-1)=1$,
# $2+0+1=3$, and $0+0-3=-3$. Therefore the answer is **B**.
#
# A flips all three signs. C reorders the valid-window results. D flips
# both the middle and final entries. E has one entry too many: valid mode
# produces $5-3+1=3$ outputs.

# %%
answer_p01 = "B"

# %% [markdown]
# ### Answer check

# %%
assert answer_p01 == "B"
