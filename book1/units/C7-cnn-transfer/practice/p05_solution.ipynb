# %% [markdown]
# # C7-cnn-transfer — Practice p05 — Solution

# %% [markdown]
# At stride one, each layer adds $K-1$ pixels per dimension. Starting at
# one pixel gives $1+(3-1)+(3-1)+(5-1)=9$, so the answer is **A**.
#
# B adds too much; C omits one two-pixel growth; D multiplies kernel
# areas instead of tracking the union span; E reports only the last
# kernel's width.

# %%
answer_p05 = "A"

# %% [markdown]
# ### Answer check

# %%
assert answer_p05 == "A"
