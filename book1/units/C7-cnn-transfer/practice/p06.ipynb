# %% [markdown]
# # C7-cnn-transfer — Practice p06
#
# **Type:** constrained coding · **Difficulty:** intro · **Concepts:** convolution, array-indexing-slicing, elementwise-ops
#
# The component form, from scratch.
#
# **(a)** Implement `conv1d_valid(x, k)` to this exact contract:
#
# - inputs are 1-D NumPy arrays; compute in float64;
# - no-flip valid-mode convolution:
#   `y[i] = sum_j x[i+j] * k[j]`, output length `len(x) - len(k) + 1`;
# - a Python loop **over output positions** is allowed (slice, multiply,
#   sum inside); nothing else does the sliding for you.
#
# **(b)** For `xa = np.array([3., 1., 4., 1., 5., 9., 2., 6.])` and
# `ka = np.array([1., -1., 2.])`, compute `y_a = conv1d_valid(xa, ka)`
# and `first_val = float(y_a[0])`.
#
# **(c)** For the seeded length-50 input below and a length-7 kernel of
# ones, set `n_out_formula` — the output length as a plain `int` from
# the formula (write the arithmetic, not `len(...)`) — and
# `n_out_measured = int(conv1d_valid(xc, kc).shape[0])`.
# They must agree.
#
# **(d)** The jump detector: with `k_step = np.array([-1., 1.])` and
# `sig = np.array([2., 2., 2., 5., 5., 1., 1.])`, compute
# `resp = conv1d_valid(sig, k_step)` and `jump_idx` — the index of the
# largest **absolute** response, as a plain `int`.
#
# **Banned (zero points): `np.convolve`, `np.correlate`, `scipy.*`,
# `torch`, `np.lib.stride_tricks` /
# `sliding_window_view`.**

# %%
import numpy as np

SEED = 20260804


# (a) YOUR CODE HERE -- def conv1d_valid(x, k): ...


# (b)
xa = np.array([3., 1., 4., 1., 5., 9., 2., 6.])
ka = np.array([1., -1., 2.])
y_a = ...        # YOUR CODE HERE
first_val = ...  # YOUR CODE HERE

# (c)
rng = np.random.default_rng(SEED)
xc = rng.standard_normal(50)
kc = np.ones(7)
n_out_formula = ...   # YOUR CODE HERE -- plain int, from the formula
n_out_measured = ...  # YOUR CODE HERE

# (d)
k_step = np.array([-1., 1.])
sig = np.array([2., 2., 2., 5., 5., 1., 1.])
resp = ...      # YOUR CODE HERE
jump_idx = ...  # YOUR CODE HERE
