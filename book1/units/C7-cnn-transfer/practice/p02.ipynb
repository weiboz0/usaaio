# %% [markdown]
# # C7-cnn-transfer — Practice p02
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** feature-maps
#
# Consider
#
# ```python
# conv = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1)
# y = conv(x)          # x has shape (2, 3, 64, 64)
# ```
#
# Which statement is true?
#
# A. `y` has shape `(2, 16, 62, 62)` — each valid-mode map is two
# pixels smaller per side.
#
# B. `y` has shape `(2, 3, 64, 64)` — convolution never changes the
# channel count.
#
# C. `y` has shape `(2, 16, 64, 64)` — sixteen feature maps, same
# spatial size because `padding=1` is "same" for a 3×3 kernel at
# stride 1.
#
# D. `y` has shape `(16, 64, 64)` — the batch dimension is consumed by
# the layer.
#
# E. The call raises a `RuntimeError` because 16 output channels cannot
# be produced from only 3 input channels.
#
# Reasoning is not required. Record your choice below.

# %%
answer_p02 = "?"  # replace with "A".."E"
