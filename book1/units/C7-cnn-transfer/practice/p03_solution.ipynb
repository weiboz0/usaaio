# %% [markdown]
# # C7-cnn-transfer — Practice p03 — Solution

# %% [markdown]
# **B** states the feature hierarchy correctly: shallow layers see local
# edges and textures, while depth grows receptive fields and supports
# part- and object-level selectivity as grids shrink and channels grow.
#
# A reverses the hierarchy. C denies learned abstraction. D confuses a
# smaller feature grid with a smaller receptive field in input pixels.
# E reverses the usual early-dense/rough and late-sparse/smooth tendency.

# %%
answer_p03 = "B"

# %% [markdown]
# ### Answer check

# %%
assert answer_p03 == "B"
