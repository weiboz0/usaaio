# %% [markdown]
# # C7-cnn-transfer — Practice p02 — Solution

# %% [markdown]
# The output-size formula gives $(64+2-3)/1+1=64$ per spatial
# dimension, and `out_channels=16` creates sixteen feature maps while
# preserving the batch of two. Therefore the answer is **C**.
#
# A ignores padding. B incorrectly treats input channels as fixed output
# channels. D drops the batch dimension. E is false because every output
# kernel spans all three input channels.

# %%
answer_p02 = "C"

# %% [markdown]
# ### Answer check

# %%
assert answer_p02 == "C"
