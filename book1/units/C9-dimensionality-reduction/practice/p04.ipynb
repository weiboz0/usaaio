# %% [markdown]
# # C9-dimensionality-reduction — Practice p04
#
# **Type:** multiple choice (numeric, normal form) · **Difficulty:** core · **Concepts:** pca, svd, singular-values
#
# A dataset of $5$ points in $\mathbb{R}^3$ is centered, and the SVD of
# the centered matrix $X_c$ has singular values
# $$\sigma = (5, 3, 1).$$
# The variance-explained ratio of the **first** principal component is a
# rational number that can be written in lowest terms as $p/q$ with
# $\gcd(p, q) = 1$ and $q > 0$.
# What is $p + q$?
#
# A. $12$
#
# B. $14$
#
# C. $44$
#
# D. $54$
#
# E. $60$
#
# Reasoning is not required. Record your choice below.

# %%
answer_p04 = "?"  # replace with "A".."E"
