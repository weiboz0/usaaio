# %% [markdown]
# # C9-dimensionality-reduction — Practice p01 — Solution

# %%
answer_p01 = "B"

# %% [markdown]
# The answer is **B**.  For a unit direction $u$, the centered projection scores are $X_cu$, and the first principal direction maximizes their sample variance.
#
# - A is too restrictive: the maximizing direction can combine several original features.
# - B is the defining variational statement.
# - C confuses the removed location $\mu$ with a direction of variation.
# - D selects a data point, not the highest-variance axis of the cloud.
# - E mistakes sign ambiguity for nonexistence: $u$ and $-u$ have equal variance and describe the same axis.

# %% [markdown]
# ### Answer check

# %%
assert answer_p01 == "B"
