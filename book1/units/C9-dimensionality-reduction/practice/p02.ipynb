# %% [markdown]
# # C9-dimensionality-reduction — Practice p02
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** umap-concept
#
# A 2-D map of a $40$-dimensional gene-expression dataset is produced by
# a **neighbor-graph layout method** of the kind taught in this unit
# (UMAP-style: build a $k$-nearest-neighbor graph in the original space,
# then arrange the points in 2-D so that graph neighbors stay close).
#
# Which statement correctly describes what such a method is designed to
# preserve?
#
# A. All pairwise distances, exactly, up to a single scale factor
#
# B. Local neighborhood structure, at the acknowledged cost of
# distorting global distances
#
# C. The directions of maximal variance, in descending order
#
# D. The units of the original features, one per map axis
#
# E. The smallest possible squared reconstruction error among all 2-D
# linear projections
#
# Reasoning is not required. Record your choice below.

# %%
answer_p02 = "?"  # replace with "A".."E"
