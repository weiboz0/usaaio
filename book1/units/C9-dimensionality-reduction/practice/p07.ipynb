# %% [markdown]
# # C9-dimensionality-reduction — Practice p07
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** truncated-svd-practice, word-embeddings, embedding-matrices, svd, singular-values, low-rank-approximation, frobenius-norm, broadcasting, aggregation-axis
#
# A rank-$4$ compression of a real embedding stack, certified both ways.
#
# For the ten words below, set:
#
# - `W` — the unit-row embedding stack in C8's convention (rows are
#   tokens, shape `(10, 100)`, float64 boundary cast, broadcasting
#   normalization);
# - `fro2` — `float((W * W).sum())`, with
#   `assert np.isclose(fro2, 10.0, atol=1e-9, rtol=0)` (unit rows:
#   $\lVert W\rVert_F^2 = N$);
# - `s` — the singular values of `W` (thin SVD);
# - `W4` — the rank-$4$ truncation
#   `U[:, :4] @ np.diag(s[:4]) @ Vt[:4]`;
# - `err_direct` — $\lVert W - W_4 \rVert_F$ measured from the residual
#   entries (broadcasting, no `np.linalg.norm` needed);
# - `err_tail` — the same number read off the spectrum,
#   $\sqrt{\sum_{i > 4} \sigma_i^2}$;
# - `id_gap` — `float(abs(err_direct - err_tail))`, and
#   `assert id_gap < 1e-9` (the error identity is your certificate that
#   `W4` was built correctly);
# - `rel_err2` — the relative squared error
#   `float(err_direct**2 / fro2)`.
#
# **Banned (zero points): sklearn (any module — `sklearn.decomposition.PCA`, `TruncatedSVD`, and everything else in the package), `scipy`, any Python loop or comprehension over array elements, `np.einsum`, `np.tensordot`, and every gensim similarity helper (`kv.most_similar`, `kv.similarity`, `kv.n_similarity`, `kv.distances`).**
# Allowed: `kv[...]` lookup (the load boundary), NumPy broadcasting, `@`, `.T`, `np.linalg.svd`, `np.cumsum`, `np.argmax`, `np.diag`.

# %%
import os, pathlib
_env_root = os.environ.get("USAAIO_BOOK_ROOT")
if _env_root:
    _root = pathlib.Path(_env_root).resolve()
else:
    _start = pathlib.Path.cwd().resolve()
    _root = next(
        p for p in [_start, *_start.parents]
        if (p / "syllabus.md").is_file() and (p / "curriculum").is_dir()
    )
os.environ["GENSIM_DATA_DIR"] = str(_root / "reference" / "cache" / "gensim")

import numpy as np
import gensim.downloader

kv = gensim.downloader.load("glove-wiki-gigaword-100")

WORDS = ["glacier", "avalanche", "summit", "ridge", "valley",
         "melody", "rhythm", "chorus", "drummer", "saxophone"]

W = ...           # YOUR CODE HERE (unit rows, float64, (10, 100))
fro2 = ...        # YOUR CODE HERE (float; assert isclose 10.0)
s = ...           # YOUR CODE HERE (thin SVD singular values)
W4 = ...          # YOUR CODE HERE (rank-4 truncation)
err_direct = ...  # YOUR CODE HERE (float)
err_tail = ...    # YOUR CODE HERE (float)
id_gap = ...      # YOUR CODE HERE (float; assert < 1e-9)
rel_err2 = ...    # YOUR CODE HERE (float)
