# %% [markdown]
# # C9-dimensionality-reduction — Practice p03
#
# **Type:** multiple choice · **Difficulty:** core · **Concepts:** local-vs-global-structure
#
# A streaming service maps $500$ songs (each a $100$-dimensional feature
# vector) to a 2-D page using a neighbor-preserving layout method (as
# taught: local structure first).
# On the page, songs $P$ and $Q$ sit inside the same tight clump; song
# $R$ sits far away on the opposite side, in one of three visible clumps.
#
# Which claim is **best supported** by the page alone?
#
# A. $P$ and $Q$ are likely genuine near neighbors in the
# $100$-dimensional feature space
#
# B. Multiplying the $P$-to-$R$ page distance by the page's scale factor
# recovers their feature-space distance
#
# C. $R$'s clump is the most internally varied of the three, because it
# is drawn the widest
#
# D. The dataset contains exactly three clusters, because the page shows
# three clumps
#
# E. The horizontal axis separates the genres, so genre is the dataset's
# dominant feature
#
# Reasoning is not required. Record your choice below.

# %%
answer_p03 = "?"  # replace with "A".."E"
