# %% [markdown]
# # C9-dimensionality-reduction — Practice p03 — Solution

# %%
answer_p03 = "A"

# %% [markdown]
# The answer is **A**.  Tight on-page neighborhoods are the one feature this kind of layout is designed to reflect.
#
# - A makes the appropriately local, probabilistic claim.
# - B treats an unsupported page distance as a calibrated original-space distance.
# - C reads quantitative within-group spread from a distorted footprint.
# - D treats three visible clumps as proof of exactly three underlying components.
# - E assigns feature meaning to an axis whose orientation and units have no such interpretation.

# %% [markdown]
# ### Answer check

# %%
assert answer_p03 == "A"
