# %% [markdown]
# # C9-dimensionality-reduction — Practice p02 — Solution

# %%
answer_p02 = "B"

# %% [markdown]
# The answer is **B**.  A neighbor-graph layout is designed to keep local neighbor relations, while distant-region geometry may be distorted.
#
# - A overclaims exact global distance preservation.
# - B states the intended local-first trade-off.
# - C describes variance-ordered linear directions instead.
# - D invents feature units and meanings for layout axes.
# - E describes a linear low-rank reconstruction objective, not a neighbor layout.

# %% [markdown]
# ### Answer check

# %%
assert answer_p02 == "B"
