# %% [markdown]
# # F2-vectors — Practice p01
#
# **Type:** constrained coding · **Difficulty:** intro · **Concepts:** vectors-and-norms
#
# **Banned (zero points): `np.linalg.norm` inside `euclidean_norm`.**

# %%
import numpy as np

# %% [markdown]
# **Euclidean norms.**
#
# **Part (a) — by hand.**
# Compute the Euclidean norm of each vector below by hand, then store your
# answers as Python floats:
#
# - $v_1 = (2, -2, 1)$ → `norm_v1_by_hand`
# - $v_2 = (6, 8)$ → `norm_v2_by_hand`
#
# **Part (b) — implement.**
# Implement `euclidean_norm(v)`, returning the Euclidean norm
# $\sqrt{\sum_i v_i^2}$ of a 1-D array `v`.
# Build it from `np.sqrt` and `np.sum`; calling `np.linalg.norm` inside
# `euclidean_norm` scores zero.
# Check that it reproduces both part (a) answers.
#
# **Part (c) — verify on generated data.**
# The provided cell generates a vector `v` with 5 entries.
# Compute its norm with your `euclidean_norm` and with the built-in
# `np.linalg.norm`, and confirm the two agree with `np.isclose`.

# %% [markdown]
# ## Part (a)

# %%
# YOUR CODE HERE
norm_v1_by_hand = ...
norm_v2_by_hand = ...

# %% [markdown]
# ## Part (b)

# %%
def euclidean_norm(v):
    # YOUR CODE HERE
    ...

# %% [markdown]
# ## Part (c)

# %%
SEED = 20260804
rng = np.random.default_rng(SEED)

v = rng.normal(size=5)
print(v)

# %%
# YOUR CODE HERE
