# %% [markdown]
# # F2-vectors — Practice p03
#
# **Type:** drill · **Difficulty:** intro · **Concepts:** dot-product, cosine-similarity

# %%
import numpy as np

# %% [markdown]
# **Dot products and direction agreement.**
#
# **Part (a) — by hand.**
# For each pair below, compute the dot product by hand and classify the angle
# between the vectors from its sign alone.
# Store the dot products as the floats `dot_1`, `dot_2`, `dot_3`, and the
# classifications as the strings `angle_1`, `angle_2`, `angle_3`, each one of
# `"acute"`, `"right"`, `"obtuse"`.
#
# 1. $(3, -1)$ and $(2, 6)$
# 2. $(1, 2)$ and $(3, 1)$
# 3. $(2, -3)$ and $(-1, 1)$
#
# **Part (b) — implement.**
# Implement `cosine_similarity(a, b)` for 1-D arrays, returning
# $\dfrac{a\cdot b}{\|a\|\,\|b\|}$.
# Check that `cosine_similarity(np.array([1.0, 0.0]), np.array([1.0, 1.0]))`
# returns approximately $\sqrt2/2 \approx 0.707$.
#
# **Part (c) — word-count vectors.**
# Three sentences were reduced to counts of the words
# ("ball", "goal", "recipe", "oven"):
#
# - $s_1 = (3, 2, 0, 0)$
# - $s_2 = (1, 2, 0, 0)$
# - $s_3 = (0, 0, 2, 3)$
#
# Compute `sim_12`, `sim_13`, `sim_23` with your function, then store
# `most_alike` as one of `"s1-s2"`, `"s1-s3"`, `"s2-s3"` — the pair with the
# highest cosine similarity.

# %% [markdown]
# ## Part (a)

# %%
# YOUR CODE HERE
dot_1, angle_1 = ..., "?"
dot_2, angle_2 = ..., "?"
dot_3, angle_3 = ..., "?"

# %% [markdown]
# ## Part (b)

# %%
def cosine_similarity(a, b):
    # YOUR CODE HERE
    ...

# %% [markdown]
# ## Part (c)

# %%
s1 = np.array([3.0, 2.0, 0.0, 0.0])
s2 = np.array([1.0, 2.0, 0.0, 0.0])
s3 = np.array([0.0, 0.0, 2.0, 3.0])

# YOUR CODE HERE
most_alike = "?"
