# %% [markdown]
# # F2-vectors — Practice p08
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** cosine-similarity, dot-product, orthogonality-orthonormality

# %%
import numpy as np

# %% [markdown]
# **Multiple choice.**
# Choose exactly one of A-E and record your choice in the code cell as a
# string, e.g. `answer_p08 = "A"`.
# Work the statements by hand before choosing.
#
# Vectors $a$ and $b$ are nonzero, and their cosine similarity is $0$.
# Which of the following MUST be true?
#
# &nbsp;&nbsp;I. $a \cdot b = 0$
# &nbsp;&nbsp;II. $\|a - b\|^2 = \|a\|^2 + \|b\|^2$
# &nbsp;&nbsp;III. $\dfrac{a}{\|a\|} \cdot \dfrac{b}{\|b\|} = 0$
# &nbsp;&nbsp;IV. $\|a\| = \|b\|$
#
# A. I only
#
# B. I and III only
#
# C. I, II, and III only
#
# D. II and IV only
#
# E. I, II, III, and IV
#
# Reasoning is not required.

# %%
# Record your choice as a capital letter string.
answer_p08 = "?"
