# %% [markdown]
# # F2-vectors — Practice p14
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** projection, residuals

# %%
import numpy as np

# %% [markdown]
# **Multiple choice.**
# Choose exactly one of A-E and record your choice in the code cell as a
# string, e.g. `answer_p14 = "A"`.
# Work each option by hand — one of them is guaranteed by the algebra of
# projection; the others all fail for some choice of inputs.
#
# Let $\hat u$ be a unit vector, $a$ any vector, $p = (a\cdot\hat u)\,\hat u$
# the projection, and $r = a - p$ the residual.
# Which statement is ALWAYS true?
#
# A. $\|p\| = a \cdot \hat u$
#
# B. $p \cdot r = 0$
#
# C. $\|r\| = \|a\| - \|p\|$
#
# D. $r = 0$ only when $a = 0$
#
# E. $p \cdot \hat u = 0$
#
# Reasoning is not required.

# %%
# Record your choice as a capital letter string.
answer_p14 = "?"
