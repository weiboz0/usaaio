# %% [markdown]
# # F2-vectors — Practice p20
#
# **Type:** scenario analysis · **Difficulty:** core · **Concepts:** distance-metrics, cosine-similarity

# %%
import numpy as np

# %% [markdown]
# **Scenario analysis: three measurements, three tools.**
# For each scenario, do the computation, store the requested values, and store
# your choice of tool as one of the strings `"euclidean"`, `"manhattan"`,
# `"cosine"`.
# A choice without the supporting computation scores zero.
#
# **Scenario 1 — robot arm error.**
# A robot arm was told to move its tip to $(6, 8)$ (cm) but ended at
# $(3, 4)$.
# Compute the straight-line size of the position error (`s1_error`).
# Which tool did you use? → `scenario_1`
#
# **Scenario 2 — restocking effort.**
# A shelf holds items of three products, counted as $(10, 4, 7)$; the target
# stock is $(8, 7, 7)$.
# Each single item added or removed is one unit of work.
# Compute the total restocking work (`s2_work`).
# Which tool computes it? → `scenario_2`
#
# **Scenario 3 — practice habits.**
# Two musicians log weekly minutes on (scales, pieces, sight-reading):
# $m_1 = (300, 150, 50)$ and $m_2 = (60, 30, 10)$.
# One practices five times as much overall.
# Compute `s3_cosine`, the cosine similarity of the two logs, and `s3_euclid`,
# their Euclidean distance.
# Which tool shows their practice *mix* is identical? → `scenario_3`
# Then answer in the markdown cell: give one situation from these three where
# Manhattan and Euclidean would put two candidate answers in a different order — or
# explain why the tools disagree in general.

# %% [markdown]
# ## Scenario 1

# %%
# YOUR CODE HERE
s1_error = ...
scenario_1 = "?"

# %% [markdown]
# ## Scenario 2

# %%
# YOUR CODE HERE
s2_work = ...
scenario_2 = "?"

# %% [markdown]
# ## Scenario 3

# %%
# YOUR CODE HERE
s3_cosine = ...
s3_euclid = ...
scenario_3 = "?"

# %% [markdown]
# **Your discussion:** *(write 1-2 sentences here)*
