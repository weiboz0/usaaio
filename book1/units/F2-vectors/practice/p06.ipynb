# %% [markdown]
# # F2-vectors — Practice p06
#
# **Type:** constrained coding · **Difficulty:** advanced · **Concepts:** projection, cosine-similarity, broadcasting, aggregation-axis
#
# **Banned (zero points): `for`, `while`, and comprehensions anywhere in the notebook.**

# %%
import numpy as np

# %% [markdown]
# **Project every row at once — no loops.**
#
# The provided cell generates `X`, a 2-D array of shape `(200, 3)` holding 200
# vectors (one per row), and a unit vector `u`.
#
# **Rules.**
# Loops are banned in this notebook.
# Do not use `for`, `while`, or comprehensions anywhere; a submission
# containing any of them scores zero.
# Work only with elementwise operations, broadcasting, and axis aggregations,
# as covered in F1-scientific-python.
#
# **Part (a).**
# Implement `project_rows(X, u)`, returning a `(200, 3)` array whose row $i$ is
# the projection of row $i$ of `X` onto the direction of the unit vector `u`,
# and store the result as `P`.
# *Hint:* `np.sum(X * u, axis=1)` has shape `(200,)`, and an array reshaped to
# `(200, 1)` broadcasts against `u`'s shape `(3,)`.
#
# **Part (b).**
# Implement `cosine_rows(X, u)`, returning a `(200,)` array whose entry $i$ is
# the cosine similarity between row $i$ of `X` and `u`.
# Store the result as `cos_all`, and store `check_range`, a bool verifying with
# `np.all` that every entry of `cos_all` lies in $[-1, 1]$.
#
# **Part (c).**
# Form the residual rows `R = X - P`.
# Verify that every row of `R` is orthogonal to `u` in a single expression —
# an axis sum of `R * u` passed to `np.allclose` — and store the resulting
# bool as `check_orth`.

# %%
SEED = 20260804
rng = np.random.default_rng(SEED)

X = rng.normal(size=(200, 3))
u = np.array([2.0, -1.0, 2.0]) / 3.0    # a unit vector: sqrt(4 + 1 + 4) / 3 = 1

print(X.shape, u, np.linalg.norm(u))

# %% [markdown]
# ## Part (a)

# %%
def project_rows(X, u):
    # YOUR CODE HERE
    ...


P = ...

# %% [markdown]
# ## Part (b)

# %%
def cosine_rows(X, u):
    # YOUR CODE HERE
    ...


cos_all = ...
check_range = ...

# %% [markdown]
# ## Part (c)

# %%
# YOUR CODE HERE
check_orth = ...
