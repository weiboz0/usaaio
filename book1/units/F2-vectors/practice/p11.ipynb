# %% [markdown]
# # F2-vectors — Practice p11
#
# **Type:** integrative · **Difficulty:** core · **Concepts:** unit-vectors, projection, residuals, broadcasting, aggregation-axis

# %%
import numpy as np

# %% [markdown]
# **Integrative: one direction, five points.**
# Later parts consume earlier results — work them in order.
#
# A direction of interest is given by $d = (3, 4)$, and five data points are
# stored as the rows of `Y` (shape `(5, 2)`).
#
# **Part (a).**
# Compute `u`, the unit vector in the direction of $d$, by normalizing.
#
# **Part (b).**
# Using `u` from part (a), compute `reach`, the `(5,)` array whose entry $i$
# is $y_i \cdot u$ (how far each point reaches along the direction), and `P`,
# the `(5, 2)` array of projections $(y_i \cdot u)\,u$.
# Broadcasting handles all five rows at once, as covered in
# F1-scientific-python.
#
# **Part (c).**
# Using `P` from part (b), compute `R = Y - P` and `res_norms`, the `(5,)`
# array of Euclidean norms of the residual rows.
# Store `best = int(np.argmin(res_norms))` and `worst = int(np.argmax(res_norms))`.
# Then answer in the markdown cell: what does a residual norm of exactly 0
# mean geometrically for the corresponding point?

# %%
d = np.array([3.0, 4.0])
Y = np.array([[4.0, 3.0],
              [8.0, 6.0],
              [-3.0, -4.0],
              [1.0, 7.0],
              [5.0, 0.0]])
print(Y.shape)

# %% [markdown]
# ## Part (a)

# %%
# YOUR CODE HERE
u = ...

# %% [markdown]
# ## Part (b)

# %%
# YOUR CODE HERE
reach = ...
P = ...

# %% [markdown]
# ## Part (c)

# %%
# YOUR CODE HERE
res_norms = ...
best = ...
worst = ...

# %% [markdown]
# **Your interpretation:** *(write 1-2 sentences here)*
