# %% [markdown]
# # F2-vectors — Practice p19
#
# **Type:** integrative · **Difficulty:** core · **Concepts:** cosine-similarity, unit-vectors, vectors-and-norms

# %%
import numpy as np

# %% [markdown]
# **Integrative: from word counts to the most alike pair.**
# Later parts consume earlier results — work them in order.
#
# Four sentences were reduced to counts of the words
# ("guitar", "drums", "violin"), stored as the rows of `S` (shape `(4, 3)`):
# row 0 is sentence 1, row 1 is sentence 2, and so on.
#
# **Part (a).**
# Compute `row_norms`, the `(4,)` array of Euclidean norms of the rows (use an
# axis sum, as covered in F1-scientific-python).
#
# **Part (b).**
# Using `row_norms` from part (a), compute `U`, the `(4, 3)` array in which
# every row of `S` is normalized to unit length.
# (Reshape the norms to `(4, 1)` so the division broadcasts.)
#
# **Part (c).**
# Using `U` from part (b), the cosine similarity of two sentences is just the
# dot product of their unit rows.
# Compute the three similarities `sim_12`, `sim_13`, `sim_14` of sentence 1
# with each other sentence, and store `most_alike`, one of
# `"s1-s2"`, `"s1-s3"`, `"s1-s4"`.
# Then answer in the markdown cell: the winning pair has different counts —
# why does it still score a perfect similarity?

# %%
S = np.array([[4.0, 2.0, 0.0],
              [2.0, 1.0, 0.0],
              [0.0, 0.0, 3.0],
              [1.0, 1.0, 1.0]])
print(S.shape)

# %% [markdown]
# ## Part (a)

# %%
# YOUR CODE HERE
row_norms = ...

# %% [markdown]
# ## Part (b)

# %%
# YOUR CODE HERE
U = ...

# %% [markdown]
# ## Part (c)

# %%
# YOUR CODE HERE
sim_12 = ...
sim_13 = ...
sim_14 = ...
most_alike = "?"

# %% [markdown]
# **Your explanation:** *(write 1-2 sentences here)*
