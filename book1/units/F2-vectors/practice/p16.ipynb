# %% [markdown]
# # F2-vectors — Practice p16
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** unit-vectors, vectors-and-norms
#
# **Banned (zero points): `for`, `while`, comprehensions, and `np.linalg.norm` anywhere in the notebook.**

# %%
import numpy as np

# %% [markdown]
# **Normalize every row, no loops.**
#
# The provided cell generates `X`, a 2-D array of shape `(120, 5)` holding 120
# vectors, one per row (none of them zero).
#
# **Rules.**
# Loops are banned in this notebook: do not use `for`, `while`, or
# comprehensions anywhere.
# `np.linalg.norm` is banned everywhere in this notebook.
# Violating either rule scores zero.
#
# **Part (a).**
# Implement `unit_rows(X)`, returning an array of the same shape `(120, 5)` in
# which every row has been rescaled to unit Euclidean length.
# Store the result as `U`.
# *Hint:* the row norms form a `(120,)` array; reshape to `(120, 1)` so the
# division broadcasts row by row.
#
# **Part (b).**
# Verify the contract: store `max_err`, a float giving the largest absolute
# deviation of the row norms of `U` from 1 (combine an axis sum, `np.abs`,
# and `np.max`).

# %%
SEED = 20260804
rng = np.random.default_rng(SEED)

X = rng.normal(size=(120, 5))
print(X.shape)

# %% [markdown]
# ## Part (a)

# %%
def unit_rows(X):
    # YOUR CODE HERE
    ...


U = ...

# %% [markdown]
# ## Part (b)

# %%
# YOUR CODE HERE
max_err = ...
