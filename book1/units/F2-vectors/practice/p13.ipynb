# %% [markdown]
# # F2-vectors — Practice p13
#
# **Type:** challenge · **Difficulty:** advanced · **Concepts:** orthogonality-orthonormality, projection, residuals

# %%
import numpy as np

# %% [markdown]
# **Challenge: build your own axes.**
# Advanced problem — everything needed was taught in this unit, but the steps
# must be assembled by you.
#
# You are given two vectors that are *not* orthogonal:
# $$v_1 = (3, 4), \qquad v_2 = (2, 1).$$
#
# **Part (a).**
# Construct an orthonormal pair $\{u_1, u_2\}$ from them using **only**
# normalization, projection, and residual:
#
# 1. `u1`: normalize $v_1$;
# 2. form the residual of $v_2$ after projecting it onto the direction `u1`;
# 3. `u2`: normalize that residual.
#
# Compute every intermediate value by hand first (the numbers come out
# exactly), then with NumPy.
#
# **Part (b).**
# Verify orthonormality numerically: $u_1\cdot u_1 = 1$, $u_2\cdot u_2 = 1$,
# $u_1\cdot u_2 = 0$.
# Then explain in 1-2 sentences in the markdown cell: *why* does step 2
# guarantee $u_1 \cdot u_2 = 0$, before any numbers are plugged in?
#
# **Part (c).**
# Use your new axes: for $w = (7, 1)$, read off the coordinates
# $t_1 = w\cdot u_1$ and $t_2 = w\cdot u_2$, and verify that
# $t_1 u_1 + t_2 u_2$ rebuilds $w$ exactly.

# %% [markdown]
# ## Part (a)

# %%
v1 = np.array([3.0, 4.0])
v2 = np.array([2.0, 1.0])

# YOUR CODE HERE
u1 = ...
u2 = ...

# %% [markdown]
# ## Part (b)

# %%
# YOUR CODE HERE

# %% [markdown]
# **Your explanation:** *(write 1-2 sentences here)*

# %% [markdown]
# ## Part (c)

# %%
w = np.array([7.0, 1.0])

# YOUR CODE HERE
t1 = ...
t2 = ...
