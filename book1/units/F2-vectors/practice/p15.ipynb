# %% [markdown]
# # F2-vectors — Practice p15
#
# **Type:** multiple choice (numeric, normal form) · **Difficulty:** core · **Concepts:** projection, residuals

# %%
import numpy as np

# %% [markdown]
# **Multiple choice (numeric, normal form).**
# Reasoning is not required. No derivation is scored — work it out by hand with exact fractions, then
# record your choice in the code cell as a string, e.g. `answer_p15 = "A"`.
#
# Let $a = (2, 7)$ and let $\hat b = \left(\tfrac35, \tfrac45\right)$ (a unit
# vector).
# Form the projection $p = (a\cdot\hat b)\,\hat b$ and the residual
# $r = a - p$.
#
# The Euclidean norm of the residual is the fraction
# $$\|r\| = \frac{p}{q}, \qquad \gcd(p, q) = 1,\ p, q\ \text{positive integers.}$$
#
# Compute $S = p + q$.
#
# A. 8
#
# B. 18
#
# C. 36
#
# D. 39
#
# E. 194

# %%
# Record your choice as a capital letter string.
answer_p15 = "?"
