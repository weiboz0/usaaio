# %% [markdown]
# # C11-neural-training — Practice p17
#
# **Type:** scenario analysis · **Difficulty:** core · **Concepts:** trained-mlp
#
# **Time budget:** 50 minutes
#
# A two-layer MLP is trained for 120 epochs on a fixed classification split.
# The table reports mean cross-entropy and accuracy measured after each listed epoch.
#
# | epoch | train loss | validation loss | train accuracy | validation accuracy | max parameter movement from initialization |
# |---:|---:|---:|---:|---:|---:|
# | 0 | 1.10 | 1.12 | 0.35 | 0.34 | 0.00 |
# | 10 | 0.63 | 0.67 | 0.73 | 0.70 | 0.41 |
# | 30 | 0.24 | 0.35 | 0.94 | 0.86 | 0.88 |
# | 60 | 0.08 | 0.52 | 0.99 | 0.81 | 1.26 |
# | 120 | 0.03 | 0.91 | 1.00 | 0.72 | 1.71 |
#
# The optimizer lifecycle is known to be correct, both splits were fixed before training, and validation was evaluated without parameter updates.
#
# Write a concise audit that does all of the following.
#
# 1. Establish from at least three named columns that genuine training occurred rather than a no-op or fabricated single metric.
# 2. Identify the approximate checkpoint you would retain and justify it using validation rather than training behavior.
# 3. Diagnose what happens after that checkpoint, distinguishing optimization success from generalization failure.
# 4. Propose two concrete interventions from the taught MLP toolkit, and predict how each should change the train/validation curves.
# 5. Name the extra evidence you would log on the next run to certify that the interventions, rather than data leakage or split changes, caused any improvement.
#
# Every claim must cite table evidence.
# The trained-MLP concept is graded through the movement/loss/accuracy certification, checkpoint choice, curve diagnosis, and predicted intervention effects.

# %% [markdown]
# ## Your audit
#
# Write your evidence-based diagnosis and intervention plan here.
