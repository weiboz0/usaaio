# %% [markdown]
# # C11-neural-training — Practice p05
#
# **Type:** constrained coding · **Difficulty:** intro · **Concepts:** softmax
#
# **Time budget:** 25 minutes
#
# Implement `stable_softmax(logits)` for a two-dimensional NumPy array of shape (N,C).
# The function must return a float64 array of the same shape, normalize each row independently, and remain finite for very large positive or negative logits.
# Subtract each row's maximum before exponentiating and retain the singleton class-axis dimension for broadcasting.
#
# The grader checks shape and dtype exactly, finite nonnegative entries, row sums within `atol=1e-12, rtol=1e-12`, agreement with moderate-logit reference values within `atol=1e-12, rtol=1e-10`, and invariance when a different scalar is added to each row within the same tolerances.
# Exact zeros caused by floating-point underflow for a class far below the row maximum are acceptable.
#
# **Banned (zero points): SciPy or PyTorch; any `for`/`while` loop or comprehension; exponentiating the unshifted logits; clipping or adding an epsilon to the denominator.**
# Only NumPy array conversion, `max`, `exp`, `sum`, and broadcasting are needed.

# %%
import numpy as np


def stable_softmax(logits: np.ndarray) -> np.ndarray:
    """Return stable rowwise softmax probabilities as float64."""
    # YOUR CODE HERE
    raise NotImplementedError


probe_p05 = np.array([[1000.0, 1001.0, 999.0], [-1000.0, -999.0, -1002.0]])
probs_p05 = stable_softmax(probe_p05)
