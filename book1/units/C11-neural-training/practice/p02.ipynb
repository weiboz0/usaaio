# %% [markdown]
# # C11-neural-training — Practice p02
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** cross-entropy-loss
#
# **Time budget:** 15 minutes
#
# For a batch of N examples and C classes, let P have shape (N,C), let y_i be the zero-based correct class index, and define the mean categorical cross-entropy loss.
# Which expression is exactly the negative log likelihood and has the correct batch averaging?
#
# A. -(1/C) sum_i log(P[i, y_i])
#
# B. -(1/N) sum_i log(P[i, y_i])
#
# C. -(1/N) sum_i P[i, y_i]
#
# D. -sum_i sum_c log(P[i,c])
#
# E. -(1/N) sum_i log(1 - P[i, y_i])
#
# Reasoning is required.
# Record one letter and explain why the one-hot form reduces to your selected expression.
# Your explanation must identify the averaging axis and describe how assigning a smaller probability to the observed class affects the loss; both items are graded.

# %%
answer_p02 = "?"  # replace with "A".."E"
reasoning_p02 = ""
