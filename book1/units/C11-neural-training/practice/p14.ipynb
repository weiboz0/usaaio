# %% [markdown]
# # C11-neural-training — Practice p14
#
# **Type:** integrative (parts consume earlier results) · **Difficulty:** core · **Concepts:** softmax, cross-entropy-loss
#
# **Time budget:** 60 minutes
#
# Build one stable fused softmax-cross-entropy routine.
# Implement `softmax_ce_with_gradient(logits, labels)` for float64 logits `(N,C)` and integer labels `(N,)`.
# Validate ranks, dimensions, nonempty class axis, and label range.
# Return a dictionary containing `probabilities` `(N,C)`, mean `loss` as a float, and `gradient` `(N,C)` for the derivative of the mean loss with respect to logits.
#
# Use one rowwise maximum shift.
# Compute probabilities from shifted exponentials, compute loss from shifted correct logits and log-sum-exp rather than from `log(probabilities)`, and compute the fused gradient with the correct batch-mean factor.
# The grader uses ordinary and magnitude-10,000 logits and checks finiteness, positivity, row sums and gradient-row sums, shift invariance, and independent reference agreement within `atol=1e-11, rtol=1e-9`.
# A centered finite-difference audit on selected coordinates must agree within `atol=2e-6, rtol=2e-5`.
# Both the stable probability computation and the independently scored loss/gradient outputs must pass.
#
# **Banned (zero points): SciPy, PyTorch, clipping, adding epsilon, taking `log` of formed probabilities, a full Jacobian per example, or numerical differentiation inside the submitted function.**

# %%
import numpy as np


def softmax_ce_with_gradient(logits, labels):
    # YOUR CODE HERE
    raise NotImplementedError


logits_p14 = np.array([[10000.0, 9998.0, 9999.0], [-9000.0, -8997.0, -9001.0], [0.5, -0.25, 1.5]])
labels_p14 = np.array([0, 1, 2], dtype=int)
result_p14 = softmax_ce_with_gradient(logits_p14, labels_p14)
