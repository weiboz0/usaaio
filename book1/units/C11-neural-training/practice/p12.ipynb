# %% [markdown]
# # C11-neural-training — Practice p12
#
# **Type:** proof / derivation · **Difficulty:** core · **Concepts:** manual-backpropagation
#
# **Time budget:** 40 minutes
#
# Consider the two-layer MLP for a batch: `Z1 = X W1^T + b1`, `H = ReLU(Z1)`, `Z2 = H W2^T + b2`, and mean softmax cross-entropy L.
# Let M denote hidden width.
# Shapes are X `(N,D)`, W1 `(M,D)`, b1 `(M,)`, Z1 and H `(N,M)`, W2 `(C,M)`, b2 `(C,)`, and integer labels y `(N,)`.
# Let P be rowwise softmax probabilities and Y the `(N,C)` one-hot matrix.
#
# Starting only from `dZ2 = (P-Y)/N`, derive the complete backward pass in reverse dependency order.
# Your final ledger must include formulas and shapes for `dW2`, `db2`, `dH`, `dZ1`, `dW1`, and `db1`.
# Define the ReLU derivative at every nonzero preactivation and state the convention you adopt at zero.
# Explain why bias gradients sum over axis 0, why shared-parameter contributions accumulate across examples, and why neither layer may be updated until every gradient has been computed from the same forward snapshot.
#
# All six gradients, the reverse dependency order, accumulation, and update-order argument are graded.
# A shape-only answer or a list of formulas without a dependency explanation receives no credit.

# %% [markdown]
# ## Your derivation
#
# Write the complete backward shape ledger and update-order argument here.
