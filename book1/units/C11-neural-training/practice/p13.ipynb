# %% [markdown]
# # C11-neural-training — Practice p13
#
# **Type:** proof / derivation · **Difficulty:** core · **Concepts:** batch-normalization
#
# **Time budget:** 40 minutes
#
# Let X have shape `(N,D)`.
# Training-mode BatchNorm uses `mu = mean_i X_i`, `v = mean_i (X_i-mu)^2`, `s = (v+eps)^(-1/2)`, `Xhat = (X-mu)s`, and `Y = gamma*Xhat + beta`, with featurewise gamma and beta.
# An upstream gradient G = partial L/partial Y also has shape `(N,D)`.
#
# Derive, with axis and shape annotations:
#
# 1. `dbeta` and `dgamma`.
# 2. The compact input gradient `dX = (gamma*s/N) * (N*G - sum_i G_i - Xhat*sum_i(G_i*Xhat_i))`.
# 3. The identities `sum_i dX_i = 0` and, up to epsilon's effect, the centered first-moment identity for dX.
# 4. Why the forward variance used to normalize the batch has denominator N while a PyTorch running-variance buffer update uses the corresponding unbiased estimate.
# 5. Which quantities are optimizer-trained parameters and which are module-updated buffers, and what changes between train and eval mode.
#
# The backward derivation, invariants, and state/mode explanation are graded independently.
# Quoting the compact formula without deriving its terms receives no credit.

# %% [markdown]
# ## Your derivation
#
# Write the forward dependency graph, backward chain, invariants, and state classification here.
