# %% [markdown]
# # C11-neural-training — Practice p06
#
# **Type:** constrained coding · **Difficulty:** intro · **Concepts:** cross-entropy-loss
#
# **Time budget:** 25 minutes
#
# Implement `stable_cross_entropy(logits, labels)`.
# `logits` is a float array of shape (N,C); `labels` is an integer array of shape (N,) with entries from 0 through C-1.
# Return the mean categorical cross-entropy as a plain Python `float`.
# Use the rowwise log-sum-exp identity directly: shift by each row maximum, form one log normalizer per row, gather the shifted correct-class logits, and average the resulting losses.
#
# Raise `ValueError` when the ranks, batch lengths, class count, or label range are invalid.
# The grader checks validation behavior, finiteness on logits of magnitude at least 10,000, shift invariance, and reference agreement within `atol=1e-12, rtol=1e-10`.
#
# **Banned (zero points): calling a softmax function; forming probabilities and then taking their logarithms; clipping; adding an epsilon; SciPy or PyTorch.**

# %%
import numpy as np


def stable_cross_entropy(logits: np.ndarray, labels: np.ndarray) -> float:
    """Return mean categorical cross-entropy from logits."""
    # YOUR CODE HERE
    raise NotImplementedError


probe_logits_p06 = np.array([[10000.0, 9999.0, 9997.0], [-8000.0, -7998.0, -8001.0]])
probe_labels_p06 = np.array([0, 1], dtype=int)
loss_p06 = stable_cross_entropy(probe_logits_p06, probe_labels_p06)
