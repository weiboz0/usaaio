# %% [markdown]
# # C11-neural-training — Practice p03
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** manual-backpropagation
#
# **Time budget:** 15 minutes
#
# A scalar loss L depends on h through two branches: u = 3h, v = h^2, and L = u + v.
# The forward value is h = -2.
# Which backward-pass description has both the correct dependency order and the correct shape rule for an array-valued version of h?
#
# A. Update h after differentiating u, then differentiate v using the updated h; an h gradient may have any broadcastable shape.
#
# B. Differentiate h before L because h appears first in the forward graph; gradient shape is unrelated to h.
#
# C. Obtain the gradients arriving through u and v, add them at h, and require the resulting gradient to have exactly h's shape.
#
# D. Multiply the two branch gradients at h and reshape the result to a scalar.
#
# E. Keep only the larger-magnitude branch gradient because both branches consume the same h.
#
# Reasoning is required.
# Record one letter, compute the two local contributions at h = -2, and state why neither parameter nor activation may be updated before all downstream contributions have arrived.
# The dependency order, accumulation rule, and shape claim are each graded.

# %%
answer_p03 = "?"  # replace with "A".."E"
reasoning_p03 = ""
