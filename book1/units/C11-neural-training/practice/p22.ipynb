# %% [markdown]
# # C11-neural-training — Practice p22
#
# **Type:** challenge · **Difficulty:** advanced · **Concepts:** manual-backpropagation
#
# **Time budget:** 70 minutes
#
# Perform a complete numerical backward pass for this three-affine-layer scalar network.
# Use column vectors and the convention `ReLU'(0)=0`.
#
# ```text
# x = (1, -2)^T
# W1 = [[1, -1], [2, 1], [-1, 2]],       b1 = (0, 1, -1)^T
# W2 = [[1, 2, -1], [-2, 1, 1]],          b2 = (1, -1)^T
# w3 = (2, -1)^T,                          b3 = 1/2
#
# z1 = W1 x + b1,   h1 = ReLU(z1)
# z2 = W2 h1 + b2,  h2 = ReLU(z2)
# y_hat = w3^T h2 + b3
# L = (1/2) (y_hat - 3)^2
# ```
#
# Give exact integer or reduced-fraction values for every forward intermediate and for `dy_hat`, `dw3`, `db3`, `dh2`, `dz2`, `dW2`, `db2`, `dh1`, `dz1`, `dW1`, `db1`, and `dx`.
# Annotate each array's shape.
# At both hidden vectors, explain how contributions from all downstream coordinates are accumulated before the ReLU mask is applied.
# Finally, verify one internal consistency identity: the outer-product shape for each weight gradient or the equality between a bias gradient and its preactivation gradient for this one-example graph.
#
# Every local derivative, both ReLU gates, dependency order, and gradient shape are graded.
#
# **Banned (zero points): autograd packages, PyTorch backward, symbolic differentiators, finite differences, or updating any supplied value during the backward pass.**

# %% [markdown]
# ## Your exact forward and backward ledger
#
# Write every requested value, shape, accumulation explanation, and consistency check here.
