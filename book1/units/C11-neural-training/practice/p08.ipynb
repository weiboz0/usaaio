# %% [markdown]
# # C11-neural-training — Practice p08
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** autograd-training, torch-optimizers
#
# **Time budget:** 35 minutes
#
# Implement `autograd_and_optimizer_step(X, y, w0, learning_rate)` on CPU in PyTorch float64.
# X has shape `(N,D)`, y `(N,)`, and w0 `(D,)`.
# Create an `nn.Parameter` initialized from a clone of w0 and an `torch.optim.SGD` optimizer containing that parameter.
# For mean squared error `mean((X @ w - y)**2)`, clear old gradients, run forward, call `backward`, clone the autograd gradient, compute the hand gradient `(2/N) * X.T @ (X @ w0 - y)`, and then let `optimizer.step()` update w.
#
# Return a dictionary containing `autograd_grad`, `hand_grad`, `before`, `after`, `loss_before`, and `loss_after`; tensor values must be detached clones and losses plain floats.
# The autograd and hand gradients are scored independently and must agree within `atol=1e-11, rtol=1e-10`.
# The optimizer portion is separately scored: `before` must equal w0, `after` must agree with the SGD update within those tolerances, the parameter must move, and the fixed probe must reduce loss.
#
# **Banned (zero points): assigning to `w.data`; manual in-place parameter updates; replacing `optimizer.step()` with a hand-coded update; NumPy; returning the hand gradient in both gradient fields.**

# %%
import torch
from torch import nn

SEED = 20260804
ATOL = 1e-11
RTOL = 1e-10
torch.manual_seed(SEED)
torch.set_default_dtype(torch.float64)


def autograd_and_optimizer_step(X, y, w0, learning_rate):
    # YOUR CODE HERE
    raise NotImplementedError


X_p08 = torch.tensor([[1.0, -2.0], [0.5, 1.5], [-1.0, 0.25], [2.0, 1.0]])
y_p08 = torch.tensor([0.5, -1.0, 0.75, 1.25])
w0_p08 = torch.tensor([0.2, -0.3])
result_p08 = autograd_and_optimizer_step(X_p08, y_p08, w0_p08, learning_rate=0.05)
