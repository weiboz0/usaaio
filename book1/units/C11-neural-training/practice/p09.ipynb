# %% [markdown]
# # C11-neural-training — Practice p09
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** batch-normalization
#
# **Time budget:** 35 minutes
#
# Implement `batchnorm_forward_audit(X, gamma, beta, running_mean, running_var, eps, momentum)` using NumPy float64.
# X has shape `(N,D)`; every other array has shape `(D,)`.
# For training output, use the current batch mean and the biased variance `mean((X-mean)**2)`, then apply `gamma * x_hat + beta`.
# Return the updated running mean using `(1-momentum)*old + momentum*batch_mean` and the updated running variance using the corresponding unbiased batch variance with denominator N-1, matching PyTorch's running-buffer convention.
# For evaluation output, normalize X with those newly updated running statistics and apply the same affine parameters.
#
# Return a dictionary with `train_output`, `eval_output`, `batch_mean`, `batch_var_biased`, `running_mean_new`, `running_var_new`, `parameter_names`, and `buffer_names`.
# The name values must be tuples: `gamma, beta` are optimizer-trained parameters, while `running_mean, running_var` are module-updated buffers.
# The grader checks every array against an independent reference within `atol=1e-10, rtol=1e-9`, verifies that inputs are unchanged, and separately grades the parameter/buffer classification.
#
# **Banned (zero points): `torch.nn.BatchNorm1d`, any other normalization routine, loops or comprehensions, and treating running statistics as optimizer parameters.**

# %%
import numpy as np


def batchnorm_forward_audit(X, gamma, beta, running_mean, running_var, eps, momentum):
    # YOUR CODE HERE
    raise NotImplementedError


X_p09 = np.array([[1.0, 4.0, 7.0], [3.0, 4.0, 9.0], [5.0, 4.0, 11.0], [7.0, 4.0, 13.0]])
gamma_p09 = np.array([1.2, -0.7, 0.5])
beta_p09 = np.array([0.1, 0.2, -0.3])
running_mean_p09 = np.array([0.5, -0.5, 1.0])
running_var_p09 = np.array([1.5, 0.75, 2.0])
result_p09 = batchnorm_forward_audit(X_p09, gamma_p09, beta_p09, running_mean_p09, running_var_p09, eps=1e-5, momentum=0.1)
