# %% [markdown]
# # C11-neural-training — Practice p15
#
# **Type:** integrative (parts consume earlier results) · **Difficulty:** core · **Concepts:** manual-backpropagation, trained-mlp
#
# **Time budget:** 60 minutes
#
# Train a two-layer NumPy MLP on deterministic noisy XOR data using a complete manual backward pass.
# `train_numpy_mlp(seed=20260804, epochs=800, learning_rate=0.12)` must perform all work with float64 and return `params`, a one-dimensional `losses` array of length epochs, integer `predictions` for the four clean XOR centers in the order below, and `max_parameter_movement` as a float.
#
# Data generation is exact.
# Create `rng = np.random.default_rng(seed)`, set `centers = [[-1,-1],[-1,1],[1,-1],[1,1]]` and labels `[0,1,1,0]`, repeat each center 24 consecutive times with `np.repeat(centers,24,axis=0)`, then add `0.12*rng.standard_normal((96,2))`; labels use the same repeat order.
# Initialize, in this draw order, `W1 = rng.standard_normal((8,2))*sqrt(1/2)`, `b1=zeros(8)`, `W2=rng.standard_normal((2,8))*sqrt(1/8)`, and `b2=zeros(2)`.
# Use full-batch stable softmax cross-entropy, ReLU, the complete mean-loss backward equations, and simultaneous gradient-descent updates.
#
# The grader requires all finite losses, exact result shapes, every parameter to move from initialization, `losses[-1] < 0.35*losses[0]`, and clean-center accuracy at least 0.95.
# A second run with the same arguments must reproduce losses and parameters within `atol=1e-10, rtol=1e-9`.
# Every manual gradient from the first training step is graded within those tolerances, so a hard-coded curve, fake prediction, or incomplete backward pass cannot pass.
# Manual backpropagation and genuine trained-MLP success are scored separately.
#
# **Banned (zero points): PyTorch, JAX, TensorFlow, autograd packages, finite-difference training gradients, sklearn, downloads, hand-written predictions, or updating a parameter before all gradients are complete.**

# %% [markdown]
# ### Return contract
#
# Return a dictionary with exactly four top-level keys.
# `params` is a dictionary with exactly `W1,b1,W2,b2`; `losses` is the one-dimensional pre-update loss history of length epochs; `predictions` is an integer array of shape `(4,)`; and `max_parameter_movement` is the largest Euclidean norm of a final-minus-initial parameter array, as a float.

# %%
import numpy as np

SEED = 20260804
ATOL = 1e-10
RTOL = 1e-9


def train_numpy_mlp(seed=SEED, epochs=800, learning_rate=0.12):
    # YOUR CODE HERE
    raise NotImplementedError


result_p15 = train_numpy_mlp()
