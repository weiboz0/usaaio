# %% [markdown]
# # C11-neural-training — Practice p20
#
# **Type:** scenario analysis · **Difficulty:** advanced · **Concepts:** trained-mlp, batch-normalization, dropout
#
# **Time budget:** 50 minutes
#
# Four seeded runs use the same MLP width, initial linear weights, optimizer, split, batch order, and 100-epoch budget.
# Validation is intended to run in eval mode.
#
# | run | BatchNorm | dropout p | final train CE | best validation CE | final validation CE | final validation accuracy | BN buffers unchanged during validation? | repeated validation logits equal? |
# |:--|:--|--:|--:|--:|--:|--:|:--|:--|
# | A | no | 0.00 | 0.03 | 0.42 | 0.86 | 0.74 | n/a | yes |
# | B | no | 0.30 | 0.16 | 0.31 | 0.38 | 0.84 | n/a | yes |
# | C | yes | 0.30 | 0.12 | 0.27 | 0.29 | 0.87 | yes | yes |
# | D | yes | 0.30 | 0.11 | 0.25 | 0.47 | 0.80 | no | no |
#
# Write an ablation audit.
#
# 1. Use train and validation evidence to certify that the MLPs learned and to diagnose run A.
# 2. Compare A with B to isolate the answer-affecting role of dropout; state the expected train/eval behavior of the dropout layer.
# 3. Compare B with C cautiously: state what evidence supports BatchNorm here and why one seeded table does not prove a universal causal law.
# 4. Reject or repair run D by explaining both failed mode postconditions and how they contaminate its metrics.
# 5. Design a fair rerun that varies one factor at a time, preserves seeds/data/initial weights/batch order, snapshots parameters and buffers, and reports uncertainty across multiple seeds.
#
# The trained-network certification, BatchNorm state audit, and dropout ablation are each graded.
# A ranking with no state-validity check receives no credit.

# %% [markdown]
# ## Your ablation audit
#
# Write the evidence-based comparisons, run-D validity decision, and controlled rerun design here.
