# %% [markdown]
# # C11-neural-training — Practice p01
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** softmax
#
# **Time budget:** 15 minutes
#
# A classifier produces the row of logits z = (1000, 1001, 999).
# A student computes softmax after first replacing z by z - a(1,1,1), where a is a scalar.
# Which claim is correct and gives a numerically stable choice of a?
#
# A. Softmax changes whenever a is nonzero, so only a = 0 is valid.
#
# B. Softmax is unchanged for every finite scalar a; choosing a = 1001 makes every exponent at most 1.
#
# C. Softmax is unchanged only when a equals the mean of the logits.
#
# D. Choosing a = 999 is stable because every shifted logit is nonnegative.
#
# E. Choosing a = 1001 changes the largest class probability to exactly 1.
#
# Reasoning is required.
# Record one letter and justify it algebraically by factoring the common exponential from the numerator and denominator.
# Your justification must also explain why the proposed shift avoids overflow; both shift invariance and stability are graded.

# %%
answer_p01 = "?"  # replace with "A".."E"
reasoning_p01 = ""  # explain invariance and numerical stability
