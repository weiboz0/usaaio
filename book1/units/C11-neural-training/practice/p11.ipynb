# %% [markdown]
# # C11-neural-training — Practice p11
#
# **Type:** proof / derivation · **Difficulty:** core · **Concepts:** softmax, cross-entropy-loss
#
# **Time budget:** 40 minutes
#
# For one example, logits z in R^C produce p_c = exp(z_c)/sum_j exp(z_j).
# The one-hot target y satisfies sum_c y_c = 1, and the loss is L = -sum_c y_c log(p_c).
#
# Derive all of the following without skipping index steps.
#
# 1. For J_ck = partial p_c / partial z_k, treat c=k and c!=k and combine the cases into `J_ck = p_c(delta_ck-p_k)`.
# 2. Show in matrix notation that `J = diag(p) - p p^T`, and prove that every row and column sums to zero.
# 3. Chain `partial L/partial p_c` through every softmax output to prove `partial L/partial z_k = p_k-y_k`.
# 4. Extend the result to a batch mean with logits Z of shape `(N,C)`, giving the exact shape and the factor introduced by averaging.
# 5. Explain why the fused gradient can be computed stably without materializing C-by-C Jacobians.
#
# Softmax Jacobian structure and the cross-entropy fusion are graded separately.
# A response that merely quotes `P-Y` without the Jacobian and chain-rule derivation receives no credit.

# %% [markdown]
# ## Your derivation
#
# Write the indexed derivation, matrix form, batch extension, and stability explanation here.
