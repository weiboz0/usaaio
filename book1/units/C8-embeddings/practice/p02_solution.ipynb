# %% [markdown]
# # C8-embeddings — Practice p02 — Solution

# %%
answer_p02 = "C"

# %% [markdown]
# The answer is **C**: words used in similar contexts tend to point in similar directions.
#
# - A incorrectly assigns a human-readable word meaning to each coordinate.
# - B incorrectly says lexicographers chose the entries and that synonyms must be identical.
# - C states the learned distributional relationship taught in the lesson.
# - D confuses contextual geometry with spelling or character similarity.
# - E contradicts the fixed-artifact guarantee: loading the same published model reproduces the same vectors.

# %% [markdown]
# ### Answer check

# %%
assert answer_p02 == "C"
