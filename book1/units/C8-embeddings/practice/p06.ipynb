# %% [markdown]
# # C8-embeddings — Practice p06
#
# **Type:** constrained coding · **Difficulty:** intro · **Concepts:** tokenization
#
# Tokenize a fresh passage and take its census — without destroying the
# order information.
#
# Using `TEXT` below and `gensim.utils.simple_preprocess`, set:
#
# - `toks` — the token list;
# - `n_tokens` — the number of tokens (occurrences);
# - `n_types` — the number of distinct words;
# - `uniq_ordered` — the distinct words **in first-occurrence order**
#   (a list);
# - `n_bread` — how many times the token `"bread"` occurs;
# - `first_cheese` — the index (position in `toks`) of the *first*
#   occurrence of `"cheese"`.
#
# **Banned (zero points): building `uniq_ordered` from a `set` in any
# way (including `sorted(set(...))`)** — sets destroy first-occurrence
# order; use the idiom taught in Session 1.

# %%
from gensim.utils import simple_preprocess

TEXT = ("At 7 a.m. the market opened: crates of bread, wheels of cheese, and jars of "
        "honey lined the stalls. The baker praised the bread; the baker's rival praised "
        "the cheese. By 9 a.m. the honey was gone.")

toks = ...          # YOUR CODE HERE
n_tokens = ...      # YOUR CODE HERE
n_types = ...       # YOUR CODE HERE
uniq_ordered = ...  # YOUR CODE HERE (banned: set() in any form)
n_bread = ...       # YOUR CODE HERE
first_cheese = ...  # YOUR CODE HERE
