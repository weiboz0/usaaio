# %% [markdown]
# # C8-embeddings — Practice p03 — Solution

# %%
answer_p03 = "B"

# %% [markdown]
# The answer is **B**. Since `W` has shape `(12, 100)`, `W @ W.T` has shape `(12, 12)`. Dot products commute, giving symmetry; unit rows give a unit diagonal; unrelated or opposed directions can have negative dot products.
#
# - A reverses the row-token convention and gives the wrong shape.
# - B states all three structural facts correctly.
# - C mistakes signed directional agreement for a nonnegative magnitude.
# - D confuses cosine similarity with Euclidean distance and reverses its interpretation.
# - E overlooks that matrix multiplication alone forms the Gram matrix.

# %% [markdown]
# ### Answer check

# %%
assert answer_p03 == "B"
