# %% [markdown]
# # C8-embeddings — Practice p15
#
# **Type:** scenario · **Difficulty:** core · **Concepts:** tokenization
#
# A field assistant tokenized the survey notes below and immediately
# wrapped the result in a `set` "to clean out the duplicates":
#
# ```python
# vocab = set(simple_preprocess(NOTES))
# ```
#
# They then filed a report claiming: *"our records show the heron was
# sighted before the otters"* (read off `list(vocab)`'s order), and
# *"each animal was logged once"* (read off `vocab`'s size).
# Both claims are wrong.
#
# **(a) Diagnose.**
# In two or three sentences: name the two pieces of information `set()`
# destroyed and tie each to one of the report's false claims — including
# why the order-based claim might have *looked* right on the
# assistant's machine.
#
# **(b) Rebuild the honest numbers.**
# From `NOTES`, set: `toks` (the token list), `n_tokens`, `n_types`,
# `uniq_ordered` (distinct tokens, first-occurrence order —
# **`set()` banned in any form, zero points**), `n_otters` and
# `n_heron` (occurrence counts of `"otters"` and `"heron"`), and
# `first_animal` — whichever of those two tokens truly appears first in
# `toks` (a `str`, computed from `toks.index(...)`, not by eye).
#
# **(c) Repair the report.**
# One sentence per claim, with the numbers from (b): what should the
# report actually say about order and about counts?

# %%
from gensim.utils import simple_preprocess

NOTES = ("Day 12 on the river: two otters at dawn, then a heron. The heron waited; "
         "the otters did not. We logged the heron at 6 a.m., the otters at 6 a.m. "
         "and 8 a.m., and one badger at dusk.")

# (b)
toks = ...          # YOUR CODE HERE
n_tokens = ...      # YOUR CODE HERE
n_types = ...       # YOUR CODE HERE
uniq_ordered = ...  # YOUR CODE HERE (banned: set() in any form)
n_otters = ...      # YOUR CODE HERE
n_heron = ...       # YOUR CODE HERE
first_animal = ...  # YOUR CODE HERE

# %% [markdown]
# *Your diagnosis (a) and repaired report sentences (c) here.*
