# %% [markdown]
# # C8-embeddings — Practice p04
#
# **Type:** multiple choice (numeric, normal form) · **Difficulty:** core · **Concepts:** cosine-similarity, vectors-and-norms, dot-product
#
# Two token vectors are rows of a raw (unnormalized) embedding matrix:
# $$u = (3, 4), \qquad v = (4, 3).$$
#
# Their cosine similarity
# $\cos(u, v) = \dfrac{u \cdot v}{\lVert u \rVert\, \lVert v \rVert}$
# is a rational number that can be written in lowest terms as $p/q$ with
# $\gcd(p, q) = 1$ and $q > 0$ (the sign, if any, lives in $p$).
# What is $p + q$?
#
# A. $2$
#
# B. $25$
#
# C. $37$
#
# D. $49$
#
# E. $51$
#
# Reasoning is not required. Record your choice below.

# %%
answer_p04 = "?"  # replace with "A".."E"
