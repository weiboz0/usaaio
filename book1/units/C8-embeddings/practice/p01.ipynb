# %% [markdown]
# # C8-embeddings — Practice p01
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** tokenization
#
# Let
#
# ```python
# s = "A 90-meter ferry, the Peregrine, left Pier 9 at dawn."
# toks = simple_preprocess(s)
# ```
#
# where `simple_preprocess` is `gensim.utils.simple_preprocess` with its
# default settings (lowercase; tokens are contiguous runs of letters;
# only pieces of 2–15 characters survive).
#
# What is `len(toks)`?
#
# A. $6$
#
# B. $8$
#
# C. $9$
#
# D. $10$
#
# E. $11$
#
# Reasoning is not required. Record your choice below.

# %%
answer_p01 = "?"  # replace with "A".."E"
