# %% [markdown]
# # C8-embeddings — Practice p20
#
# **Type:** drill · **Difficulty:** intro · **Concepts:** embedding-matrices
#
# Build one small embedding matrix and read its basic facts — the
# convention drill.
#
# For the four words below, set:
#
# - `V` — the embedding matrix, rows are tokens in list order, shape
#   `(4, 100)`, **float64, cast at the load boundary**
#   (`np.asarray(kv[WORDS], dtype=np.float64)`);
# - `shape_ok` — a `bool`: `V.shape == (4, 100)`;
# - `dtype_ok` — a `bool`: `V.dtype == np.float64`;
# - `row0_is_dawn` — a `bool`: whether row 0 equals the boundary-cast
#   vector of `"dawn"` (use `np.allclose`);
# - `norms` — the raw row norms, **flat** shape `(4,)`, broadcast
#   register (no `np.linalg`, no loops);
# - `norm_dawn` — `float(norms[0])`.

# %%
import os, pathlib
_env_root = os.environ.get("USAAIO_BOOK_ROOT")
if _env_root:
    _root = pathlib.Path(_env_root).resolve()
else:
    _start = pathlib.Path.cwd().resolve()
    _root = next(
        p for p in [_start, *_start.parents]
        if (p / "syllabus.md").is_file() and (p / "curriculum").is_dir()
    )
os.environ["GENSIM_DATA_DIR"] = str(_root / "reference" / "cache" / "gensim")

import numpy as np
import gensim.downloader

kv = gensim.downloader.load("glove-wiki-gigaword-100")

WORDS = ["dawn", "dusk", "noon", "midnight"]

V = ...            # YOUR CODE HERE
shape_ok = ...     # YOUR CODE HERE
dtype_ok = ...     # YOUR CODE HERE
row0_is_dawn = ... # YOUR CODE HERE
norms = ...        # YOUR CODE HERE (shape (4,))
norm_dawn = ...    # YOUR CODE HERE
