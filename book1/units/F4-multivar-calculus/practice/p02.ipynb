# %% [markdown]
# # F4-multivar-calculus — Practice p02
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** gradient, multivar-chain-rule
#
# Let $g(a, b) = (2a + b)^3$. Using the chain rule, the gradient $\nabla g$ at the point $(a, b) = (1, 1)$ is:
#
# A. $(27, 27)$
#
# B. $(54, 27)$
#
# C. $(18, 9)$
#
# D. $(54, 54)$
#
# E. $(6, 3)$
#
# Record your choice below.

# %%
import numpy as np

answer_p02 = "?"  # replace with "A".."E"
