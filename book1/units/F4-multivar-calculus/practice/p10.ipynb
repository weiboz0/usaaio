# %% [markdown]
# # F4-multivar-calculus — Practice p10
#
# **Type:** constrained coding · **Difficulty:** advanced · **Concepts:** sum-of-squares-gradients, gradient, broadcasting, aggregation-axis
#
# Regularized sum of squares, pure broadcasting.
#
# With `X (N,d)`, `y (N,)`, `w (d,)` and a constant `lam` ≥ 0, define
# $$R(w) = \frac{1}{N}\sum_n\Big(y_n - \sum_k X_{n,k}w_k\Big)^2 + \lambda\sum_k w_k^2 .$$
#
# Write `r_gradient(X, y, w, lam)` (shape `(d,)`). **Banned: `@`, `np.matmul`, `np.dot`, `.T`, loops — zero points.**
#
# With the p07 seeded data and `lam = 0.1`: `g_reg = r_gradient(X, y, w, 0.1)`, plus `g_unreg = r_gradient(X, y, w, 0.0)` and `reg_effect = np.abs(g_reg - g_unreg)` — then a one-line markdown note stating the exact formula the difference should equal (and check it: `formula_gap`).

# %%
import numpy as np

SEED = 20260804
rng = np.random.default_rng(SEED)
X = rng.normal(0, 1, (50, 3))
y = rng.normal(0, 1, 50)
w = np.array([0.5, -1.0, 2.0])

def r_gradient(X, y, w, lam):
    # YOUR CODE HERE
    ...

g_reg = ...       # YOUR CODE HERE
g_unreg = ...     # YOUR CODE HERE
reg_effect = ...  # YOUR CODE HERE
formula_gap = ... # YOUR CODE HERE

# %% [markdown]
# *Your one-line note on what `reg_effect` should equal.*
