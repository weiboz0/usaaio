# %% [markdown]
# # F4-multivar-calculus — Practice p11
#
# **Type:** proof · **Difficulty:** advanced · **Concepts:** tanh-derivative
#
# **Reasoning is required.**
#
# **(a)** Starting from $\tanh x = \dfrac{e^x - e^{-x}}{e^x + e^{-x}}$, derive $\tanh'(x) = 1 - \tanh^2(x)$ using the quotient rule and algebra. Every step justified.
#
# **(b)** Show that $0 < \tanh'(x) \le 1$ for all real $x$, with equality only at $x = 0$.
#
# **(c) Concrete anchor:** verify numerically at $x = 0.7$: compute `direct` (central difference of `np.tanh` with `h = 1e-6`) and `identity_val` ($1 - \tanh^2(0.7)$), then `anchor_gap = abs(direct - identity_val)`.

# %% [markdown]
# *Your derivation for (a) and argument for (b) here.*

# %%
import numpy as np

# (c) YOUR CODE HERE
direct = ...
identity_val = ...
anchor_gap = ...
