# %% [markdown]
# # F4-multivar-calculus — Practice p05
#
# **Type:** constrained coding · **Difficulty:** intro · **Concepts:** partial-derivatives
#
# Numerical partial derivatives by central differences.
#
# Write `partial_v(f, u, v, h)` returning the central-difference estimate
# $$\frac{f(u, v+h) - f(u, v-h)}{2h}.$$
#
# Then, for `f = lambda u, v: u**2 * v + 3*v`, compute `est = partial_v(f, 2.0, 1.0, 1e-6)` and `exact` — the value you get by differentiating by hand — and `gap = abs(est - exact)`.
#
# Constraints: no loops; no libraries beyond NumPy (zero points otherwise).

# %%
import numpy as np

def partial_v(f, u, v, h):
    # YOUR CODE HERE
    ...

f = lambda u, v: u**2 * v + 3*v
est = ...   # YOUR CODE HERE
exact = ... # YOUR CODE HERE (hand-derived value)
gap = ...   # YOUR CODE HERE
