# %% [markdown]
# # F4-multivar-calculus — Practice p04
#
# **Type:** multiple choice (numeric, normal form) · **Difficulty:** core · **Concepts:** sum-of-squares-gradients
#
# For data points $x = (1, 2)$, $y = (3, 5)$ define
# $$Q(w) = \sum_{n=1}^{2} (y_n - w\,x_n)^2 .$$
#
# Compute $Q'(w)$ at $w = 2$.
# Your answer is an integer that can be written as $s \cdot m$ with $s \in \{+1, -1\}$ and $m$ a positive integer.
# What is $s + m$? (E.g. an answer of $-7$ gives $-1 + 7 = 6$.)
#
# A. 3
#
# B. 5
#
# C. 7
#
# D. 9
#
# E. 11
#
# Reasoning is not required. Record your choice below.

# %%
import numpy as np

answer_p04 = "?"  # replace with "A".."E"
