# %% [markdown]
# # F4-multivar-calculus — Practice p18
#
# **Type:** challenge · **Difficulty:** core · **Concepts:** gradient, partial-derivatives, tanh-derivative, broadcasting
#
# Where is a surface steepest — and where is it flat?
#
# Consider $g(x, y) = \tanh(x) + \tfrac{1}{2} y^2$ on the grid $x \in [-3, 3]$, $y \in [-2, 2]$.
#
# **(a)** Hand-derive $\nabla g$ and implement `g_grad_norm(xx, yy)` returning $\lVert\nabla g\rVert$ elementwise on coordinate grids `xx, yy` (built via broadcasting from `np.linspace(-3, 3, 301)` and `np.linspace(-2, 2, 201)` with shape tricks — NO `np.meshgrid`, no loops; zero points).
#
# **(b)** Find `flat_point` — the $(x, y)$ on the grid where the gradient size is smallest — and `steep_norm` — the largest gradient size on the grid (use argmin/argmax + index arithmetic).
#
# **(c)** One sentence each: why the flat point sits where it does (two separate one-variable facts), and why the steepest locations hug a particular edge of the grid.

# %%
import numpy as np

xs = np.linspace(-3, 3, 301)
ys = np.linspace(-2, 2, 201)

def g_grad_norm(xx, yy):
    # YOUR CODE HERE
    ...

# YOUR CODE HERE
flat_point = ...
steep_norm = ...

# %% [markdown]
# *Your (c) sentences here.*
