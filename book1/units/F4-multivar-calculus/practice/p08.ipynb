# %% [markdown]
# # F4-multivar-calculus — Practice p08
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** multivar-chain-rule
#
# Chain rule, numerically confirmed.
#
# Let $r(t) = (\cos t, \sin t, t^2)$ and $f(p) = p_0^2 + 3 p_1 + p_2$. The chain rule says
# $$\frac{d}{dt} f(r(t)) = \sum_{k} \frac{\partial f}{\partial p_k}\Big|_{r(t)} \cdot r_k'(t).$$
#
# 1. Hand-derive the formula for $\tfrac{d}{dt} f(r(t))$ and implement it as `chain_exact(t)` (plain NumPy scalar math).
# 2. Implement `chain_numeric(t, h)` = central difference of the composite $f(r(\cdot))$.
# 3. Set `vals = np.array([chain_exact(t) for t in (0.5, 1.0, 2.0)])` — this listing loop is allowed — and `gap = max |chain_exact - chain_numeric|` over those three points with `h = 1e-6`.
#
# No other loops; no symbolic libraries (zero points).

# %%
import numpy as np

def chain_exact(t):
    # YOUR CODE HERE
    ...

def chain_numeric(t, h):
    # YOUR CODE HERE
    ...

vals = ...  # YOUR CODE HERE
gap = ...   # YOUR CODE HERE
