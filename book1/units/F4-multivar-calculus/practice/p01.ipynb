# %% [markdown]
# # F4-multivar-calculus — Practice p01
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** partial-derivatives
#
# Let $f(u, v) = u^2 v + 3v$.
#
# What is $\dfrac{\partial f}{\partial v}$?
#
# A. $2uv$
#
# B. $u^2 + 3$
#
# C. $2uv + 3$
#
# D. $u^2 v + 3$
#
# E. $2u + 3$
#
# Record your choice below.

# %%
import numpy as np

answer_p01 = "?"  # replace with "A".."E"
