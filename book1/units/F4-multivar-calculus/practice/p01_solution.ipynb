# %% [markdown]
# # F4-multivar-calculus — Practice p01 — Solution

# %% [markdown]
# Treating $u$ as constant, differentiating $u^2v+3v$ with respect to $v$ gives $u^2+3$. Therefore the correct choice is B.

# %%
import numpy as np

answer_p01 = "B"

# %% [markdown]
# ### Answer check

# %%
my_answer_letter = answer_p01
assert my_answer_letter == "B"
