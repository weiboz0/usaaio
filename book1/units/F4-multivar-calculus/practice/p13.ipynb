# %% [markdown]
# # F4-multivar-calculus — Practice p13
#
# **Type:** integrative · **Difficulty:** core · **Concepts:** partial-derivatives, gradient, sum-of-squares-gradients
#
# Fitting a two-coefficient rule by hand-derived gradient.
#
# Data: `hours = np.array([1., 2., 3., 4., 5.])`, `scores = np.array([52., 55., 61., 64., 70.])`. Model the scores as $s_n \approx w_0 + w_1 h_n$ and define
# $$Q(w_0, w_1) = \frac{1}{5}\sum_n (s_n - w_0 - w_1 h_n)^2 .$$
#
# **(a)** Hand-derive $\partial Q/\partial w_0$ and $\partial Q/\partial w_1$ (component form; write them in the markdown cell).
#
# **(b)** Implement `q2_gradient(w0, w1)` from your (a) formulas (no loops; broadcasting only).
#
# **(c)** Using YOUR gradient: starting from $(w_0, w_1) = (0, 0)$, take 2,000 tiny downhill nudges `w -= 0.01 * grad` (this repetition loop IS allowed) and report `w_final`, plus `grad_norm_final` (size of the gradient at the end — should be near 0).
#
# **(d)** One sentence: what do the final $w_0, w_1$ mean for the hours→score relationship?

# %% [markdown]
# *Your (a) derivation here.*

# %%
import numpy as np

hours = np.array([1., 2., 3., 4., 5.])
scores = np.array([52., 55., 61., 64., 70.])

def q2_gradient(w0, w1):
    # YOUR CODE HERE
    ...

# (c) YOUR CODE HERE
w_final = ...
grad_norm_final = ...

# %% [markdown]
# *Your (d) sentence here.*
