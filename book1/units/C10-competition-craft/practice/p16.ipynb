# %% [markdown]
# # C10-competition-craft — Practice p16
#
#
# **Type:** scenario · **Difficulty:** core · **Concepts:** hidden-test-protocol, train-test-split
#
# Four submissions to the apiary competition; the grading report
# came back.
# Diagnose each — precisely.
#
# - **Submission 1** scored **0**.
#   Its function: `def predict_labels(X_test): return
#   pipe.predict(X_test)` — the model behind it validates at 0.81.
# - **Submission 2** scored **0**.
#   Its function: `def predict_labels(X_test): return
#   pd.Series(pipe.predict(X_test))` — no index argument; the
#   submitter tested it on `X.iloc[:30]` and every check passed.
# - **Submission 3** scored **0** despite a flawless contract.
#   Its notebook contains a cell running the dataset script with its
#   grading flag and loading the held-back rows "just to double-check
#   the score before submitting."
# - **Submission 4** scored **0.71** against its claimed
#   "validation macro-F1 = 0.93."
#   Its protocol: fit the scaler+kNN pipeline on **all 600 rows**,
#   *then* carve 150 of those rows and measure macro-F1 on them.
#
# **(a) Code.**
# With the fitted `pipe` from the stub: demonstrate Submission 1's and
# Submission 2's failures on `probe = X.iloc[400:430]` —
# `fail_1` = the name of the first self-check Submission 1 fails
# (string, one of `"series"`, `"length"`, `"index"`, `"vocab"`), and
# `fail_2` = likewise for Submission 2.
# Also `passes_on_head` — a `bool`: does Submission 2 pass all four
# checks on `X.iloc[:30]`?
# (It should — that is the trap.)
#
# **(b) Written, 2–3 sentences per submission:** name the violated
# clause or protocol rule, explain *why* the grader's outcome
# followed, and give the one-line fix (for Submission 4: name the leak
# and state what an honest estimate would have required).
#
# **Banned (zero points): any supervised estimator other than `KNeighborsClassifier` — including the LogisticRegression / RandomForest / GradientBoosting / SVC / MLP families, and re-implementing any of them by hand; reading or printing the held-back split; imports beyond `sklearn` / `numpy` / `pandas` / `matplotlib`.** Any preprocessing is allowed.

# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

SEED = 20260804

df = pd.read_csv("../data/train.csv")
FEATURES = [c for c in df.columns if c != "outcome"]
X = df[FEATURES]
y = df["outcome"].to_numpy()

pipe = Pipeline([("scaler", StandardScaler()),
                 ("knn", KNeighborsClassifier(n_neighbors=11))]).fit(X, y)

probe = X.iloc[400:430]

# YOUR CODE HERE (reproduce both broken functions; run the checks)

fail_1 = ...          # YOUR CODE HERE (str)
fail_2 = ...          # YOUR CODE HERE (str)
passes_on_head = ...  # YOUR CODE HERE (bool)

# %% [markdown]
# *Your (b) diagnoses here.*
