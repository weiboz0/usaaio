# %% [markdown]
# # C10-competition-craft — Practice p21 — Solution

# %% [markdown]
# The answer is **B**. Requiring $\gcd(|p|,q)=1$ removes every common positive scale factor, and $q>0$ fixes the remaining simultaneous-sign duplication.
#
# Trap by trap: A permits infinitely many scaled forms such as $1/2=2/4$. C reduces scale but still permits both $(p,q)$ and $(-p,-q)$. D cannot represent negative rationals at all and does not require reduction even for positive ones. E excludes every rational with absolute value at least one and still does not enforce coprimality. Only B gives one ordered pair for every nonzero rational.

# %%
answer_p21 = "B"

# %% [markdown]
# ### Answer check

# %%
assert answer_p21 == "B"
