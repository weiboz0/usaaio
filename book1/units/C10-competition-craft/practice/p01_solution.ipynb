# %% [markdown]
# # C10-competition-craft — Practice p01 — Solution

# %%
import numpy as np

answer_p01 = "B"
answer_p01

# %% [markdown]
# **B is correct.** It returns the required `pd.Series`, keeps one prediction per input row, and explicitly preserves `X_test.index`.
#
# - A returns a list, so it breaks R3 and has no contract index.
# - C installs a new default index; it only appears correct for a conveniently indexed head slice and breaks R4 elsewhere.
# - D returns a `DataFrame`, not a `Series`, so it breaks R3.
# - E returns the pipeline's NumPy array, so it also breaks R3.

# %% [markdown]
# ### Answer check

# %%
assert answer_p01 == "B"
assert answer_p01 in set("ABCDE")
