# %% [markdown]
# # C10-competition-craft — Practice p24
#
# **Type:** constrained coding · **Difficulty:** advanced · **Concepts:** api-constraint-compliance
#
# *Coding is required.*
#
# Implement
# ```python
# def competition_ranks(values):
#     ...
# ```
# for a one-dimensional NumPy float array. Return integer ranks where rank 1 is best (largest value), tied values receive the same rank, and each value's rank is \(1+\) the number of array entries strictly greater than it. This is competition ranking, so gaps after ties are intentional.
#
# Use broadcasting comparisons and an axis sum. Apply the function to `values`, assigning the exact identifiers `ranks` and `tie_ok`; `tie_ok` is `True` exactly when both pairs of tied values receive equal ranks.
#
# **Banned (zero points): `sort`/`sorted`, `argsort`, `partition`/`argpartition`, SciPy ranking helpers, Python loops/comprehensions, `map`/`filter`, `np.vectorize`, pandas `apply`, or a helper that performs any banned operation.**

# %%
import numpy as np

values = np.array([2.7, -4.3, 8.1, 2.7, 5.9, 8.1])


def competition_ranks(values):
    # YOUR CODE HERE
    ...


ranks = ...   # YOUR CODE HERE, integer array shape (6,)
tie_ok = ...  # YOUR CODE HERE, bool
