# %% [markdown]
# # C10-competition-craft — Practice p23
#
# **Type:** scenario · **Difficulty:** advanced · **Concepts:** api-constraint-compliance
#
# *Reasoning is required. No coding is needed; the code cell records the audit verdict.*
#
# A prompt says:
#
# > Imports are unrestricted. In any executed cell, calls to `sklearn.metrics.f1_score`, pandas `Series.apply`/`DataFrame.apply`, Python loops/comprehensions, `map`/`filter`, or helpers wrapping those operations score zero. Use vectorized confusion-count arithmetic. Dead, uncalled definitions are still executed notebook content, but an unused import alone is not a call.
#
# Audit this submission:
#
# ```python
# # line 1
# from sklearn.metrics import f1_score
#
# # line 3
# def encode_labels(series):
#     # line 5
#     return series.apply(lambda value: 1 if value == "cedar" else 0)
#
# # line 7
# encoded = encode_labels(labels)
# # line 8
# score = vectorized_macro_f1(y_true, encoded)
# ```
#
# Set `import_is_violation`, `first_violation_line`, `violating_api`, and `verdict`. Then write 3–5 sentences distinguishing the harmless import from the priced call and stating one compliant vectorized replacement.
#
# **Banned (zero points): running the code, deleting the helper before auditing it, or treating a wrapper as closing the ban.**

# %%
import_is_violation = ...
first_violation_line = ...
violating_api = ...
verdict = ...

# %% [markdown]
# *Your 3–5 sentence audit here.*
