# %% [markdown]
# # C10-competition-craft — Practice p02
#
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** hidden-test-protocol
#
# The apiary harness's training table was produced by a public,
# seeded generator script; the same script can also write a held-back
# split of 200 further rows, used for grading.
#
# Which statement correctly describes the hidden-test protocol?
#
# A. The held-back rows use a different feature schema, so
# `predict_labels` must be written to handle missing columns.
#
# B. Reading the held-back split once — to sanity-check your score
# before submitting — is acceptable as long as no model is fitted on
# it.
#
# C. The graders regenerate the held-back split deterministically and
# call your `predict_labels` on it; your notebook never reads it, and
# every number you report must be computable without it.
#
# D. Because the generator is seeded and public, the split is not
# really hidden, so the protocol is advisory and carries no grading
# consequence.
#
# E. Your validation macro-F1 is the official score; the held-back
# rows are consulted only to break ties between submissions.
#
# Record your choice below.

# %%
import numpy as np

answer_p02 = "?"  # replace with "A".."E"
