# %% [markdown]
# # C10-competition-craft — Practice p08
#
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** prediction-function-contract, train-test-split, f1-macro, knn, feature-scaling, sklearn-pipelines
#
# The contract, with an honestly chosen k.
#
# On `../data/train.csv` (bridge to `X` as a feature `DataFrame` and
# `y` as usual):
#
# 1. carve the unit's pinned validation split:
#    `train_test_split(X, y, test_size=150, random_state=SEED,
#    stratify=y)`;
# 2. for each `k` in `ks = [3, 5, 7, 9, 11, 15]`: fit a scaler+kNN
#    `Pipeline` on the training part and record the **validation
#    macro-F1** → `val_f1s`, shape `(6,)`;
# 3. `best_k` — the `k` with the highest `val_f1s`, **smallest `k`
#    winning ties** (an `int`);
# 4. refit the `best_k` pipeline on **all 600 rows** and define
#    `predict_labels` to the contract;
# 5. `contract_ok` — all four self-checks pass on
#    `probe = X.iloc[350:390]` (one `bool`).
#
# A loop over `ks` is permitted.
#
# **Banned (zero points): any supervised estimator other than `KNeighborsClassifier` — including the LogisticRegression / RandomForest / GradientBoosting / SVC / MLP families, and re-implementing any of them by hand; reading or printing the held-back split; imports beyond `sklearn` / `numpy` / `pandas` / `matplotlib`.** Any preprocessing is allowed.
#
# **Additionally banned (zero points): judging the sweep by accuracy (`.score`) —
# the sweep's judge is `f1_score(..., average="macro")`.**

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

SEED = 20260804
ks = np.array([3, 5, 7, 9, 11, 15])

df = pd.read_csv("../data/train.csv")
FEATURES = [c for c in df.columns if c != "outcome"]
X = df[FEATURES]
y = df["outcome"].to_numpy()

# YOUR CODE HERE (carve, sweep, refit)

val_f1s = ...      # YOUR CODE HERE (shape (6,))
best_k = ...       # YOUR CODE HERE (int)


def predict_labels(X_test):
    ...            # YOUR CODE HERE


probe = X.iloc[350:390]
contract_ok = ...  # YOUR CODE HERE
