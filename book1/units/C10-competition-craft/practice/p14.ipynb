# %% [markdown]
# # C10-competition-craft — Practice p14
#
#
# **Type:** integrative · **Difficulty:** advanced · **Concepts:** notebook-discipline, train-test-split, f1-macro, knn, feature-scaling, sklearn-pipelines
#
# The disciplined notebook: audit a wreck, then build the clean
# version and *prove* it deterministic.
# Parts consume earlier results.
#
# **(a) The dead-cell audit.**
# A teammate's submission notebook contains, in order:
#
# 1. imports + `SEED = 20260804`
# 2. load `../data/train.csv`; bridge to `X`, `y`
# 3. `df2 = pd.read_csv("bees_old.csv")` — leftover from an abandoned
#    experiment; the file no longer exists
# 4. the pinned carve (`test_size=150, random_state=SEED, stratify=y`)
# 5. sweep `k` over `[7, 9, 11]` on the 7 `SIGNAL` columns (scaled
#    pipeline, judged by validation macro-F1) → `val_f1s`, `best_k`
# 6. `plt.hist(df["hive_mass"])` — an exploration plot kept "for
#    reference"; the column was renamed `autumn_hive_mass_kg` weeks ago
# 7. final refit of the `best_k` pipeline on all rows (`SIGNAL`
#    columns); `predict_labels` defined
# 8. `print(best_model_old.score(X, y))` — `best_model_old` was
#    defined in a cell deleted last week
# 9. contract self-checks + the writeup cell
#
# `dead_cells` — the sorted list of cell numbers that violate the
# no-dead-cells rule (each would *crash* a fresh top-to-bottom run).
#
# **(b) The clean rebuild.**
# Implement cells 1–2, 4–5, 7, 9 as one flow (the `SIGNAL` list is
# given in the stub): deliverables `val_f1s` (shape `(3,)`), `best_k`
# (smallest on ties), `predict_labels` (contract; note the final model
# consumes only the `SIGNAL` columns of whatever `X_test` arrives),
# `contract_ok` on `probe = X.iloc[250:290]`.
#
# **(c) The determinism audit.**
# `run_submission` — a no-argument function repeating the whole (b)
# flow and returning `(best_k, val_f1s[-1], preds)` where `preds` is
# `predict_labels(probe).to_numpy()`; call twice; `audit_ok` — exact
# equality of all three components.
#
# **(d) Written, one line per dead cell:** which discipline rule it
# breaks and what the grader's fresh run would do at that cell.
#
# A loop over the swept `k` values is permitted.
#
# **Banned (zero points): any supervised estimator other than `KNeighborsClassifier` — including the LogisticRegression / RandomForest / GradientBoosting / SVC / MLP families, and re-implementing any of them by hand; reading or printing the held-back split; imports beyond `sklearn` / `numpy` / `pandas` / `matplotlib`.** Any preprocessing is allowed.

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

SEED = 20260804
SIGNAL = ["honey_stores_kg", "autumn_hive_mass_kg", "varroa_mite_index",
          "forager_traffic_per_min", "brood_frames", "daily_temp_swing_c",
          "queen_age_years"]
ks = np.array([7, 9, 11])

df = pd.read_csv("../data/train.csv")
FEATURES = [c for c in df.columns if c != "outcome"]
X = df[FEATURES]
y = df["outcome"].to_numpy()

dead_cells = ...   # YOUR CODE HERE (sorted list of ints)

# YOUR CODE HERE (carve, SIGNAL sweep, final refit)

val_f1s = ...      # YOUR CODE HERE (shape (3,))
best_k = ...       # YOUR CODE HERE (int)


def predict_labels(X_test):
    ...            # YOUR CODE HERE (uses only the SIGNAL columns)


probe = X.iloc[250:290]
contract_ok = ...  # YOUR CODE HERE (bool)


def run_submission():
    ...            # YOUR CODE HERE (the whole flow, from df)


audit_ok = ...     # YOUR CODE HERE (bool)

# %% [markdown]
# *Your (d) lines here.*
