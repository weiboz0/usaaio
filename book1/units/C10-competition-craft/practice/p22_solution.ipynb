# %% [markdown]
# # C10-competition-craft — Practice p22 — Solution

# %%
first_violation_line = 3
verdict = "zero"
priced_points = 0

# %% [markdown]
# Line 3 performs the explicitly prohibited `** 0.5` square-root operation, so the zero-points clause prices the entire six-point deliverable at zero. Moving that call behind `hidden_norm` changes only its name and location: line 6 still executes the same banned operation through the helper. Mathematical correctness cannot restore partial credit after this contract violation.

# %% [markdown]
# ### Answer check

# %%
assert first_violation_line == 3
assert verdict == "zero"
assert priced_points == 0
