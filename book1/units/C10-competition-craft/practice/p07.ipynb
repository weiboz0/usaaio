# %% [markdown]
# # C10-competition-craft — Practice p07
#
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** metric-driven-iteration, accuracy-precision-recall, f1-score, f1-macro, broadcasting
#
# Macro-F1 from its pieces — no metric wrappers.
#
# Twenty validation predictions are given below.
# Using **boolean masks and NumPy only**, compute:
#
# - `C` — the 2×2 confusion matrix as an integer array, rows = actual,
#   columns = predicted, classes in sorted order
#   (`struggles` = 0, `thrives` = 1);
# - `prec`, `rec`, `f1` — the per-class one-vs-rest precision, recall,
#   and F1 arrays, shape `(2,)`, in the same class order;
# - `f1_macro` — the mean of `f1` (a `float`);
# - `acc` — the accuracy (a `float`).
#
# Verification anchor (this course's isclose contract — atol as
# stated, rtol=0): your `f1_macro` must satisfy
# `np.isclose(f1_macro, 251/351, atol=1e-12, rtol=0)`, and `acc` must
# equal `0.75` exactly.
#
# **Banned (zero points): `sklearn` (all of it — this problem is the
# from-parts register); loops.**

# %%
import numpy as np

y_true = np.array(["struggles", "thrives", "thrives", "struggles", "thrives",
                   "struggles", "thrives", "thrives", "struggles", "thrives",
                   "thrives", "struggles", "thrives", "thrives", "struggles",
                   "thrives", "thrives", "thrives", "thrives", "thrives"])
y_pred = np.array(["struggles", "thrives", "struggles", "struggles", "thrives",
                   "thrives", "thrives", "thrives", "struggles", "struggles",
                   "thrives", "struggles", "thrives", "thrives", "thrives",
                   "thrives", "struggles", "thrives", "thrives", "thrives"])

C = ...         # YOUR CODE HERE (2, 2) int
prec = ...      # YOUR CODE HERE (2,)
rec = ...       # YOUR CODE HERE (2,)
f1 = ...        # YOUR CODE HERE (2,)
f1_macro = ...  # YOUR CODE HERE
acc = ...       # YOUR CODE HERE
