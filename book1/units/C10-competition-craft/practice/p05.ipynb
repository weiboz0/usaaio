# %% [markdown]
# # C10-competition-craft — Practice p05
#
#
# **Type:** constrained coding · **Difficulty:** intro · **Concepts:** prediction-function-contract, pandas-basics, csv-data-loading, knn, feature-scaling, sklearn-pipelines
#
# A minimal legal submission, end to end.
#
# Load `../data/train.csv` and build:
#
# - `X` — feature `DataFrame` (every column except `outcome`, in file
#   order); `y` — the `outcome` labels as a NumPy array;
# - `pipe` — a `Pipeline` with steps `"scaler"` = `StandardScaler()`
#   and `"knn"` = `KNeighborsClassifier(n_neighbors=5)`, fitted on
#   **all 600 rows**;
# - `predict_labels` — the course contract: takes a feature
#   `DataFrame` of any length (training columns, training order),
#   returns a `pd.Series` with matching length, matching index, values
#   from the training label vocabulary;
# - `contract_ok` — a single `bool`: all four self-checks (Series /
#   length / index / vocabulary) pass on `probe = X.iloc[200:225]`.
#
# **Banned (zero points): any supervised estimator other than `KNeighborsClassifier` — including the LogisticRegression / RandomForest / GradientBoosting / SVC / MLP families, and re-implementing any of them by hand; reading or printing the held-back split; imports beyond `sklearn` / `numpy` / `pandas` / `matplotlib`.** Any preprocessing is allowed.

# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

SEED = 20260804

df = pd.read_csv("../data/train.csv")
FEATURES = [c for c in df.columns if c != "outcome"]

X = ...            # YOUR CODE HERE
y = ...            # YOUR CODE HERE
pipe = ...         # YOUR CODE HERE (fit on ALL rows)


def predict_labels(X_test):
    ...            # YOUR CODE HERE


probe = X.iloc[200:225]
contract_ok = ...  # YOUR CODE HERE (one bool, all four checks)
