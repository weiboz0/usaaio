# %% [markdown]
# # C10-competition-craft — Practice p03 — Solution

# %%
import numpy as np

answer_p03 = "C"
answer_p03

# %% [markdown]
# **C is correct.** It freezes a seeded, stratified carve, uses the actual grading metric, records and caps selection, and calibrates the final validation score as optimistic.
#
# - A selects by accuracy, a different objective from macro-F1.
# - B confounds candidate quality with split luck.
# - D measures memorization on rows used for fitting.
# - E repeatedly selects the maximum of validation noise and then reports that selected maximum without the required optimism caveat.

# %% [markdown]
# ### Answer check

# %%
assert answer_p03 == "C"
assert answer_p03 in set("ABCDE")
