# %% [markdown]
# # C10-competition-craft — Practice p20 — Solution

# %% [markdown]
# Since $299=23\cdot13$ and $391=23\cdot17$, dividing by the common factor gives $(-13,17)$; the first nonzero coordinate is negative, so the required sign convention negates both coordinates to $(13,-17)$. Merely dividing by the gcd is insufficient because it removes scale duplicates but leaves the two sign-equivalent representatives $(-13,17)$ and $(13,-17)$.

# %%
a = 13
b = -17
decoded = 100 * a + b

# %% [markdown]
# ### Answer check

# %%
assert (a, b) == (13, -17)
assert a > 0
assert decoded == 1283
