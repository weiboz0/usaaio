# %% [markdown]
# # C10-competition-craft — Practice p21
#
# **Type:** multiple choice · **Difficulty:** advanced · **Concepts:** normal-form-answers
#
# *Reasoning is not required. No coding is needed; the code cell only records your choice.*
#
# Which ONE rule gives a unique ordered pair \((p,q)\) for every nonzero rational number \(r=p/q\)?
#
# A. \(q\ne0\).
#
# B. \(\gcd(|p|,q)=1\) and \(q>0\).
#
# C. \(\gcd(|p|,|q|)=1\), with no sign rule.
#
# D. \(p>0\) and \(q>0\).
#
# E. \(|p|<|q|\) and \(q>0\).
#
# Record one capital letter.
#
# **Banned (zero points): using a fraction-normalization library to enumerate examples.** Judge the stated contract itself.

# %%
answer_p21 = "?"  # replace with A-E
