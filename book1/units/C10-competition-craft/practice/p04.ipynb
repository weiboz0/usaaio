# %% [markdown]
# # C10-competition-craft — Practice p04
#
#
# **Type:** multiple choice (numeric, normal form) · **Difficulty:** core · **Concepts:** metric-driven-iteration, accuracy-precision-recall, f1-score, f1-macro
#
# A validation set of 20 colonies produced this confusion matrix
# (rows = actual, columns = predicted, in the order `struggles`,
# `thrives`):
#
# $$C = \begin{pmatrix} 3 & 3 \\ 1 & 13 \end{pmatrix}$$
#
# Compute the **macro-F1** (mean of the two one-vs-rest per-class F1
# scores) as an exact fraction in lowest terms $p/q$ with
# $\gcd(p, q) = 1$, $p, q > 0$, and compute the **accuracy**.
#
# Report $S = p + q$ **if macro-F1 < accuracy**, or $S = p + q - 2$
# otherwise.
#
# A. 8
#
# B. 9
#
# C. 24
#
# D. 26
#
# E. 57
#
# Reasoning is not required. Record your choice below.

# %%
import numpy as np

answer_p04 = "?"  # replace with "A".."E"
