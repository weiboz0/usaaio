# %% [markdown]
# # C10-competition-craft — Practice p19
#
# **Type:** drill · **Difficulty:** intro · **Concepts:** normal-form-answers
#
# *Reasoning is not required. No coding is needed; the code cell records the decoded answer.*
#
# A calculation produces the raw fraction \(-187/323\). The prompt requires
# \[
# \frac{p}{q}\quad\text{with}\quad \gcd(|p|,q)=1,\ q>0,
# \]
# then asks for the integer `decoded = q - p`.
#
# Set the exact identifiers `p`, `q`, and `decoded`. Normalize first; do not decode the unreduced numerator and denominator.
#
# **Banned (zero points): `fractions.Fraction`, SymPy, a gcd API, or any automatic fraction-reduction helper.** This is a hand decode drill.

# %%
p = ...
q = ...
decoded = ...
