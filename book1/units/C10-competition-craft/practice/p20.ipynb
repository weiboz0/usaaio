# %% [markdown]
# # C10-competition-craft — Practice p20
#
# **Type:** drill · **Difficulty:** core · **Concepts:** normal-form-answers
#
# *Reasoning is required. No coding is needed; use the code cell only to record exact integers.*
#
# The direction vector \((-299,391)\) must be reported as the unique integer pair \((a,b)\) satisfying all three rules:
#
# 1. it points along the same unoriented line, so multiplying by a nonzero scalar is allowed;
# 2. \(\gcd(|a|,|b|)=1\);
# 3. the first nonzero coordinate is positive.
#
# After normalizing, the prompt asks for `decoded = 100 * a + b`.
#
# Set `a`, `b`, and `decoded`, then explain in one sentence why merely dividing by the gcd is not enough here.
#
# **Banned (zero points): NumPy/SciPy/SymPy normalization helpers, gcd APIs, or brute-force searches over candidate pairs.**

# %%
a = ...
b = ...
decoded = ...

# %% [markdown]
# *Your one-sentence sign-normalization explanation here.*
