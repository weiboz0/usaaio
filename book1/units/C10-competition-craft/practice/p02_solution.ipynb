# %% [markdown]
# # C10-competition-craft — Practice p02 — Solution

# %%
import numpy as np

answer_p02 = "C"
answer_p02

# %% [markdown]
# **C is correct.** The graders can deterministically regenerate their grading rows, but the student notebook never reads them; all student-reported evidence comes from training-only validation.
#
# - A invents a schema mismatch; the contract promises the training feature schema.
# - B is still answer-key leakage even if the rows are not used for fitting.
# - D mistakes reproducibility for permission: the protocol is binding and violations score zero.
# - E confuses an honest estimate with the separate grading score.

# %% [markdown]
# ### Answer check

# %%
assert answer_p02 == "C"
assert answer_p02 in set("ABCDE")
