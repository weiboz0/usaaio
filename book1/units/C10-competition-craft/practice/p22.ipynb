# %% [markdown]
# # C10-competition-craft — Practice p22
#
# **Type:** scenario · **Difficulty:** core · **Concepts:** api-constraint-compliance
#
# *Reasoning is required. No coding is needed; the code cell records the audit verdict.*
#
# An assignment says:
#
# > Compute `length` using elementwise multiplication and `np.sum`. Calls to `np.linalg`, `math.hypot`, `np.sqrt`, `** 0.5`, or any helper that reconstructs a square-root norm score zero. The deliverable is worth 6 points; a ban violation prices the whole problem at zero.
#
# A submission contains:
#
# ```python
# # line 1
# def hidden_norm(v):
#     # line 3
#     return np.sum(v * v) ** 0.5
#
# # line 6
# length = hidden_norm(x)
# ```
#
# Set `first_violation_line`, `verdict` (`"full-credit-eligible"` or `"zero"`), and `priced_points`. In 2–3 sentences, explain why moving the prohibited operation behind a helper does not change the price.
#
# **Banned (zero points): executing or rewriting the submission to discover the verdict.** This is a text audit.

# %%
first_violation_line = ...
verdict = ...
priced_points = ...

# %% [markdown]
# *Your 2–3 sentence audit here.*
