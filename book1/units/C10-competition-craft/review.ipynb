# %% [markdown]
# # C10-competition-craft — Review
#
# Work through this notebook *after* the four lesson sessions and
# (ideally) the practice sets.
# It is a consolidation tool: the concept summary, the craft checklists
# you should run before any submission, a self-quiz spanning every
# taught concept, and pointers to what to redo.
# Quiz answers are collapsed at the very end — commit to your answers
# before looking.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Concept summary
#
# | Concept | One-line summary | Key fact to retain | Session |
# |---|---|---|---|
# | `prediction-function-contract` | `predict_labels(X_test) -> pd.Series`: any-length feature DataFrame in; Series out — same length, same index, original order, training-vocabulary values | the grader aligns by index; any clause violation scores **zero** regardless of model quality | 1 |
# | `hidden-test-protocol` | the held-back split is regenerated deterministically for grading; your notebook never reads it | "hidden" is a protocol, not encryption — every reported number must be computable without the held-back rows | 1 |
# | `metric-driven-iteration` | macro-F1 (mean of per-class one-vs-rest F1s) judged on a frozen seeded stratified carve; baseline → error analysis → one change → re-validate, logged and capped | macro weighs classes equally, so accuracy > macro-F1 whenever the minority lags; selection on the carve inflates the estimate | 2 |
# | `notebook-discipline` | pin seeds, cell order = execution order, no dead cells, deterministic re-run | the audit: wrap the whole flow in a function, run twice, demand **exact** equality | 3 |
# | `writeup-quality` | one markdown cell: approach / intuition / alternatives, every claim backed by a printed number | the six-point rubric — recipe+protocol, data-grounded and task-grounded reasons, alternative-with-outcome + limitation | 3 |
# | `normal-form-answers` | Submit numeric and symbolic answers in the exact requested reduced/sign/identifier form | mathematically equivalent but nonconforming form can miss the register | 1–3 |
# | `api-constraint-compliance` | Required names, signatures, allowed APIs, and bans are executable grading conditions | a correct idea under a forbidden API or wrong identifier earns zero | 1–4 |
#
# ## The pre-submission checklists
#
# **The contract self-check (run on a mid-table probe):**
#
# ```python
# probe = X.iloc[300:340]                  # NOT the top of the table
# out = predict_labels(probe)
# isinstance(out, pd.Series)               # R3
# len(out) == len(probe)                   # R4 length
# out.index.equals(probe.index)            # R4 index
# set(out.unique()) <= set(np.unique(y))   # R5 vocabulary
# ```
#
# **Macro-F1 from the confusion matrix (rows=actual, cols=predicted,
# sorted label order):**
#
# ```python
# diag = np.diag(C).astype(float)
# prec = diag / C.sum(axis=0)              # column sums: predicted-as-k
# rec  = diag / C.sum(axis=1)              # row sums: actually-k
# f1   = 2 * prec * rec / (prec + rec)
# macro = f1.mean()
# ```
#
# **The frozen carve (this unit's pinned protocol):**
#
# ```python
# X_tr, X_val, y_tr, y_val = train_test_split(
#     X, y, test_size=150, random_state=SEED, stratify=y)
# ```
#
# **The determinism audit:**
#
# ```python
# def run_submission():
#     ...                                  # carve, fit, evaluate, predict
#     return val_f1, probe_preds
#
# a, b = run_submission(), run_submission()
# assert a[0] == b[0] and (a[1] == b[1]).all()    # EXACT, not isclose
# ```
#
# **The discipline rules:** D1 pin every seed · D2 cell order =
# execution order · D3 no dead cells · D4 deterministic re-run
# (Restart & Run All, twice, compare).
#
# **The writeup rubric (score your own before submitting):**
# W-A recipe with values / protocol with score · W-B model reason from
# the data / metric reason from the task · W-C alternative with
# outcome / honest limitation.
#
# ## Session 4 workflow review
#
# | Concept | One-line summary | Preflight evidence |
# |---|---|---|
# | `colab-markdown-solution-authoring` | Choose text cells for rendered claims and code cells for executable evidence; order them as one reproducible response | ordered mixed-cell plan plus rendered preview |
# | `markdown-code-snippets` | A multi-line excerpt needs matched triple backticks and a language label; it never replaces executable code | rendered `python` fence plus real definition |
# | `markdown-math-formulae` | Use inline math for symbols and display math for central formulae; define and interpret every symbol | rendered formula plus meaning sentence |
# | `colab-coding-submission` | Restart and Run All, inspect identifiers/outputs/files, download `.ipynb`, reopen the downloaded copy | passing checks and verified artifact |
# | `cpu-and-gpu-round-boundary` | Round 1 is CPU-only; Round 2 permits Colab L4/GPU | exact declaration with no later workflow assumed |
#
# ### Six-row submission checklist
#
# 1. **Writeup:** approach, intuition, alternatives; every number backed by output.
# 2. **Authoring:** each claim and computation is in the correct cell type and order.
# 3. **Fenced code:** matched `python` fence, plus executable required identifier elsewhere.
# 4. **Markdown math:** inline/display delimiters render; symbols and interpretation are present.
# 5. **Coding:** bounded selection, final refit, prediction contract, fresh run, outputs/files, download.
# 6. **Round policy:** Round 1 CPU only; Round 2 Colab L4/GPU allowed.
#
# ### Redo pointers for Session 4
#
# | Weak spot | Redo |
# |---|---|
# | cell types, fences, formula rendering | Session 4 §§1–4 → p15 |
# | fresh-run, identifiers, outputs, files, download | Session 4 §5 → p15 → p17 |
# | Round 1 CPU / Round 2 L4-GPU boundary | Session 4 §6 → p15, p17, p18 |
# | full six-row assembly | Session 4 §7 → p17 |
# | full six-row audit and repair | Session 4 §7 → p18 |
#
# ## Self-quiz
#
# Work every item on paper (and NumPy where asked) *before* opening the
# answers at the end.
#
# 1. **(prediction-function-contract)** Recite R1–R5 and explain why a mid-table probe catches an index reset that a top-of-table probe can miss.
# 2. **(hidden-test-protocol)** State the protocol in two sentences: one about what the student never touches and one about what the grader regenerates and scores.
# 3. **(metric-driven-iteration)** For a 2:1 task, explain why macro-F1 can be far below accuracy and why the validation carve must stay seeded, stratified, and frozen.
# 4. **(metric-driven-iteration)** State the selection-on-validation fact, the `max of noise` mechanism, and why a declared candidate cap belongs in the log.
# 5. **(notebook-discipline)** Name D1–D4 and the fresh-run failure each prevents; explain why the two-run audit demands exact equality.
# 6. **(writeup-quality)** Name all six rubric points and identify the contradiction in a writeup that reports k=11 scoring 0.81 but submits k=7 at 0.79 without explanation.
# 7. **(normal-form-answers)** A prompt requests `p/q` in lowest terms with `q > 0`; your calculation gives `-6/-8`. What exact answer is compliant, and why is `-6/-8` not?
# 8. **(api-constraint-compliance)** A correct prediction array is returned by `predict_label` using a banned estimator. Name both independent zero-point violations.
# 9. **(colab-markdown-solution-authoring)** Give the mixed-cell workflow from deliverable headings through the grader's fresh run of the downloaded notebook.
# 10. **(markdown-code-snippets)** Repair an unmatched Python fence and explain why the rendered excerpt cannot replace the executable `predict_labels`.
# 11. **(markdown-math-formulae)** Render macro-F1 as display mathematics, define `$K$` and `$F_{1,k}$`, and state its equal-class interpretation.
# 12. **(colab-coding-submission)** Name the observable evidence that replaces self-attested restart/download/output booleans: exact notebook name, fresh grader run, stage trace, and pinned file contents.
# 13. **(cpu-and-gpu-round-boundary)** Correct both claims: `GPU is always allowed in Colab` and `GPU is never allowed`.
# 14. **(integration)** For p17, state the exact baseline, four log rows, and what must happen after the final recipe is selected.
# 15. **(integration)** Why do p15, p17, and p18 use six separately scored rows, and which existing model-selection/writeup duties must p17 and p18 preserve?
#
# ## What to redo, per weak spot
#
# | Shaky on … | Redo |
# |---|---|
# | contract clauses + self-checks | Session 1 §3, §5; `p01`, `p05`, `p08` |
# | hidden-test protocol | Session 1 §4, §6; `p02`, `p09`, `p16` |
# | macro-F1 arithmetic | Session 2 §1–3; `p04`, `p07`, `p11` |
# | validation honesty + iteration | Session 2 §4–6; `p03`, `p12`, `p13` |
# | discipline + determinism | Session 3 §1–2; `p06`, `p10`, `p14` |
# | the writeup rubric | Session 3 §3–4; `p15`, `p18` |
# | the whole arc, timed | Session 3 §5; `p17` — then `mocktests/` |
#
# ## Quiz answers
#
# <details><summary><b>Answers 1–15</b> (open only after committing to yours)</summary>
#
# 1. R1 exact name; R2 any input length; R3 `pd.Series`; R4 same length, index, and order; R5 training-vocabulary labels. Resetting an already `0..n-1` index hides the error, while a mid-table index exposes it.
# 2. The student never reads, prints, or uses held-back rows. The grader regenerates them deterministically and scores `predict_labels` once.
# 3. Macro-F1 gives each class equal weight, so a weak minority class is not hidden by majority accuracy. The carve stays seeded, stratified, and frozen so comparisons use one reproducible class-balanced protocol.
# 4. Repeatedly selecting on one carve makes the surviving score optimistic; the mechanism is `max of noise`. A candidate cap limits that selection pressure and makes the campaign auditable.
# 5. D1 seeds prevent run-to-run drift; D2 order prevents stale dependencies; D3 no dead cells prevents fresh-run crashes; D4 exact two-run agreement exposes remaining nondeterminism. Same code/data/environment owes exact equality.
# 6. W-A1 recipe, W-A2 protocol+score, W-B1 data-grounded model reason, W-B2 task-grounded metric reason, W-C1 measured alternative, W-C2 limitation. The reported winner contradicts the submitted k with no stated reason.
# 7. `3/4`: multiply numerator and denominator by `-1`, then reduce by 2. `-6/-8` is not lowest terms and has a negative denominator.
# 8. The identifier violates the exact name (`predict_label` versus `predict_labels`), and the estimator violates the explicit API ban. Either independently triggers zero.
# 9. Outline text-cell deliverables; insert code evidence; run while drafting; remove dead cells; preview rendered cells; package exact outputs; submit the exact `.ipynb`, which the grader opens and runs fresh.
# 10. Use opening triple backticks plus `python`, the body on separate lines, and a matching close. A rendered fence communicates code but never defines the callable identifier.
# 11. `F_{1,\mathrm{macro}} = \frac{1}{K}\sum_{k=1}^{K}F_{1,k}`; `$K$` is the number of classes and `$F_{1,k}$` is class k's F1, so classes receive equal weight.
# 12. The submitted file has the exact required name; the grader executes it fresh; immutable checks inspect the ordered stage trace and reload exact-schema artifacts to compare their contents with in-memory results.
# 13. Round 1 is CPU-only. Round 2 permits the Colab L4/GPU environment; this permission does not itself teach the later workflow.
# 14. Baseline is scaled 5-NN on all 12 features; rows are baseline, iter-1, iter-2, iter-3. After selection, refit the chosen pipeline on all labeled rows, expose `predict_labels`, and package the pinned outputs.
# 15. Separate rows make each workflow concept independently gradable. p17/p18 must still preserve bounded selection, honest validation, final refit, packaged predictions, and an approach/intuition/alternatives writeup.
#
# </details>
