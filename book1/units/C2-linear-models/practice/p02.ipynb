# %% [markdown]
# # C2-linear-models — Practice p02
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** mse-loss
#
# A model produced predictions $\hat y = (2, 5, 3)$ for targets
# $y = (1, 3, 3)$, with
# $\mathrm{MSE} = \frac{1}{n}\sum_i (\hat y_i - y_i)^2$.
#
# What is the MSE?
#
# A. $1$
#
# B. $5/3$
#
# C. $5/2$
#
# D. $3$
#
# E. $5$
#
# Reasoning is not required. Record your choice below.

# %%
import numpy as np

answer_p02 = "?"  # replace with "A".."E"
