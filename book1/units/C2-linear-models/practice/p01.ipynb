# %% [markdown]
# # C2-linear-models — Practice p01
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** linear-regression
#
# A linear model $\hat y_i = \sum_k X_{ik} w_k + b$ has weights
# $w = (2, -1)$ and bias $b = 3$.
#
# What does it predict for an example with feature row $x = (4, 5)$?
#
# A. $-2$
#
# B. $3$
#
# C. $6$
#
# D. $8$
#
# E. $13$
#
# Reasoning is not required. Record your choice below.

# %%
import numpy as np

answer_p01 = "?"  # replace with "A".."E"
