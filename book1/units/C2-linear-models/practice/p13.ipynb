# %% [markdown]
# # C2-linear-models — Practice p13
#
# **Type:** integrative · **Difficulty:** core · **Concepts:** linear-regression, mse-loss, l2-regularization, residuals, partial-derivatives, gradient, sum-of-squares-gradients, broadcasting, aggregation-axis
#
# A three-part arc; each part consumes the previous one.
#
# $$X = \begin{pmatrix} 1 & 0 \\ 2 & 1 \\ 0 & 1 \\ 1 & 2 \end{pmatrix},
# \qquad y = (3, 3, 1, 4), \qquad w = (1, 1), \qquad b = 1 .$$
#
# **(a) By hand** (then confirm in code): compute the predictions, the
# residuals $r_i = \hat y_i - y_i$, and the MSE.
# Set `preds`, `resid`, `mse_hand` accordingly.
#
# **(b)** Write `mse_grad_w(X, y, w, b)` (shape `(2,)`,
# $\frac{2}{n}\sum_i r_i X_{ij}$) and `mse_grad_b(X, y, w, b)` (scalar,
# $\frac{2}{n}\sum_i r_i$).
# **Banned inside both (zero points): `@`, `np.matmul`, `np.dot`, `.T`,
# `np.einsum`, `np.inner`, `np.tensordot`, any `np.linalg` function, any
# loop.**
# Evaluate both at the given weights (`grad_w`, `grad_b`) and compute
# `check_gap` against central differences of the MSE with $h = 10^{-6}$
# (the checker MAY loop).
# Cross-check `grad_w` against a hand computation using (a)'s residuals.
#
# **(c)** For $\lambda = 0.5$, the ridge gradient adds the penalty pull:
# compute `ridge_grad = grad_w + 2 * lam * w` (consuming (b)'s result),
# then `diff_vec = ridge_grad - grad_w` and
# `formula_gap` — the max abs difference between `diff_vec` and the
# predicted $2\lambda w$.
# In one sentence, compare the penalty pulls felt by the two features at
# these weights and explain why they come out the way they do.

# %%
import numpy as np

X = np.array([[1.0, 0.0],
              [2.0, 1.0],
              [0.0, 1.0],
              [1.0, 2.0]])
y = np.array([3.0, 3.0, 1.0, 4.0])
w = np.array([1.0, 1.0])
b = 1.0
lam = 0.5

# (a)
preds = ...     # YOUR CODE HERE
resid = ...     # YOUR CODE HERE
mse_hand = ...  # YOUR CODE HERE


# (b)
def mse_grad_w(X, y, w, b):
    # YOUR CODE HERE (banned: @, np.matmul, np.dot, .T, np.einsum, loops)
    ...


def mse_grad_b(X, y, w, b):
    # YOUR CODE HERE (same bans)
    ...


grad_w = ...     # YOUR CODE HERE
grad_b = ...     # YOUR CODE HERE
check_gap = ...  # YOUR CODE HERE (checker MAY loop)

# (c)
ridge_grad = ...   # YOUR CODE HERE
diff_vec = ...     # YOUR CODE HERE
formula_gap = ...  # YOUR CODE HERE

# %% [markdown]
# *Your one-sentence answer for (c) here.*
