# %% [markdown]
# # C2-linear-models — Practice p03 — Solution

# %%
import numpy as np

lam = 1.0
l1_pull_near_zero = lam
l2_pull_at_zero = 0.0
exact_zero_supported = (l1_pull_near_zero > 0.0) and (l2_pull_at_zero == 0.0)
claim_matches = np.array([False, False, exact_zero_supported, False, False])
answer_p03 = str(np.array(list("ABCDE"))[np.flatnonzero(claim_matches)[0]])

# %% [markdown]
# The absolute-value penalty retains a pull of magnitude $\lambda$ on either side of zero, allowing the kink to contain the optimum when the data pull is weak. The squared penalty's pull approaches zero with the weight, so the accurate statement is C.

# %% [markdown]
# ### Answer check

# %%
assert exact_zero_supported
assert answer_p03 == "C"
