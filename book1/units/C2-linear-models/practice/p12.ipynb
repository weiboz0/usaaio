# %% [markdown]
# # C2-linear-models — Practice p12
#
# **Type:** proof · **Difficulty:** core · **Concepts:** l2-regularization
#
# **Reasoning is required.**
#
# The one-dimensional ridge loss is
# $$g(w) \;=\; (w - a)^2 \;+\; \lambda\,w^2, \qquad \lambda \ge 0 .$$
#
# **(a)** Derive the exact minimizer by ordinary Calc AB differentiation:
# show $w^\* = \dfrac{a}{1 + \lambda}$, and justify that it is a minimum
# (not merely a critical point).
#
# **(b)** Show that for $a \ne 0$ the minimizer is *never* exactly zero,
# for any $\lambda \ge 0$: argue directly from your formula, **and**
# separately by evaluating $g'(0)$ and explaining why a point with
# $g'(0) \ne 0$ cannot be the minimum of a differentiable function.
# Conclude in one sentence what this means for L2's ability to produce
# sparsity, in contrast with the L1 case analysis of p11.
#
# **(c) Concrete anchor:** for $(a, \lambda) = (3, 2)$ compute
# `w_star_hand` from your formula, `w_star_grid` — the argmin of $g$ over
# `grid = np.linspace(-1, 3, 400001)` — and
# `anchor_gap = abs(w_star_hand - w_star_grid)` (should be
# $\le 10^{-5}$).

# %% [markdown]
# *Your derivation for (a) and argument for (b) here.*

# %%
import numpy as np

# (c) YOUR CODE HERE
w_star_hand = ...
w_star_grid = ...
anchor_gap = ...
