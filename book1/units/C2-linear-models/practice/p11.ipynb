# %% [markdown]
# # C2-linear-models — Practice p11
#
# **Type:** proof · **Difficulty:** advanced · **Concepts:** l1-regularization, sparsity
#
# **Reasoning is required.**
#
# The one-dimensional penalized loss
# $$f(w) \;=\; (w - a)^2 \;+\; \lambda\,|w|, \qquad \lambda \ge 0,$$
# is this unit's laboratory for L1 regularization: $a$ is where the data
# term alone would put the weight.
#
# **(a)** Derive the exact minimizer $w^\*(a, \lambda)$ by Calc AB case
# analysis: treat the regions $w > 0$ and $w < 0$ with ordinary
# derivatives (stating each candidate's admissibility condition), and
# treat the kink $w = 0$ with one-sided slopes ($f$ has a minimum there
# exactly when the right-hand slope is $\ge 0$ and the left-hand slope is
# $\le 0$).
# Assemble the three cases into the complete formula, and verify the cases
# agree at the boundary $|a| = \lambda/2$.
# Every step justified.
#
# **(b)** State the exact condition under which $w^\* = 0$, and explain in
# two or three sentences — using the one-sided slopes from (a) — why the
# absolute-value penalty can hold the minimum at *exactly* zero while the
# squared penalty $\lambda w^2$ (whose derivative at $0$ is $0$) cannot.
#
# **(c) Concrete anchors:** verify numerically.
# For $(a, \lambda) = (3, 4)$ compute `w_star_hand` from your formula and
# `w_star_grid` — the argmin of $f$ over
# `grid = np.linspace(-2, 4, 600001)` — and
# `anchor_gap = abs(w_star_hand - w_star_grid)` (should be $\le 10^{-5}$).
# For $(a, \lambda) = (1.5, 4)$ compute `w_star_zero` from your formula
# (it should be exactly `0.0`) and check the grid argmin agrees.

# %% [markdown]
# *Your derivation for (a) and argument for (b) here.*

# %%
import numpy as np

# (c) YOUR CODE HERE
w_star_hand = ...
w_star_grid = ...
anchor_gap = ...
w_star_zero = ...
