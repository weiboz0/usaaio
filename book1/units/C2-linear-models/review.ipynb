# %% [markdown]
# # C2-linear-models — Review
#
# Use this after all three lessons and, ideally, the practice sets.
# Commit to the quiz before opening the collapsed answers.

# %%
import numpy as np

# %% [markdown]
# ## Concept summary
#
# | Concept | Summary | Key fact |
# |---|---|---|
# | Linear model | explicit bias or augmented design | use a ones column or separate $b$, never both |
# | MSE/gradient | $L=\lVert X\beta-y\rVert^2/n$ | for $r=X\beta-y$, $\nabla L=(2/n)X^Tr$ |
# | Normal equations | $X^TX\hat\beta=X^Ty$ | equivalent to $X^T\hat r=0$ |
# | Rank | independent columns | full rank iff Gram is positive definite/invertible; $n>p$ is insufficient |
# | Consistency | exact fit versus closest fit | $X\beta=y$ may be inconsistent while least squares still exists |
# | Pseudoinverse | $\beta^+=X^+y$ | minimum-norm minimizer; all minimizers are $\beta^++\mathcal N(X)$ |
# | Projectors | $XX^+$ and $X^+X$ | project onto column and row spaces |
# | L2 | squared-weight charge | shrinking pull $2\lambda w_k$ fades near zero |
# | L1 | absolute-weight charge | constant one-sided pull creates exact zeros |
# | Sparsity | exactly zero coefficients | rounded display is not evidence |
#
# ## Formula and idiom sheet
#
# Explicit bias:
# $\hat y_i=\sum_kX_{ik}w_k+b$.
# Augmented design:
# $X:(n,p)$, $\beta=(b,w_1,\ldots,w_d)^T:(p,)$,
# $y:(n,)$. Residuals are predictions minus targets.
#
# \[
# L(\beta)=\frac1n\lVert X\beta-y\rVert^2,\qquad
# \nabla_\beta L=\frac2nX^T(X\beta-y).
# \]
# \[
# X^TX\hat\beta=X^Ty
# \Longleftrightarrow X^T\hat r=0.
# \]
# Also,
# $v^TX^TXv=\lVert Xv\rVert^2$.
#
# Under a full-column-rank contract:
#
# \`\`\`python
# beta = np.linalg.solve(X.T @ X, X.T @ y)
# \`\`\`
#
# Do not form \`np.linalg.inv(X.T @ X)\`.
# At general rank:
#
# \`\`\`python
# beta_plus = np.linalg.pinv(X) @ y
# P_col = X @ np.linalg.pinv(X)
# P_row = np.linalg.pinv(X) @ X
# \`\`\`
#
# Every minimizer is $\beta^++z$, $z\in\mathcal N(X)$, and
# \[
# \lVert\beta^++z\rVert^2
# =\lVert\beta^+\rVert^2+\lVert z\rVert^2.
# \]
#
# Regularization:
#
# - ridge adds $\lambda\sum_kw_k^2$ and gradient pull
#   $2\lambda w_k$; 1-D minimizer $a/(1+\lambda)$;
# - lasso adds $\lambda\sum_k|w_k|$; 1-D minimizer is zero when
#   $|a|\le\lambda/2$, otherwise
#   $a-\operatorname{sign}(a)\lambda/2$;
# - this course excludes the bias from both penalties.
#
# Numerical discipline:
#
# \`\`\`python
# ATOL = 1e-10
# RTOL = 0.0
# np.allclose(X.T @ (X @ beta - y), 0.0, atol=ATOL, rtol=RTOL)
# \`\`\`
#
# ## Self-quiz
#
# Fifteen items cover all taught concepts.
#
# 1. A raw array is \`(40, 3)\` and needs an intercept. Give augmented
#    shapes of $X$, $\beta$, $X^Ty$, and $X^TX$.
# 2. Derive the MSE gradient, including its factor and shape.
# 3. State the normal equations and residual-orthogonality form; explain
#    why the residual can be nonzero.
# 4. Distinguish inconsistency of $X\beta=y$ from existence of a
#    least-squares minimizer.
# 5. Prove $X^TX$ is positive semidefinite and state what makes it
#    positive definite.
# 6. Refute “$n>p$ implies unique coefficients” with a matrix and null
#    vector.
# 7. Name the required full-rank NumPy solver and the banned tempting
#    inverse route.
# 8. State $\beta^+=X^+y$ and its residual-norm and coefficient-norm
#    optimality properties.
# 9. If $z\in\mathcal N(X)$, what changes under
#    $\beta\mapsto\beta+z$?
# 10. What do $XX^+$ and $X^+X$ project onto, and why do their identities
#     need explicit tolerances?
# 11. In one sentence, contrast Session 1 evaluation, Session 2
#     closed-form fitting, and C3 iterative fitting.
# 12. Give ridge's gradient pull and compute its 1-D minimizer for
#     $a=6,\lambda=2$.
# 13. Compute lasso's 1-D minimizers for $(a,\lambda)=(4,2)$ and
#     $(-1,3)$; state the general zero threshold.
# 14. Explain why L1 can create exact zeros while L2 usually only shrinks.
# 15. For stored weights \`[0.011, -0.004, 2.099, 0.0]\`, count exact
#     zeros, give the NumPy expression, and explain why a rounded display
#     is insufficient.
#
# ## What to redo
#
# | Weak spot | Redo | Reread |
# |---|---|---|
# | model/MSE/gradient (1–3) | p01, p02, p05, p09, p13 | Session 1; Session 2 §1 |
# | consistency/rank (4–6) | p19, p21, p22 | Session 2 §1–3 |
# | solve/pseudoinverse (7–10) | p20, p23, p24 | Session 2 §2–6 |
# | workflow boundary (11) | p13, p20, p23 | Sessions 1–2; C3 preview |
# | L2/L1/sparsity (12–15) | p03, p07, p08, p10–p12, p15, p17 | Session 3 §2–7 |
#
# ## Self-quiz answers
#
# <details><summary><b>Click to reveal</b></summary>
#
# 1. $X:(40,4)$, $\beta:(4,)$, $X^Ty:(4,)$, $X^TX:(4,4)$.
# 2. $(2/n)X^T(X\beta-y)$, shape $(p,)$.
# 3. $X^TX\hat\beta=X^Ty$ and $X^T\hat r=0$; the residual can be a
#    nonzero vector perpendicular to $\operatorname{col}(X)$.
# 4. Exact consistency requires $y\in\operatorname{col}(X)$; projection
#    gives a least-squares minimizer for every $y$.
# 5. $v^TX^TXv=\lVert Xv\rVert^2\ge0$; full column rank makes this
#    strictly positive for every $v\ne0$.
# 6. $X=\begin{pmatrix}1&2\\2&4\\3&6\end{pmatrix}$ with
#    $v=(-2,1)^T$.
# 7. \`np.linalg.solve(X.T @ X, X.T @ y)\`; forming
#    \`np.linalg.inv(X.T @ X)\` is banned.
# 8. It minimizes residual norm and, among all residual minimizers,
#    uniquely minimizes coefficient norm.
# 9. Coefficients change; predictions, residuals, and MSE do not.
# 10. Column and row spaces, respectively; floating-point roundoff
#     requires declared \`atol\`/\`rtol\`.
# 11. Session 1 evaluates/differentiates supplied parameters; Session 2
#     computes closed-form OLS; C3 updates parameters iteratively.
# 12. Pull $2\lambda w_k$; minimizer $6/(1+2)=2$.
# 13. $3$ and $0$; zero iff $|a|\le\lambda/2$.
# 14. L1's one-sided pull keeps constant magnitude at the origin, while
#     L2's $2\lambda w$ pull fades to zero.
# 15. One; \`int((w == 0).sum())\`; formatting can print a nonzero value
#     as zero.
#
# </details>
