# %% [markdown]
# # C2-linear-models — Linear Models, Closed-Form OLS, and Regularization
#
# This index maps the unit's three lesson sessions, 24 practice problems,
# and review.
#
# ## Unit goals
#
# By the end of C2 you can:
#
# - compute $\hat y_i=\sum_k X_{ik}w_k+b$, residuals
#   $r_i=\hat y_i-y_i$, MSE, and gradients at supplied weights;
# - move between an explicit bias and the augmented design convention
#   $X:(n,p)$, $\beta:(p,)$, with a ones column for the intercept;
# - derive $\nabla_\beta L=(2/n)X^T(X\beta-y)$, the normal equations
#   $X^TX\hat\beta=X^Ty$, and residual orthogonality $X^T\hat r=0$;
# - distinguish exact consistency from least squares and distinguish
#   existence from coefficient uniqueness/identifiability;
# - prove full column rank iff $X^TX$ is positive definite/invertible,
#   while rejecting the false shortcut $n>p$;
# - implement full-rank OLS with \`np.linalg.solve\`, never a blind Gram
#   inverse;
# - use $X^+y$ for general-rank least squares, characterize the nullspace
#   family, and prove the pseudoinverse solution is minimum norm;
# - interpret $XX^+$ and $X^+X$ as projectors, using explicit numerical
#   tolerances;
# - evaluate L2/L1 penalties, derive their 1-D closed forms, and explain
#   why L1 creates exact sparsity while L2 shrinks.
#
# ## Prerequisites
#
# F1 supplies NumPy/broadcasting; F2 and F3 supply norms,
# orthogonality, matrix maps, column spaces, rank, and projections; F4
# supplies gradients and sum-of-squares derivatives; C1 supplies
# train/test scoreboards and overfitting. Calculus AB supplies derivatives,
# case analysis, and one-sided limits.
#
# ## Session map
#
# | Session | Notebook | Time | Covers |
# |---|---|---:|---|
# | 1 | \`lessons/01-linear-regression-and-mse.ipynb\` | ~85 min | prediction; residuals/MSE; train/test scoreboards; gradients; residual orthogonality |
# | 2 | \`lessons/02-normal-equations-rank-pseudoinverse.ipynb\` | ~90 min | augmented design; normal equations; rank/Gram equivalence; consistency; solve; pseudoinverse; nullspaces/projectors; tolerances |
# | 3 | \`lessons/03-regularization-and-sparsity.ipynb\` | ~85 min | L2/L1 penalties; ridge and soft-threshold closed forms; sparsity; supplied regularization paths |
#
# ## Practice sets
#
# Twenty-four statement notebooks live in \`practice/\`.
#
# **Set A — fundamentals:** \`p01\`, \`p02\`, \`p05\`, and \`p09\`
# cover prediction, residuals, and MSE after Session 1.
#
# **Set B — exam register:** \`p03\`–\`p04\`, \`p06\`–\`p08\`,
# \`p10\`–\`p12\` cover gradients and regularization.
# After Session 2, \`p19\` derives the estimator,
# \`p20\` implements full-rank solve, \`p22\` proves the rank/Gram
# equivalence, and \`p23\` implements general-rank pseudoinverse OLS.
#
# **Set C — integration/challenge:** \`p13\`–\`p18\` integrate the
# original unit. \`p21\` consumes an exact normal-system derivation in a
# controlled numerical check; \`p24\` proves the complete nullspace family
# and minimum-norm claim.
#
# ## How to study
#
# 1. Run Session 1; solve the Set A problems.
# 2. Run Session 2 with dimensions beside every expression; solve
#    \`p19\`–\`p23\`, preserving the required proofs.
# 3. Run Session 3; complete the remaining Set B work.
# 4. Do Set C under time pressure, especially \`p21\` and \`p24\`.
# 5. Finish with \`review.ipynb\` and use its weak-spot redo table.
#
# Budget: 260 lesson minutes + 590 practice minutes + 55 review minutes =
# 905 total.

# %%
# Environment check — this unit needs numpy and matplotlib (installed with F1).
import numpy as np
import matplotlib

print("numpy", np.__version__, "| matplotlib", matplotlib.__version__)
