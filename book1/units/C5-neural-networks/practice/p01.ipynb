# %% [markdown]
# # C5-neural-networks — Practice p01
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** perceptron
#
# A perceptron has weights $w = (3, -2)$ and bias $b = -4$, with this
# course's threshold convention (output $1$ exactly when the pre-activation
# $z = \sum_k w_k x_k + b$ satisfies $z \ge 0$).
#
# For the input $x = (2, 1)$, which statement is correct?
#
# A. $z = 0$ and the output is $0$.
#
# B. $z = 0$ and the output is $1$.
#
# C. $z = 4$ and the output is $1$.
#
# D. $z = -4$ and the output is $0$.
#
# E. $z = 8$ and the output is $1$.
#
# Reasoning is not required. Record your choice below.

# %%
import numpy as np

answer_p01 = "?"  # replace with "A".."E"
