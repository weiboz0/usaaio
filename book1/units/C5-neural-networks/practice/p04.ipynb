# %% [markdown]
# # C5-neural-networks — Practice p04
#
# **Type:** multiple choice (numeric, normal form) · **Difficulty:** core · **Concepts:** mlp-architecture
#
# A $2 \to 2 \to 1$ network takes $x = (1, 2)$.
# The hidden layer has weights
# $W^{(1)} = \begin{pmatrix} 2 & -1 \\ -1 & 1 \end{pmatrix}$ (row $j$ holds
# the weights of hidden unit $j$), bias $b^{(1)} = (-1, 1)$, and **step**
# activation ($1$ if the pre-activation is $\ge 0$, else $0$).
# The output layer is affine — no activation — with weights
# $w^{(2)} = (4, 5)$ and bias $b^{(2)} = -\tfrac52$.
#
# The output $y$ is a positive rational number.
# Write it in lowest terms as $y = p/q$ with $\gcd(p, q) = 1$ and $q > 0$.
# What is $p + q$?
#
# A. 6
#
# B. 7
#
# C. 9
#
# D. 15
#
# E. 17
#
# Reasoning is not required. Record your choice below.

# %%
import numpy as np

answer_p04 = "?"  # replace with "A".."E"
