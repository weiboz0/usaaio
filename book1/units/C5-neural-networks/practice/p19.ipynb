# %% [markdown]
# # C5-neural-networks — Practice p19
#
# **Type:** drill · **Difficulty:** intro · **Concepts:** threshold-activation
#
# Threshold reflexes: evaluate first by hand, then let NumPy referee.
#
# **Task A.** For
# `z_list = [-3.5, -1.0, 0.0, 0.25, 2.0, -0.001]`, write the step
# activation's outputs (course convention: fire on $z \ge 0$) **by hand**
# as `step_by_hand`, a Python list of six `1.0`/`0.0` values, and
# `n_fire_by_hand`, the int count of firing entries.
#
# **Task B.** For the fixed pre-activation matrix
#
# $$Z = \begin{pmatrix} 1.5 & -2.0 & 0.0 \\ -0.5 & 3.0 & -0.25 \end{pmatrix},$$
#
# fill `H_by_hand`, a nested Python list (2 rows × 3 columns) of the step
# outputs, by hand.
#
# **Task C.** Implement `step_activation(z)` (elementwise, floats) and
# compute `step_vals = step_activation(np.array(z_list))` and
# `H = step_activation(Z)`.
# Print comparisons against your hand answers — every entry must agree
# before you move on.

# %%
import numpy as np

z_list = [-3.5, -1.0, 0.0, 0.25, 2.0, -0.001]
Z = np.array([[1.5, -2.0, 0.0], [-0.5, 3.0, -0.25]])

step_by_hand = ...    # YOUR CODE HERE — list of six 1.0/0.0
n_fire_by_hand = ...  # YOUR CODE HERE — int

H_by_hand = ...       # YOUR CODE HERE — nested list, 2 x 3


def step_activation(z):
    # YOUR CODE HERE
    ...


step_vals = ...       # YOUR CODE HERE
H = ...               # YOUR CODE HERE
# print your comparisons here
