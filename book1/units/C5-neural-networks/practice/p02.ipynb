# %% [markdown]
# # C5-neural-networks — Practice p02
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** threshold-activation, activation-functions
#
# This unit's three activation functions are the step
# ($\mathrm{step}(z) = 1$ if $z \ge 0$, else $0$), $\tanh$, and
# $\mathrm{relu}(z) = \max(z, 0)$.
#
# Which statement is correct?
#
# A. $\mathrm{step}(0) = 0$, because only strictly positive pre-activations
# fire.
#
# B. $\mathrm{relu}(-3) = -3$ and $\mathrm{relu}(3) = 3$: ReLU passes every
# input through unchanged.
#
# C. $\mathrm{step}(0) = 1$, $\mathrm{relu}(-3) = 0$, and every $\tanh$
# output lies strictly between $-1$ and $1$.
#
# D. $\tanh(0) = 1$, so $\tanh$ fires on the boundary just like the step.
#
# E. $\mathrm{step}(2.7) = 2.7$: for nonnegative inputs the step returns the
# pre-activation itself.
#
# Reasoning is not required. Record your choice below.

# %%
import numpy as np

answer_p02 = "?"  # replace with "A".."E"
