# %% [markdown]
# # C5-neural-networks — Practice p21
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** perceptron
#
# *Coding is required.*
#
# A perceptron's decision boundary passes through \(A=(5,4)\) and \(B=(16,11)\). The point \(P=(20,7)\) must be on the firing side and \(N=(3,9)\) on the non-firing side. The course convention is \(y=1\) when \(w\cdot x+b\ge0\).
#
# Find the **primitive integer** representation: `w` is a NumPy array of two integers with \(\gcd(|w_0|,|w_1|)=1\), and `b` is an integer; choose the sign so \(P\) fires. Set `boundary_scores` for \(A,B\), `probe_scores` for \(P,N\), and `probe_outputs` using the supplied activation. In 2–3 sentences, connect the segment direction \(B-A\) to your normal vector.
#
# **Banned (zero points): training or optimizing a classifier, searching over candidate weights, calling a geometry/linear-algebra solver, or hardcoding `probe_outputs` without computing `probe_scores`.**

# %%
import numpy as np

A = np.array([5, 4])
B = np.array([16, 11])
P = np.array([20, 7])
N = np.array([3, 9])


def step_activation(z):
    return (z >= 0).astype(int)


w = ...               # YOUR CODE HERE, shape (2,), integer dtype
b = ...               # YOUR CODE HERE, int
boundary_scores = ... # YOUR CODE HERE, shape (2,)
probe_scores = ...    # YOUR CODE HERE, shape (2,)
probe_outputs = ...   # YOUR CODE HERE, shape (2,)

# %% [markdown]
# *Your 2–3 sentence geometric explanation here.*
