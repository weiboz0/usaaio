# %% [markdown]
# # C5-neural-networks — Practice p15
#
# **Type:** scenario analysis · **Difficulty:** core · **Concepts:** threshold-activation
#
# A teammate implements the step activation as `(z > 0).astype(float)` —
# strict inequality — and their region counts disagree with the answer key.
# You referee.
#
# The setting: the detector $w = (1, -1)$, $b = 0$ (fires when
# $x_1 \ge x_2$) evaluated on the $6 \times 6$ integer grid built below
# (all 36 points $(x_1, x_2)$ with $x_1, x_2 \in \{0, \dots, 5\}$).
#
# **(a)** Compute `n_ge` = how many grid points fire under the course
# convention `(z >= 0)`, and `n_gt` = how many fire under the teammate's
# `(z > 0)` — both **ints**, computed vectorized from `z_grid`.
#
# **(b)** `n_disagree` = the int number of grid points where the two
# versions differ, computed from the two label arrays (not by subtraction of
# counts).
#
# **(c)** In the markdown cell (2–3 sentences): characterize geometrically
# *which* points disagree, explain why hand-designed integer problems hit
# this set constantly, and state the fix (which convention this course and
# its exam register pin, and the one-character change).
#
# **Banned (zero points): loops.**

# %%
import numpy as np

g = np.arange(6)
X1, X2 = np.meshgrid(g, g, indexing="ij")
grid_pts = np.stack([X1.ravel(), X2.ravel()], axis=1).astype(float)   # (36, 2)
z_grid = grid_pts[:, 0] - grid_pts[:, 1]                              # detector pre-activations

n_ge = ...       # YOUR CODE HERE — int
n_gt = ...       # YOUR CODE HERE — int
n_disagree = ... # YOUR CODE HERE — int

# %% [markdown]
# *Your (c) diagnosis here (2–3 sentences).*
