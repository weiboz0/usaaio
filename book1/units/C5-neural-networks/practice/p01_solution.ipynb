# %% [markdown]
# # C5-neural-networks — Practice p01 — Solution

# %% [markdown]
# The pre-activation is $z=3(2)-2(1)-4=0$.  The course convention uses $z\geq 0$, so a boundary value fires and the answer is **B**.
#
# - A has the right pre-activation but incorrectly uses a strict threshold.
# - C omits or misapplies part of the weighted sum: the result is not $4$.
# - D treats the bias as the whole pre-activation.
# - E ignores the negative-weight contribution and bias.

# %%
import numpy as np

SEED = 20260804
answer_p01 = "B"
z_value = 3.0 * 2.0 + (-2.0) * 1.0 - 4.0
output = float(z_value >= 0)
answer_p01, z_value, output

# %% [markdown]
# ### Answer check

# %%
assert answer_p01 == "B"
assert np.isclose(z_value, 0.0, atol=1e-12, rtol=0)
assert np.isclose(output, 1.0, atol=1e-12, rtol=0)
