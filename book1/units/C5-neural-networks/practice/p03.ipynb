# %% [markdown]
# # C5-neural-networks — Practice p03
#
# **Type:** multiple choice · **Difficulty:** core · **Concepts:** relu-activation
#
# Define
# $$f(z) = \mathrm{relu}(z - 1) - \mathrm{relu}(z - 3).$$
#
# Which statement describes $f$?
#
# A. $f(z) = 0$ for every $z \le 3$, and $f$ grows with slope $1$ for
# $z > 3$.
#
# B. $f$ is $0$ for $z \le 1$, grows with slope $1$ on $1 \le z \le 3$, and
# is constant at $2$ for $z \ge 3$.
#
# C. $f$ is $0$ for $z \le 1$ and grows with slope $1$ for all $z \ge 1$:
# the two terms never interact.
#
# D. $f$ is $0$ for $z \le 1$, grows with slope $1$ on $1 \le z \le 3$, and
# is constant at $3$ for $z \ge 3$.
#
# E. $f(2) = -1$: between the kinks the subtracted term dominates.
#
# Reasoning is not required. Record your choice below.

# %%
import numpy as np

answer_p03 = "?"  # replace with "A".."E"
