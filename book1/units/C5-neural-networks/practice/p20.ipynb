# %% [markdown]
# # C5-neural-networks — Practice p20
#
# **Type:** drill · **Difficulty:** intro · **Concepts:** perceptron
#
# Three perceptrons, three points — the full evaluation table, by hand
# first.
#
# The three units (weights, bias): unit 1: $w = (1, 1)$, $b = -2$;
# unit 2: $w = (2, -1)$, $b = 0$; unit 3: $w = (-1, 3)$, $b = -3$.
# The three input points: $(0, 0)$, $(2, 1)$, $(1, 3)$.
#
# **Task A.** Fill `outputs_by_hand`, a nested Python list of shape
# $3 \times 3$ where **row $i$ = input point $i$** and **column $j$ = unit
# $j$** (this matches `affine_layer`'s output orientation: points are rows,
# units are columns).
# Course convention: fire on $z \ge 0$.
#
# **Task B.** Stack the three units into `W` (shape `(3, 2)`, row $j$ =
# unit $j$) and `b` (shape `(3,)`), stack the points into `X` (shape
# `(3, 2)`), and compute `outputs = step_activation(affine_layer(X, W, b))`
# with the given helpers.
# Print `outputs` next to your hand table — every entry must agree.
#
# **Task C.** One entry of the table comes from a pre-activation of exactly
# $0$. Say which (point, unit) it is in the markdown cell — and check that
# your hand table scored it as firing.

# %%
import numpy as np


# Given — the unit's pinned helpers (Session 2). Do not modify.
def affine_layer(x, W, b):
    """Pre-activations z[i, j] = sum_k x[i, k] * W[j, k] + b[j].

    x: (n, d_in)   W: (d_out, d_in)   b: (d_out,)   ->   (n, d_out)
    """
    return (x[:, None, :] * W[None, :, :]).sum(axis=2) + b


def step_activation(z):
    """Threshold activation, elementwise: 1.0 where z >= 0, else 0.0."""
    return (z >= 0).astype(float)

X = ...  # YOUR CODE HERE — shape (3, 2), the three points as rows
W = ...  # YOUR CODE HERE — shape (3, 2), row j = unit j
b = ...  # YOUR CODE HERE — shape (3,)

outputs_by_hand = ...  # YOUR CODE HERE — nested 3 x 3 list
outputs = ...          # YOUR CODE HERE — via the helpers
# print your comparison here

# %% [markdown]
# *Your Task C answer here.*
