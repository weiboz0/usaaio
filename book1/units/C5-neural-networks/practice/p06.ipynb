# %% [markdown]
# # C5-neural-networks — Practice p06
#
# **Type:** constrained coding · **Difficulty:** intro · **Concepts:** activation-functions
#
# Implement the unit's activation vocabulary, exactly to contract.
#
# **(a)** Write `step_activation(z)` — elementwise threshold, returning
# **floats** (`1.0` where `z >= 0`, else `0.0`), any input shape preserved —
# and `relu(z)` — elementwise $\max(z, 0)$, shape preserved.
#
# **(b)** Apply them to the fixed vector `z_vec` below:
# `step_vals`, `relu_vals`, and `tanh_vals` (use `np.tanh`).
#
# **(c)** For the seeded matrix `Z`: `n_fired` = the **int** number of
# entries the step activation fires on, and `relu_total` = the **float** sum
# of all ReLU outputs.
#
# **Banned (zero points): loops, `np.vectorize`, `np.where`, `np.select`,
# `np.piecewise`, `np.heaviside`, `np.clip`.**
# Comparisons, `np.maximum`, dtype casts, and reductions are the intended
# tools.

# %%
import numpy as np

SEED = 20260804
z_vec = np.array([-2.0, -0.5, 0.0, 0.7, 3.0])
rng = np.random.default_rng(SEED)
Z = rng.normal(0, 1, (4, 5))


def step_activation(z):
    # YOUR CODE HERE (banned: loops, np.vectorize, np.where, np.select, np.piecewise)
    ...


def relu(z):
    # YOUR CODE HERE (same bans)
    ...


step_vals = ...   # YOUR CODE HERE
relu_vals = ...   # YOUR CODE HERE
tanh_vals = ...   # YOUR CODE HERE

n_fired = ...     # YOUR CODE HERE — int
relu_total = ...  # YOUR CODE HERE — float
