# %% [markdown]
# # C5-neural-networks — Practice p07
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** relu-activation
#
# ReLU ramps, assembled into a staircase.
#
# **(a)** Write `ramp(z, a, b)` returning
# $\mathrm{relu}(z - a) - \mathrm{relu}(z - b)$ elementwise (assume
# $a < b$), with `relu` built from `np.maximum`.
#
# **(b)** Build the staircase
# $$g(z) = \mathrm{ramp}(z, 0, 2) + 2 \cdot \mathrm{ramp}(z, 4, 5)$$
# and evaluate it: `g_grid` on the given `grid`, and `g_probes` on the given
# `probes` array.
#
# **(c)** `plateau_val` = the **float** value of $g$ at $z = 10.0$ (the
# final plateau height).
#
# **(d)** In the markdown cell: list the $z$-locations of all kinks of $g$
# and the slope of $g$ on each piece between them.
#
# **Banned (zero points): loops, `np.where`, `np.select`, `np.piecewise`,
# `np.clip`, `np.interp`.**
# Compose ReLUs — that is the point.

# %%
import numpy as np

grid = np.linspace(-2.0, 8.0, 501)
probes = np.array([-1.0, 1.0, 3.0, 4.5, 6.0])


def ramp(z, a, b):
    # YOUR CODE HERE (banned: loops, np.where, np.select, np.piecewise, np.clip, np.interp)
    ...


g_grid = ...      # YOUR CODE HERE — shape (501,)
g_probes = ...    # YOUR CODE HERE — shape (5,)
plateau_val = ... # YOUR CODE HERE — float

# %% [markdown]
# *Your (d) kink locations and per-piece slopes here.*
