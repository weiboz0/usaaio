# %% [markdown]
# # C5-neural-networks — Practice p10
#
# **Type:** constrained coding · **Difficulty:** advanced · **Concepts:** weight-init-variance
#
# Three weight scales, one deep stack — the Session 3 experiment, rebuilt to
# contract.
#
# Propagate a seeded batch through $D = 15$ layers of width $C = 128$
# (no biases, no activation — the pure scale bookkeeping), recording the
# spread after every layer.
#
# **(a)** Write `propagate(sigma)` which:
# creates `rng = np.random.default_rng(20260804)`,
# draws the input batch `h = rng.normal(0, 1, (256, 128))`,
# then 15 times draws `W = rng.normal(0, sigma, (128, 128))` **in that
# order** and updates `h` to the layer output
# $h_{ij} \leftarrow \sum_k h_{ik} W_{jk}$ (zero bias),
# appending `float(h.std())` after each layer;
# it returns the `(15,)` array of spreads.
#
# **(b)** Run all three scalings:
# `stds_a = propagate(1/128)`, `stds_b = propagate(1/np.sqrt(128))`,
# `stds_c = propagate(0.3)`, and store `final_a`, `final_b`, `final_c`
# (floats, the last entry of each).
#
# **(c)** Set `which_stable` to `"a"`, `"b"`, or `"c"` — the scaling whose
# spread stays order-1 — and, in the markdown cell, justify it with the
# per-layer factor $\sigma\sqrt{C}$ for all three.
#
# **Banned (zero points): `@`, `np.matmul`, `np.dot`, `np.einsum`,
# `np.tensordot`, `.T`, `np.inner`, any `np.linalg` function.**
# The **only** loop allowed is the single loop over the 15 layers.
# The rng call order inside `propagate` is part of the contract — deviating
# changes every number.

# %%
import numpy as np

SEED = 20260804


def propagate(sigma):
    # YOUR CODE HERE (banned: @, np.matmul, np.dot, np.einsum, np.tensordot, .T, np.inner, np.linalg.*;
    # only the single loop over the 15 layers is allowed)
    ...


stds_a = ...   # YOUR CODE HERE — sigma = 1/128
stds_b = ...   # YOUR CODE HERE — sigma = 1/sqrt(128)
stds_c = ...   # YOUR CODE HERE — sigma = 0.3

final_a = ...  # YOUR CODE HERE — float
final_b = ...  # YOUR CODE HERE — float
final_c = ...  # YOUR CODE HERE — float

which_stable = ...  # YOUR CODE HERE — "a", "b", or "c"

# %% [markdown]
# *Your (c) justification via the per-layer factor $\sigma\sqrt{C}$ here.*
