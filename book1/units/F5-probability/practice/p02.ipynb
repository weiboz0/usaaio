# %% [markdown]
# # F5-probability — Practice p02
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** expectation
#
# A game wheel has 5 equally likely sectors paying 0, 0, 2, 5, and 13 tokens.
# Let $W$ be the payout of one spin.
#
# What is $E[W]$, and what does it mean?
#
# A. 4 — the payout you should expect on every single spin.
#
# B. 4 — the long-run average payout per spin over many spins.
#
# C. 2 — the most likely payout.
#
# D. 5 — the middle value of the possible payouts.
#
# E. 13/5 — the largest payout divided by the number of sectors.
#
# Record your choice below.

# %%
import numpy as np

answer_p02 = "?"  # replace with "A".."E"
