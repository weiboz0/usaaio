# %% [markdown]
# # F5-probability — Practice p16
#
# **Type:** scenario analysis · **Difficulty:** core · **Concepts:** independence, covariance
#
# A café tracks, per hour: `drinks` sold, `pastries` sold, and the outdoor `temp`erature. Seeded hourly data for 2,000 hours:
#
# ```python
# rng = np.random.default_rng(20260804)
# temp = rng.normal(15, 8, 2000)
# drinks = np.clip(80 - 2.0 * temp + rng.normal(0, 6, 2000), 0, None)   # hot drinks
# pastries = rng.poisson(30, 2000).astype(float)                        # steady sellers
# ```
#
# **(a)** Reproduce the data exactly as above, then compute `cov_dt` = covariance(drinks, temp) and `cov_pt` = covariance(pastries, temp) using YOUR `my_cov` definition from p10 (rewrite it here; same bans: no `np.cov`, no loops).
#
# **(b)** In 2-3 sentences: which pair behaves as independent and which not, what the SIGN of the non-zero covariance says about hot-drink sales, and one caution about reading covariance magnitude across variables with different units.

# %%
import numpy as np

rng = np.random.default_rng(20260804)
# YOUR CODE HERE (reproduce data, define my_cov, compute)
cov_dt = ...
cov_pt = ...

# %% [markdown]
# *Your analysis here (2-3 sentences).*
