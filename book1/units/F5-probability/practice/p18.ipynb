# %% [markdown]
# # F5-probability — Practice p18
#
# **Type:** challenge · **Difficulty:** advanced · **Concepts:** covariance, sampling-simulation, variance
#
# Covariance is about PAIRING, not about the two value collections.
#
# **(a)** With `rng = np.random.default_rng(20260804)`, draw `a = rng.integers(1, 11, 50_000).astype(float)` and set `b = 3.0 * a + rng.normal(0, 2, 50_000)`. Compute `cov_ab` with a definition-based covariance (no `np.cov`, no loops — zero points).
#
# **(b)** Make `b_shuffled` — the SAME values as `b`, order randomized by `rng.permutation` — and compute `cov_ab_shuffled`.
#
# **(c)** Compute the variances of `b` and `b_shuffled`.
#
# **(d)** In 3-4 sentences: explain why (b) collapses toward zero while (c) shows identical variances, and state the general principle (what covariance measures that variance cannot). Predict — WITHOUT running — what `cov_ab_shuffled` would be if you shuffled `a` with the SAME permutation as `b`, then verify with one more computation `cov_same_perm`.

# %%
import numpy as np

rng = np.random.default_rng(20260804)

# YOUR CODE HERE
cov_ab = ...
cov_ab_shuffled = ...
var_b = ...
var_b_shuffled = ...
cov_same_perm = ...

# %% [markdown]
# *Your explanation + prediction here (3-4 sentences).*
