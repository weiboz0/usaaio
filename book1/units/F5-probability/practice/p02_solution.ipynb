# %% [markdown]
# # F5-probability — Practice p02 — Solution

# %% [markdown]
# The expectation is the probability-weighted payout, here the arithmetic mean of five equally likely sectors: $(0+0+2+5+13)/5=4$. It describes the long-run average over many spins, not a guarantee for one spin, so the answer is B.

# %%
import numpy as np

exact_expectation = (0 + 0 + 2 + 5 + 13) / 5
answer_p02 = "B"

# %% [markdown]
# ### Answer check

# %%
assert exact_expectation == 4
expectation_interpretation_choice = "B"
assert answer_p02 == expectation_interpretation_choice
