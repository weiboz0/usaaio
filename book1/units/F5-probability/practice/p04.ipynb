# %% [markdown]
# # F5-probability — Practice p04
#
# **Type:** multiple choice (numeric, normal form) · **Difficulty:** core · **Concepts:** expectation, variance
#
# A random variable $T$ takes the value 1 with probability $\tfrac{1}{4}$, the value 3 with probability $\tfrac{1}{2}$, and the value 7 with probability $\tfrac{1}{4}$.
#
# Compute $\mathrm{Var}[T]$.
# Your answer can be written as $\tfrac{p}{q}$ where $p$ and $q$ are positive integers with $\gcd(p, q) = 1$.
# What is the value of $p + q$?
#
# A. 6.
#
# B. 9.
#
# C. 11.
#
# D. 21.
#
# E. 23.
#
# Reasoning is not required. Record your choice below.

# %%
import numpy as np

answer_p04 = "?"  # replace with "A".."E"
