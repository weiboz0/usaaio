# %% [markdown]
# # F5-probability — Practice p12
#
# **Type:** proof · **Difficulty:** core · **Concepts:** variance, expectation
#
# **Reasoning is required.**
#
# **(a)** Starting from the definition $\mathrm{Var}[X] = E[(X - \mu)^2]$ with $\mu = E[X]$, derive the shortcut form $\mathrm{Var}[X] = E[X^2] - (E[X])^2$ for a discrete random variable, justifying each step with linearity of expectation (expand the square; treat $\mu$ as a constant).
#
# **(b) Concrete anchor:** for the spinner $S$ taking values 2, 4, 9 with probabilities 0.5, 0.3, 0.2, compute BOTH sides by hand in the markdown cell, then verify with a probability-weighted-sum computation in the code cell (no `np.var` — zero points).

# %% [markdown]
# *Your derivation for (a) and hand computation for (b) here.*

# %%
import numpy as np

values = np.array([2., 4., 9.])
probs = np.array([0.5, 0.3, 0.2])

# YOUR CODE HERE — both sides of the identity
lhs = ...   # E[(X-mu)^2]
rhs = ...   # E[X^2] - (E[X])^2
