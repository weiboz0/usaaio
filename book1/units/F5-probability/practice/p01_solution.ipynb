# %% [markdown]
# # F5-probability — Practice p01 — Solution

# %% [markdown]
# A random variable maps each outcome of an uncertain, repeatable process to a value. The lightning count is not required to be uniform or unpredictable in every statistical sense, so choice B is the defining description.

# %%
import numpy as np

answer_p01 = "B"

# %% [markdown]
# ### Answer check

# %%
definition_choice = "B"
assert answer_p01 == definition_choice
