# %% [markdown]
# # F5-probability — Practice p10
#
# **Type:** constrained coding · **Difficulty:** advanced · **Concepts:** covariance
#
# Implement covariance twice and reconcile.
#
# 1. Write `my_cov(a, b)`: sample covariance of two same-length arrays via the definition $\frac{1}{n}\sum_i (a_i - \bar a)(b_i - \bar b)$. Banned (zero points): `np.cov`, `np.corrcoef`, loops. `np.mean` allowed.
# 2. Write `my_cov_shortcut(a, b)` using the shortcut form $\overline{ab} - \bar a\,\bar b$ (mean of products minus product of means). Same bans.
# 3. With `rng = np.random.default_rng(20260804)`, draw `u = rng.integers(1, 7, 100_000)` and build `w = 2*u + rng.integers(0, 3, 100_000)` (dependent by construction) and `q = rng.integers(1, 7, 100_000)` (independent of `u`).
# 4. Set `cov_uw = my_cov(u, w)`, `cov_uq = my_cov(u, q)`, `shortcut_gap = abs(my_cov(u, w) - my_cov_shortcut(u, w))`.
# 5. Markdown: one sentence on the sign/size of `cov_uw` vs `cov_uq` and why.

# %%
import numpy as np

def my_cov(a, b):
    # YOUR CODE HERE
    ...

def my_cov_shortcut(a, b):
    # YOUR CODE HERE
    ...

rng = np.random.default_rng(20260804)
# YOUR CODE HERE
cov_uw = ...
cov_uq = ...
shortcut_gap = ...

# %% [markdown]
# *Your one-sentence interpretation here.*
