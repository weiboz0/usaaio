# %% [markdown]
# # F5-probability — Practice p15
#
# **Type:** scenario analysis · **Difficulty:** core · **Concepts:** gaussian-distribution, sampling-simulation
#
# A lab's balance adds a random error to every weighing. A calibration sheet claims: errors average 0 g with standard deviation 0.2 g, and single errors are roughly Gaussian.
#
# A student weighs one 50.0 g standard mass **four times** and averages the four readings.
#
# **(a)** Using the rules from this unit, compute the standard deviation `sd_avg` of the four-reading average exactly (hint: the average is a scaled sum of independent errors).
#
# **(b)** Simulate 100,000 such four-reading averages (`SEED = 20260804`, `rng.normal(0, 0.2, ...)` allowed as the stated-fact sampler; no loops) and compute `sim_sd`.
#
# **(c)** The student claims: "averaging four readings makes my measurement four times more precise." In 2-3 sentences, use your (a)/(b) numbers to correct the claim precisely (how much does the spread actually shrink, and what WOULD it take to shrink it fourfold?).

# %%
import numpy as np

# (a) YOUR CODE HERE
sd_avg = ...

# (b) YOUR CODE HERE
SEED = 20260804
sim_sd = ...

# %% [markdown]
# *Your correction of the claim here (2-3 sentences).*
