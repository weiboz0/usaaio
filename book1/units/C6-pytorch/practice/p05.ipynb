# %% [markdown]
# # C6-pytorch — Practice p05
#
# **Type:** constrained coding · **Difficulty:** intro · **Concepts:** torch-tensors, broadcasting, aggregation-axis
#
# Tensor fundamentals on a seeded matrix — the F1 moves, in torch.
#
# For the seeded `(6, 4)` tensor `M` below, compute:
#
# **(a)** `col_means` — the mean of each column, shape `(4,)`.
#
# **(b)** `row_maxes` — the largest entry of each row, shape `(6,)`.
#
# **(c)** `n_negative` — the number of strictly negative entries, as a
# plain Python `int`.
#
# **(d)** `centered` — `M` with each column's mean subtracted from that
# column (broadcasting), shape `(6, 4)`; and `check_zero` — the maximum
# absolute column-mean of `centered`, as a plain `float` (it should be at
# float64 rounding level, below `1e-12`).
#
# **Banned (zero points): importing NumPy; any `for`/`while` loop or
# comprehension.**
# Tensor methods with `dim=` and broadcasting only.

# %%
import torch
import torch.nn as nn

torch.set_default_dtype(torch.float64)   # course convention (Session 1)


torch.manual_seed(20260804)
M = torch.randn(6, 4)

col_means = ...   # YOUR CODE HERE
row_maxes = ...   # YOUR CODE HERE
n_negative = ...  # YOUR CODE HERE
centered = ...    # YOUR CODE HERE
check_zero = ...  # YOUR CODE HERE
