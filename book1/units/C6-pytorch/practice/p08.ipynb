# %% [markdown]
# # C6-pytorch — Practice p08
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** custom-layers
#
# Build the unit's pinned dense layer from its written spec — without
# peeking at the lesson.
#
# **(a)** Implement `DenseLayer(nn.Module)`:
#
# - the constructor takes `weight` of shape `(out, in)` — one row per
#   output unit — and `bias` of shape `(out,)`, and registers **both** as
#   parameters constructed with `requires_grad=False`;
# - `forward(x)` returns `x @ weight.T + bias` for `x` of shape
#   `(n, in)`.
#
# **(b)** Instantiate it with the tensors `W`, `b` below and compute
# `y = layer(x)` for the given `x` (shape `(2, 2)` in, `(2, 3)` out).
#
# **(c)** Audit your layer: `n_tensors` — the number of registered
# parameter tensors (plain `int`); `all_frozen` — `True` iff every
# registered parameter has `requires_grad == False` (plain `bool`).
#
# **Banned (zero points): `nn.Linear`, `nn.LazyLinear`, or any built-in
# torch layer that owns parameters — the registration is the graded
# skill; importing NumPy; loops in `forward`.**

# %%
import torch
import torch.nn as nn

torch.set_default_dtype(torch.float64)   # course convention (Session 1)


# (a) YOUR CODE HERE — class DenseLayer


W = torch.tensor([[1.0, -1.0],
                  [0.5, 2.0],
                  [0.0, 1.0]])
b = torch.tensor([0.0, -1.0, 2.0])
x = torch.tensor([[2.0, 1.0],
                  [-1.0, 3.0]])

# (b) YOUR CODE HERE
layer = ...
y = ...

# (c) YOUR CODE HERE
n_tensors = ...
all_frozen = ...
