# %% [markdown]
# # C6-pytorch — Practice p03
#
# **Type:** multiple choice · **Difficulty:** core · **Concepts:** requires-grad
#
# Consider
#
# ```python
# class Probe(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.a = nn.Parameter(torch.zeros(3), requires_grad=False)
#         self.b = torch.ones(3)
#         self.c = nn.Parameter(torch.ones(2))
#
#
# m = Probe()
# n = len(list(m.parameters()))
# flags = sorted(p.requires_grad for p in m.parameters())
# ```
#
# What are `n` and `flags`?
#
# A. `n = 3`, `flags = [False, False, True]`
#
# B. `n = 2`, `flags = [False, False]`
#
# C. `n = 2`, `flags = [False, True]`
#
# D. `n = 3`, `flags = [False, True, True]`
#
# E. `n = 1`, `flags = [False]`
#
# Reasoning is not required. Record your choice below.

# %%
import torch
import torch.nn as nn

answer_p03 = "?"  # replace with "A".."E"
