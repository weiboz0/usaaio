# %% [markdown]
# # C6-pytorch — Practice p02
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** python-inheritance
#
# Consider this plain-Python program:
#
# ```python
# class Base:
#     def __init__(self):
#         self.tag = "base"
#
#     def name(self):
#         return "Base-" + self.tag
#
#
# class Child(Base):
#     def __init__(self):
#         super().__init__()
#         self.tag = "child"
#
#
# print(Child().name())
# ```
#
# What does it print?
#
# A. `Base-base`
#
# B. `Base-child`
#
# C. `Child-child`
#
# D. It raises `AttributeError: 'Child' object has no attribute 'tag'`.
#
# E. It raises `TypeError` because `Child` defines no `name` method.
#
# Reasoning is not required. Record your choice below.

# %%
answer_p02 = "?"  # replace with "A".."E"
