# %% [markdown]
# # C6-pytorch — Practice p04
#
# **Type:** multiple choice (numeric, normal form) · **Difficulty:** core · **Concepts:** parameter-counting
#
# A network maps $3 \to 6 \to 4 \to 2$ through three dense layers of the
# pinned `DenseLayer` kind (weights **and** biases), with a
# `ThresholdGate` after each dense layer.
#
# Let $N$ be the total number of parameters (individual numbers) the
# network holds.
# $N$ can be written uniquely as $N = 2^a \cdot b$ with $a \ge 0$ an
# integer and $b$ odd.
# What is $a + b$?
#
# A. 26
#
# B. 31
#
# C. 32
#
# D. 62
#
# E. 63
#
# Reasoning is not required. Record your choice below.

# %%
answer_p04 = "?"  # replace with "A".."E"
