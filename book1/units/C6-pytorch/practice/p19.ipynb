# %% [markdown]
# # C6-pytorch — Practice p19
#
# **Type:** drill · **Difficulty:** intro · **Concepts:** torch-tensors
#
# Rapid-fire one-liners.
# Each deliverable is a single expression (the seeded draw may take its
# own two lines, as shown); **no loops or comprehensions anywhere (zero
# points)**.
#
# - `m` — `a` reshaped to `(3, 4)`;
# - `col_sums` — column sums of `m`, shape `(4,)`;
# - `row_maxes` — the largest entry of each row of `m`, shape `(3,)`;
# - `n_evens` — how many entries of `a` are even (plain `int`);
# - `af` — `a` cast to `torch.float64`;
# - `mean_all` — the mean of `af` (plain `float`);
# - `t_lin` — the NumPy array `lin` wrapped as a tensor **sharing its
#   memory**;
# - `lin_dtype` — `t_lin`'s dtype;
# - `shares` — `True` iff `t_lin.numpy()` shares memory with `lin`
#   (use `np.shares_memory`);
# - `r` — a fresh seeded draw: `torch.manual_seed(20260804)` then
#   `torch.randn(4)`;
# - `n_pos` — how many entries of `r` are strictly positive (plain
#   `int`).

# %%
import numpy as np
import torch

torch.set_default_dtype(torch.float64)   # course convention (Session 1)

a = torch.arange(12)
lin = np.linspace(0.0, 1.0, 5)

m = ...          # YOUR CODE HERE
col_sums = ...   # YOUR CODE HERE
row_maxes = ...  # YOUR CODE HERE
n_evens = ...    # YOUR CODE HERE
af = ...         # YOUR CODE HERE
mean_all = ...   # YOUR CODE HERE
t_lin = ...      # YOUR CODE HERE
lin_dtype = ...  # YOUR CODE HERE
shares = ...     # YOUR CODE HERE

# seeded draw (two lines allowed):
# YOUR CODE HERE
r = ...
n_pos = ...      # YOUR CODE HERE
