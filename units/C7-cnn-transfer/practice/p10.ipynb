# %% [markdown]
# # C7-cnn-transfer — Practice p10
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** layer-freezing, nn-module, requires-grad, parameter-counting
#
# Selective freezing with a two-currency audit.
#
# **(a)** Freeze **exactly** the parameters of the stem and the first
# two stages: every parameter whose qualified name starts with
# `"conv1"`, `"bn1"`, `"layer1"`, or `"layer2"` gets
# `requires_grad = False`; every other parameter keeps `True`.
# Use an explicit loop/filter over `model.named_parameters()`.
#
# **(b)** Audit, in both currencies:
#
# - `n_frozen_tensors` — how many parameter *tensors* are frozen
#   (plain `int`);
# - `n_frozen_scalars` — how many *numbers* are frozen;
# - `n_trainable_scalars` — how many numbers remain trainable;
# - `split_ok` — `True` iff the two scalar counts sum to the model
#   total (compute the total from `model.parameters()` too).
#
# **(c)** `trainable_tops` — the sorted list of top-level name prefixes
# (the part before the first `"."`) that still own at least one
# trainable parameter.
#
# **Banned (zero points): `model.requires_grad_(...)` (the loop is the
# skill); `torchsummary`.**

# %%
# Cache pin (course convention, plan 009): pretrained weights live in the repo's
# gitignored reference/cache/ -- resolve it from the repo root BEFORE importing torch.
import os, pathlib
_root = next(p for p in [pathlib.Path.cwd(), *pathlib.Path.cwd().parents]
             if (p / "pyproject.toml").exists())
os.environ["TORCH_HOME"] = str(_root / "reference" / "cache" / "torch")

import torch
import torch.nn as nn
from torchvision.models import resnet50, ResNet50_Weights

# float32 register (course exception): pretrained resnet50 is a float32 artifact.
# No float64 default here; inputs are cast .to(torch.float32) at the model
# boundary; float comparisons state atol=1e-6 / rtol=1e-5.
SEED = 20260804

model = resnet50(weights=ResNet50_Weights.IMAGENET1K_V1)
model.eval()
assert next(model.parameters()).dtype == torch.float32


# (a) YOUR CODE HERE -- the freezing loop


# (b)
n_frozen_tensors = ...     # YOUR CODE HERE
n_frozen_scalars = ...     # YOUR CODE HERE
n_trainable_scalars = ...  # YOUR CODE HERE
split_ok = ...             # YOUR CODE HERE

# (c)
trainable_tops = ...       # YOUR CODE HERE
