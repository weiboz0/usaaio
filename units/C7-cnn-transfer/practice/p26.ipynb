# %% [markdown]
# # C7-cnn-transfer — Practice p26
#
# **Type:** challenge · **Difficulty:** advanced · **Concepts:** convolution, tensor-shape-tracing
#
# *Coding is required.*
#
# Implement
# ```python
# def trace_conv_stack(input_shape, specs):
#     ...
# ```
# where `input_shape` is a \((B,C,H,W)\) tuple and each item of `specs` is
# `(c_out, k_h, k_w, s_h, s_w, p_h, p_w)`. Return `trace`, a list containing the output \((B,C,H,W)\) tuple after every convolution. Use the ordinary dilation-1 floor formula independently on both axes; a loop over `specs` is allowed.
#
# Apply it to:
# ```python
# input_shape = (3, 17, 191, 227)
# specs = [
#     (31, 7, 3, 2, 1, 3, 1),
#     (43, 3, 5, 3, 2, 0, 2),
#     (59, 1, 7, 1, 3, 0, 0),
# ]
# ```
# and assign the returned list to the exact identifier `trace`. Raise `ValueError` if any computed spatial size is below 1.
#
# **Banned (zero points): `torch.nn.functional`/`nn.functional`, importing `torch` or `torchvision`, constructing or running a layer/model, model summaries, and delegating the arithmetic to any shape-calculator API.** Repackaging a banned call in a helper is still a banned call.

# %%
def trace_conv_stack(input_shape, specs):
    # YOUR CODE HERE
    ...


input_shape = (3, 17, 191, 227)
specs = [
    (31, 7, 3, 2, 1, 3, 1),
    (43, 3, 5, 3, 2, 0, 2),
    (59, 1, 7, 1, 3, 0, 0),
]
trace = trace_conv_stack(input_shape, specs)
