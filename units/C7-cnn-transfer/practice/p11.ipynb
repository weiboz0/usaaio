# %% [markdown]
# # C7-cnn-transfer — Practice p11
#
# **Type:** constrained coding · **Difficulty:** advanced · **Concepts:** transfer-learning, model-truncation, python-inheritance, nn-module, custom-layers, requires-grad, parameter-counting
#
# A complete transfer construction, to contract.
#
# **(a) Hand prediction first.**
# In the cell marked `(a)`, set two plain-`int` literals from hand
# arithmetic (show the sums in comments):
#
# - `hand_frozen` — the parameter scalars of the stem + `layer1` +
#   `layer2` (Session 2 §6's per-child table is the reference);
# - `hand_trainable` — the parameters of a fresh `nn.Linear(512, 9)`.
#
# **`numel` (and any code-derived count) is banned in cell (a) — zero
# points.**
#
# **(b) The build.** Implement `Transfer9(nn.Module)`:
#
# - constructor takes the pretrained `model`; attributes **exactly**:
#   `backbone` — `nn.Sequential` of the first six children (through
#   `layer2`); `pool` — `nn.AdaptiveAvgPool2d(1)`; `head` —
#   `nn.Linear(512, 9)`;
# - the constructor freezes every `backbone` parameter (and only
#   those);
# - `forward(x)` = backbone → pool → `torch.flatten(..., 1)` → head.
#
# **(c) Audit.** Build `net = Transfer9(model)`, put it in `eval()`,
# and compute under `torch.inference_mode()` on the seeded batch:
#
# - `out_shape` — the output shape as a plain tuple (expect `(2, 9)`);
# - `n_frozen`, `n_trainable` — scalar counts over
#   `net.parameters()` (**`numel` is allowed here** — this is the
#   check cell);
# - `counts_match` — `True` iff they equal `hand_frozen` /
#   `hand_trainable`;
# - `trainable_names` — sorted names of trainable parameter tensors
#   (expect exactly the head's two).
#
# **Banned (zero points):
# `torchvision.models.feature_extraction`; forward hooks; mutating the
# global `model.fc`; `numel`/`torchsummary`/`state_dict`-size reads in
# cell (a).**

# %%
# Cache pin (course convention, plan 009): pretrained weights live in the repo's
# gitignored reference/cache/ -- resolve it from the repo root BEFORE importing torch.
import os, pathlib
_root = next(p for p in [pathlib.Path.cwd(), *pathlib.Path.cwd().parents]
             if (p / "pyproject.toml").exists())
os.environ["TORCH_HOME"] = str(_root / "reference" / "cache" / "torch")

import torch
import torch.nn as nn
from torchvision.models import resnet50, ResNet50_Weights

# float32 register (course exception): pretrained resnet50 is a float32 artifact.
# No float64 default here; inputs are cast .to(torch.float32) at the model
# boundary; float comparisons state atol=1e-6 / rtol=1e-5.
SEED = 20260804

model = resnet50(weights=ResNet50_Weights.IMAGENET1K_V1)
model.eval()
assert next(model.parameters()).dtype == torch.float32

torch.manual_seed(SEED)
x = torch.randn(2, 3, 224, 224).to(torch.float32)

# %%
# (a) hand arithmetic only -- numel banned in this cell
hand_frozen = ...     # YOUR CODE HERE (int literal; show the sum in a comment)
hand_trainable = ...  # YOUR CODE HERE (int literal; show the arithmetic)

# %%
# (b) YOUR CODE HERE -- class Transfer9(nn.Module): ...


# (c)
net = ...              # YOUR CODE HERE
out_shape = ...        # YOUR CODE HERE
n_frozen = ...         # YOUR CODE HERE
n_trainable = ...      # YOUR CODE HERE
counts_match = ...     # YOUR CODE HERE
trainable_names = ...  # YOUR CODE HERE
