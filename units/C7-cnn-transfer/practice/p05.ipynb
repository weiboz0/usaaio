# %% [markdown]
# # C7-cnn-transfer — Practice p05
#
# **Type:** multiple choice · **Difficulty:** core · **Concepts:** receptive field
#
# A network consists of three stacked convolutions, all at stride 1
# (padding does not affect receptive-field size):
#
# 1. $3\times3$, then
# 2. $3\times3$, then
# 3. $5\times5$.
#
# The receptive field of one output of layer 3, in input pixels per
# dimension, is:
#
# A. 9
#
# B. 11
#
# C. 7
#
# D. 45
#
# E. 5
#
# Reasoning is not required; answer from the growth rule, not from
# running code. Record your choice below.

# %%
answer_p05 = "?"  # replace with "A".."E"
