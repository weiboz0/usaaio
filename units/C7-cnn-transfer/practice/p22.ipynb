# %% [markdown]
# # C7-cnn-transfer — Practice p22
#
# **Type:** drill · **Difficulty:** intro · **Concepts:** feature hierarchy
#
# Rapid-fire facts and two tiny measurements.
# Each deliverable is a single expression or literal; **no loops or
# comprehensions (zero points)**.
#
# - `order` — the four hierarchy stages
#   `"objects"`, `"textures"`, `"edges"`, `"parts"` as a list, from
#   **shallowest to deepest**;
# - `rf_dir` — `"grows"` or `"shrinks"`: receptive fields with depth;
# - `grid_dir` — `"grows"` or `"shrinks"`: spatial map size with depth
#   (in ResNet-style networks);
# - `channels_dir` — `"grows"` or `"shrinks"`: channel counts with
#   depth;
# - `af_early` — the activation fraction (share of entries `> 0`) of
#   `m_early` below, as a plain `float`;
# - `af_late` — the same for `m_late`;
# - `sparser` — `"early"` or `"late"`: which regime's maps are sparser
#   (fewer nonzeros), reading your two measurements;
# - `deep_shape` — which of `(1, 256, 56, 56)` / `(1, 2048, 7, 7)`
#   belongs to the deeper layer (a plain tuple).

# %%
import numpy as np

SEED = 20260804

m_early = np.array([[1., 0., 3., 0.],
                    [0., 2., 0., 4.],
                    [3., 0., 1., 0.],
                    [0., 4., 0., 2.]])
m_late = np.array([[0., 0., 0., 0.],
                   [0., 3., 3., 0.],
                   [0., 3., 3., 0.],
                   [0., 0., 0., 0.]])

order = ...         # YOUR CODE HERE
rf_dir = ...        # YOUR CODE HERE
grid_dir = ...      # YOUR CODE HERE
channels_dir = ...  # YOUR CODE HERE
af_early = ...      # YOUR CODE HERE
af_late = ...       # YOUR CODE HERE
sparser = ...       # YOUR CODE HERE
deep_shape = ...    # YOUR CODE HERE
