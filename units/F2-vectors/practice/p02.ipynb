# %% [markdown]
# # F2-vectors — Practice p02
#
# **Type:** constrained coding · **Difficulty:** intro · **Concepts:** distance-metrics, vectors-and-norms
#
# **Banned (zero points): `for`, `while`, and comprehensions in part (c).**

# %%
import numpy as np

# %% [markdown]
# **Two rulers, one closest point.**
#
# **Part (a) — by hand.**
# For $p = (1, 2)$ and $q = (4, 6)$, compute by hand:
#
# - the Euclidean distance $\|p - q\|$ → store as the float `euclid_pq_by_hand`
# - the Manhattan distance $\|p - q\|_1$ → store as the float `manhattan_pq_by_hand`
#
# **Part (b) — implement.**
# Implement `euclidean_distance(a, b)` and `manhattan_distance(a, b)` for 1-D
# arrays `a` and `b`.
# Check that both reproduce your part (a) answers.
#
# **Part (c) — all distances at once.**
# The provided cell generates `points`, a 2-D array of shape `(6, 2)` holding
# six points (one per row), and a query point `q`.
# Using broadcasting and an axis sum, as covered in F1-scientific-python —
# no loops needed — compute:
#
# - `euclid_all`, shape `(6,)`: Euclidean distance from `q` to every point;
# - `manhattan_all`, shape `(6,)`: Manhattan distance from `q` to every point;
# - `closest_euclid = int(np.argmin(euclid_all))` and
#   `closest_manhattan = int(np.argmin(manhattan_all))`.
#
# Do the two rulers pick the same closest point here?
#
# **Rules for part (c).**
# Compute all six distances of each kind in a single broadcasting expression
# with an axis sum; using `for`, `while`, or a comprehension anywhere in
# part (c) scores zero.

# %% [markdown]
# ## Part (a)

# %%
# YOUR CODE HERE
euclid_pq_by_hand = ...
manhattan_pq_by_hand = ...

# %% [markdown]
# ## Part (b)

# %%
def euclidean_distance(a, b):
    # YOUR CODE HERE
    ...


def manhattan_distance(a, b):
    # YOUR CODE HERE
    ...

# %% [markdown]
# ## Part (c)

# %%
SEED = 20260804
rng = np.random.default_rng(SEED)

points = rng.integers(-9, 10, size=(6, 2)).astype(float)
q = np.array([1.0, 2.0])
print(points)

# %%
# YOUR CODE HERE
