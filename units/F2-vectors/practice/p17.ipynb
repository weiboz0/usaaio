# %% [markdown]
# # F2-vectors — Practice p17

# %%
import numpy as np

# %% [markdown]
# **Most similar row, no loops.**
#
# The provided cell generates `X`, a 2-D array of shape `(80, 3)` holding 80
# vectors (one per row, none zero), and a nonzero query vector `q`.
#
# **Rules.**
# Loops are banned in this notebook: do not use `for`, `while`, or
# comprehensions anywhere.
# `np.linalg.norm` is banned everywhere in this notebook.
# Violating either rule scores zero.
#
# **Part (a).**
# Implement `cosine_to_query(X, q)`, returning the `(80,)` array whose entry
# $i$ is the cosine similarity between row $i$ of `X` and `q`.
# Store the result as `sims`.
#
# **Part (b).**
# Implement `most_similar(X, q)`, returning the **int** index of the row of
# `X` whose direction agrees most with `q` (the largest cosine similarity).
# It must reuse `cosine_to_query` and `np.argmax`.
# Store the result as `best_row`.
#
# **Part (c).**
# Store `check_range`, a bool verifying with `np.all` that every entry of
# `sims` lies in $[-1, 1]$.

# %%
SEED = 20260804
rng = np.random.default_rng(SEED)

X = rng.normal(size=(80, 3))
q = rng.normal(size=3)
print(X.shape, q)

# %% [markdown]
# ## Part (a)

# %%
def cosine_to_query(X, q):
    # YOUR CODE HERE
    ...


sims = ...

# %% [markdown]
# ## Part (b)

# %%
def most_similar(X, q):
    # YOUR CODE HERE
    ...


best_row = ...

# %% [markdown]
# ## Part (c)

# %%
# YOUR CODE HERE
check_range = ...
