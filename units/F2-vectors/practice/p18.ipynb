# %% [markdown]
# # F2-vectors — Practice p18

# %%
import numpy as np

# %% [markdown]
# **The Pythagorean split.**
#
# Reasoning is required for every part of this problem.
# Show your steps in the markdown cells provided; a bare numeric answer scores
# zero.
# You may use the final code cell only to double-check your arithmetic.
#
# Let $a = (4, 2)$ and $b = (1, 1)$, and let
# $p = \dfrac{a\cdot b}{b\cdot b}\,b$ be the projection of $a$ onto the
# direction of $b$, with residual $r = a - p$.
#
# **Part (a).**
# Compute $p$ and $r$ by hand, then verify by hand that
# $$\|a\|^2 = \|p\|^2 + \|r\|^2$$
# with exact integers.
#
# **Part (b).**
# In 2-3 sentences, prove the general fact: whenever $r \cdot p = 0$,
# $$\|p + r\|^2 = \|p\|^2 + \|r\|^2 .$$
# Expand $\|p + r\|^2$ as a dot product and name the algebra rules you use.
#
# **Part (c).**
# In one sentence, explain why the hypothesis $r\cdot p = 0$ is guaranteed for
# the projection/residual pair — cite the property of residuals from the
# lesson.

# %% [markdown]
# ## Part (a) — your reasoning
#
# *(Write your steps here.)*

# %% [markdown]
# ## Part (b) — your proof
#
# *(Write your 2-3 sentences here.)*

# %% [markdown]
# ## Part (c) — your sentence
#
# *(Write here.)*

# %% [markdown]
# ## Numeric check (optional)

# %%
# YOUR CODE HERE — double-check part (a)
