# %% [markdown]
# # F2-vectors — Practice p05

# %%
import numpy as np

# %% [markdown]
# **Projection and residual.**
#
# **Part (a) — by hand.**
# Let $a = (4, 2)$ and $b = (1, 1)$.
# Using $\text{proj} = \dfrac{a\cdot b}{b\cdot b}\,b$, compute by hand the
# projection of $a$ onto the direction of $b$ and the residual
# $r = a - \text{proj}$.
# Store them as the arrays `proj_by_hand` and `resid_by_hand`, and check by
# hand that $r \cdot b = 0$.
#
# **Part (b) — implement.**
# Implement `project(a, b)`, returning the projection of `a` onto the
# direction of any nonzero vector `b`, and `residual(a, b)`, returning
# `a - project(a, b)`.
# Check that both reproduce your part (a) answers.
#
# **Part (c) — verify the two key properties.**
# The provided cell generates vectors `a` and `b` with 4 entries each.
# Compute `proj_c = project(a, b)` and `resid_c = residual(a, b)`, then verify
# numerically (each as a bool produced with `np.isclose`):
#
# - `check_orth`: the residual is orthogonal to `b`;
# - `check_pyth`: $\|a\|^2 = \|\text{proj}\|^2 + \|r\|^2$ — the Pythagorean
#   theorem, which applies because the two pieces are orthogonal.

# %% [markdown]
# ## Part (a)

# %%
# YOUR CODE HERE
proj_by_hand = ...
resid_by_hand = ...

# %% [markdown]
# ## Part (b)

# %%
def project(a, b):
    # YOUR CODE HERE
    ...


def residual(a, b):
    # YOUR CODE HERE
    ...

# %% [markdown]
# ## Part (c)

# %%
SEED = 20260804
rng = np.random.default_rng(SEED)

a = rng.normal(size=4)
b = rng.normal(size=4)
print(a)
print(b)

# %%
# YOUR CODE HERE
check_orth = ...
check_pyth = ...
