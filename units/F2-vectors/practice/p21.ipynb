# %% [markdown]
# # F2-vectors — Practice p21

# %%
import numpy as np

# %% [markdown]
# **Challenge: three perpendicular axes in 3-D.**
# Advanced problem — the two-vector construction from p13, pushed one step
# further with a second residual.
#
# You are given three vectors in 3-D, none orthogonal to the others:
# $$v_1 = (1, 2, 2), \qquad v_2 = (1, 0, 0), \qquad v_3 = (0, 1, 0).$$
#
# **Part (a).**
# Build an orthonormal *triple* $\{u_1, u_2, u_3\}$ using only normalization,
# projection, and residual:
#
# 1. `u1`: normalize $v_1$;
# 2. `u2`: normalize the residual of $v_2$ after projecting onto the
#    direction `u1`;
# 3. `u3`: normalize what is left of $v_3$ after subtracting its projections
#    onto **both** `u1` and `u2`:
#    $r_3 = v_3 - (v_3\cdot u_1)\,u_1 - (v_3\cdot u_2)\,u_2$.
#
# **Part (b).**
# Verify all six orthonormality conditions numerically: the three self dot
# products equal 1 and the three pair dot products equal 0.
# Then explain in 1-2 sentences in the markdown cell why $r_3$ is orthogonal
# to *both* $u_1$ and $u_2$ (check $r_3\cdot u_1$ and $r_3\cdot u_2$ by
# expanding, using $u_1\cdot u_2 = 0$).
#
# **Part (c).**
# For $w = (3, 0, 6)$, read off the three coordinates
# $t_i = w\cdot u_i$ and verify that $t_1 u_1 + t_2 u_2 + t_3 u_3$ rebuilds
# $w$.

# %% [markdown]
# ## Part (a)

# %%
v1 = np.array([1.0, 2.0, 2.0])
v2 = np.array([1.0, 0.0, 0.0])
v3 = np.array([0.0, 1.0, 0.0])

# YOUR CODE HERE
u1 = ...
u2 = ...
u3 = ...

# %% [markdown]
# ## Part (b)

# %%
# YOUR CODE HERE

# %% [markdown]
# **Your explanation:** *(write 1-2 sentences here)*

# %% [markdown]
# ## Part (c)

# %%
w = np.array([3.0, 0.0, 6.0])

# YOUR CODE HERE
t1 = ...
t2 = ...
t3 = ...
