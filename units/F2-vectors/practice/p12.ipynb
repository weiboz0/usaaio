# %% [markdown]
# # F2-vectors — Practice p12

# %%
import numpy as np

# %% [markdown]
# **Scenario analysis: pick the right ruler.**
# For each scenario, do the computation, store the requested values, and store
# your choice of tool as one of the strings `"euclidean"`, `"manhattan"`,
# `"cosine"`.
# A choice without the supporting computation scores zero; judgment is part of
# the task.
#
# **Scenario 1 — bike courier.**
# A courier rides through a street grid from the corner $(2, 3)$ to the corner
# $(7, 9)$ (coordinates in blocks).
# Compute both the Euclidean and Manhattan distances between the corners
# (`s1_euclid`, `s1_manhattan`).
# Which number predicts the blocks actually ridden? → `scenario_1`
#
# **Scenario 2 — delivery drone.**
# A drone flies in a straight line between the same two corners.
# Which tool measures its flight distance? → `scenario_2`
# (No new computation needed — reuse part 1's numbers.)
#
# **Scenario 3 — shopping lists.**
# Two households buy the same three staples weekly; one household is twice as
# large.
# Their purchase-count vectors are $h_1 = (6, 2, 4)$ and $h_2 = (12, 4, 8)$.
# Compute the Euclidean distance between them (`s3_euclid`) and their cosine
# similarity (`s3_cosine`).
# Which tool correctly reports that the households buy in the *same
# proportions*? → `scenario_3`
# Then answer in the markdown cell: why does the Euclidean distance mislead
# here?

# %% [markdown]
# ## Scenario 1

# %%
# YOUR CODE HERE
s1_euclid = ...
s1_manhattan = ...
scenario_1 = "?"

# %% [markdown]
# ## Scenario 2

# %%
# YOUR CODE HERE
scenario_2 = "?"

# %% [markdown]
# ## Scenario 3

# %%
# YOUR CODE HERE
s3_euclid = ...
s3_cosine = ...
scenario_3 = "?"

# %% [markdown]
# **Your explanation for scenario 3:** *(write 1-2 sentences here)*
