# %% [markdown]
# # F2-vectors — Practice p10

# %%
import numpy as np

# %% [markdown]
# **Distances to a query, both rulers, no loops.**
#
# The provided cell generates `X`, a 2-D array of shape `(150, 4)` holding 150
# vectors (one per row), and a query vector `q` with 4 entries.
#
# **Rules.**
# Loops are banned in this notebook: do not use `for`, `while`, or
# comprehensions anywhere.
# `np.linalg.norm` is banned everywhere in this notebook.
# Violating either rule scores zero.
# Build everything from elementwise operations, broadcasting, and axis
# aggregations, as covered in F1-scientific-python.
#
# **Part (a).**
# Implement `euclidean_to_query(X, q)` and `manhattan_to_query(X, q)`, each
# returning a `(150,)` array whose entry $i$ is the corresponding distance
# from row $i$ of `X` to `q`.
# Store the results as `euclid_all` and `manhattan_all`.
#
# **Part (b).**
# The Manhattan distance can never be smaller than the Euclidean distance for
# the same pair of points.
# Verify this holds for all 150 rows at once and store the result as the bool
# `check_dominance` (use `np.all`).
#
# **Part (c).**
# Store `closest = int(np.argmin(euclid_all))`, the row index of the point
# closest to `q` under the Euclidean ruler.

# %%
SEED = 20260804
rng = np.random.default_rng(SEED)

X = rng.normal(size=(150, 4))
q = rng.normal(size=4)
print(X.shape, q)

# %% [markdown]
# ## Part (a)

# %%
def euclidean_to_query(X, q):
    # YOUR CODE HERE
    ...


def manhattan_to_query(X, q):
    # YOUR CODE HERE
    ...


euclid_all = ...
manhattan_all = ...

# %% [markdown]
# ## Part (b)

# %%
# YOUR CODE HERE
check_dominance = ...

# %% [markdown]
# ## Part (c)

# %%
# YOUR CODE HERE
closest = ...
