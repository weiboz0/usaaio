# %% [markdown]
# # F2-vectors — Practice p04

# %%
import numpy as np

# %% [markdown]
# **Unit vectors and an orthonormal pair.**
#
# **Part (a) — normalize.**
# Implement `normalize(v)`, returning $v/\|v\|$.
# Then, by hand, normalize $(3, 4)$ and store the result as the array
# `u_by_hand`.
# Check that `normalize(np.array([3.0, 4.0]))` matches `u_by_hand`, and that
# `normalize(np.array([2.0, -1.0, 2.0]))` has Euclidean norm 1.
#
# **Part (b) — orthogonal or not.**
# Using dot products, decide whether each pair is orthogonal and store the
# results as the booleans `orth_ab` and `orth_cd`:
#
# - $a = (2, 1, -2)$ and $b = (1, 2, 2)$ → `orth_ab`
# - $c = (1, 1, 0)$ and $d = (1, 0, 1)$ → `orth_cd`
#
# **Part (c) — build an orthonormal pair.**
# Let `u1 = np.array([0.6, 0.8])`.
# Find, by hand, a unit vector orthogonal to `u1` and store it as the array
# `u2`.
# Then verify that $\{u_1, u_2\}$ is orthonormal by computing the three dot
# products $u_1\cdot u_1$, $u_2\cdot u_2$, and $u_1\cdot u_2$.

# %% [markdown]
# ## Part (a)

# %%
def normalize(v):
    # YOUR CODE HERE
    ...


# YOUR CODE HERE
u_by_hand = ...

# %% [markdown]
# ## Part (b)

# %%
a = np.array([2.0, 1.0, -2.0])
b = np.array([1.0, 2.0, 2.0])
c = np.array([1.0, 1.0, 0.0])
d = np.array([1.0, 0.0, 1.0])

# YOUR CODE HERE
orth_ab = ...
orth_cd = ...

# %% [markdown]
# ## Part (c)

# %%
u1 = np.array([0.6, 0.8])

# YOUR CODE HERE
u2 = ...
