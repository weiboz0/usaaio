# %% [markdown]
# # F2-vectors — Practice p07

# %%
import numpy as np

# %% [markdown]
# **The residual is orthogonal to the projection direction.**
#
# Reasoning is required for every part of this problem.
# Show your steps in the markdown cells provided; a bare numeric answer scores
# zero.
# Work parts (a) and (b) by hand with exact fractions — no decimals.
# You may use the final code cell only to double-check your arithmetic.
#
# Let $a = (5, 1)$ and $\hat b = \left(\tfrac35, \tfrac45\right)$.
#
# **Part (a).**
# Show that $\hat b$ is a unit vector.
#
# **Part (b).**
# Compute the projection $p = (a \cdot \hat b)\,\hat b$ and the residual
# $r = a - p$ as exact fractions, and show that $r \cdot \hat b = 0$ exactly.
#
# **Part (c).**
# In 2-3 sentences, argue that part (b) is no accident: for **any** vector $a$
# and **any** unit vector $\hat b$, the residual $r = a - (a\cdot\hat b)\,\hat b$
# satisfies $r \cdot \hat b = 0$.
# Name the dot-product rules your argument uses.

# %% [markdown]
# ## Part (a) — your reasoning
#
# *(Write your steps here.)*

# %% [markdown]
# ## Part (b) — your reasoning
#
# *(Write your steps here.)*

# %% [markdown]
# ## Part (c) — your argument
#
# *(Write your 2-3 sentences here.)*

# %% [markdown]
# ## Numeric check (optional)

# %%
# YOUR CODE HERE — double-check the fractions from parts (a) and (b)
