# %% [markdown]
# # F2-vectors — Practice p09
#
# **Type:** multiple choice (numeric, normal form) · **Difficulty:** core · **Concepts:** unit-vectors, vectors-and-norms

# %%
import numpy as np

# %% [markdown]
# **Multiple choice (numeric, normal form).**
# Reasoning is not required. Work the problem by hand, then record your choice in
# the code cell as a string, e.g. `answer_p09 = "A"`.
#
# Let $v = (9, 3)$.
# Its unit vector $\hat v = v / \|v\|$ can be written in the normal form
# $$\hat v = \frac{1}{\sqrt{a}}\,(b,\ c)$$
# where $a$, $b$, $c$ are positive integers with $\gcd(b, c) = 1$.
# (The gcd condition makes this way of writing $\hat v$ unique — reporting the
# unreduced form is the classic trap.)
#
# Compute $S = a + b + c$.
#
# A. 12
#
# B. 14
#
# C. 16
#
# D. 24
#
# E. 102

# %%
# Record your choice as a capital letter string.
answer_p09 = "?"
