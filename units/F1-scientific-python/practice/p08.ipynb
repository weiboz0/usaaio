# %% [markdown]
# # F1-scientific-python — Practice p08
#
# **Concepts:** broadcasting, numpy-arrays • **Set B (exam register)** — five-option
# multiple choice; work it by hand before touching the keyboard.
#
# Let
#
# ```python
# A = np.arange(6).reshape(2, 3)
# B = np.ones(3)
# ```
#
# Exactly one statement about `C = A + B` is true. Record your choice as a letter.
#
# - **(A)** The operation raises an error because the shapes `(2, 3)` and `(3,)`
#   differ.
# - **(B)** `C` has shape `(2, 3)` and dtype `float64`.
# - **(C)** `C` has shape `(2, 3)` and dtype `int64`.
# - **(D)** `C` has shape `(3, 3)` and dtype `float64`.
# - **(E)** `C` has shape `(3,)` because the smaller shape wins.

# %%
import numpy as np

# %% [markdown]
# **Your answer.** Replace the `"?"` with a single letter `"A"`–`"E"`. (Reason it
# out first: apply the shape-compatibility rules, then think about what dtype
# `int64 + float64` produces.)

# %%
answer_p08 = "?"

# %% [markdown]
# **Verify in code** (after committing to an answer): build `C`, print its shape
# and dtype.

# %%
# YOUR CODE HERE
