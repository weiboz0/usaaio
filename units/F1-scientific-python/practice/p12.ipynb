# %% [markdown]
# # F1-scientific-python — Practice p12
#
# **Concepts:** random-seeding, aggregation-axis • **Set C (scenario
# analysis)** — judgment, not just computation. A classmate shows you this
# notebook cell and complains: *"my numbers change every time I run it, and my
# per-student averages look wrong — there are only 30 students but I get 4
# numbers."*
#
# ```python
# rng = np.random.default_rng()
# data = rng.integers(50, 101, size=(30, 4))   # 30 students x 4 quiz scores
# student_avg = data.mean(axis=0)              # meant to be one average per student
# print(student_avg)
# ```
#
# Diagnose both problems in writing, then fix them in code.

# %%
import numpy as np

# %% [markdown]
# **Part a — why do the numbers change every run?** Explain in 1–3 sentences in
# the markdown cell below (edit it), naming the exact line at fault and the fix.
#
# *(Write your explanation here.)*

# %%
# no code needed for part a — write your explanation in the markdown cell above

# %% [markdown]
# **Part b — why 4 numbers instead of 30?** Explain in 1–2 sentences (edit this
# cell): which axis did the classmate collapse, and which should it have been?
#
# *(Write your explanation here.)*

# %%
# no code needed for part b — write your explanation in the markdown cell above

# %% [markdown]
# **Part c — the corrected cell.** Write the fixed version: `SEED = 20260804`,
# a seeded `rng`, the same `(30, 4)` draw as **`data_fixed`**, and
# **`student_avg_fixed`** with shape `(30,)`. Then demonstrate reproducibility:
# build a second generator from the same seed, redraw, and show the two `data`
# arrays are identical.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Part d — judgment call.** The classmate suggests: *"easier fix — I'll just
# rerun until the averages look reasonable, screenshot them, and hardcode the
# numbers."* In 2–3 sentences (edit this cell): why is seeding the right practice
# instead?
#
# *(Write your answer here.)*

# %%
# no code needed for part d — write your answer in the markdown cell above
