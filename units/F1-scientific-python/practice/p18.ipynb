# %% [markdown]
# # F1-scientific-python — Practice p18
#
# **Concepts:** array-indexing-slicing, aggregation-axis • **Set B (exam
# register)** — predict-the-output multiple choice. By hand only, then verify.
#
# Let
#
# ```python
# A = np.arange(1, 13).reshape(3, 4)
# ```
#
# What is the value of `A[1:, ::2].sum(axis=1)`?
#
# - **(A)** `[12 20]`
# - **(B)** `[14 18]`
# - **(C)** `[26 42]`
# - **(D)** `[14 22]`
# - **(E)** an error is raised

# %%
import numpy as np

# %% [markdown]
# **Your answer.** Replace the `"?"` with a single letter `"A"`–`"E"`, and write
# your trace (rows kept, columns kept, what the axis collapse does) in the
# markdown cell below.
#
# *(Write your trace here.)*

# %%
answer_p18 = "?"

# %% [markdown]
# **Verify in code** after committing to an answer.

# %%
# YOUR CODE HERE
