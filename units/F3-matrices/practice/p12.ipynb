# %% [markdown]
# # F3-matrices — Practice p12
#
# **Type:** proof · **Difficulty:** advanced · **Concepts:** linear independence & span, invertibility via rank
#
# **Reasoning is required.**
#
# A $3\times 3$ matrix $A$ has rows $r_1, r_2, r_3$ satisfying $r_3 = r_1 - 2r_2$.
#
# **(a)** Show that any combination $c_1 r_1 + c_2 r_2 + c_3 r_3$ can be rewritten using only $r_1$ and $r_2$ — hence the span of the rows has at most 2 independent directions and $\mathrm{rank}(A) \le 2$.
#
# **(b)** Explain in 2-3 sentences why a $3\times 3$ matrix with rank $\le 2$ cannot be inverted, arguing from the map picture: some 3-D target vectors are never reached, OR two different inputs collide on the same output (either argument accepted; connect it to what an inverse would have to undo).
#
# **(c) Concrete anchor:** for $r_1 = (1, 0, 2)$, $r_2 = (0, 1, -1)$, build $A$, and exhibit a nonzero vector `x_collide` with $A$ applied to `x_collide` = 0 (find it from the row relation; verify `collide_norm` — the length of the output — is ≈ 0 using broadcasting only, no `@`).

# %% [markdown]
# *Your reasoning for (a)–(b) here.*

# %%
import numpy as np

r1 = np.array([1., 0., 2.])
r2 = np.array([0., 1., -1.])
# (c) YOUR CODE HERE
A = ...
x_collide = ...
collide_norm = ...
