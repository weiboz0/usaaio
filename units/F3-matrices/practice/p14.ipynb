# %% [markdown]
# # F3-matrices — Practice p14
#
# **Type:** integrative · **Difficulty:** core · **Concepts:** Gram matrices, matrix multiplication, linear independence & span
#
# Gram as a dependence detector.
#
# **(a)** For the seeded `W (5, 3)` below (which hides one dependent row), compute `G = gram(W)` (p07 bans apply).
#
# **(b)** Using YOUR `G`: compute the cosine grid `C` as in p10 and find `dependent_pair` — the (i, j), i<j, with the largest |cosine| below the exact-1 diagonal (use index grids; report as a tuple).
#
# **(c)** Verify directly: for your pair, compute `alpha` — the scalar with $w_j \approx \alpha\, w_i$ (least-surprise route: ratio of dot products or of lengths with sign) — and `dependence_gap` = length of $w_j - \alpha w_i$.
#
# **(d)** One sentence: what does (c) certify about the rank of `W`, via the independent-direction count?

# %%
import numpy as np

SEED = 20260804
rng = np.random.default_rng(SEED)
W = rng.normal(0, 1, (5, 3))
W[3] = -1.7 * W[1]   # the hidden dependence

def gram(W):
    # YOUR CODE HERE (p07 bans)
    ...

G = ...              # YOUR CODE HERE
C = ...              # YOUR CODE HERE
dependent_pair = ... # YOUR CODE HERE
alpha = ...          # YOUR CODE HERE
dependence_gap = ... # YOUR CODE HERE

# %% [markdown]
# *Your (d) sentence here.*
