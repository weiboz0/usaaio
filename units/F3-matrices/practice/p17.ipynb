# %% [markdown]
# # F3-matrices — Practice p17
#
# **Type:** challenge · **Difficulty:** advanced · **Concepts:** outer products, matrix from action, rank
#
# Minimal rank-1 decomposition of an action.
#
# A map on $\mathbb{R}^4$ acts by
# $$S x = \big(x_0 - x_2,\ 2x_0 - 2x_2 + x_1,\ x_1,\ 3x_0 - 3x_2\big).$$
#
# **(a)** Reconstruct `S` (4×4).
#
# **(b)** Determine `I_min` — the smallest number of outer products whose sum equals `S` — by finding the independent-direction count of `S`'s columns (reason in markdown; no `np.linalg`).
#
# **(c)** Exhibit such a minimal decomposition: arrays `us` and `vs`, each with `I_min` rows, with $S = \sum_i$ outer(`us[i]`, `vs[i]`) — verify `decomp_gap` ≈ 0 (broadcasting only; a loop over the `I_min` terms is allowed for the summation).
#
# **(d)** 1-2 sentences: why can't fewer than `I_min` outer products work? (Connect to the rank bound: a sum of $k$ rank-1 pieces has rank at most $k$.)

# %% [markdown]
# *Your (a)/(b) reasoning here.*

# %%
import numpy as np

# YOUR CODE HERE
S = ...
I_min = ...
us = ...
vs = ...
decomp_gap = ...

# %% [markdown]
# *Your (d) argument here.*
