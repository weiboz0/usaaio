# %% [markdown]
# # F3-matrices — Practice p15
#
# **Type:** scenario analysis · **Difficulty:** core · **Concepts:** matrices as linear maps, matrix from action
#
# An image-editing tool applies 2-D point transformations. The vendor documents transform "Style-K" only through examples: $(1,0)\mapsto(2,0)$, $(0,1)\mapsto(0,3)$, and $(1,1)\mapsto(2,3)$.
#
# **(a)** Is Style-K consistent with a LINEAR map? Check using the third example against the first two (markdown reasoning), then reconstruct its matrix `K` if so.
#
# **(b)** A second transform "Style-L" is documented by $(1,0)\mapsto(1,1)$, $(0,1)\mapsto(-1,1)$, and $(2,-1)\mapsto(3,0)$. Same check: consistent with linearity? Reconstruct `L` or set `L = None` and explain.
#
# **(c)** 2-3 sentences: why do TWO basis examples suffice to pin down any linear 2-D transform, and what role does the third example play in each case above? Compute `check_K`, `check_L` (max abs deviation of the third documented example from the reconstructed map's prediction; broadcasting only).

# %% [markdown]
# *Your (a)/(b) reasoning here.*

# %%
import numpy as np

# YOUR CODE HERE
K = ...
check_K = ...
L = ...        # or None
check_L = ...  # deviation for Style-L's third example

# %% [markdown]
# *Your (c) explanation here.*
