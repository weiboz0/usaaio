# %% [markdown]
# # F3-matrices — Practice p07
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** matrix multiplication, Gram matrices
#
# The exam's banned-`@` register.
#
# Write `gram(W)` computing the Gram matrix $G = W W^{\mathsf T}$ of `W (n, d)` — that is, $G_{ij}$ = dot product of rows $i$ and $j$ of $W$.
#
# **Banned (zero points): `@`, `np.matmul`, `np.dot`, `.T`, `np.einsum`, loops.** Route: `(W[:, None, :] * W[None, :, :]).sum(axis=2)`-style broadcasting.
#
# For the seeded `W` below: `G = gram(W)`; then `diag_check` = max abs difference between `np.diagonal(G)` and the squared row lengths; and `sym_check` = max abs difference between `G` and its mirror `G_mirror` (obtained WITHOUT `.T` — hint: `np.swapaxes` is also banned; recompute or use `G[j, i]` thinking via fancy indexing `G[np.arange...]`… simplest legal route: `np.transpose` is ALSO banned — instead verify symmetry by asserting `G[i, j]` entries equal `gram`'s value computed with rows swapped, i.e. `sym_check = np.abs(G - gram(W)[::1]).max()` is trivial — so instead: build index grids `I, J` with broadcasting and compare `G[I, J]` to `G[J, I]`).

# %%
import numpy as np

SEED = 20260804
rng = np.random.default_rng(SEED)
W = rng.normal(0, 1, (6, 4))

def gram(W):
    # YOUR CODE HERE (banned: @, np.matmul, np.dot, .T, np.einsum, loops)
    ...

G = ...          # YOUR CODE HERE
diag_check = ... # YOUR CODE HERE
sym_check = ...  # YOUR CODE HERE (index-grid comparison)
