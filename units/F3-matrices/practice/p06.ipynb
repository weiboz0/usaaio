# %% [markdown]
# # F3-matrices — Practice p06
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** matrix multiplication
#
# Row-times-column, spelled out.
#
# Write `matmul_manual(A, B)` computing the matrix product of `A (n, k)` and `B (k, m)` **with two nested loops over the output entries** (this problem's point is the definition — loops are REQUIRED here; each output entry must be computed as an explicit sum of products, `np.sum` over a 1-D slice allowed).
#
# Then check it: for the seeded matrices below, compute `C_manual = matmul_manual(A, B)`, `C_fast = A @ B`, and `agreement_gap` = max abs difference.
#
# Banned inside `matmul_manual` (zero points): `@`, `np.matmul`, `np.dot`, `np.einsum`, `np.tensordot`.

# %%
import numpy as np

SEED = 20260804
rng = np.random.default_rng(SEED)
A = rng.normal(0, 1, (4, 3))
B = rng.normal(0, 1, (3, 5))

def matmul_manual(A, B):
    # YOUR CODE HERE (nested loops REQUIRED)
    ...

C_manual = ...      # YOUR CODE HERE
C_fast = ...        # YOUR CODE HERE
agreement_gap = ... # YOUR CODE HERE
