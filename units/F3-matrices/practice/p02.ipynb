# %% [markdown]
# # F3-matrices — Practice p02
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** matrix multiplication
#
# Let $A$ be a $2\times 3$ matrix and $B$ a $3\times 4$ matrix.
#
# Which statement about products is correct?
#
# A. $AB$ is $3\times 3$ and $BA$ is $2\times 4$.
#
# B. $AB$ is $2\times 4$ and $BA$ is undefined.
#
# C. $AB$ is undefined and $BA$ is $3\times 2$.
#
# D. Both $AB$ and $BA$ are defined whenever the total number of entries matches.
#
# E. $AB$ is $2\times 4$ and $BA$ is $4\times 2$.
#
# Record your choice below.

# %%
import numpy as np

answer_p02 = "?"  # replace with "A".."E"
