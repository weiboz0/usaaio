# %% [markdown]
# # F3-matrices — Practice p08
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** matrix from action
#
# Probe the machine.
#
# You are given a mystery linear map as a Python function `mystery(x)` (below) taking a shape-`(4,)` vector. Because the map is linear, feeding it the four standard basis vectors reveals the full matrix: column $j$ of $M$ is `mystery(e_j)`.
#
# Write `reconstruct(fn, d)` returning the `(d, d)` matrix of the linear map `fn` by probing with basis vectors — build the identity's rows with `np.eye`, probe, and assemble. A loop over the d probes IS allowed; nothing else may loop.
#
# Set `M = reconstruct(mystery, 4)`, then verify on a fresh seeded vector: `probe_gap` = max abs difference between `mystery(v)` and the product `M` applied to `v` via broadcasting (banned in the verification: `@`, `np.matmul`, `np.dot`).

# %%
import numpy as np

def mystery(x):
    return np.array([x[1] - x[3], 2*x[0], x[2] + x[3], x[0] - x[1]])

def reconstruct(fn, d):
    # YOUR CODE HERE
    ...

M = ...          # YOUR CODE HERE
SEED = 20260804
rng = np.random.default_rng(SEED)
v = rng.normal(0, 1, 4)
probe_gap = ...  # YOUR CODE HERE
