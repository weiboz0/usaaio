# %% [markdown]
# # F5-probability — Practice p17
#
# **Type:** challenge · **Difficulty:** advanced · **Concepts:** variance of sums, independence
#
# A portfolio splits a fixed budget across $C$ independent ventures. Venture $c$ returns $x_c$ per unit invested, with $E[x_c] = 0$ and $\mathrm{Var}[x_c] = \sigma^2$ (same for all). Investing fraction $w_c \ge 0$ (with $\sum_c w_c = 1$) gives total return $y = \sum_c w_c x_c$.
#
# **(a)** Express $\mathrm{Var}[y]$ in terms of the $w_c$ and $\sigma^2$ (state the rules used).
#
# **(b)** Among equal splits $w_c = 1/C$, what is $\mathrm{Var}[y]$? What happens as $C$ grows?
#
# **(c)** Prove the equal split minimizes $\mathrm{Var}[y]$ over all valid weight choices for fixed $C$ (hint from the lesson's pitfalls: compare $\sum w_c^2$ with $1/C$ by expanding $\sum_c (w_c - 1/C)^2 \ge 0$).
#
# **(d) Concrete anchor:** $C = 5$, $\sigma^2 = 4$: compute `var_equal` (equal split) and `var_skewed` for $w = (0.6, 0.1, 0.1, 0.1, 0.1)$ by hand in markdown, then verify both by seeded simulation (`SEED = 20260804`, 300,000 draws each, `rng.normal` allowed, no loops).

# %% [markdown]
# *Your reasoning for (a)–(c) and hand values for (d) here.*

# %%
import numpy as np

SEED = 20260804
rng = np.random.default_rng(SEED)

# (d) YOUR CODE HERE
var_equal = ...
var_skewed = ...
sim_var_equal = ...
sim_var_skewed = ...
