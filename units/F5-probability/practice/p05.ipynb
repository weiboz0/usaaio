# %% [markdown]
# # F5-probability — Practice p05
#
# **Type:** constrained coding · **Difficulty:** intro · **Concepts:** sampling & simulation, random variables
#
# Simulate rolling two fair six-sided dice and summing them.
#
# Write a function `simulate_sums`:
#
# 1. Inputs: integer `n_trials`, integer `seed`.
# 2. Create `rng = np.random.default_rng(seed)` INSIDE the function.
# 3. Simulate `n_trials` rolls of two dice (values 1–6 each, equally likely) and return a NumPy array of shape `(n_trials,)` holding the sums.
#
# Constraints: you may use only `rng.integers` for randomness; **no Python loops** (`for`, `while`, comprehensions) — a submission containing any of them scores zero.
#
# Then, using `simulate_sums(100_000, 20260804)`, compute the fraction of sums equal to 7 and store it in `frac_seven`.

# %%
import numpy as np

def simulate_sums(n_trials, seed):
    # YOUR CODE HERE
    ...

frac_seven = ...  # YOUR CODE HERE
