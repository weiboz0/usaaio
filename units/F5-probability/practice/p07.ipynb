# %% [markdown]
# # F5-probability — Practice p07
#
# **Type:** constrained coding · **Difficulty:** intro · **Concepts:** variance
#
# Write `my_variance(values, probs)` computing the variance of a discrete random variable from its value/probability tables:
#
# 1. Inputs: NumPy arrays `values` (shape `(k,)`) and `probs` (shape `(k,)`, summing to 1).
# 2. Return $\mathrm{Var} = E[X^2] - (E[X])^2$ computed **from the definition of expectation as a probability-weighted sum**.
#
# Constraints: `np.var`, `np.average`, and `np.mean` are **banned** (zero points) — use elementwise multiplication and `.sum()` only. No loops.
#
# Evaluate `v = my_variance(np.array([1., 3., 7.]), np.array([0.25, 0.5, 0.25]))`.

# %%
import numpy as np

def my_variance(values, probs):
    # YOUR CODE HERE
    ...

v = ...  # YOUR CODE HERE
