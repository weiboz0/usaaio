# %% [markdown]
# # F5-probability — Practice p11
#
# **Type:** proof · **Difficulty:** advanced · **Concepts:** variance of sums, independence, expectation
#
# **Reasoning is required.**
#
# Let $x_0, \dots, x_{C-1}$ and $s_0, \dots, s_{C-1}$ be $2C$ mutually independent random variables with $E[s_c] = E[x_c] = 0$, $\mathrm{Var}[s_c] = \sigma_s^2$, and $\mathrm{Var}[x_c] = \sigma^2$ for every $c$. Define the scaled sum
# $$y = \sum_{c=0}^{C-1} s_c\, x_c.$$
#
# **(a)** Show that $E[s_c x_c] = 0$ for each $c$, stating the fact about independent random variables you use.
#
# **(b)** Show that $\mathrm{Var}[s_c x_c] = \sigma_s^2 \sigma^2$.
#
# **(c)** Conclude that $\mathrm{Var}[y] = C\,\sigma_s^2\sigma^2$, and solve for the $\sigma_s$ that makes $\mathrm{Var}[y] = \sigma^2$.
#
# **(d) Concrete anchor:** for $C = 4$, $\sigma^2 = 9$, and your $\sigma_s$ from (c), verify by seeded simulation (`SEED = 20260804`, 400,000 samples, `rng.normal` allowed here as the stated-fact sampler) that the simulated $\mathrm{Var}[y]$ lands near 9. Write your reasoning for (a)–(c) in the markdown cell; put (d) in the code cell.

# %% [markdown]
# *Your reasoning for (a)–(c) here.*

# %%
import numpy as np

SEED = 20260804
rng = np.random.default_rng(SEED)

# (d) YOUR CODE HERE
sim_var_y = ...
