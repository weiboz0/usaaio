# %% [markdown]
# # F5-probability — Practice p13
#
# **Type:** integrative (parts consume earlier results) · **Difficulty:** core · **Concepts:** random variables, expectation, variance, sampling & simulation
#
# A delivery depot models the number of parcels $P$ arriving per minute as taking values 0, 1, 2, 3 with probabilities 0.35, 0.35, 0.2, 0.1.
#
# **(a)** Compute `mu` $= E[P]$ and `var_p` $= \mathrm{Var}[P]$ exactly from the tables (probability-weighted sums; `np.var`/`np.average` banned — zero points).
#
# **(b)** Using YOUR `mu` and `var_p` from (a): the depot watches for 900 independent minutes; let $T$ be the total parcel count. Compute `mu_T` and `var_T` exactly using linearity and the variance-of-sums rule (no simulation).
#
# **(c)** Simulate $T$ 50,000 times (`SEED = 20260804`, index-lookup sampling as in p06, one `(50_000, 900)` array, no loops) and compute `sim_mu_T`, `sim_var_T`.
#
# **(d)** Set `mu_gap = abs(mu_T - sim_mu_T)` and `var_gap = abs(var_T - sim_var_T)`; one sentence on whether (c) confirms (b).

# %%
import numpy as np

values = np.array([0., 1., 2., 3.])
probs = np.array([0.35, 0.35, 0.2, 0.1])

# (a) YOUR CODE HERE
mu = ...
var_p = ...

# (b) YOUR CODE HERE
mu_T = ...
var_T = ...

# (c) YOUR CODE HERE
SEED = 20260804
sim_mu_T = ...
sim_var_T = ...

# (d)
mu_gap = ...
var_gap = ...

# %% [markdown]
# *Your one-sentence conclusion here.*
