# %% [markdown]
# # F5-probability — Practice p08
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** variance of sums, independence
#
# Verify the variance-of-sums rule by simulation.
#
# 1. With `rng = np.random.default_rng(20260804)`, draw two INDEPENDENT samples `x` and `y`, each of shape `(500_000,)`: `x` uniform integers from {1,…,6} (a die), `y` from {0, 2, 5} with equal probability (index trick from p06; `rng.choice` banned, zero points).
# 2. Compute `var_x`, `var_y`, `var_sum` = the sample variances of `x`, `y`, and `x + y` (here `np.var` IS allowed — the point is the identity, not reimplementation).
# 3. Set `additivity_gap = abs(var_sum - (var_x + var_y))`.
# 4. In a markdown cell, state in one sentence WHY the gap should be small, naming the property of `x` and `y` that licenses the rule.
#
# No loops anywhere.

# %%
import numpy as np

rng = np.random.default_rng(20260804)

# YOUR CODE HERE
var_x = ...
var_y = ...
var_sum = ...
additivity_gap = ...

# %% [markdown]
# *Your one-sentence explanation here.*
