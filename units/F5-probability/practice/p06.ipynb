# %% [markdown]
# # F5-probability — Practice p06
#
# **Type:** constrained coding · **Difficulty:** intro · **Concepts:** expectation, sampling & simulation
#
# The wheel from the lesson pays 0, 0, 2, 5, 13 tokens on five equally likely sectors.
#
# 1. Compute the exact expectation `exact_mean` from the definition (a plain arithmetic expression — no randomness).
# 2. Write `estimate_mean(n_spins, seed)`: seeded `default_rng`, simulate `n_spins` spins by sampling sector indices with `rng.integers`, return the average payout. No loops.
# 3. Set `est = estimate_mean(200_000, 20260804)` and `gap = abs(est - exact_mean)`.
#
# Constraint: `np.mean` is allowed; `rng.choice` is **banned** (build the payout lookup with array indexing) — zero points otherwise.

# %%
import numpy as np

payouts = np.array([0, 0, 2, 5, 13])

exact_mean = ...  # YOUR CODE HERE

def estimate_mean(n_spins, seed):
    # YOUR CODE HERE
    ...

est = ...  # YOUR CODE HERE
gap = ...  # YOUR CODE HERE
