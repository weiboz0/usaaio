# %% [markdown]
# # F5-probability — Practice p09
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** Gaussian distribution, sampling & simulation
#
# Build bell-curve evidence from sums.
#
# 1. `rng = np.random.default_rng(20260804)`.
# 2. Create `sums`: 100,000 rows of 40 fair coin flips (0/1 via `rng.integers`), summed per row — shape `(100_000,)`. No loops (zero points).
# 3. Standardize: `z = (sums - sums.mean()) / sums.std()`.
# 4. Compute `inside_1sd`, `inside_2sd`: the fractions of `z` within 1 and within 2 of 0.
# 5. Plot a 30-bin histogram of `z` with title and axis labels.
#
# In a markdown cell: compare `inside_1sd`/`inside_2sd` to the Gaussian facts stated in the lesson (≈0.68 / ≈0.95) in one sentence.

# %%
import numpy as np
import matplotlib.pyplot as plt

rng = np.random.default_rng(20260804)

# YOUR CODE HERE
sums = ...
z = ...
inside_1sd = ...
inside_2sd = ...

# %% [markdown]
# *Your one-sentence comparison here.*
