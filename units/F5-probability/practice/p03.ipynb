# %% [markdown]
# # F5-probability — Practice p03
#
# **Type:** multiple choice · **Difficulty:** core · **Concepts:** variance, variance of sums
#
# $X$ and $Y$ are **independent** random variables with $\mathrm{Var}[X] = 4$ and $\mathrm{Var}[Y] = 9$.
# Let $S = X + Y$ and $D = X - Y$.
#
# Which statement is true?
#
# A. $\mathrm{Var}[S] = 13$ and $\mathrm{Var}[D] = -5$.
#
# B. $\mathrm{Var}[S] = 13$ and $\mathrm{Var}[D] = 5$.
#
# C. $\mathrm{Var}[S] = 13$ and $\mathrm{Var}[D] = 13$.
#
# D. $\mathrm{Var}[S] = \sqrt{4}+\sqrt{9} = 5$ and $\mathrm{Var}[D] = 1$.
#
# E. Nothing can be said without knowing $E[X]$ and $E[Y]$.
#
# Record your choice below.

# %%
import numpy as np

answer_p03 = "?"  # replace with "A".."E"
