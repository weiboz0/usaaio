# %% [markdown]
# # F5-probability — Practice p01
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** random variables
#
# A weather station records, every day, the number of lightning strikes detected (a whole number ≥ 0).
# Call this daily count $L$.
#
# Which statement best describes what makes $L$ a **random variable**?
#
# A. $L$ is random, so it can take any value with equal chance.
#
# B. $L$ is a quantity whose value is determined by the outcome of a repeatable uncertain process, taking one of a set of possible values each day.
#
# C. $L$ is a variable in Python whose value changes when the program re-runs.
#
# D. $L$ is unpredictable, so no statements about its long-run behaviour are possible.
#
# E. $L$ becomes a random variable only after we compute its average.
#
# Record your choice below.

# %%
import numpy as np

answer_p01 = "?"  # replace with "A".."E"
