# %% [markdown]
# # F5-probability — Practice p14
#
# **Type:** integrative · **Difficulty:** advanced · **Concepts:** variance of sums, Gaussian distribution, sampling & simulation
#
# **(a)** A sensor's reading is the sum of 25 independent error sources, each uniform on the integers {−2, −1, 0, 1, 2}. Compute the exact `mu_R` and `var_R` of the total reading $R$ (single-source variance first — probability-weighted sums, `np.var` banned).
#
# **(b)** Using (a): the lesson's stated Gaussian facts say roughly 95% of readings should land within $2\sqrt{\mathrm{Var}[R]}$ of $\mu_R$. Compute that interval's endpoints `lo`, `hi`.
#
# **(c)** Simulate 200,000 readings (`SEED = 20260804`, one array, no loops), compute `frac_inside` = fraction inside `[lo, hi]`, and state in one sentence whether the Gaussian approximation held and WHY a sum of many independent pieces should look Gaussian (the lesson's stated fact).

# %%
import numpy as np

# (a) YOUR CODE HERE
mu_R = ...
var_R = ...

# (b) YOUR CODE HERE
lo = ...
hi = ...

# (c) YOUR CODE HERE
SEED = 20260804
frac_inside = ...

# %% [markdown]
# *Your one-sentence conclusion here.*
