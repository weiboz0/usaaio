# %% [markdown]
# # C10-competition-craft — Practice p01
#
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** prediction function contract
#
# A fitted scaler+kNN pipeline named `pipe` already exists
# (trained on the apiary table), and `X_test` is a feature `DataFrame`
# in the training column order.
#
# Which implementation honors this course's prediction-function
# contract?
#
# A.
# ```python
# def predict_labels(X_test):
#     return list(pipe.predict(X_test))
# ```
#
# B.
# ```python
# def predict_labels(X_test):
#     return pd.Series(pipe.predict(X_test), index=X_test.index)
# ```
#
# C.
# ```python
# def predict_labels(X_test):
#     return pd.Series(pipe.predict(X_test)).reset_index(drop=True)
# ```
#
# D.
# ```python
# def predict_labels(X_test):
#     return pd.DataFrame({"label": pipe.predict(X_test)},
#                         index=X_test.index)
# ```
#
# E.
# ```python
# def predict_labels(X_test):
#     return pipe.predict(X_test)
# ```
#
# Record your choice below.

# %%
import numpy as np

answer_p01 = "?"  # replace with "A".."E"
