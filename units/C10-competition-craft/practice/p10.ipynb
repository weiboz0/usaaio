# %% [markdown]
# # C10-competition-craft — Practice p10
#
#
# **Type:** constrained coding · **Difficulty:** advanced · **Concepts:** notebook discipline
#
# Hunt the nondeterminism, then prove the fix.
#
# A teammate's experiment function is transcribed below.
# Their notebook prints a different `val_f1` on every Restart & Run
# All, and their writeup's claimed number matches none of them:
#
# ```python
# def run_experiment():                        # THEIR VERSION (broken)
#     perm = np.random.permutation(len(df))    # <-- unseeded, global RNG
#     val_idx, tr_idx = perm[:150], perm[150:]
#     pipe = Pipeline([("scaler", StandardScaler()),
#                      ("knn", KNeighborsClassifier(n_neighbors=7))])
#     pipe.fit(X.iloc[tr_idx], y[tr_idx])
#     preds = pipe.predict(X.iloc[val_idx])
#     return f1_score(y[val_idx], preds, average="macro"), preds
# ```
#
# Your job:
#
# 1. rewrite `run_experiment` so the **whole flow is deterministic**:
#    the permutation must come from
#    `np.random.default_rng(SEED).permutation(len(df))` — a fresh,
#    seeded generator created *inside* the function; everything else
#    unchanged (same split sizes, same `k = 7`, same pipeline);
# 2. `f1_a, preds_a` and `f1_b, preds_b` — two independent calls;
# 3. `deterministic` — `True` iff `f1_a == f1_b` **exactly** and
#    `(preds_a == preds_b).all()`.
#
# Two written sentences: which discipline rule the original breaks,
# and why the audit in step 3 uses `==` rather than `np.isclose`.
#
# **Banned (zero points): any supervised estimator other than `KNeighborsClassifier` — including the LogisticRegression / RandomForest / GradientBoosting / SVC / MLP families, and re-implementing any of them by hand; reading or printing the held-back split; imports beyond `sklearn` / `numpy` / `pandas` / `matplotlib`.** Any preprocessing is allowed.
#
# **Additionally banned: `np.random.seed` / `np.random.permutation`
# (the legacy global RNG — the fix must use a seeded `default_rng`).**

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import f1_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

SEED = 20260804

df = pd.read_csv("../data/train.csv")
FEATURES = [c for c in df.columns if c != "outcome"]
X = df[FEATURES]
y = df["outcome"].to_numpy()


def run_experiment():
    ...                 # YOUR CODE HERE (the deterministic rewrite)


f1_a, preds_a = ...     # YOUR CODE HERE
f1_b, preds_b = ...     # YOUR CODE HERE
deterministic = ...     # YOUR CODE HERE (bool)

# %% [markdown]
# *Your two written sentences here.*
