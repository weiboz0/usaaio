# %% [markdown]
# # C10-competition-craft — Practice p03
#
#
# **Type:** multiple choice · **Difficulty:** core · **Concepts:** metric driven iteration
#
# Four teammates iterate on the apiary task (graded metric:
# macro-F1 on a held-back split).
# Which workflow is the honest one?
#
# A. Carve one seeded validation split; sweep candidates judged by
# validation *accuracy*; report the winner's validation macro-F1.
#
# B. For each candidate, carve a *fresh* validation split with a new
# seed, so no split gets worn out; compare the candidates' scores.
#
# C. Freeze one seeded, stratified validation carve; judge every
# candidate by validation macro-F1; log every attempt, cap the number
# of iterations, and expect the held-back score to land slightly below
# the final validation number.
#
# D. Judge candidates by macro-F1 on the *training* rows — with 450
# rows instead of 150, the estimate is steadier.
#
# E. Iterate on the frozen carve without a cap until validation
# macro-F1 stops improving, then report the final validation number as
# the expected held-back score.
#
# Record your choice below.

# %%
import numpy as np

answer_p03 = "?"  # replace with "A".."E"
