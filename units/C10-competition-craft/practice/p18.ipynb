# %% [markdown]
# # C10-competition-craft — Practice p18
#
#
# **Type:** challenge · **Difficulty:** advanced · **Concepts:** writeup quality
#
# The grader's seat.
# A complete (flawed) submission is transcribed below.
# Audit it end to end: find the contract violation, expose the metric
# confusion, score the writeup, and produce the corrected version.
#
# **The submission (transcribed):**
#
# ```python
# # cell 1
# import numpy as np, pandas as pd
# from sklearn.metrics import f1_score
# from sklearn.model_selection import train_test_split
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.pipeline import Pipeline
# from sklearn.preprocessing import StandardScaler
# SEED = 20260804
# df = pd.read_csv("../data/train.csv")
# FEATURES = [c for c in df.columns if c != "outcome"]
# X, y = df[FEATURES], df["outcome"].to_numpy()
#
# # cell 2
# X_tr, X_val, y_tr, y_val = train_test_split(
#     X, y, test_size=150, random_state=SEED, stratify=y)
# model = Pipeline([("scaler", StandardScaler()),
#                   ("knn", KNeighborsClassifier(n_neighbors=9))])
# model.fit(X_tr, y_tr)
# print("our macro-F1:", model.score(X_val, y_val))   # prints 0.8066666666666666
#
# # cell 3
# model.fit(X, y)
# def predict_labels(X_test):
#     preds = model.predict(X_test)
#     pretty = np.char.capitalize(preds.astype(str))   # "Struggles"/"Thrives"
#     return pd.Series(pretty, index=X_test.index)
# ```
#
# **Its writeup:**
#
# > **Approach.** `StandardScaler` +
# > `KNeighborsClassifier(n_neighbors=9)` pipeline on all 12 features.
# > Our macro-F1 is 0.81.
# > **Intuition.** kNN is a strong algorithm and 9 is a good number of
# > neighbors.
# > Macro-F1 is the right metric because the 2:1 class imbalance means
# > accuracy would flatter a majority-only rule.
# > **Alternatives.** None — we got it right the first time.
#
# **(a) The contract audit (code).**
# Reproduce the submission's recipe and its `predict_labels` exactly;
# run the four self-checks on `probe = X.iloc[50:90]`;
# `violated_check` — the name of the check that fails (string, one of
# `"series"`, `"length"`, `"index"`, `"vocab"`).
#
# **(b) The metric audit (code).**
# `claimed` — the number cell 2 actually printed, recomputed (a
# `float`: what `.score` measures on the validation split);
# `honest_val_f1` — the same recipe's true validation **macro-F1** (a
# `float`).
# One written sentence: what `.score` computes for a classifier, and
# what the writeup therefore mislabeled.
#
# **(c) The rubric (code + written).**
# `rubric_scores` (dict, keys `"W-A1"`…`"W-C2"`, each 0 or 1) and
# `rubric_total` for the writeup as submitted — judge W-A2 against the FULL published
# rubric criterion (protocol AND value — exactly as p15 graded the same
# situation); in your written line, note separately that the value that IS
# present is also mislabeled — but do not double-penalize: the mislabel is
# audit (b)'s finding, while the missing protocol is what fails W-A2; then
# one written line per criterion.
#
# **(d) The rewrite (code + markdown).**
# `predict_labels_fixed` — the corrected contract function (training
# vocabulary, everything else unchanged); `fixed_ok` — all four checks
# pass on `probe`; and a corrected 6/6 writeup in the markdown cell,
# using your honest numbers from (b).
#
# **Banned (zero points): any supervised estimator other than `KNeighborsClassifier` — including the LogisticRegression / RandomForest / GradientBoosting / SVC / MLP families, and re-implementing any of them by hand; reading or printing the held-back split; imports beyond `sklearn` / `numpy` / `pandas` / `matplotlib`.** Any preprocessing is allowed.

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

SEED = 20260804

df = pd.read_csv("../data/train.csv")
FEATURES = [c for c in df.columns if c != "outcome"]
X = df[FEATURES]
y = df["outcome"].to_numpy()

# YOUR CODE HERE (reproduce the submission; audit it)

violated_check = ...  # YOUR CODE HERE (str)
claimed = ...         # YOUR CODE HERE (float)
honest_val_f1 = ...   # YOUR CODE HERE (float)
rubric_scores = ...   # YOUR CODE HERE (dict)
rubric_total = ...    # YOUR CODE HERE (int)


def predict_labels_fixed(X_test):
    ...               # YOUR CODE HERE


probe = X.iloc[50:90]
fixed_ok = ...        # YOUR CODE HERE (bool)

# %% [markdown]
# *Your (b)/(c) written parts and (d) corrected writeup here.*
