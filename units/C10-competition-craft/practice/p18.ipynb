# %% [markdown]
# # C10-competition-craft — Practice p18
#
# **Type:** challenge · **Difficulty:** advanced · **Budget:** 105 minutes
#
# **Concepts:** writeup-quality, colab-markdown-solution-authoring, markdown-code-snippets, markdown-math-formulae, colab-coding-submission, cpu-and-gpu-round-boundary, train-test-split, class-imbalance, accuracy-precision-recall, f1-macro, knn, feature-scaling, sklearn-pipelines
#
# Below is a raw Colab submission transcribed cell by cell, with its submitted cell type preserved. Audit what the artifact actually does, map every defect to a repair, and produce a corrected submission. The transcript is evidence, not a diagnosis list.
#
# ### Cell 1 — code
#
# ```python
# # Approach: kNN is powerful and our result is strong.
# # Intuition: scaling is probably useful.
# # Macro F1 = sum F1_k / K
# RUNTIME = "GPU"
# ```
#
# ### Cell 2 — text
#
# ````text
# ```python
# def predict_labels(X_test):
#     return final_model.predict(X_test)
# ````
#
# ### Cell 3 — code
#
# ```python
# import numpy as np, pandas as pd
# from sklearn.model_selection import train_test_split
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.pipeline import Pipeline
# from sklearn.preprocessing import StandardScaler
# SEED = 20260804
# df = pd.read_csv("../data/train.csv")
# FEATURES = [c for c in df.columns if c != "outcome"]
# X, y = df[FEATURES], df["outcome"].to_numpy()
# X_tr, X_val, y_tr, y_val = train_test_split(
#     X, y, test_size=150, random_state=SEED, stratify=y)
# trials = []
# for k in range(1, 52, 2):
#     trial = Pipeline([("scale", StandardScaler()),
#                       ("knn", KNeighborsClassifier(n_neighbors=k))])
#     trial.fit(X_tr, y_tr)
#     trials.append((trial.score(X_val, y_val), k, trial))
# claimed_macro_f1, best_k, final_model = max(trials)
# print("validation macro-F1", claimed_macro_f1)
# ```
#
# ### Cell 4 — text
#
# ````text
# The score is macro F1 = 2PR/P+R and all classes count the same.
# ```python def predict_labels(X_test): return final_model.predict(X_test)
# ````
#
# ### Cell 5 — code
#
# ```python
# def predict_label(X_test):
#     pretty = np.char.capitalize(final_model.predict(X_test).astype(str))
#     return pd.Series(pretty, index=X_test.index)
# probe = X.iloc[50:90]
# pd.DataFrame({"prediction": predict_label(probe)}).to_csv("final.csv")
# ```
#
# ### Cell 6 — text
#
# > **Approach.** We tried many neighbor counts and kept the best one.
# > **Intuition.** kNN is a strong algorithm.
# > **Alternatives.** None worth reporting.
# > Round 1 GPU enabled in Colab.
#
# Submit one artifact for each of the **six separately scored rows**.

# %% [markdown]
# | Row | Scored deliverable |
# |---|---|
# | 1 — writeup quality | A corrected **Approach / Intuition / Alternatives** section. It must accurately describe the repaired bounded selection, pinned validation, macro-F1, full refit, one measured alternative, and one limitation. |
# | 2 — Colab authoring | `cell_audit`: map each numbered source cell's submitted type, required type, complete defect set, and repair; then provide a corrected ordered `cell_plan`. |
# | 3 — fenced code | Repair and render the malformed `predict_labels` excerpt with matched `python` fences, while keeping the executable function in a code cell. |
# | 4 — Markdown math | Repair the malformed formula into display math, define `$K$` and `$F_{1,k}$`, and interpret equal class weighting. |
# | 5 — coding submission | Audit and repair the executable path under the exact bounded grid and artifacts below: one frozen stratified carve, true macro-F1, smallest-`k` tie rule, full refit, exact contract function, fresh-run stage trace, and immutable file checks. Submit the notebook itself as exactly `C10-p18.ipynb`; the grader opens that downloaded artifact and runs it fresh. |
# | 6 — CPU/GPU boundary | Diagnose the illegal GPU use and state Round 1 CPU only versus Round 2 Colab L4/GPU allowed, without teaching the later workflow. |
#
# **Banned (zero points): any supervised estimator other than `KNeighborsClassifier`, including reimplementations; an undeclared or unbounded candidate search; reading or printing the held-back split; imports beyond `sklearn`, `numpy`, `pandas`, and `matplotlib`; enabling or claiming a Round 1 GPU.**
#
# ### Corrected coding and artifact contract
#
# First reproduce the raw draft's selection exactly as an audit only: try every odd `k` from 1 through 51 on the same pinned carve, rank candidates by the raw classifier `.score`, and preserve the raw `max` tie behavior. Bind `raw_selected_model`, `raw_selected_k`, and `claimed_score`, where `claimed_score` is the raw draft's printed score. Then compute `raw_selected_macro_f1` from predictions made by that same `raw_selected_model` on that same validation carve. Record these two metrics separately from the corrected bounded-grid recipe; the raw reproduction must not choose or alter the corrected recipe.
#
# Evaluate exactly `K_GRID = np.array([5, 7, 9, 11, 15])` on the one pinned carve, using true validation macro-F1 and the smallest `k` on ties. `selection_log` has exactly columns `k,val_f1,selected`, exactly five rows in grid order, boolean `selected`, and exactly one selected row. Refit the selected scaled-kNN pipeline on all 600 labeled rows.
#
# Write `p18_audit.csv` with `index=False`, exactly columns `cell_number,submitted_type,required_type,defect,repair`, and exactly six rows ordered 1 through 6. Each row must completely describe that source cell; use semicolon-separated clauses where one cell has multiple defects. `submitted_type` must reproduce the transcript; `required_type` is exactly one of `text`, `code`, or `split`.
#
# Write `p18_predictions.csv` with `index=False`, exactly columns `row_id,prediction`, and exactly 40 rows. `row_id` equals `X.iloc[50:90].index` in order and `prediction` equals the repaired `predict_labels(X.iloc[50:90])` in order. No alternate filename, path, schema, or summary boolean substitutes for either artifact.

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

SEED = 20260804
K_GRID = np.array([5, 7, 9, 11, 15])
df = pd.read_csv("../data/train.csv")
FEATURES = [c for c in df.columns if c != "outcome"]
X = df[FEATURES]
y = df["outcome"].to_numpy()
stage_trace = ["setup"]

# %%
cell_audit = ...   # YOUR CODE HERE: six records, one per raw cell, complete defects/repairs
cell_plan = ...    # YOUR CODE HERE: corrected ordered (cell_type, purpose) tuples

# YOUR CODE HERE: make one pinned stratified carve and reproduce the raw selection for audit only
raw_selected_model = ...  # winner from odd k=1,...,51 ranked by raw .score and raw max ties
raw_selected_k = ...      # k belonging to raw_selected_model
claimed_score = raw_selected_model.score(X_val, y_val)
raw_selected_macro_f1 = f1_score(
    y_val, raw_selected_model.predict(X_val), average="macro")

# YOUR CODE HERE: separately evaluate exactly K_GRID with true macro-F1
selection_log = ...   # one row per k; exact columns k, val_f1, selected
selected_k = ...      # smallest k on ties
corrected_val_f1 = ...  # Python float for selected_k under the corrected recipe
stage_trace.append("select")

# %%
# YOUR CODE HERE: refit selected scaled-kNN pipeline on all labeled rows
final_model = ...

def predict_labels(X_test):
    # YOUR CODE HERE: preserve length, index, order, and original vocabulary
    ...

stage_trace.append("refit")
probe = X.iloc[50:90]
probe_predictions = predict_labels(probe)
direct_probe_predictions = final_model.predict(probe)
contract_checks = {
    "series": isinstance(probe_predictions, pd.Series),
    "length": len(probe_predictions) == len(probe),
    "index": probe_predictions.index.equals(probe.index),
    "vocab": set(probe_predictions.unique()) <= set(np.unique(y)),
}
assert all(contract_checks.values())
assert np.array_equal(probe_predictions.to_numpy(), direct_probe_predictions)
contract_ok = all(contract_checks.values())

# %%
# YOUR CODE HERE: write p18_audit.csv and p18_predictions.csv exactly as specified.
...
stage_trace.append("package")

_grader_X_tr, _grader_X_val, _grader_y_tr, _grader_y_val = train_test_split(
    X, y, test_size=150, random_state=SEED, stratify=y)

_grader_raw_records = []
for _grader_k in range(1, 52, 2):
    _grader_model = Pipeline([("scale", StandardScaler()),
                              ("knn", KNeighborsClassifier(n_neighbors=_grader_k))])
    _grader_model.fit(_grader_X_tr, _grader_y_tr)
    _grader_raw_records.append(
        (float(_grader_model.score(_grader_X_val, _grader_y_val)),
         _grader_k, _grader_model))
_grader_claimed_score, _grader_raw_k, _grader_raw_model = max(
    _grader_raw_records, key=lambda item: (item[0], item[1]))
_grader_raw_macro_f1 = float(f1_score(
    _grader_y_val, _grader_raw_model.predict(_grader_X_val), average="macro"))
assert isinstance(raw_selected_model, Pipeline)
assert raw_selected_model.named_steps["knn"].n_neighbors == _grader_raw_k
assert int(raw_selected_k) == _grader_raw_k
assert np.allclose(claimed_score, _grader_claimed_score, atol=1e-12, rtol=0)
assert np.array_equal(raw_selected_model.predict(_grader_X_val),
                      _grader_raw_model.predict(_grader_X_val))
assert np.allclose(raw_selected_macro_f1, _grader_raw_macro_f1, atol=1e-12, rtol=0)
assert raw_selected_model.named_steps["knn"]._fit_X.shape[0] == len(_grader_X_tr)

_grader_grid_scores = []
for _grader_k in K_GRID:
    _grader_model = Pipeline([("scale", StandardScaler()),
                              ("knn", KNeighborsClassifier(n_neighbors=int(_grader_k)))])
    _grader_model.fit(_grader_X_tr, _grader_y_tr)
    _grader_grid_scores.append(float(f1_score(
        _grader_y_val, _grader_model.predict(_grader_X_val), average="macro")))
_grader_best_score = max(_grader_grid_scores)
_grader_selected_k = min(int(k) for k, score in zip(K_GRID, _grader_grid_scores)
                         if score == _grader_best_score)
_grader_selected_flags = [int(k) == _grader_selected_k for k in K_GRID]
assert isinstance(selection_log, pd.DataFrame)
assert list(selection_log.columns) == ["k", "val_f1", "selected"]
assert selection_log.index.tolist() == [0, 1, 2, 3, 4]
assert selection_log["k"].tolist() == K_GRID.tolist()
assert pd.api.types.is_float_dtype(selection_log["val_f1"].dtype)
assert np.allclose(selection_log["val_f1"], _grader_grid_scores, atol=1e-12, rtol=0)
assert pd.api.types.is_bool_dtype(selection_log["selected"].dtype)
assert selection_log["selected"].tolist() == _grader_selected_flags
assert int(selection_log["selected"].sum()) == 1
assert int(selected_k) == _grader_selected_k
assert isinstance(corrected_val_f1, float)
assert np.allclose(corrected_val_f1, _grader_best_score, atol=1e-12, rtol=0)
assert isinstance(final_model, Pipeline)
assert list(final_model.named_steps) == ["scale", "knn"]
assert isinstance(final_model.named_steps["scale"], StandardScaler)
assert isinstance(final_model.named_steps["knn"], KNeighborsClassifier)
assert final_model.named_steps["knn"].n_neighbors == _grader_selected_k
assert final_model.feature_names_in_.tolist() == FEATURES
assert int(final_model.named_steps["scale"].n_samples_seen_) == len(X)
assert final_model.named_steps["knn"]._fit_X.shape == X.shape
assert np.array_equal(probe_predictions.to_numpy(), direct_probe_predictions)

saved_audit = pd.read_csv("p18_audit.csv")
saved_predictions = pd.read_csv("p18_predictions.csv")
assert list(saved_audit.columns) == ["cell_number", "submitted_type", "required_type", "defect", "repair"]
assert saved_audit["cell_number"].tolist() == [1, 2, 3, 4, 5, 6]
assert saved_audit["submitted_type"].tolist() == ["code", "text", "code", "text", "code", "text"]
assert set(saved_audit["required_type"]) <= {"text", "code", "split"}
assert saved_audit["defect"].str.strip().ne("").all()
assert saved_audit["repair"].str.strip().ne("").all()
assert list(saved_predictions.columns) == ["row_id", "prediction"]
assert len(saved_predictions) == 40
assert saved_predictions["row_id"].tolist() == probe.index.tolist()
assert saved_predictions["prediction"].tolist() == direct_probe_predictions.tolist()
assert stage_trace == ["setup", "select", "refit", "package"]

# %% [markdown]
# ## Row 1 — Corrected writeup
#
# ### Approach
#
# *Describe the repaired bounded pipeline, validation, metric, and refit using your computed values.*
#
# ### Intuition
#
# *Ground scaling/kNN and macro-F1 in this data and task.*
#
# ### Alternatives
#
# *Quote at least one measured grid alternative and state a limitation.*
#
# ## Row 3 — Repaired fenced excerpt
#
# *Insert the matched fenced Python excerpt here.*
#
# ## Row 4 — Repaired formula and interpretation
#
# *Insert display math, symbol definitions, and interpretation here.*
#
# ## Metric-audit sentence
#
# *State what neutral `claimed_score` computed, what the raw draft mislabeled, and how it compares with `raw_selected_macro_f1` for the same raw-selected model. Separately report `corrected_val_f1` for the corrected bounded-grid recipe.*
#
# ## Row 6 — Round-policy diagnosis
#
# *Write the diagnosis and exact boundary here.*
