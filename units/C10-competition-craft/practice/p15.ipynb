# %% [markdown]
# # C10-competition-craft — Practice p15
#
#
# **Type:** scenario · **Difficulty:** core · **Concepts:** writeup quality
#
# You are the grader.
# Score the writeup below against the unit's six-point rubric —
# mechanically, criterion by criterion.
#
# **The rubric** (from Session 3):
#
# | Criterion | +1 if the writeup… |
# |---|---|
# | W-A1 | names the full recipe: preprocessing, model family **with hyperparameter values**, feature set |
# | W-A2 | states the validation protocol (carve size, seed policy, stratification) **and** the final model's validation metric value |
# | W-B1 | grounds the model choice in a property of *this data* |
# | W-B2 | grounds the metric choice in a property of *this task* |
# | W-C1 | names ≥1 concrete alternative **with its measured outcome** or a precise reason for rejection |
# | W-C2 | states an honest limitation or next step |
#
# **The submitted writeup:**
#
# > **Approach.** We used a scaled k-nearest-neighbors pipeline
# > (`StandardScaler` + `KNeighborsClassifier(n_neighbors=9)`) on all
# > 12 features.
# > **Intuition.** After standardization each feature contributes
# > comparably to the distances, so colonies with similar inspection
# > profiles end up near each other — which is exactly the structure
# > kNN votes over.
# > We optimized macro-F1 because the classes are imbalanced roughly
# > 2:1 and the struggling colonies are the ones the apiary needs to
# > find.
# > **Alternatives.** We also tried k = 5 and k = 13.
# > Overall we believe our model is very strong.
#
# **(a)** `scores` — a dict with keys `"W-A1"`, `"W-A2"`, `"W-B1"`,
# `"W-B2"`, `"W-C1"`, `"W-C2"`, each 0 or 1; `total` — their sum.
#
# **(b)** Written: one line per criterion justifying the 0 or 1 —
# quote the phrase that earns the point or name exactly what is
# missing.
#
# **(c)** Written: rewrite the writeup so it would score 6/6 for the
# *same underlying work*, inventing **no** numbers you could not
# actually have — where a number is required that the writeup failed
# to record, write `[NUMBER]` and add one sentence naming which
# notebook output the grader should find it in.

# %%
import numpy as np

scores = ...  # YOUR CODE HERE (dict, six keys, each 0 or 1)
total = ...   # YOUR CODE HERE (int)

# %% [markdown]
# *Your (b) justifications and (c) rewrite here.*
