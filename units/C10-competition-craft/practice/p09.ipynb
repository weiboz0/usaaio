# %% [markdown]
# # C10-competition-craft — Practice p09
#
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** hidden test protocol
#
# A full grading rehearsal — on rows you *pretend* not to see.
#
# The protocol forbids touching the real held-back split, but nothing
# forbids simulating the whole ceremony inside the training table:
# carve off 200 rows, treat them as pretend-hidden, run your entire
# selection process without them, then score **once**.
#
# On `../data/train.csv` (bridge as usual):
#
# 1. `X_work, X_sim, y_work, y_sim = train_test_split(X, y,
#    test_size=200, random_state=SEED, stratify=y)` — `X_sim` is the
#    pretend-hidden split: from here until step 5 it must not be
#    touched;
# 2. from the 400 work rows, carve a validation split:
#    `train_test_split(X_work, y_work, test_size=100,
#    random_state=SEED, stratify=y_work)`;
# 3. for each `k` in `ks = [3, 5, 7, 9, 11]`: scaler+kNN pipeline on
#    the 300 training rows, validation macro-F1 → `val_f1s` (shape
#    `(5,)`); `best_k` — highest, smallest on ties;
# 4. refit the `best_k` pipeline on **all 400 work rows**;
# 5. `rehearsal_f1` — macro-F1 on the pretend-hidden rows: the one and
#    only evaluation they get;
# 6. `optimism_gap` — `val_f1s.max() - rehearsal_f1` (a `float`).
#
# Two written sentences: (i) why a positive `optimism_gap` was
# *expected* (name the mechanism from Session 2 §6); (ii) why this
# exercise is protocol-clean even though it "peeked" at `X_sim` in
# step 5.
#
# A loop over `ks` is permitted.
#
# **Banned (zero points): any supervised estimator other than `KNeighborsClassifier` — including the LogisticRegression / RandomForest / GradientBoosting / SVC / MLP families, and re-implementing any of them by hand; reading or printing the held-back split; imports beyond `sklearn` / `numpy` / `pandas` / `matplotlib`.** Any preprocessing is allowed.

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

SEED = 20260804
ks = np.array([3, 5, 7, 9, 11])

df = pd.read_csv("../data/train.csv")
FEATURES = [c for c in df.columns if c != "outcome"]
X = df[FEATURES]
y = df["outcome"].to_numpy()

# YOUR CODE HERE (two-stage carve, sweep, refit, single evaluation)

val_f1s = ...       # YOUR CODE HERE (shape (5,))
best_k = ...        # YOUR CODE HERE (int)
rehearsal_f1 = ...  # YOUR CODE HERE (float)
optimism_gap = ...  # YOUR CODE HERE (float)

# %% [markdown]
# *Your two written sentences here.*
