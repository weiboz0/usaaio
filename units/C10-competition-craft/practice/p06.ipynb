# %% [markdown]
# # C10-competition-craft — Practice p06
#
#
# **Type:** constrained coding · **Difficulty:** intro · **Concepts:** notebook discipline
#
# Seeds are promises: the same carve, every run, forever.
#
# Using `../data/train.csv` (bridge as usual to `X`, `y`):
#
# 1. `make_carve` — a function of **no arguments** returning
#    `X_tr, X_val, y_tr, y_val` via
#    `train_test_split(X, y, test_size=150, random_state=SEED,
#    stratify=y)`;
# 2. `val_counts` — dict mapping each label to its count in `y_val`
#    (plain `int`s);
# 3. `carve_identical` — call `make_carve()` **twice**; `True` iff the
#    two validation index sequences are *exactly* equal
#    (`.index.equals(...)`) and the two `y_val` arrays are elementwise
#    identical;
# 4. `seed_matters` — carve twice more with `random_state=1` and
#    `random_state=2` (all else unchanged); `True` iff those two
#    validation index sequences **differ** — the printed evidence that
#    an unpinned seed would break deterministic re-run.
#
# One written sentence below the code: which discipline rule (D1–D4)
# the two-call equality habit checks, and what a grader's
# Restart-&-Run-All does to a notebook that fails it.
#
# **Banned (zero points): `np.random.seed` (legacy global seeding);
# imports beyond `sklearn` / `numpy` / `pandas` / `matplotlib`.**

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

SEED = 20260804

df = pd.read_csv("../data/train.csv")
FEATURES = [c for c in df.columns if c != "outcome"]
X = df[FEATURES]
y = df["outcome"].to_numpy()


def make_carve():
    ...                # YOUR CODE HERE


val_counts = ...       # YOUR CODE HERE
carve_identical = ...  # YOUR CODE HERE
seed_matters = ...     # YOUR CODE HERE

# %% [markdown]
# *Your written sentence here.*
