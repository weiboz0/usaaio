# %% [markdown]
# # C10-competition-craft — Practice p13
#
#
# **Type:** integrative · **Difficulty:** core · **Concepts:** prediction function contract
#
# The submission arc, start to finish.
# Parts consume earlier results.
#
# On `../data/train.csv`:
#
# **(a)** Bridge: `X` (feature `DataFrame`, file column order), `y`;
# `class_counts` — dict label → `int` count.
#
# **(b)** The pinned carve:
# `train_test_split(X, y, test_size=150, random_state=SEED,
# stratify=y)`.
#
# **(c)** Baseline: scaler + 5-NN pipeline fit on the training part;
# `val_f1_base` — its validation macro-F1 (a `float`).
#
# **(d)** Error analysis: `C_val` — the validation confusion matrix
# (`confusion_matrix`, sorted label order); `weaker_class` — the label
# (string) with the *lower* per-class F1, computed from `C_val`'s
# pieces (not from a metrics wrapper).
#
# **(e)** One change: sweep `k` over `ks = [5, 7, 9, 11]` (same
# features, same carve, judged by validation macro-F1) → `val_f1s`
# (shape `(4,)`), `best_k` (smallest on ties).
#
# **(f)** Ship it: refit the `best_k` pipeline on **all 600 rows**,
# define `predict_labels` to the contract, and set `contract_ok` — all
# four self-checks on `probe = X.iloc[100:140]`.
#
# A loop over `ks` is permitted.
#
# **Banned (zero points): any supervised estimator other than `KNeighborsClassifier` — including the LogisticRegression / RandomForest / GradientBoosting / SVC / MLP families, and re-implementing any of them by hand; reading or printing the held-back split; imports beyond `sklearn` / `numpy` / `pandas` / `matplotlib`.** Any preprocessing is allowed.

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix, f1_score
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

SEED = 20260804
ks = np.array([5, 7, 9, 11])

df = pd.read_csv("../data/train.csv")

# YOUR CODE HERE (bridge, carve, baseline, error analysis, sweep, ship)

class_counts = ...  # YOUR CODE HERE (dict)
val_f1_base = ...   # YOUR CODE HERE (float)
C_val = ...         # YOUR CODE HERE (2, 2)
weaker_class = ...  # YOUR CODE HERE (str)
val_f1s = ...       # YOUR CODE HERE (shape (4,))
best_k = ...        # YOUR CODE HERE (int)


def predict_labels(X_test):
    ...             # YOUR CODE HERE


probe = ...         # YOUR CODE HERE (X.iloc[100:140])
contract_ok = ...   # YOUR CODE HERE (bool)
