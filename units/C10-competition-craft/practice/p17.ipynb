# %% [markdown]
# # C10-competition-craft — Practice p17
#
#
# **Type:** challenge · **Difficulty:** advanced · **Concepts:** writeup-quality, train-test-split, f1-macro, knn, feature-scaling, sklearn-pipelines
#
# The capped mini-competition.
# Everything this unit taught, under the real constraints, ~75 minutes
# recommended, timed.
#
# Run a complete campaign on `../data/train.csv`, with the iteration
# budget **capped at exactly three** and the move sequence pinned (so
# your campaign is reproducible and comparable):
#
# **Baseline.** The pinned carve (`test_size=150, random_state=SEED,
# stratify=y`); scaled 5-NN on all 12 features; log its validation
# macro-F1.
#
# **Iteration 1 — move (i):** sweep `k` over `[5, 7, 9, 11, 15]` on
# the current feature set; accept the best `k` (smallest on ties).
#
# **Iteration 2 — move (ii):** switch the feature set to the 7
# `SIGNAL` columns (given in the stub), keeping the accepted `k`;
# accept iff validation macro-F1 improves.
#
# **Iteration 3 — move (i) again:** re-sweep `k` over the same grid on
# the *current* feature set; accept the best `k` (smallest on ties) —
# record whether anything changed.
#
# **Deliverables:**
#
# - `log_df` — a DataFrame with **exactly** the columns
#   `["step", "change", "val_f1", "accepted"]` and four rows
#   (`baseline`, `iter-1`, `iter-2`, `iter-3`); `val_f1` floats,
#   `accepted` bools (the baseline row's `accepted` is `True`);
# - `final_val_f1` — the last *accepted* state's validation macro-F1
#   (a `float`);
# - the final model refit on **all 600 rows**; `predict_labels` to the
#   contract; `contract_ok` on `probe = X.iloc[150:190]`;
# - **the writeup cell** (markdown below): approach / intuition /
#   alternatives, aiming for 6/6 — every number quoted from your own
#   log;
# - `self_scores` — your own rubric scoring of your writeup (dict,
#   keys `"W-A1"`…`"W-C2"`), and `self_total`.
#
# Loops over the swept `k` values are permitted.
#
# **Banned (zero points): any supervised estimator other than `KNeighborsClassifier` — including the LogisticRegression / RandomForest / GradientBoosting / SVC / MLP families, and re-implementing any of them by hand; reading or printing the held-back split; imports beyond `sklearn` / `numpy` / `pandas` / `matplotlib`.** Any preprocessing is allowed.

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

SEED = 20260804
SIGNAL = ["honey_stores_kg", "autumn_hive_mass_kg", "varroa_mite_index",
          "forager_traffic_per_min", "brood_frames", "daily_temp_swing_c",
          "queen_age_years"]
sweep_ks = np.array([5, 7, 9, 11, 15])

df = pd.read_csv("../data/train.csv")
FEATURES = [c for c in df.columns if c != "outcome"]
X = df[FEATURES]
y = df["outcome"].to_numpy()

# YOUR CODE HERE (carve, baseline, three pinned iterations, final refit)

log_df = ...        # YOUR CODE HERE (4 rows, pinned columns)
final_val_f1 = ...  # YOUR CODE HERE (float)


def predict_labels(X_test):
    ...             # YOUR CODE HERE


probe = X.iloc[150:190]
contract_ok = ...   # YOUR CODE HERE (bool)

self_scores = ...   # YOUR CODE HERE (dict)
self_total = ...    # YOUR CODE HERE (int)

# %% [markdown]
# *Your writeup cell here (approach / intuition / alternatives).*
