# %% [markdown]
# # F6-svd-spectral — Practice p08
#
# **Type:** constrained coding · **Difficulty:** intro · **Concepts:** Frobenius norm
#
# Write `frob(A)` computing the Frobenius norm of any matrix **from its entries** — square, sum, root.
#
# **Banned inside `frob` (zero points): every `np.linalg` call, and loops.** Route: elementwise `*` (or `**2`) plus `.sum()`.
#
# For the seeded `A` below:
#
# 1. `frob_val = frob(A)`.
# 2. `check_gap` = absolute difference between `frob_val` and `np.linalg.norm(A)` — **`np.linalg.norm` is allowed in this check line only.**
# 3. `scale_gap` = absolute difference between `frob(-3 * A)` and `3 * frob_val` (the scaling law $\lVert cA \rVert_F = |c|\,\lVert A \rVert_F$).
#
# Contract: `check_gap < 1e-10` and `scale_gap < 1e-10`.

# %%
import numpy as np

SEED = 20260804
rng = np.random.default_rng(SEED)
A = rng.normal(0, 1, (5, 7))


def frob(A):
    # YOUR CODE HERE (banned: np.linalg.*, loops)
    ...


frob_val = ...   # YOUR CODE HERE
check_gap = ...  # YOUR CODE HERE (np.linalg.norm allowed here only)
scale_gap = ...  # YOUR CODE HERE
