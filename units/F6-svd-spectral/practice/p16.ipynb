# %% [markdown]
# # F6-svd-spectral — Practice p16
#
# **Type:** proof / derivation · **Difficulty:** advanced · **Concepts:** low-rank approximation
#
# **Reasoning is required.**
#
# Derive the exact truncation-error identity: for the rank-$r$ truncation $W_r$ of $W = \sum_k \sigma_k u_k v_k^{\mathsf T}$,
#
# $$\lVert W - W_r \rVert_F^2 = \sum_{i > r} \sigma_i^2.$$
#
# Structure your derivation as three claims:
#
# **(a)** Tail form: show $W - W_r = \sum_{k > r} \sigma_k u_k v_k^{\mathsf T}$.
#
# **(b)** The tail is SVD-shaped: argue that the sub-families $\{u_k\}_{k>r}$ and $\{v_k\}_{k>r}$ are orthonormal and the tail coefficients are non-negative and descending — so the right-hand sum presents $W - W_r$ *in valid SVD form*, with singular values $(\sigma_{r+1}, \sigma_{r+2}, \dots)$.
#
# **(c)** Apply p15's master identity **to the tail matrix** and conclude.
# Add one sentence of scope hygiene: this identity computes the truncation's error; it does **not** by itself prove that no other rank-$r$ matrix does better (that optimality statement is Eckart–Young, which this course states without proof).
#
# **(d) Numeric anchor:** for the seeded `W (9, 6)` below and $r = 2$, compute `err_sq` = $\lVert W - W_2 \rVert_F^2$ directly (build the truncation) and `tail_sum` = $\sum_{i>2}\sigma_i^2$, plus `anchor_gap` = their absolute difference; the final assertion must pass.
#
# **Allowed `np.linalg` calls (part d only): `np.linalg.svd` and `np.linalg.norm`.**

# %% [markdown]
# *Your reasoning for (a)–(c) here.*

# %%
import numpy as np

SEED = 20260804
rng = np.random.default_rng(SEED)
W = rng.normal(0, 1, (9, 6))
r = 2

# (d) YOUR CODE HERE
err_sq = ...
tail_sum = ...
anchor_gap = ...

assert np.isclose(err_sq, tail_sum, rtol=0, atol=1e-8)
