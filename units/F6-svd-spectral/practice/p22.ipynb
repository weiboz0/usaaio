# %% [markdown]
# # F6-svd-spectral — Practice p22
#
# **Type:** challenge · **Difficulty:** advanced · **Concepts:** eigenvalues & eigenvectors
#
# Find the top eigenpair of a symmetric matrix with **`np.linalg` banned entirely** — by power iteration (Session 1 §6: under repeated application, the largest-magnitude eigen-direction wins).
#
# The seeded cell builds `S = B @ B.T (4, 4)` — symmetric and PSD, with a well-separated top eigenvalue.
#
# 1. Write `power_iterate(S, x0, iters)`: repeat `iters` times — multiply by `S`, then renormalize to unit length using `np.sqrt((y**2).sum())`; return the final unit vector.
#    (A Python loop over the iterations is expected and allowed.)
# 2. `q_top` = `power_iterate(S, x0, 200)` from the given start `x0`.
# 3. `lam_est` = the energy $q_{\text{top}} \cdot (S\, q_{\text{top}})$ — the eigenvalue estimate.
# 4. `resid_max` = max absolute entry of $S q_{\text{top}} - \lambda_{\text{est}}\, q_{\text{top}}$.
# 5. `est_short` = the same energy estimate after only 5 iterations — record it and compare in the markdown cell.
#
# Then, in the markdown cell, two sentences: *why* the iterate turns toward the top eigen-direction (argue with the eigen-mix picture from Session 1 §6), and why PSD-ness of `S` conveniently removes the sign-flip complication that a negative dominant eigenvalue would cause.
#
# **Banned (zero points): every `np.linalg` call.** Everything else in NumPy is available.
#
# Contract: `resid_max < 1e-8`; `q_top` unit length to within `1e-10`.

# %%
import numpy as np

SEED = 20260804
rng = np.random.default_rng(SEED)
B = rng.normal(0, 1, (4, 6))
S = B @ B.T
x0 = np.ones(4) / 2.0            # a unit start vector


def power_iterate(S, x0, iters):
    # YOUR CODE HERE (banned: np.linalg.*)
    ...


q_top = ...      # YOUR CODE HERE
lam_est = ...    # YOUR CODE HERE
resid_max = ...  # YOUR CODE HERE
est_short = ...  # YOUR CODE HERE (5 iterations)

# %% [markdown]
# *Your two sentences here.*
