# %% [markdown]
# # F6-svd-spectral — Practice p09
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** spectral decomposition
#
# The seeded cell below builds a symmetric matrix `S (6, 6)`.
#
# 1. Eigen-decompose with `np.linalg.eigh` and apply the pinned reorder idiom: `vals_desc (6,)` descending, `vecs_desc (6, 6)` columns matched.
# 2. `orth_gap` = max absolute entry of $Q^{\mathsf T}Q - I_6$.
# 3. `recon_gap` = max absolute entry of $Q\,\mathrm{diag}(\lambda)\,Q^{\mathsf T} - S$.
# 4. Rebuild `S` a second way — as the **atom sum** $\sum_i \lambda_i q_i q_i^{\mathsf T}$ (outer products via broadcasting or `np.outer`; a Python loop over the 6 atoms is fine) — and set `sum_gap` = max absolute entry of the difference from `S`.
#
# **Allowed `np.linalg` calls: `np.linalg.eigh` only. Any other `np.linalg` call scores zero.**
#
# Contract: `orth_gap < 1e-10`, `recon_gap < 1e-10`, `sum_gap < 1e-10`.

# %%
import numpy as np

SEED = 20260804
rng = np.random.default_rng(SEED)
B = rng.normal(0, 1, (6, 6))
S = (B + B.T) / 2

vals_desc = ...  # YOUR CODE HERE
vecs_desc = ...  # YOUR CODE HERE
orth_gap = ...   # YOUR CODE HERE
recon_gap = ...  # YOUR CODE HERE
sum_gap = ...    # YOUR CODE HERE (atom-sum route)
