# %% [markdown]
# # F6-svd-spectral — Practice p10
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** SVD
#
# For the seeded `W (7, 4)` below, unpack the **thin** SVD and verify every clause of its output contract:
#
# 1. `U, s, Vt` from `np.linalg.svd(W, full_matrices=False)`; record `shapes = (U.shape, s.shape, Vt.shape)`.
# 2. `recon_gap` = max absolute entry of $U\,\mathrm{diag}(s)\,V^{\mathsf T} - W$.
# 3. `u_gap` = max absolute entry of $U^{\mathsf T}U - I_4$; `v_gap` = max absolute entry of $V^{\mathsf T}V - I_4$ (careful: `Vt` is already $V^{\mathsf T}$).
# 4. `desc_ok` = a Python `bool`, `True` iff `s` is non-increasing (`np.diff` is a clean route).
# 5. `nonneg_ok` = a Python `bool`, `True` iff every entry of `s` is $\ge 0$.
#
# **Allowed `np.linalg` calls: `np.linalg.svd` only. Any other `np.linalg` call scores zero.**
#
# Contract: `shapes == ((7, 4), (4,), (4, 4))`, `recon_gap < 1e-10`, `u_gap < 1e-10`, `v_gap < 1e-10`, `desc_ok` and `nonneg_ok` both `True`.

# %%
import numpy as np

SEED = 20260804
rng = np.random.default_rng(SEED)
W = rng.normal(0, 1, (7, 4))

U, s, Vt = ..., ..., ...  # YOUR CODE HERE
shapes = ...              # YOUR CODE HERE
recon_gap = ...           # YOUR CODE HERE
u_gap = ...               # YOUR CODE HERE
v_gap = ...               # YOUR CODE HERE
desc_ok = ...             # YOUR CODE HERE (bool)
nonneg_ok = ...           # YOUR CODE HERE (bool)
