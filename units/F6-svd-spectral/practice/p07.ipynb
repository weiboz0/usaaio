# %% [markdown]
# # F6-svd-spectral — Practice p07
#
# **Type:** constrained coding · **Difficulty:** intro · **Concepts:** eigenvalues & eigenvectors
#
# Let $M = \begin{pmatrix} 6 & 2 \\ 1 & 5 \end{pmatrix}$.
#
# 1. Use `np.linalg.eig` to compute the eigen-decomposition; strip the (zero) imaginary parts and reorder to the course's **descending** convention: `vals_desc (2,)` and `vecs_desc (2, 2)` with eigenvectors as columns, pairs matched.
# 2. `resid_max` = the largest eigen-equation residual $\max_i \max\bigl|M q_i - \lambda_i q_i\bigr|$ (max absolute entry, no norm call).
# 3. `quad_max` = $\max_i \bigl|(6 - \lambda_i)(5 - \lambda_i) - 2 \cdot 1\bigr|$ — both computed eigenvalues must kill the dependent-rows quadratic.
#
# **Allowed `np.linalg` calls: `np.linalg.eig` only. Any other `np.linalg` call scores zero.**
#
# Contract: `resid_max < 1e-10` and `quad_max < 1e-10`.

# %%
import numpy as np

M = np.array([[6., 2.], [1., 5.]])

vals_desc = ...  # YOUR CODE HERE (real, descending)
vecs_desc = ...  # YOUR CODE HERE (columns matched to vals_desc)
resid_max = ...  # YOUR CODE HERE
quad_max = ...   # YOUR CODE HERE
