# %% [markdown]
# # F6-svd-spectral — Practice p06
#
# **Type:** multiple choice · **Difficulty:** core · **Concepts:** spectral decomposition
#
# A symmetric matrix $S$ has spectral decomposition with eigenvalues $\lambda = (6, 2, -1)$ (descending) and orthonormal eigenvectors $q_1, q_2, q_3$.
# Let $x = q_1 - 2\,q_3$.
# What is $S\,x$?
#
# A. $6\,q_1 - 2\,q_3$
#
# B. $6\,q_1 + 2\,q_3$
#
# C. $6\,q_1 - q_3$
#
# D. $q_1 - 2\,q_3$
#
# E. It cannot be determined without knowing the entries of the $q_i$
#
# **Allowed `np.linalg` calls: none needed — answer by hand** (apply $S$ eigenvector by eigenvector).
#
# Reasoning is not required. Record your choice below.

# %%
import numpy as np

answer_p06 = "?"  # replace with "A".."E"
