# %% [markdown]
# # F6-svd-spectral — Practice p02
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** Frobenius norm
#
# Compute the Frobenius norm of
# $$B = \begin{pmatrix} 1 & -2 \\ 2 & 0 \\ -1 & 3 \end{pmatrix}.$$
#
# A. $\sqrt{15}$
#
# B. $\sqrt{17}$
#
# C. $\sqrt{19}$
#
# D. $19$
#
# E. $3$
#
# **Allowed `np.linalg` calls: none needed — answer by hand.**
#
# Reasoning is not required. Record your choice below.

# %%
import numpy as np

answer_p02 = "?"  # replace with "A".."E"
