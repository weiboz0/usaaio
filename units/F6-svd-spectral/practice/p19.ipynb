# %% [markdown]
# # F6-svd-spectral — Practice p19
#
# **Type:** scenario analysis · **Difficulty:** core · **Concepts:** singular values
#
# A teammate's lab logbook contains four claims about singular values.
# For each, produce numeric evidence on the seeded `W (5, 8)` below, set the boolean verdict (`True` = the claim is correct), and write a one-sentence verdict in the markdown cell citing your evidence.
#
# 1. **Claim 1:** "Doubling every entry of a matrix doubles its singular values."
#    Evidence: `scale_gap` = max absolute difference between $\sigma(2W)$ and $2\,\sigma(W)$; verdict `claim1`.
# 2. **Claim 2:** "A matrix and its transpose have the same singular values."
#    Evidence: `transpose_gap` = max absolute difference between $\sigma(W^{\mathsf T})$ and $\sigma(W)$; verdict `claim2`.
# 3. **Claim 3:** "`np.linalg.svd` returns the singular values in ascending order, like `eigh`."
#    Evidence: `desc_ok` = bool, whether $\sigma(W)$ is non-increasing; verdict `claim3`.
# 4. **Claim 4:** "For a matrix with negative entries, some singular values come out negative."
#    Evidence: `min_sigma` = the smallest singular value of $W$ (the seeded `W` does have negative entries — worth one glance); verdict `claim4`.
#
# **Allowed `np.linalg` calls: `np.linalg.svd` only. Any other `np.linalg` call scores zero.**
#
# Contract: the four booleans, the three numeric evidence variables, and four verdict sentences.

# %%
import numpy as np

SEED = 20260804
rng = np.random.default_rng(SEED)
W = rng.normal(0, 1, (5, 8))

scale_gap = ...      # YOUR CODE HERE
claim1 = ...         # YOUR CODE HERE (bool)
transpose_gap = ...  # YOUR CODE HERE
claim2 = ...         # YOUR CODE HERE (bool)
desc_ok = ...        # YOUR CODE HERE (bool)
claim3 = ...         # YOUR CODE HERE (bool)
min_sigma = ...      # YOUR CODE HERE
claim4 = ...         # YOUR CODE HERE (bool)

# %% [markdown]
# *Your four one-sentence verdicts here.*
