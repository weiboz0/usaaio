# %% [markdown]
# # C5-neural-networks — Practice p08
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** mlp-architecture
#
# The unit's two pinned helpers, written to contract from memory, then
# composed into a forward pass.
# (These exact names and semantics carry into C6-pytorch — the contract is
# the deliverable.)
#
# **(a)** Write `affine_layer(x, W, b)`: for `x` of shape
# $(n, d_{\text{in}})$, `W` of shape $(d_{\text{out}}, d_{\text{in}})$ (row
# $j$ = weights of unit $j$), `b` of shape $(d_{\text{out}},)$, return the
# $(n, d_{\text{out}})$ array with entries
# $z_{ij} = \sum_k x_{ik} W_{jk} + b_j$.
#
# **(b)** Write `step_activation(z)`: elementwise, `1.0` where `z >= 0`,
# else `0.0`, floats.
#
# **(c)** Forward the fixed batch `X` through the $3 \to 2 \to 1$ network
# below (step at the hidden layer, affine output): store the hidden
# pre-activations `z1` (shape `(3, 2)`), the hidden activations `h1`, and
# the outputs `y` (shape `(3, 1)`).
#
# **Banned (zero points): `@`, `np.matmul`, `np.dot`, `np.einsum`, `np.tensordot`, `.T`, loops.**
# The component-sum form via broadcasting is the intended implementation.

# %%
import numpy as np

X = np.array([[1.0, 0.0, 2.0], [-1.0, 2.0, 0.0], [0.5, 1.0, 1.0]])
W1 = np.array([[1.0, -1.0, 2.0], [0.0, 3.0, -1.0]])
b1 = np.array([-1.0, 0.5])
W2 = np.array([[2.0, -3.0]])
b2 = np.array([0.5])


def affine_layer(x, W, b):
    # YOUR CODE HERE (banned: @, np.matmul, np.dot, np.einsum, np.tensordot, .T, loops)
    ...


def step_activation(z):
    # YOUR CODE HERE (same bans)
    ...


z1 = ...  # YOUR CODE HERE — shape (3, 2)
h1 = ...  # YOUR CODE HERE — shape (3, 2)
y = ...   # YOUR CODE HERE — shape (3, 1)
