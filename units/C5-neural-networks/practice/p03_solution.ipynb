# %% [markdown]
# # C5-neural-networks — Practice p03 — Solution

# %% [markdown]
# The answer is **B**.  Before $1$ both ReLUs vanish.  From $1$ to $3$, only the first term is active, so the slope is $1$.  After $3$, both terms have slope $1$ and cancel, leaving $(z-1)-(z-3)=2$.
#
# - A places the first kink at $3$ instead of $1$.
# - C overlooks cancellation after the second ReLU turns on.
# - D uses the second kink location as the plateau height; the height is the kink separation, $2$.
# - E has the wrong sign: $f(2)=1-0=1$.

# %%
import numpy as np

SEED = 20260804
answer_p03 = "B"
probe_z = np.array([0.0, 2.0, 4.0])
probe_f = np.maximum(probe_z - 1.0, 0.0) - np.maximum(probe_z - 3.0, 0.0)
answer_p03, probe_f

# %% [markdown]
# ### Answer check

# %%
assert answer_p03 == "B"
assert np.allclose(probe_f, [0.0, 1.0, 2.0], atol=1e-12)
