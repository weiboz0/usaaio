# %% [markdown]
# # C5-neural-networks — Practice p02 — Solution

# %% [markdown]
# The answer is **C**: the step includes zero, ReLU clips negative values to zero, and $\tanh$ has range $(-1,1)$.
#
# - A uses $z>0$ instead of the pinned $z\geq0$ convention.
# - B is wrong for negative inputs: $\operatorname{relu}(-3)=0$.
# - D confuses tanh with step; $\tanh(0)=0$.
# - E confuses step with ReLU; step returns a binary value, so $\operatorname{step}(2.7)=1$.

# %%
import numpy as np

SEED = 20260804
answer_p02 = "C"
step_zero = float(0.0 >= 0)
relu_neg_three = float(np.maximum(-3.0, 0.0))
tanh_zero = float(np.tanh(0.0))
answer_p02, step_zero, relu_neg_three, tanh_zero

# %% [markdown]
# ### Answer check

# %%
assert answer_p02 == "C"
assert np.isclose(step_zero, 1.0, atol=1e-12)
assert np.isclose(relu_neg_three, 0.0, atol=1e-12)
assert np.isclose(tanh_zero, 0.0, atol=1e-12)
