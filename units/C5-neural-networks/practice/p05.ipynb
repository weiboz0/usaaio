# %% [markdown]
# # C5-neural-networks — Practice p05
#
# **Type:** constrained coding · **Difficulty:** intro · **Concepts:** perceptron
#
# One perceptron, evaluated on a whole batch at once.
#
# **(a)** Write `perceptron_forward(x, w, b)` taking a batch `x` of shape
# `(n, d)`, weights `w` of shape `(d,)`, and a scalar bias `b`, and
# returning the `(n,)` **float** array of perceptron outputs under the
# course convention (fire, i.e. `1.0`, exactly when
# $z_i = \sum_k x_{ik} w_k + b \ge 0$).
#
# **(b)** Apply it to the seeded data below: store the outputs in
# `outputs` and the firing fraction in `frac_on` (a float).
#
# **Banned (zero points): `@`, `np.matmul`, `np.dot`, `np.einsum`, `np.tensordot`, `.T`, loops, `np.inner`, any `np.linalg` function.**
# Broadcasting and axis-aware reductions only.

# %%
import numpy as np

SEED = 20260804
rng = np.random.default_rng(SEED)
X = rng.normal(0, 1, (8, 3))
w = np.array([1.5, -2.0, 0.5])
b = -0.25


def perceptron_forward(x, w, b):
    # YOUR CODE HERE (banned: @, np.matmul, np.dot, np.einsum, np.tensordot, .T, loops)
    ...


outputs = ...   # YOUR CODE HERE — shape (8,), floats
frac_on = ...   # YOUR CODE HERE — float
