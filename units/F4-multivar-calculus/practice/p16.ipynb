# %% [markdown]
# # F4-multivar-calculus — Practice p16
#
# **Type:** scenario analysis · **Difficulty:** core · **Concepts:** tanh derivative, multivariable chain rule
#
# A sensor pipeline squashes its reading: the reported value is $r(t) = \tanh(0.5\, m(t))$ where $m(t)$ is the raw measurement at time $t$. Around $t_0$, engineers know $m(t_0) = 4.0$ and $m'(t_0) = 6.0$.
#
# **(a)** Compute the reported value's rate of change `r_rate` $= \tfrac{d}{dt}\tanh(0.5\,m(t))\big|_{t_0}$ (chain rule + the tanh identity; `np.tanh` allowed).
#
# **(b)** Compute the same quantity if instead $m(t_0) = 0.0$ (same $m'$): `r_rate_zero`.
#
# **(c)** The team is alarmed that the reported value "barely moves" despite the raw signal changing fast. In 2-3 sentences, explain the saturation effect with your two numbers, and state at which raw-measurement level the pipeline is MOST responsive.

# %%
import numpy as np

# YOUR CODE HERE
r_rate = ...
r_rate_zero = ...

# %% [markdown]
# *Your (c) explanation here.*
