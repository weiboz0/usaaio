# %% [markdown]
# # F4-multivar-calculus — Practice p03
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** tanh derivative
#
# Given $\tanh x = \dfrac{e^x - e^{-x}}{e^x + e^{-x}}$ and the identity $\tanh'(x) = 1 - \tanh^2(x)$:
#
# which value does $\tanh'(0)$ take, and how does $\tanh'(x)$ behave as $x \to \infty$?
#
# A. $\tanh'(0) = 0$; the derivative grows without bound.
#
# B. $\tanh'(0) = 1$; the derivative approaches 0.
#
# C. $\tanh'(0) = 1$; the derivative approaches 1.
#
# D. $\tanh'(0) = \tfrac12$; the derivative approaches 0.
#
# E. $\tanh'(0) = 0$; the derivative approaches 1.
#
# Record your choice below.

# %%
import numpy as np

answer_p03 = "?"  # replace with "A".."E"
