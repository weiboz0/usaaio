# %% [markdown]
# # F4-multivar-calculus — Practice p12
#
# **Type:** proof · **Difficulty:** core · **Concepts:** multivariable chain rule, partial derivatives
#
# **Reasoning is required.**
#
# Let $f(u, v)$ have continuous partials, and let $u = 2t$, $v = t^2$.
#
# **(a)** State the multivariable chain rule for $\dfrac{d}{dt} f(2t, t^2)$ and explain in 2-3 sentences why BOTH terms must appear (what changes as $t$ nudges, and why each route contributes).
#
# **(b)** For the specific $f(u, v) = u v + v^2$: compute $\tfrac{d}{dt} f(2t, t^2)$ TWICE — once via the chain rule, once by substituting first and differentiating the single-variable result — and show the two expressions agree.
#
# **(c) Concrete anchor:** evaluate both expressions at $t = 1.5$ in the code cell (`via_chain`, `via_subst`, `anchor_gap`).

# %% [markdown]
# *Your statement, explanation, and double computation here.*

# %%
import numpy as np

t = 1.5
# (c) YOUR CODE HERE
via_chain = ...
via_subst = ...
anchor_gap = ...
