# %% [markdown]
# # F4-multivar-calculus — Practice p06
#
# **Type:** constrained coding · **Difficulty:** intro · **Concepts:** gradient
#
# A full numeric gradient.
#
# Write `num_gradient(f, point, h)`:
#
# 1. Inputs: `f` taking a NumPy array of shape `(d,)`; `point` of shape `(d,)`; step `h`.
# 2. Return the array of central-difference partials — nudge ONE coordinate at a time by ±h. A loop over the d coordinates IS allowed here (d is small); NumPy vectorization inside is welcome.
#
# For `f = lambda p: (p**2).sum() + 2*p[0]*p[1]` at `point = np.array([1.0, 2.0])`, compute `grad_est = num_gradient(f, point, 1e-6)` and `grad_exact` (hand-derived array), then `max_gap = np.abs(grad_est - grad_exact).max()`.

# %%
import numpy as np

def num_gradient(f, point, h):
    # YOUR CODE HERE
    ...

f = lambda p: (p**2).sum() + 2*p[0]*p[1]
point = np.array([1.0, 2.0])
grad_est = ...    # YOUR CODE HERE
grad_exact = ...  # YOUR CODE HERE
max_gap = ...     # YOUR CODE HERE
