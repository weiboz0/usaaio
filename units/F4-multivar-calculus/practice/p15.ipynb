# %% [markdown]
# # F4-multivar-calculus — Practice p15
#
# **Type:** scenario analysis · **Difficulty:** core · **Concepts:** gradient, partial derivatives
#
# A drone measures signal strength $S(x, y)$ over a field. At its current position, numerical probing gives $\partial S/\partial x \approx 3.2$ and $\partial S/\partial y \approx -2.4$.
#
# **(a)** In which compass direction (unit vector) should the drone move for the fastest signal INCREASE, and at what initial rate per meter? Compute `direction` (shape-`(2,)` unit vector) and `rate`.
#
# **(b)** The pilot instead flies due north (+y). Compute the initial rate of change `rate_north` along that path.
#
# **(c)** A teammate claims: "since ∂S/∂x is the biggest number, flying due east is fastest." In 2-3 sentences, correct the claim using the gradient's direction property (and your (a)/(b) numbers).

# %%
import numpy as np

# YOUR CODE HERE
direction = ...
rate = ...
rate_north = ...

# %% [markdown]
# *Your (c) correction here.*
