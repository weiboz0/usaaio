# %% [markdown]
# # F4-multivar-calculus — Practice p02 — Solution

# %% [markdown]
# Let $q=2a+b$, so $g=q^3$ and $\nabla g=3q^2(2,1)$. At $(1,1)$, $q=3$, hence the gradient is $(54,27)$ and the correct choice is B.

# %%
import numpy as np

gradient = np.array([54.0, 27.0])
answer_p02 = "B"

# %% [markdown]
# ### Answer check

# %%
my_answer_letter = answer_p02
assert np.allclose(gradient, np.array([54.0, 27.0]))
assert my_answer_letter == "B"
