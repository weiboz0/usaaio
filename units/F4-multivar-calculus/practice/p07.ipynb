# %% [markdown]
# # F4-multivar-calculus — Practice p07
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** sum-of-squares gradients
#
# The exam's canonical gradient, component form.
#
# Given a data grid `X` of shape `(N, d)` (row $n$ holds the numbers $X_{n,0},\dots,X_{n,d-1}$), targets `y` of shape `(N,)`, and coefficients `w` of shape `(d,)`, define
# $$Q(w) = \frac{1}{N}\sum_{n=0}^{N-1}\Big(y_n - \sum_{k=0}^{d-1} X_{n,k} w_k\Big)^2 .$$
#
# Write `q_gradient(X, y, w)` returning the shape-`(d,)` array of partials $\partial Q / \partial w_j = -\tfrac{2}{N}\sum_n \big(y_n - \sum_k X_{n,k}w_k\big) X_{n,j}$.
#
# **Banned (zero points): `@`, `np.matmul`, `np.dot`, `.T`, any loop.** Use elementwise multiplication, broadcasting, and axis sums only.
#
# Evaluate `g = q_gradient(X, y, w)` for the seeded data below, and `check_gap` = max abs difference against `num_gradient`-style central differences (reuse your p06 approach inline — the checker MAY loop).

# %%
import numpy as np

SEED = 20260804
rng = np.random.default_rng(SEED)
X = rng.normal(0, 1, (50, 3))
y = rng.normal(0, 1, 50)
w = np.array([0.5, -1.0, 2.0])

def q_gradient(X, y, w):
    # YOUR CODE HERE (banned: @, np.matmul, np.dot, .T, loops)
    ...

g = ...          # YOUR CODE HERE
check_gap = ...  # YOUR CODE HERE
