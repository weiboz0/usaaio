# %% [markdown]
# # F4-multivar-calculus — Practice p14
#
# **Type:** integrative · **Difficulty:** advanced · **Concepts:** multivariable chain rule, sum-of-squares gradients, gradient
#
# A squashed model, end to end.
#
# With the p07 seeded data (`X (50,3)`, `y (50,)`), model $\hat y_n = \tanh\big(\sum_k X_{n,k} w_k\big)$ and define $L(w) = \frac{1}{N}\sum_n (y_n - \hat y_n)^2$.
#
# **(a)** Hand-derive $\partial L/\partial w_j$ (chain rule through the square AND through tanh; component form).
#
# **(b)** Implement `l_gradient(X, y, w)`. **Banned: `@`, `np.matmul`, `np.dot`, `.T`, loops.**
#
# **(c)** Verify against central differences at `w = np.array([0.2, -0.3, 0.1])`: `check_gap` (checker may loop).
#
# **(d)** One sentence: which factor in your formula shrinks the contribution of points where the weighted sum is large in magnitude, and why does that make sense given the bound from p11(b) together with the saturation behaviour (tanh′ → 0 far from 0) worked in lesson 02?

# %% [markdown]
# *Your (a) derivation here.*

# %%
import numpy as np

SEED = 20260804
rng = np.random.default_rng(SEED)
X = rng.normal(0, 1, (50, 3))
y = rng.normal(0, 1, 50)

def l_gradient(X, y, w):
    # YOUR CODE HERE
    ...

w = np.array([0.2, -0.3, 0.1])
grad = ...       # YOUR CODE HERE
check_gap = ...  # YOUR CODE HERE

# %% [markdown]
# *Your (d) sentence here.*
