# %% [markdown]
# # F4-multivar-calculus — Practice p17
#
# **Type:** challenge · **Difficulty:** advanced · **Concepts:** sum-of-squares gradients, multivariable chain rule
#
# Gradient of a CHAINED sum of squares.
#
# With the p07 seeded data, define a two-stage rule: $z_n = \sum_k X_{n,k} u_k$ (shape `(N,)` from `u (3,)`), then predictions $\hat y_n = c\, z_n + b$ (scalars $c, b$), and
# $$M(u, c, b) = \frac{1}{N}\sum_n (y_n - c z_n - b)^2 .$$
#
# **(a)** Hand-derive all five partials: $\partial M/\partial u_k$ (three of them, via the chain through $z$), $\partial M/\partial c$, $\partial M/\partial b$.
#
# **(b)** Implement `m_gradients(u, c, b)` returning `(grad_u, grad_c, grad_b)`. **Banned (zero points): `@`, `np.matmul`, `np.dot`, `.T`, loops.**
#
# **(c)** Verify all five against central differences at `u = np.array([0.4, -0.2, 0.7]), c = 1.5, b = -0.3`: `max_check_gap` (checker may loop).
#
# **(d)** One sentence: your $\partial M/\partial u_k$ contains the factor $c$ — explain its role via the chain rule.

# %% [markdown]
# *Your (a) derivations here.*

# %%
import numpy as np

SEED = 20260804
rng = np.random.default_rng(SEED)
X = rng.normal(0, 1, (50, 3))
y = rng.normal(0, 1, 50)

def m_gradients(u, c, b):
    # YOUR CODE HERE
    ...

u = np.array([0.4, -0.2, 0.7]); c = 1.5; b = -0.3
grad_u, grad_c, grad_b = ..., ..., ...  # YOUR CODE HERE
max_check_gap = ...  # YOUR CODE HERE

# %% [markdown]
# *Your (d) sentence here.*
