# %% [markdown]
# # F4-multivar-calculus — Practice p09
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** tanh derivative, gradient
#
# A smooth squashing of a weighted sum.
#
# Define $g(w) = \tanh\!\big(\sum_k a_k w_k\big)$ for constants `a` of shape `(d,)`.
#
# 1. Hand-derive $\partial g/\partial w_j$ using the chain rule and the identity $\tanh' = 1 - \tanh^2$.
# 2. Implement `tanh_gradient(a, w)` returning the shape-`(d,)` gradient. **Banned: `@`, `np.matmul`, `np.dot`, loops** (`np.tanh` allowed).
# 3. For `a = np.array([1.0, -2.0, 0.5])`, `w = np.array([0.3, 0.1, -0.4])`, set `grad = tanh_gradient(a, w)` and verify with central differences: `check_gap` (checker may loop).

# %%
import numpy as np

def tanh_gradient(a, w):
    # YOUR CODE HERE
    ...

a = np.array([1.0, -2.0, 0.5])
w = np.array([0.3, 0.1, -0.4])
grad = ...       # YOUR CODE HERE
check_gap = ...  # YOUR CODE HERE
