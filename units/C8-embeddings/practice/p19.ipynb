# %% [markdown]
# # C8-embeddings — Practice p19
#
# **Type:** drill · **Difficulty:** intro · **Concepts:** gensim usage
#
# Five quick reads off the loaded model — each one line.
# **Gensim API required throughout.**
#
# Set:
#
# - `dim` — the model's vector dimensionality (`int`);
# - `has_trumpet` — membership of `"trumpet"` (`bool`);
# - `has_trumpetish` — membership of `"trumpetish"` (`bool`);
# - `sim_cello` — `float(kv.similarity("violin", "cello"))`;
# - `sim_garlic` — `float(kv.similarity("violin", "garlic"))`;
# - `closer_word` — `"cello"` or `"garlic"`, whichever is more similar
#   to `"violin"`, decided *in code*;
# - `top1` — the single nearest vocabulary word to `"trumpet"` (a
#   `str`, via `kv.most_similar` with `topn=1`).

# %%
import os, pathlib
_root = next(p for p in [pathlib.Path.cwd(), *pathlib.Path.cwd().parents]
             if (p / "pyproject.toml").exists())
os.environ["GENSIM_DATA_DIR"] = str(_root / "reference" / "cache" / "gensim")

import numpy as np
import gensim.downloader

kv = gensim.downloader.load("glove-wiki-gigaword-100")

dim = ...            # YOUR CODE HERE
has_trumpet = ...    # YOUR CODE HERE
has_trumpetish = ... # YOUR CODE HERE
sim_cello = ...      # YOUR CODE HERE
sim_garlic = ...     # YOUR CODE HERE
closer_word = ...    # YOUR CODE HERE
top1 = ...           # YOUR CODE HERE
