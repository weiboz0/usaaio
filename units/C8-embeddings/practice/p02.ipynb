# %% [markdown]
# # C8-embeddings — Practice p02
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** word embeddings
#
# The unit's pretrained GloVe model maps each of its 400,000 vocabulary
# words to a dense vector in $\mathbb{R}^{100}$.
# Exactly one of the following statements about these vectors is true.
# Which one?
#
# A. Each of the 100 dimensions corresponds to one specific English word,
#    and a coordinate's value counts co-occurrences with that word.
#
# B. The vector entries were assigned by lexicographers so that
#    synonyms received identical coordinates.
#
# C. Words that occur in similar contexts in the training corpus end up
#    with vectors pointing in similar directions.
#
# D. Two words receive similar vectors exactly when their spellings are
#    similar, since the model reads characters.
#
# E. The vectors change slightly on every load, so numeric results based
#    on them cannot be reproduced.
#
# Reasoning is not required. Record your choice below.

# %%
answer_p02 = "?"  # replace with "A".."E"
