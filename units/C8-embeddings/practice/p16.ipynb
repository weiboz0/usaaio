# %% [markdown]
# # C8-embeddings — Practice p16
#
# **Type:** scenario · **Difficulty:** core · **Concepts:** nearest-neighbor-search
#
# A teammate wrote this neighbor function for the pinned similarity
# matrix `S` of the six ship words below, and insists it "returns the
# top k for token i":
#
# ```python
# def neighbors_bad(S, i, k):
#     return np.argsort(S[i])[:k]
# ```
#
# **(a) Predict, then verify.**
# Build `W` and `S` for `WORDS` (pinned register).
# *Before running it*: describe what `neighbors_bad(S, 0, 3)` actually
# returns.
# Then set `bad_words` — the words it returns for query `"anchor"`,
# `k = 3` — and `bad_sims`, their similarities (shape `(3,)`), and
# confirm your prediction.
#
# **(b) Name the two bugs.**
# Two sentences: the bug you just saw, and the *second* bug that would
# remain even after someone patches the first with `[::-1]`
# (demonstrate it: set `stillbad_words` — the first 3 words of the
# descending order without exclusion).
#
# **(c) Fix it.**
# Write `neighbors_fixed(S, i, k)` — descending, self-excluded by mask,
# position-safe — and set `good_words` and `good_sims` for the same
# query. **Banned inside it (zero points): any `np.linalg` function,
# any Python loop, `np.einsum`, `np.tensordot`, `sklearn`, `scipy`,
# and every gensim similarity helper.**
#
# **(d) One stated-fact question.**
# Your teammate also notices that across many queries in a big
# experiment, one very common word keeps appearing in almost every
# top-10 list. In two sentences: name the two phenomena from Session 3
# that predict this, and state the practical rule for reading such
# lists.

# %%
import os, pathlib
_root = next(p for p in [pathlib.Path.cwd(), *pathlib.Path.cwd().parents]
             if (p / "pyproject.toml").exists())
os.environ["GENSIM_DATA_DIR"] = str(_root / "reference" / "cache" / "gensim")

import numpy as np
import gensim.downloader

kv = gensim.downloader.load("glove-wiki-gigaword-100")

WORDS = ["anchor", "mast", "rudder", "sail", "deck", "cabin"]

# (a)
W = ...             # YOUR CODE HERE
S = ...             # YOUR CODE HERE
bad_words = ...     # YOUR CODE HERE
bad_sims = ...      # YOUR CODE HERE

# (b)
stillbad_words = ...  # YOUR CODE HERE


# (c)
def neighbors_fixed(S, i, k):
    # YOUR CODE HERE
    ...


good_words = ...    # YOUR CODE HERE
good_sims = ...     # YOUR CODE HERE

# %% [markdown]
# *Your prediction (a), bug names (b), and stated-fact answer (d) here.*
