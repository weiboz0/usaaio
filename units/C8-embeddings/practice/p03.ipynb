# %% [markdown]
# # C8-embeddings — Practice p03
#
# **Type:** multiple choice · **Difficulty:** core · **Concepts:** similarity matrices
#
# `W` is an embedding matrix in this course's convention — 12 tokens as
# rows, shape `(12, 100)`, every row unit-normalized — and
# `S = W @ W.T`.
# Exactly one statement is true. Which one?
#
# A. `S` has shape `(100, 100)`, one entry per pair of embedding
#    dimensions.
#
# B. `S` is symmetric, its diagonal entries equal $1$ (up to float
#    error), and its off-diagonal entries may be negative.
#
# C. Every entry of `S` is nonnegative, because a similarity measures a
#    magnitude.
#
# D. $S_{ij}$ is the Euclidean distance between rows $i$ and $j$, so
#    larger entries mean less similar tokens.
#
# E. Computing `S` requires `np.linalg`; it cannot be produced by `@`
#    alone.
#
# Reasoning is not required. Record your choice below.

# %%
answer_p03 = "?"  # replace with "A".."E"
