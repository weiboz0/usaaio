# %% [markdown]
# # C8-embeddings — Practice p08
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** embedding-matrices, vectors-and-norms, unit-vectors, cosine-similarity, broadcasting, aggregation-axis
#
# Row statistics and the centroid of unit rows.
#
# For the six words below, set:
#
# - `V`, `W` — raw and unit-row matrices, shapes `(6, 100)`, float64,
#   the pinned register;
# - `norms_flat` — the raw row norms as a **flat** `(6,)` array (no
#   `keepdims` this time — it is about to index words, not divide
#   rows);
# - `longest`, `shortest` — the words with the largest and smallest raw
#   norm (`str`, via `np.argmax` / `np.argmin`);
# - `centroid` — the mean of `W`'s rows, shape `(100,)`;
# - `centroid_norm` — its Euclidean norm as a `float` (broadcast
#   register). Note that it is **well below 1** even though every row
#   has norm 1 — averaging unit vectors that point in different
#   directions cancels length;
# - `closest` — the word whose unit row has the largest cosine with the
#   *normalized* centroid (`str`).
#
# **Banned (zero points): any `np.linalg` function, any Python loop or comprehension over array elements, `np.einsum`, `np.tensordot`, `sklearn`, `scipy`, and every gensim similarity helper (`kv.most_similar`, `kv.similarity`, `kv.n_similarity`, `kv.distances`).**
# Vector lookup (`kv[...]`) is allowed — it is the load boundary.

# %%
import os, pathlib
_root = next(p for p in [pathlib.Path.cwd(), *pathlib.Path.cwd().parents]
             if (p / "pyproject.toml").exists())
os.environ["GENSIM_DATA_DIR"] = str(_root / "reference" / "cache" / "gensim")

import numpy as np
import gensim.downloader

kv = gensim.downloader.load("glove-wiki-gigaword-100")

WORDS = ["thunder", "breeze", "drizzle", "hail", "fog", "frost"]

V = ...             # YOUR CODE HERE
W = ...             # YOUR CODE HERE
norms_flat = ...    # YOUR CODE HERE (shape (6,))
longest = ...       # YOUR CODE HERE
shortest = ...      # YOUR CODE HERE
centroid = ...      # YOUR CODE HERE (shape (100,))
centroid_norm = ... # YOUR CODE HERE
closest = ...       # YOUR CODE HERE
