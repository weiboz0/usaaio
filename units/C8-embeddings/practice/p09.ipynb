# %% [markdown]
# # C8-embeddings — Practice p09
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** nearest-neighbor-search, gram-matrices, matrix-multiplication, unit-vectors, cosine-similarity
#
# The neighbor recipe as a reusable function.
#
# Build, for the six words below, the unit-row stack `W` (shape
# `(6, 100)`, float64, pinned register) and the similarity matrix
# `S = W @ W.T`.
# Then write
#
# ```python
# def top_k(S, i, k):
#     ...
# ```
#
# returning the indices (a NumPy integer array of length `k`) of the
# `k` most similar tokens to token `i`, **descending, with token `i`
# itself excluded by mask** (position-safe — do not assume the self
# sits first).
#
# Set:
#
# - `S` — the similarity matrix, shape `(6, 6)`;
# - `top3_idx` — `top_k(S, 0, 3)` (query `"guitar"`);
# - `top3_words` — the corresponding words, in rank order (a list of
#   `str`);
# - `top3_sims` — the corresponding similarities, shape `(3,)`.
#
# **Banned (zero points): any `np.linalg` function, any Python loop or comprehension over array elements, `np.einsum`, `np.tensordot`, `sklearn`, `scipy`, and every gensim similarity helper (`kv.most_similar`, `kv.similarity`, `kv.n_similarity`, `kv.distances`).**
# Vector lookup (`kv[...]`) is allowed — it is the load boundary.

# %%
import os, pathlib
_root = next(p for p in [pathlib.Path.cwd(), *pathlib.Path.cwd().parents]
             if (p / "pyproject.toml").exists())
os.environ["GENSIM_DATA_DIR"] = str(_root / "reference" / "cache" / "gensim")

import numpy as np
import gensim.downloader

kv = gensim.downloader.load("glove-wiki-gigaword-100")

WORDS = ["guitar", "piano", "drums", "flute", "cello", "trumpet"]

W = ...          # YOUR CODE HERE (unit rows, float64)
S = ...          # YOUR CODE HERE


def top_k(S, i, k):
    # YOUR CODE HERE (argsort desc, mask out i, first k)
    ...


top3_idx = ...   # YOUR CODE HERE
top3_words = ... # YOUR CODE HERE
top3_sims = ...  # YOUR CODE HERE
