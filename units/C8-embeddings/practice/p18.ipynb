# %% [markdown]
# # C8-embeddings — Practice p18
#
# **Type:** challenge · **Difficulty:** advanced · **Concepts:** gensim usage
#
# **This problem requires the gensim API throughout** — manual vector
# arithmetic scores zero here; the point is fluency with the library's
# own similarity tools and the frequency-ordering fact.
#
# **(a) Pair similarities.**
# Set `sim_gale = float(kv.similarity("breeze", "gale"))` and
# `sim_hammer = float(kv.similarity("breeze", "hammer"))`, and
# `more_related` — whichever of `"gale"` / `"hammer"` is more similar
# to `"breeze"` (a `str`, decided *in code*).
#
# **(b) The universe knob.**
# GloVe's vocabulary is frequency-ordered, and
# `most_similar(..., restrict_vocab=n)` searches only the `n` most
# frequent words.
# Set `top5_narrow` and `top5_wide` — the top-5 neighbor *words* of
# `"lantern"` (lists of `str`) with `restrict_vocab=10000` and
# `restrict_vocab=100000` respectively — and
# `n_common = len(set(top5_narrow) & set(top5_wide))`.
# (Set intersection is the right tool *here* — membership, not order,
# is the question. One-line comment: why is that OK in this problem
# when p06/p15 banned sets?)
#
# **(c) Explain the change.**
# Two sentences: why can widening the universe *replace* most of the
# narrow list, and why can it never *add* a word to the search that the
# narrow call had already ranked? (Use the frequency-ordering fact;
# `"lantern"` itself sits outside the top 10,000 — check
# `kv.key_to_index["lantern"]` and set `lantern_rank` to it.)
#
# **(d) Multi-word queries.**
# `most_similar` accepts `positive=[...]` with several words.
# Set `top3_pair` — the top-3 neighbor words (list of `str`) for
# `positive=["rain", "wind"]` with `topn=3, restrict_vocab=20000` —
# and `sim_first` — the top hit's similarity (`float`).

# %%
import os, pathlib
_root = next(p for p in [pathlib.Path.cwd(), *pathlib.Path.cwd().parents]
             if (p / "pyproject.toml").exists())
os.environ["GENSIM_DATA_DIR"] = str(_root / "reference" / "cache" / "gensim")

import numpy as np
import gensim.downloader

kv = gensim.downloader.load("glove-wiki-gigaword-100")

# (a)
sim_gale = ...      # YOUR CODE HERE
sim_hammer = ...    # YOUR CODE HERE
more_related = ...  # YOUR CODE HERE (decided in code)

# (b)
top5_narrow = ...   # YOUR CODE HERE (restrict_vocab=10000)
top5_wide = ...     # YOUR CODE HERE (restrict_vocab=100000)
n_common = ...      # YOUR CODE HERE

# (c)
lantern_rank = ...  # YOUR CODE HERE

# (d)
top3_pair = ...     # YOUR CODE HERE
sim_first = ...     # YOUR CODE HERE

# %% [markdown]
# *Your two-sentence explanation for (c) here.*
