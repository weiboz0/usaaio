# %% [markdown]
# # C8-embeddings — Practice p21
#
# **Type:** challenge · **Difficulty:** advanced · **Concepts:** nearest-neighbor-search
#
# *Coding is required.*
#
# Implement
# ```python
# def nearest_indices(similarities, query_index, k):
#     ...
# ```
# for a one-dimensional NumPy similarity array. The query's self-similarity is included at `query_index`; exclude it before taking neighbors. Rank larger similarities first. **Tie convention:** equal similarities keep their smaller original vocabulary index first. The required register is a descending stable argsort: negate a copy of the scores, explicitly call `np.argsort(..., kind="stable")`, then slice.
#
# Apply the function to the supplied scores with `query_index=3`, `k=4`. Set `neighbors`, `self_excluded`, and `tie_order_ok`; the latter checks that the three tied candidates appear in original-index order.
#
# **Banned (zero points): Python `sorted`, loops/comprehensions, `argpartition`, `lexsort`, default/unstable `argsort`, perturbing scores with epsilons, deleting a tied candidate, or asking gensim/model APIs for neighbors.** A helper that uses a banned ordering route is also banned.

# %%
import numpy as np

similarities = np.array([0.63, 0.91, 0.91, 1.0, 0.84, 0.91, 0.37])


def nearest_indices(similarities, query_index, k):
    # YOUR CODE HERE
    ...


neighbors = ...      # YOUR CODE HERE, NumPy integer array shape (4,)
self_excluded = ...  # YOUR CODE HERE, bool
tie_order_ok = ...   # YOUR CODE HERE, bool
