# %% [markdown]
# # C8-embeddings — Practice p17
#
# **Type:** challenge · **Difficulty:** advanced · **Concepts:** word embeddings
#
# Odd-one-out, by geometry alone.
# In each list below, four words share a theme and one does not.
# The detector: the intruder is the word with the **lowest mean cosine
# similarity to the other words in its list**.
#
# Write
#
# ```python
# def odd_one_out(kv, words):
#     ...
# ```
#
# returning the intruder (a `str`).
# Inside: build the unit-row stack and `S = W @ W.T` (pinned register);
# each word's mean similarity to the *others* is
# `(S.sum(axis=1) - 1.0) / (len(words) - 1)` — derive that expression's
# correctness in a one-line comment (what does subtracting the 1
# remove?) — then `np.argmin`.
#
# Set `odd_words` — the list of the four intruders, in order — and
# `odd_means` — the corresponding four mean-similarity values (a list
# of `float`, each rounded to 4 decimals).
#
# **Banned inside `odd_one_out` (zero points): any `np.linalg`
# function, any Python loop or comprehension over array elements,
# `np.einsum`, `np.tensordot`, `sklearn`, `scipy`, and every gensim
# similarity helper.**
# One Python loop *over the four lists* (to fill `odd_words` /
# `odd_means`) is allowed — the ban governs array arithmetic, not
# list bookkeeping.

# %%
import os, pathlib
_root = next(p for p in [pathlib.Path.cwd(), *pathlib.Path.cwd().parents]
             if (p / "pyproject.toml").exists())
os.environ["GENSIM_DATA_DIR"] = str(_root / "reference" / "cache" / "gensim")

import numpy as np
import gensim.downloader

kv = gensim.downloader.load("glove-wiki-gigaword-100")

LISTS = [
    ["snow", "rain", "fog", "thunder", "cello"],
    ["guitar", "piano", "flute", "trumpet", "salmon"],
    ["bread", "cheese", "honey", "garlic", "falcon"],
    ["otter", "heron", "badger", "salmon", "trumpet"],
]


def odd_one_out(kv, words):
    # YOUR CODE HERE (unit rows -> S -> mean-to-others -> argmin)
    ...


odd_words = ...  # YOUR CODE HERE (loop over LISTS allowed)
odd_means = ...  # YOUR CODE HERE (4 floats, rounded to 4 decimals)
