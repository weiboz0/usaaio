# %% [markdown]
# # C11-neural-training — Practice p04
#
# **Type:** multiple choice (numeric, normal form) · **Difficulty:** intro · **Concepts:** dropout
#
# **Time budget:** 15 minutes
#
# In training mode, inverted dropout independently keeps each coordinate with probability q = 3/4 and divides each kept coordinate by q.
# Apply it to h = (-2, 1, 4), producing h_tilde.
# Write the ratio E[h_tilde_1] / E[h_tilde_2 + h_tilde_3] as a/b, where indices are one-based, b > 0, and gcd(|a|,b) = 1.
# Which reduced signed fraction is the ratio?
#
# A. -3/10
#
# B. -2/5
#
# C. -1/2
#
# D. 2/5
#
# E. 3/5
#
# Reasoning is required.
# Record one letter and derive the expectation of every coordinate used in the ratio from the Bernoulli keep mask and the 1/q scale.
# You must explicitly verify b > 0 and gcd(|a|,b) = 1; an unreduced or sign-ambiguous fraction receives no credit.

# %%
answer_p04 = "?"  # replace with "A".."E"
reasoning_p04 = ""
