# %% [markdown]
# # C11-neural-training — Practice p10
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** dropout
#
# **Time budget:** 35 minutes
#
# Implement `dropout_train_eval(x, p, seed=20260804)` on CPU with `torch.nn.Dropout`.
# Use float64, construct one dropout module, set the seed before the training sequence, and return two consecutive training-mode outputs followed by two evaluation-mode outputs.
# Also reset the same seed and reproduce the two-output training sequence with the same module.
# Return a dictionary with `train_first`, `train_second`, `repeat_first`, `repeat_second`, `eval_first`, and `eval_second`, all detached clones.
#
# For the nonzero fixed input below, the grader checks that every training entry is either zero or the corresponding input divided by `1-p` within `atol=1e-12, rtol=1e-12`; that resetting seed 20260804 reproduces each training output; that the two consecutive training masks differ; and that both evaluation outputs equal the input within those tolerances.
# These are invariant checks rather than a version-fragile published mask or exact sample mean.
#
# **Banned (zero points): hand-constructing a Bernoulli mask; calling `torch.nn.functional.dropout`; reseeding between the two consecutive training calls; scaling evaluation output; or returning a precomputed tensor.**

# %%
import torch
from torch import nn

SEED = 20260804
torch.set_default_dtype(torch.float64)


def dropout_train_eval(x, p, seed=SEED):
    # YOUR CODE HERE
    raise NotImplementedError


x_p10 = torch.linspace(-3.0, 3.0, 101)
x_p10[x_p10 == 0] = 0.125
result_p10 = dropout_train_eval(x_p10, p=0.25)
