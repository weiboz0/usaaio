# %% [markdown]
# # C4-classical-ml-practice — Practice p15
#
#
# **Type:** integrative · **Difficulty:** advanced · **Concepts:** sklearn pipelines, cross-validation, knn
#
# The honest model-selection arc, in full exam register.
# Parts consume earlier results.
#
# On sklearn's wine dataset:
#
# **(a)** Split:
# `train_test_split(X, y, test_size=0.25, random_state=SEED, stratify=y)`
# → `X_tr, X_te, y_tr, y_te`.
#
# **(b)** For each `k` in `ks = [1, 3, 5, 7, 9, 11]`: build a
# `Pipeline` (steps `"scaler"` = `StandardScaler()`, `"knn"` =
# `KNeighborsClassifier(n_neighbors=k)`) and record the **mean** 5-fold
# `cross_val_score` on the training rows → `cv_means`, shape `(6,)`.
#
# **(c)** `best_k` — highest mean, **smallest `k` on ties** (an
# `int`).
# State in one written sentence which NumPy call implements the tie
# rule for free and why.
#
# **(d)** Refit the `best_k` pipeline on all training rows;
# `test_acc` — its accuracy on the held-out rows, the test set's first
# and only use.
#
# **(e)** One written sentence: your `cv_means` for `k = 7, 9, 11` tie
# to 4 decimals — what does the tie rule choose, and why prefer the
# smaller `k` at equal measured accuracy?
#
# **Banned (zero points): scoring any candidate on the test rows;
# scaling outside the pipeline (in particular, any
# `StandardScaler().fit` on `X` or `X_tr` at top level); models other
# than `KNeighborsClassifier`.** A loop over `ks` is permitted.

# %%
import numpy as np
from sklearn.datasets import load_wine
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

SEED = 20260804
X, y = load_wine(return_X_y=True)
ks = np.array([1, 3, 5, 7, 9, 11])

# YOUR CODE HERE

cv_means = ...  # YOUR CODE HERE (shape (6,))
best_k = ...    # YOUR CODE HERE
test_acc = ...  # YOUR CODE HERE

# %% [markdown]
# *Your (c) and (e) sentences here.*
