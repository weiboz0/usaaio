# %% [markdown]
# # C4-classical-ml-practice — Practice p02
#
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** knn, feature scaling
#
# A 1-nearest-neighbor classifier uses **raw** (unstandardized)
# Euclidean distance on two features: `height_m` (values spread over
# roughly 0.5 m) and `income_usd` (values spread over roughly \$50,000).
#
# Which statement is true?
#
# A. Both features influence the choice of nearest neighbor roughly
# equally, because Euclidean distance sums over all features.
#
# B. The nearest neighbor is determined almost entirely by
# `income_usd`; `height_m` contributes a negligible share of every
# squared distance.
#
# C. The nearest neighbor is determined almost entirely by `height_m`,
# because smaller numbers give more precise distances.
#
# D. Standardizing the features cannot change which training point is
# nearest, since both columns are transformed by the same kind of
# formula.
#
# E. Euclidean distance is undefined when features carry different
# physical units, so the classifier will raise an error.
#
# Record your choice below.

# %%
import numpy as np

answer_p02 = "?"  # replace with "A".."E"
