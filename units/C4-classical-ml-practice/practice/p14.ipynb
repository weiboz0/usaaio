# %% [markdown]
# # C4-classical-ml-practice — Practice p14
#
#
# **Type:** integrative · **Difficulty:** core · **Concepts:** pandas-basics, csv-data-loading, knn, feature-scaling, random-seeding, broadcasting, aggregation-axis, distance-metrics, train-test-split, accuracy-precision-recall
#
# End-to-end, library-free: the whole unit in one arc.
# Parts consume earlier results.
#
# **(a)** Load `data/beans.csv`; build `X`
# (`["length_mm", "width_mm", "mass_g", "moisture_pct"]`, that order)
# and `y` (`species`).
#
# **(b)** Split by a seeded permutation:
# `perm = np.random.default_rng(SEED).permutation(90)`; the first 70
# permuted indices are training rows, the last 20 are test rows →
# `X_tr, y_tr, X_te, y_te`.
#
# **(c)** Standardize `X_tr` and `X_te` with the **training** rows'
# per-column mean and population std → `Z_tr, Z_te`.
#
# **(d)** Implement 5-NN with **string labels**: squared-distance
# matrix by broadcasting, `np.argsort`, then a majority vote per query
# row via `np.unique(..., return_counts=True)` (a loop **over the 20
# test rows** is permitted for the vote only) → `preds`, shape
# `(20,)`.
#
# **(e)** `test_acc` — the fraction of `preds` matching `y_te`; and
# `test_acc_raw` — the same pipeline of steps but **skipping (c)**
# (distances on raw features).
# One written sentence: which feature's scale explains the direction of
# the gap?
#
# **Banned (zero points): importing `sklearn` (the point is to own
# every step); loops other than the sanctioned vote loop in (d);
# computing any statistic from test rows in (c).**

# %%
import numpy as np
import pandas as pd

SEED = 20260804
FEATURES = ["length_mm", "width_mm", "mass_g", "moisture_pct"]

# (a) YOUR CODE HERE
X = ...
y = ...

# (b) YOUR CODE HERE
X_tr, y_tr, X_te, y_te = ..., ..., ..., ...

# (c) YOUR CODE HERE
Z_tr, Z_te = ..., ...

# (d) YOUR CODE HERE
preds = ...

# (e) YOUR CODE HERE
test_acc = ...
test_acc_raw = ...

# %% [markdown]
# *Your (e) sentence here.*
