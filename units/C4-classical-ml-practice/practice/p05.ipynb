# %% [markdown]
# # C4-classical-ml-practice — Practice p05
#
#
# **Type:** constrained coding · **Difficulty:** intro · **Concepts:** pandas basics, CSV data loading
#
# The exam's starter-code move: from CSV to the `(X, y)` pair.
#
# Load `data/beans.csv` (columns: `species`, `length_mm`, `width_mm`,
# `mass_g`, `moisture_pct`) and produce:
#
# - `df` — the DataFrame, via `pd.read_csv`;
# - `n_rows` — the number of rows (an `int`);
# - `class_counts` — rows per species, via `value_counts()`;
# - `X` — NumPy feature matrix from the columns
#   `["length_mm", "width_mm", "mass_g", "moisture_pct"]` **in exactly
#   that order**, shape `(n_rows, 4)`, float dtype;
# - `y` — NumPy label array from `species`, shape `(n_rows,)`.
#
# **Banned (zero points): loops; `open()`/manual parsing/the `csv`
# module — `pd.read_csv` only; building `X` column-by-column instead of
# via one column-list selection + `.to_numpy()`.**

# %%
import numpy as np
import pandas as pd

FEATURES = ["length_mm", "width_mm", "mass_g", "moisture_pct"]

df = ...            # YOUR CODE HERE (pd.read_csv)
n_rows = ...        # YOUR CODE HERE
class_counts = ...  # YOUR CODE HERE
X = ...             # YOUR CODE HERE (column list -> .to_numpy())
y = ...             # YOUR CODE HERE
