# %% [markdown]
# # C4-classical-ml-practice — Practice p06
#
#
# **Type:** constrained coding · **Difficulty:** intro · **Concepts:** CSV data loading
#
# Load `data/sensors.csv` (columns: `status` with values `ok`/`faulty`,
# then `temp_c`, `vibration_mm_s`, `pressure_pa`) and produce:
#
# - `sensors` — the DataFrame;
# - `n_faulty` — the number of rows with status `"faulty"` (an `int`,
#   from a mask aggregation);
# - `pressure_mean` — the mean of `pressure_pa` (a `float`);
# - `hot` — the DataFrame of rows with `temp_c` strictly greater than
#   67.0;
# - `hot_faulty_frac` — the fraction of the rows of `hot` whose status
#   is `"faulty"` (a `float` in [0, 1]; note the denominator is the
#   number of *hot* rows);
# - `X_sub` — NumPy array of the columns
#   `["temp_c", "vibration_mm_s"]` in that order, shape `(60, 2)`.
#
# **Banned (zero points): loops; `open()`/manual parsing/the `csv`
# module — `pd.read_csv` only.**

# %%
import numpy as np
import pandas as pd

sensors = ...          # YOUR CODE HERE
n_faulty = ...         # YOUR CODE HERE
pressure_mean = ...    # YOUR CODE HERE
hot = ...              # YOUR CODE HERE
hot_faulty_frac = ...  # YOUR CODE HERE
X_sub = ...            # YOUR CODE HERE
