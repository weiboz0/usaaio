# %% [markdown]
# # C4-classical-ml-practice — Practice p20
#
#
# **Type:** drill · **Difficulty:** intro · **Concepts:** pandas basics, CSV data loading
#
# Rapid-fire one-liners over `data/beans.csv`.
# Each deliverable is a single expression (plus the load); no loops
# anywhere (zero points).
#
# - `beans` — the loaded DataFrame;
# - `n_rows`, `n_cols` — from its shape (ints);
# - `class_counts` — rows per species (`value_counts()`);
# - `mean_mass` — mean of `mass_g` over all beans (float);
# - `mass_by_species` — mean `mass_g` per species (`groupby`);
# - `n_heavy` — number of beans with `mass_g > 0.7` (int);
# - `n_heavy_cava` — number of beans with `mass_g > 0.7` **and**
#   species `"cava"` (int);
# - `max_moisture` — the largest `moisture_pct` (float);
# - `X` — NumPy array of
#   `["length_mm", "width_mm", "mass_g", "moisture_pct"]` (that
#   order), shape `(90, 4)`;
# - `y` — NumPy array of `species`, shape `(90,)`.

# %%
import numpy as np
import pandas as pd

beans = ...            # YOUR CODE HERE
n_rows = ...           # YOUR CODE HERE
n_cols = ...           # YOUR CODE HERE
class_counts = ...     # YOUR CODE HERE
mean_mass = ...        # YOUR CODE HERE
mass_by_species = ...  # YOUR CODE HERE
n_heavy = ...          # YOUR CODE HERE
n_heavy_cava = ...     # YOUR CODE HERE
max_moisture = ...     # YOUR CODE HERE
X = ...                # YOUR CODE HERE
y = ...                # YOUR CODE HERE
