# %% [markdown]
# # C4-classical-ml-practice — Practice p08
#
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** feature scaling
#
# Standardization by hand, with the train-statistics discipline.
#
# Implement `standardize(X_tr, X_te)` returning `(Z_tr, Z_te, mu, sd)`
# where `mu` and `sd` are the per-column mean and (population) standard
# deviation **of the training rows only**, and both parts are
# transformed as $z = (x - \mu)/\sigma$ with those same statistics.
#
# Then, for the seeded data below:
#
# - `Z_train, Z_test, mu, sd` — from your function;
# - `train_mean_max` — `np.abs(Z_train.mean(axis=0)).max()` (should be
#   ≈ 0);
# - `train_std_gap` — `np.abs(Z_train.std(axis=0) - 1).max()` (should
#   be ≈ 0);
# - `z_test_first` — `Z_test[0]`, the first standardized test row
#   (shape `(2,)`; it will **not** have mean-0/std-1 behavior of its
#   own — that is the point of train statistics).
#
# **Banned (zero points): importing `sklearn` (in particular
# `StandardScaler` — this problem is the by-hand register), loops,
# computing any statistic from `X_te`.**

# %%
import numpy as np

SEED = 20260804
rng = np.random.default_rng(SEED)
X_train = np.column_stack([rng.normal(20.0, 5.0, 12),
                           rng.normal(3000.0, 400.0, 12)])
X_test = np.column_stack([rng.normal(20.0, 5.0, 4),
                          rng.normal(3000.0, 400.0, 4)])


def standardize(X_tr, X_te):
    # YOUR CODE HERE (train statistics only; banned: sklearn, loops)
    ...


Z_train, Z_test, mu, sd = ...  # YOUR CODE HERE (call standardize)
train_mean_max = ...           # YOUR CODE HERE
train_std_gap = ...            # YOUR CODE HERE
z_test_first = ...             # YOUR CODE HERE
