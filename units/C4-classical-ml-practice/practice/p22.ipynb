# %% [markdown]
# # C4-classical-ml-practice — Practice p22
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** tabular-feature-engineering
#
# *Coding is required.*
#
# The table below has 17 candidate predictors, only a few informative. Split first, then build `pipe` with exact steps:
#
# 1. `("select", SelectKBest(score_func=f_classif, k=7))`
# 2. `("scale", StandardScaler())`
# 3. `("knn", KNeighborsClassifier(n_neighbors=9))`
#
# Fit `pipe` on `X_tr, y_tr` only. Set `selected_idx` to the selector's seven selected column indices as a NumPy array, `test_acc` to the held-out accuracy as a plain `float`, and retrieve the fitted selector as `sel = pipe.named_steps["select"]`. Set `selection_is_train_only` to `True` only when `sel.scores_` matches `f_classif(X_tr, y_tr)[0]` with `atol=1e-9, rtol=0` and does not match `f_classif(X, y)[0]` under that same contract. This audit must demonstrate both that selection used the training rows and that it differs from full-data selection.
#
# **Banned (zero points): calling `fit` or `fit_transform` on `SelectKBest` outside `pipe`, selecting columns before the split, fitting on `X`/`y`, or using validation labels to change `k`.** Hiding any of those operations in a helper is still banned.

# %%
import numpy as np
from sklearn.datasets import make_classification
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

SEED = 20260804
X, y = make_classification(
    n_samples=227,
    n_features=17,
    n_informative=5,
    n_redundant=3,
    n_repeated=0,
    class_sep=1.37,
    random_state=SEED,
)
X_tr, X_te, y_tr, y_te = train_test_split(
    X, y, test_size=0.29, random_state=SEED, stratify=y
)

pipe = ...                    # YOUR CODE HERE
# fit pipe here
sel = ...                     # YOUR CODE HERE, fitted selector
selected_idx = ...            # YOUR CODE HERE, shape (7,)
test_acc = ...                # YOUR CODE HERE, float
selection_is_train_only = ... # YOUR CODE HERE, bool
