# %% [markdown]
# # C12-classical-models — Practice p27
#
# **Type:** challenge · **Difficulty:** advanced · **Concepts:** svm, margin-and-hinge-loss
#
# **Time budget:** 50 minutes
#
# Reconstruct a kernel support-vector decision function from pinned fitted state. The RBF kernel is
# $K(x,z)=\exp(-\gamma\|x-z\|^2)$ with `gamma=0.5`. Support vectors, signed dual coefficients
# $\alpha_it_i$, intercept, and probes are supplied below.
#
# 1. Implement `reconstruct_scores(support_vectors, signed_dual, intercept, gamma, X_probe)` using
#    broadcasting only. Return float64 shape `(M,)`.
# 2. Return `contributions` shape `(S,M)`, where row `i` is the complete signed contribution before
#    adding the intercept.
# 3. Predict `+1` for score `>=0`, else `-1`.
# 4. Hand-derive the first probe's kernel values and score; use exact exponent expressions before
#    decimals.
# 5. Audit the supplied coefficients: infer each support vector's label sign, identify which have
#    zero/nonzero influence at each probe, and explain why a non-support training row would vanish.
#
# The grader checks shapes/dtypes, the complete contribution matrix and scores against independent
# references within `atol=1e-12, rtol=1e-10`, and catches omitted signs/intercept or an unsquared
# distance.
#
# **Banned (zero points): `sklearn`, loops over probes, replacing RBF by a dot product, applying a
# sigmoid, or hard-coding expected scores.**

# %%
import numpy as np

support_vectors_p27 = np.array([[-1.,0.],[0.,1.],[1.,0.],[0.,-1.]], dtype=np.float64)
signed_dual_p27 = np.array([-0.8, 0.6, 0.7, -0.5], dtype=np.float64)
intercept_p27 = 0.15
gamma_p27 = 0.5
X_probe_p27 = np.array([[0.,0.],[1.,1.],[-1.,-1.]], dtype=np.float64)


def reconstruct_scores(support_vectors, signed_dual, intercept, gamma, X_probe):
    # YOUR CODE HERE
    raise NotImplementedError


result_p27 = reconstruct_scores(
    support_vectors_p27, signed_dual_p27, intercept_p27, gamma_p27, X_probe_p27
)
# YOUR FIRST-PROBE DERIVATION AND SUPPORT AUDIT HERE
