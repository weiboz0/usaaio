# %% [markdown]
# # C12-classical-models — Practice p30
#
# **Type:** challenge · **Difficulty:** advanced · **Concepts:** k-means, lloyd-algorithm
#
# **Time budget:** 50 minutes
#
# Build a robust k-means comparison around the fixed dataset below.
#
# 1. Implement `robust_lloyd(X, initial_centroids, max_iter=100, tol=1e-10)` with Session-6
#    distance ties, empty-cluster repair, exact mean updates, consistent objective trace, and
#    validation. Return a dictionary with labels, centroids, objective trace, iteration count, and
#    number of repairs.
# 2. Run the three supplied initializations in order. Check every cluster is nonempty, each trace is
#    nonincreasing within `atol=1e-10, rtol=1e-8`, and results are deterministic.
# 3. Select the run with smallest final WCSS; exact ties choose the smaller initialization index.
# 4. Compare partitions with co-clustering matrices rather than raw cluster numbers, and report
#    pairwise agreement fractions.
# 5. Fit `KMeans(n_clusters=3, init="k-means++", n_init=10, max_iter=100, tol=1e-10,
#    random_state=20260804)` on the same data. Compare final WCSS and centers up to permutation,
#    without claiming either implementation must choose identical labels.
#
# The grader uses the public data plus hidden duplicated-point/empty-cluster cases and independent
# references within `atol=1e-10, rtol=1e-8`.
#
# **Banned (zero points): dropping empty clusters, random repair, comparing raw cluster ids across
# runs, non-centroid updates, or selecting a run using hidden group labels.**

# %%
import numpy as np
from sklearn.cluster import KMeans

X_p30 = np.array([[0.,0.],[0.,0.],[0.,2.],[1.,1.],
                  [8.,8.],[8.,10.],[9.,9.],[9.,9.],
                  [4.,4.],[4.,5.]], dtype=np.float64)
initializations_p30 = [
    np.array([[0.,0.],[0.,0.],[9.,9.]], dtype=np.float64),
    np.array([[0.,2.],[4.,4.],[8.,10.]], dtype=np.float64),
    np.array([[1.,1.],[4.,5.],[9.,9.]], dtype=np.float64),
]


def robust_lloyd(X, initial_centroids, max_iter=100, tol=1e-10):
    # YOUR CODE HERE
    raise NotImplementedError


runs_p30 = [robust_lloyd(X_p30, init) for init in initializations_p30]
# YOUR SELECTION, CO-CLUSTERING, AND SKLEARN COMPARISON HERE
