# %% [markdown]
# # C9-dimensionality-reduction — Practice p06
#
# **Type:** constrained coding · **Difficulty:** intro · **Concepts:** truncated SVD (practice)
#
# The thin-SVD contract, on a matrix small enough to inspect.
#
# For the seeded matrix `A` built below (shape `(9, 5)`), set:
#
# - `U`, `s`, `Vt` — the thin SVD (`full_matrices=False`);
# - `shapes_ok` — a `bool`: `U`, `s`, `Vt` have shapes `(9, 5)`,
#   `(5,)`, `(5, 5)`;
# - `desc_ok` — a `bool`: the singular values arrive in descending
#   order (no reordering — that idiom belongs to `eigh`);
# - `recon_gap` — `float(np.max(np.abs(U @ np.diag(s) @ Vt - A)))`, and
#   `assert recon_gap < 1e-12`;
# - `fro_gap` — the absolute difference between
#   $\lVert A \rVert_F^2$ (computed from entries, broadcasting only)
#   and $\sum_i \sigma_i^2$, a `float`, and `assert fro_gap < 1e-9`
#   (F6-04's identity, verified).
#
# **Banned (zero points): sklearn (any module — `sklearn.decomposition.PCA`, `TruncatedSVD`, `StandardScaler`, and everything else in the package), `scipy`, any Python loop or comprehension over array elements, `np.einsum`, `np.tensordot`.**
# Allowed: plain NumPy broadcasting, `@`, `.T`, and `np.linalg.svd`.

# %%
import numpy as np

SEED = 20260804
rng = np.random.default_rng(SEED)
A = rng.normal(0.0, 1.5, (9, 5))

U = ...          # YOUR CODE HERE (thin SVD, full_matrices=False)
s = ...          # YOUR CODE HERE
Vt = ...         # YOUR CODE HERE
shapes_ok = ...  # YOUR CODE HERE (bool)
desc_ok = ...    # YOUR CODE HERE (bool)
recon_gap = ...  # YOUR CODE HERE (float; assert < 1e-12)
fro_gap = ...    # YOUR CODE HERE (float; assert < 1e-9)
