# %% [markdown]
# # C9-dimensionality-reduction — Practice p15
#
# **Type:** scenario · **Difficulty:** core · **Concepts:** UMAP (concept)
#
# A product team clustered its customer base ($80$ features per
# customer) and presented a 2-D map made with a neighbor-graph layout
# method (UMAP-style, as taught).
# The slide's caption reads:
#
# > *(a)* "Segment A sits closer to B than to C on the map, so A's
# > customers are more similar to B's than to C's."
# > *(b)* "These two accounts land in the same tight clump — they are
# > probably genuinely similar customers."
# > *(c)* "Segment C is drawn largest, so it is the most diverse
# > segment."
# > *(d)* "We will regenerate this map next quarter and compare the two
# > pictures position by position."
#
# The analytics team also computed honest **original-space** distances
# between the segment centroids (the matrix `D_cent` below, ordered
# A, B, C, D).
#
# **(1) Audit each claim.**
# Set `verdicts` — a `dict` mapping `"a"`, `"b"`, `"c"`, `"d"` to
# `"supported"` or `"unsupported"` (judged against this unit's stated
# facts about what such maps preserve).
#
# **(2) Check claim (a) against the data.**
# From `D_cent`, set `true_nearest` — the segment (`"B"`, `"C"`, or
# `"D"`) whose centroid is genuinely nearest to A's — and
# `claim_a_holds` — a `bool`, whether the map's nearest (B) agrees.
#
# **(3) Diagnose.**
# In the markdown cell, one or two sentences per *unsupported* claim:
# name the stated fact it violates, and — for (a) — what the
# original-space numbers actually show.
#
# No bans beyond the unit's standing ones — this problem needs only
# plain NumPy on a $4 \times 4$ array.

# %%
import numpy as np

SEGMENTS = ["A", "B", "C", "D"]
D_cent = np.array([
    [ 0.0, 14.2,  9.8, 21.5],
    [14.2,  0.0, 12.1, 16.4],
    [ 9.8, 12.1,  0.0, 18.9],
    [21.5, 16.4, 18.9,  0.0],
])

verdicts = ...       # YOUR CODE HERE (dict: "a".."d" -> "supported"/"unsupported")
true_nearest = ...   # YOUR CODE HERE (computed from D_cent, not by eye)
claim_a_holds = ...  # YOUR CODE HERE (bool)

# %% [markdown]
# *Your diagnosis (3) here.*
