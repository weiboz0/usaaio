# %% [markdown]
# # C9-dimensionality-reduction — Practice p09
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** truncated-svd-practice, embedding-matrices, svd, singular-values, low-rank-approximation, frobenius-norm
#
# Budget-driven rank choice on a $24$-word stack — decisions with
# certificates, straight from the spectrum.
#
# For the words below, set:
#
# - `W` — the unit-row stack, C8's convention, shape `(24, 100)`;
# - `s` — its singular values (thin SVD);
# - `rel_err2` — the length-$24$ array of relative squared Frobenius
#   errors of the rank-$r$ truncations, `rel_err2[r - 1]` for rank $r$,
#   computed **entirely from `s`** via the tail identity and one
#   `np.cumsum` — no $W_r$ may be built anywhere in this problem;
# - `r_star` — a `dict` mapping each budget in `BUDGETS` to the
#   **smallest** rank whose relative squared error is at most that
#   budget (`int` values; the `np.argmax`-on-boolean idiom; a Python
#   loop **over the three budgets** is allowed as bookkeeping);
# - for every budget, `assert` the two-sided certificate: the chosen
#   rank meets the budget and the rank below it does not.
#
# Note what the deliverable is *not*: no plot, no truncated matrices —
# the entire analysis lives in the spectrum.
#
# **Banned (zero points): sklearn (any module — `sklearn.decomposition.PCA`, `TruncatedSVD`, and everything else in the package), `scipy`, any Python loop or comprehension over array elements, `np.einsum`, `np.tensordot`, and every gensim similarity helper (`kv.most_similar`, `kv.similarity`, `kv.n_similarity`, `kv.distances`).**
# Allowed: `kv[...]` lookup (the load boundary), NumPy broadcasting, `@`, `.T`, `np.linalg.svd`, `np.cumsum`, `np.argmax`, `np.diag`.

# %%
import os, pathlib
_root = next(p for p in [pathlib.Path.cwd(), *pathlib.Path.cwd().parents]
             if (p / "pyproject.toml").exists())
os.environ["GENSIM_DATA_DIR"] = str(_root / "reference" / "cache" / "gensim")

import numpy as np
import gensim.downloader

kv = gensim.downloader.load("glove-wiki-gigaword-100")

WORDS = ["sparrow", "pigeon", "crow", "robin", "owl", "swan",
         "apple", "mango", "plum", "cherry", "peach", "grape",
         "hammer", "wrench", "chisel", "pliers", "saw", "drill",
         "jacket", "scarf", "sweater", "collar", "sleeve", "cloak"]
BUDGETS = (0.20, 0.10, 0.02)

W = ...         # YOUR CODE HERE (unit rows, float64, (24, 100))
s = ...         # YOUR CODE HERE
rel_err2 = ...  # YOUR CODE HERE (shape (24,), from s alone)
r_star = ...    # YOUR CODE HERE (dict {budget: int}; loop over BUDGETS OK)

# YOUR CODE HERE: the two-sided certificate asserts, one pair per budget
