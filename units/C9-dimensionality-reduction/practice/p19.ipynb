# %% [markdown]
# # C9-dimensionality-reduction — Practice p19
#
# **Type:** scenario analysis · **Difficulty:** core · **Concepts:** pca, variance, bias-variance-intuition, overfitting
#
# *Reasoning is required. No coding is needed; the code cell records the exact scenario verdict.*
#
# A team projects a fixed training split onto the first $r$ principal components, fits the same downstream classifier at every $r$, and evaluates once on a held-out test split. The cumulative variance-explained ratio (`cum_evr`) measures how much **feature variance** the projection keeps; it is not itself a generalization score.
#
# | retained rank $r$ | `cum_evr` | train accuracy | test accuracy |
# |---:|---:|---:|---:|
# | 1 | 0.47 | 0.66 | 0.64 |
# | 2 | 0.72 | 0.79 | 0.76 |
# | 4 | 0.90 | 0.91 | 0.83 |
# | 7 | 0.98 | 0.98 | 0.71 |
#
# 1. Set `selected_r: int` to the rank you would deploy from this table and justify it using the held-out score rather than `cum_evr` alone.
# 2. Set `capacity_trend: str` to either `"increases-with-r"` or `"decreases-with-r"`. Explain why retaining more components gives the downstream rule more capacity.
# 3. Set `r1_diagnosis: str` and `r7_diagnosis: str` to `"underfitting"`, `"balanced"`, or `"overfitting"`. Cite both the score level and train-test gap.
# 4. In 3–5 sentences, distinguish the feature variance measured by `cum_evr` from the across-training-samples variance in the bias–variance tradeoff, and explain why high EVR does not guarantee a small train-test gap.

# %%
selected_r: int = ...
capacity_trend: str = ""
r1_diagnosis: str = ""
r7_diagnosis: str = ""

# %% [markdown]
# **Your 3–5 sentence variance-and-gap explanation:**
