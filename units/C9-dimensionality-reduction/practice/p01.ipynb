# %% [markdown]
# # C9-dimensionality-reduction — Practice p01
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** PCA
#
# A dataset $X$ of shape $(n, d)$ is centered to
# $X_c = X - X.\mathrm{mean(axis=0)}$.
# As taught in this unit, the **first principal direction** $v_1$ of the
# data is:
#
# A. the coordinate axis of the single original feature with the largest
# variance
#
# B. the unit vector $u$ maximizing the sample variance of the
# projection scores $X_c\, u$
#
# C. the unit vector pointing from the origin toward the mean vector
# $\mu$
#
# D. the row of $X_c$ with the largest norm, rescaled to unit length
#
# E. undefined, because $u$ and $-u$ produce different variances, so no
# single maximizer exists
#
# Reasoning is not required. Record your choice below.

# %%
answer_p01 = "?"  # replace with "A".."E"
