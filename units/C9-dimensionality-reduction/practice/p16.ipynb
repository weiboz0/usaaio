# %% [markdown]
# # C9-dimensionality-reduction — Practice p16
#
# **Type:** scenario · **Difficulty:** core · **Concepts:** UMAP (concept)
#
# Your lab has a $60$-dimensional measurement dataset and three analysis
# goals.
# For each goal, the available "views" are: a **PCA projection**
# (`"pca"`), a **neighbor-graph layout** of the kind taught in this unit
# (`"neighbor-map"`), or **no 2-D picture at all — compute in the
# original space** (`"original-space"`).
#
# > *(i)* Flag likely near-duplicate records for manual review.
# > *(ii)* Report *how far apart*, quantitatively, two known
# > experimental groups are.
# > *(iii)* Present two axes with explicit feature recipes (loadings)
# > and a stated fraction of variance shown.
#
# **(1) Choose.**
# Set `choices` — a `dict` mapping `"i"`, `"ii"`, `"iii"` to one of the
# three strings above.
# (One goal is served *best* by skipping pictures entirely — recall
# which quantity every 2-D view either shrinks or distorts.)
#
# **(2) Quantify the PCA option's honesty for this dataset.**
# The dataset's top six variance-explained ratios are given below.
# Set `kept2` — the variance fraction a 2-D PCA scatter would keep
# (a `float`) — and `lost2 = 1 - kept2`.
#
# **(3) Justify.**
# In the markdown cell: one sentence per goal naming the stated fact or
# guarantee behind your choice, plus one sentence on what a
# `kept2`-sized window means for reading the PCA scatter of goal (iii)
# (what kind of structure could hide in `lost2`?).
#
# No bans beyond the unit's standing ones — the only computation is on
# the given array.

# %%
import numpy as np

evr_top6 = np.array([0.21, 0.13, 0.09, 0.07, 0.06, 0.05])
# (the remaining 54 components share the rest)

choices = ...  # YOUR CODE HERE (dict: "i"/"ii"/"iii" -> view string)
kept2 = ...    # YOUR CODE HERE (float)
lost2 = ...    # YOUR CODE HERE (float)

# %% [markdown]
# *Your justifications (3) here.*
