# %% [markdown]
# # C2-linear-models — Practice p03
#
# **Type:** multiple choice · **Difficulty:** core · **Concepts:** L1 regularization, sparsity
#
# A linear model is trained twice on the same dataset with the same
# strength $\lambda > 0$: once with the penalty
# $\lambda \sum_k w_k^2$ added to the MSE, once with
# $\lambda \sum_k |w_k|$.
#
# Which statement is correct?
#
# A. The squared penalty typically produces more weights that are exactly
#    zero, because squaring punishes small weights the hardest.
#
# B. Neither penalty can make any weight exactly zero, because the MSE
#    term is smooth.
#
# C. The absolute-value penalty can hold weights at exactly zero, because
#    its slope keeps the constant magnitude $\lambda$ arbitrarily close to
#    zero, so a weak data pull cannot move the weight off the origin.
#
# D. The two penalties always produce identical weights whenever
#    $\lambda$ is the same, since both charge for size.
#
# E. The absolute-value penalty shrinks every weight by the common factor
#    $1/(1+\lambda)$ but never reaches zero.
#
# Reasoning is not required. Record your choice below.

# %%
import numpy as np

answer_p03 = "?"  # replace with "A".."E"
