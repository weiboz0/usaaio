# %% [markdown]
# # C2-linear-models — Practice p09
#
# **Type:** constrained coding · **Difficulty:** intro · **Concepts:** linear regression, MSE loss
#
# Predictions to residuals to score, end to end on hand-checkable data.
#
# For the dataset and given weights below, compute — in this order and
# each from the previous —
#
# - `preds`: the shape-`(4,)` predictions
#   $\hat y_i = \sum_k X_{ik} w_k + b$;
# - `resid`: the shape-`(4,)` residuals $r_i = \hat y_i - y_i$
#   (predictions **minus** targets — this course's pinned convention);
# - `mse_val`: the scalar $\frac{1}{n}\sum_i r_i^2$;
# - `worst_i`: the integer index of the example with the largest
#   $|r_i|$ (use `np.argmax`).
#
# **Banned (zero points): `@`, `np.matmul`, `np.dot`, `.T`, `np.einsum`,
# `np.inner`, `np.tensordot`, any `np.linalg` function, any loop.**
#
# Every number is small enough to verify by hand — do so before running.

# %%
import numpy as np

X = np.array([[1.0, 2.0],
              [3.0, 0.0],
              [2.0, 1.0],
              [0.0, 4.0]])
y = np.array([4.0, 2.0, 3.0, 6.0])
w = np.array([1.0, 1.0])
b = 0.0

preds = ...    # YOUR CODE HERE
resid = ...    # YOUR CODE HERE
mse_val = ...  # YOUR CODE HERE
worst_i = ...  # YOUR CODE HERE
