# %% [markdown]
# # C2-linear-models — Practice p07
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** L2 regularization
#
# Ridge loss and its weight-gradient, evaluated at given weights.
#
# For the linear model $\hat y_i = \sum_k X_{ik} w_k + b$ and
# $$L(w, b) = \frac{1}{n}\sum_i (\hat y_i - y_i)^2 + \lambda \sum_k w_k^2$$
# (bias **not** penalized), write:
#
# - `ridge_loss(X, y, w, b, lam)` — the scalar $L$;
# - `ridge_grad_w(X, y, w, b, lam)` — the shape-`(d,)` array of partials
#   $\dfrac{\partial L}{\partial w_j} = \dfrac{2}{n}\sum_i r_i X_{ij}
#   + 2\lambda w_j$ with $r_i = \hat y_i - y_i$;
# - `ridge_grad_b(X, y, w, b, lam)` — the scalar
#   $\dfrac{2}{n}\sum_i r_i$.
#
# **Banned inside all three functions (zero points): `@`, `np.matmul`,
# `np.dot`, `.T`, `np.einsum`, `np.inner`, `np.tensordot`, any `np.linalg`
# function, any loop.**
#
# Evaluate all three at the seeded data and given weights below, then
# compute `check_gap` — the max abs difference of the four partials
# (three weights and the bias) against central differences of
# `ridge_loss` with $h = 10^{-6}$ (the checker MAY loop).

# %%
import numpy as np

SEED = 20260804
rng = np.random.default_rng(SEED)
X = rng.normal(0, 1, (20, 3))
y = rng.normal(0, 1, 20)
w0 = np.array([1.0, -1.0, 0.5])
b0 = 0.5
lam = 0.4


def ridge_loss(X, y, w, b, lam):
    # YOUR CODE HERE (banned: @, np.matmul, np.dot, .T, np.einsum, loops)
    ...


def ridge_grad_w(X, y, w, b, lam):
    # YOUR CODE HERE (same bans)
    ...


def ridge_grad_b(X, y, w, b, lam):
    # YOUR CODE HERE (same bans)
    ...


loss_val = ...   # YOUR CODE HERE
grad_w = ...     # YOUR CODE HERE
grad_b = ...     # YOUR CODE HERE
check_gap = ...  # YOUR CODE HERE (checker MAY loop)
