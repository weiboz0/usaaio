# %% [markdown]
# # C2-linear-models — Practice p05
#
# **Type:** constrained coding · **Difficulty:** intro · **Concepts:** linear regression
#
# The linear model, component form, exam-safe.
#
# Write `predict(X, w, b)` returning the shape-`(n,)` prediction array
# $$\hat y_i = \sum_{k} X_{ik}\, w_k + b .$$
#
# **Banned (zero points): `@`, `np.matmul`, `np.dot`, `.T`, `np.einsum`,
# `np.inner`, `np.tensordot`, any `np.linalg` function, any loop.**
# Use elementwise multiplication, broadcasting, and axis sums only.
#
# For the seeded data below compute `preds = predict(X, w, b)` and
# `pred_first = float(preds[0])`.

# %%
import numpy as np

SEED = 20260804
rng = np.random.default_rng(SEED)
X = rng.normal(0, 1, (30, 3))
w = np.array([1.5, -2.0, 0.5])
b = 4.0


def predict(X, w, b):
    # YOUR CODE HERE (banned: @, np.matmul, np.dot, .T, np.einsum, loops)
    ...


preds = ...       # YOUR CODE HERE
pred_first = ...  # YOUR CODE HERE
