# %% [markdown]
# # C2-linear-models — Practice p08
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** L1 regularization
#
# Lasso loss at supplied candidates, and the kink, measured.
#
# **Part 1.**
# Write `lasso_loss(X, y, w, b, lam)` returning
# $$L(w, b) = \frac{1}{n}\sum_i \Big(\sum_k X_{ik} w_k + b - y_i\Big)^2
#  + \lambda \sum_k |w_k| $$
# (bias **not** penalized).
# **Banned inside the function (zero points): `@`, `np.matmul`, `np.dot`,
# `.T`, `np.einsum`, `np.inner`, `np.tensordot`, any `np.linalg` function,
# any loop.**
#
# Three candidate settings are supplied for the seeded data below
# ($\lambda = 0.8$ throughout):
#
# - **a**: $w = (1, -2)$, $b = 0.5$;
# - **b**: $w = (0, -2.5)$, $b = 1$;
# - **c**: $w = (0, 0)$, $b = 3$.
#
# Compute `pen_a`, `pen_b`, `pen_c` (the penalty term alone) and
# `loss_a`, `loss_b`, `loss_c` (the full $L$), and set `lowest` to
# `"a"`, `"b"`, or `"c"` for the smallest full loss.
#
# **Part 2 (the kink, measured).**
# For $g(w) = |w|$ compute the one-sided difference quotients at $0$ with
# $h = 10^{-6}$:
# `slope_right` $= \big(g(h) - g(0)\big)/h$ and
# `slope_left` $= \big(g(0) - g(-h)\big)/h$, plus
# `kink_jump = slope_right - slope_left`.

# %%
import numpy as np

SEED = 20260804
rng = np.random.default_rng(SEED)
X = rng.normal(0, 1, (15, 2))
y = X[:, 0] - 2 * X[:, 1] + 0.5 + rng.normal(0, 0.4, 15)
lam = 0.8


def lasso_loss(X, y, w, b, lam):
    # YOUR CODE HERE (banned: @, np.matmul, np.dot, .T, np.einsum, loops)
    ...


pen_a, loss_a = ..., ...   # YOUR CODE HERE
pen_b, loss_b = ..., ...   # YOUR CODE HERE
pen_c, loss_c = ..., ...   # YOUR CODE HERE
lowest = ...               # YOUR CODE HERE ("a", "b", or "c")

slope_right = ...  # YOUR CODE HERE
slope_left = ...   # YOUR CODE HERE
kink_jump = ...    # YOUR CODE HERE
