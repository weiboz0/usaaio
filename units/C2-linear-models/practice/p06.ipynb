# %% [markdown]
# # C2-linear-models — Practice p06
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** MSE loss
#
# The scoreboard function, then a two-candidate ruling.
#
# Write `mse(X, y, w, b)` returning the scalar
# $$\mathrm{MSE} = \frac{1}{n}\sum_{i}\Big(\sum_k X_{ik} w_k + b - y_i\Big)^2 .$$
#
# **Banned (zero points): `@`, `np.matmul`, `np.dot`, `.T`, `np.einsum`,
# `np.inner`, `np.tensordot`, any `np.linalg` function, any loop.**
#
# Two candidate weight settings are supplied for the seeded data below:
#
# - candidate **a**: $w = (2, -1)$, $b = 3$;
# - candidate **b**: $w = (1.5, -0.5)$, $b = 2.5$.
#
# Compute `mse_a` and `mse_b`, and set `better` to the string `"a"` or
# `"b"` for the candidate with the smaller MSE.

# %%
import numpy as np

SEED = 20260804
rng = np.random.default_rng(SEED)
X = rng.normal(0, 1, (25, 2))
y = 2 * X[:, 0] - X[:, 1] + 3 + rng.normal(0, 0.3, 25)


def mse(X, y, w, b):
    # YOUR CODE HERE (banned: @, np.matmul, np.dot, .T, np.einsum, loops)
    ...


mse_a = ...   # YOUR CODE HERE
mse_b = ...   # YOUR CODE HERE
better = ...  # YOUR CODE HERE ("a" or "b")
