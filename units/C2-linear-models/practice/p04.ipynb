# %% [markdown]
# # C2-linear-models — Practice p04
#
# **Type:** multiple choice (numeric, normal form) · **Difficulty:** core · **Concepts:** MSE loss, linear regression
#
# For the dataset
# $$X = \begin{pmatrix} 1 & 2 \\ 2 & 0 \end{pmatrix}, \qquad y = (2, 1),$$
# the linear model $\hat y_i = \sum_k X_{ik} w_k + b$ is evaluated at
# $w = (2, -1)$, $b = 1$, with
# $\mathrm{MSE} = \frac{1}{n}\sum_i(\hat y_i - y_i)^2$.
#
# Compute $\dfrac{\partial\,\mathrm{MSE}}{\partial w_1 (zero-based: the coefficient `w[1]`)}$ at these weights.
# Your answer is a nonzero integer that can be written as $s \cdot m$ with
# $s \in \{+1, -1\}$ and $m$ a positive integer.
# What is $s + m$? (E.g. an answer of $-7$ gives $-1 + 7 = 6$.)
#
# A. $-1$
#
# B. $0$
#
# C. $1$
#
# D. $3$
#
# E. $5$
#
# Reasoning is not required. Record your choice below.

# %%
import numpy as np

answer_p04 = "?"  # replace with "A".."E"
