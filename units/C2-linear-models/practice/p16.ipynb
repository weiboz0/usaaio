# %% [markdown]
# # C2-linear-models — Practice p16
#
# **Type:** scenario analysis · **Difficulty:** core · **Concepts:** L2 regularization, MSE loss
#
# Two ridge models for the same task were trained elsewhere at different
# strengths and handed to you (supplied below):
#
# - model **S**, trained at $\lambda = 0.01$:
#   $w_S = (1.9,\, 0.2,\, -1.1,\, 0.9)$, $b_S = 1.4$,
#   penalized training loss $0.9$;
# - model **B**, trained at $\lambda = 5$:
#   $w_B = (1.0,\, 0.7,\, 0.0,\, 0.1)$, $b_B = 1.9$,
#   penalized training loss $8.1$.
#
# A teammate declares: *"Model B is obviously far worse — its loss is 8.1
# against model S's 0.9."*
#
# **(a)** Compute `mse_S` and `mse_B`: each model's **plain MSE**
# (no penalty term) on the seeded held-out test set below.
#
# **(b)** Set `better_model` to `"S"` or `"B"` according to the test MSEs
# from (a).
#
# **(c) Reasoning is required (2–4 sentences):**
# explain the teammate's mistake.
# Name the two different scoreboards being conflated, say why penalized
# totals computed at *different* $\lambda$ are not comparable (whose
# "tax" is higher, mechanically?), and state what the fair comparison is —
# citing your (a) numbers.

# %%
import numpy as np

SEED = 20260804
rng = np.random.default_rng(SEED)
X_test = rng.normal(0, 1, (40, 4))
y_test = 1.2 * X_test[:, 0] + 0.8 * X_test[:, 1] + 2 + rng.normal(0, 0.5, 40)

w_S = np.array([1.9, 0.2, -1.1, 0.9])
b_S = 1.4
w_B = np.array([1.0, 0.7, 0.0, 0.1])
b_B = 1.9

mse_S = ...         # YOUR CODE HERE
mse_B = ...         # YOUR CODE HERE
better_model = ...  # YOUR CODE HERE ("S" or "B")

# %% [markdown]
# *Your (c) reasoning here.*
