# %% [markdown]
# # C2-linear-models — Practice p17
#
# **Type:** challenge · **Difficulty:** advanced · **Concepts:** L1 regularization, L2 regularization, sparsity
#
# The decoupled closed forms, vectorized and certified.
#
# For a decoupled penalized loss, each coordinate minimizes its own
# one-dimensional term (lesson Session 2 §4): given the supplied pull
# vector `a` and strength $\lambda = 2.5$,
#
# $$\text{L1:}\quad w^{L1}_k = \arg\min_w\, (w - a_k)^2 + \lambda|w|
# \qquad\qquad
# \text{L2:}\quad w^{L2}_k = \arg\min_w\, (w - a_k)^2 + \lambda w^2 .$$
#
# **(a)** Compute `w_l1` — the shape-`(5,)` soft-threshold answer — in
# **one vectorized expression** (route: `np.where` with `np.abs` and
# `np.sign`).
# **Banned (zero points): `@`, `np.matmul`, `np.dot`, `.T`, `np.einsum`,
# `np.inner`, `np.tensordot`, any `np.linalg` function, any loop.**
#
# **(b)** Compute `w_l2` — the shape-`(5,)` ridge closed form
# $a_k/(1+\lambda)$ — same bans.
#
# **(c)** Certify (a) per coordinate against brute evaluation: for each
# $k$, evaluate $(w - a_k)^2 + \lambda|w|$ on
# `grid = np.linspace(-5, 5, 1000001)`, take the grid argmin, and set
# `max_anchor_gap` to the largest $|w^{L1}_k - \text{grid argmin}_k|$
# (should be $\le 10^{-5}$).
# The certifying checker MAY loop over the five coordinates.
#
# **(d)** Compute `zeros_l1` and `zeros_l2` — exact-zero counts of the two
# answers — and `shrink_check`: the max abs difference between `w_l2` and
# `a / 3.5` (should be exactly `0.0`).
# One sentence: which coordinates did L1 kill, and what single inequality
# predicted each kill?

# %%
import numpy as np

a = np.array([3.0, -1.0, 0.5, -4.0, 1.2])
lam = 2.5

# (a)
w_l1 = ...  # YOUR CODE HERE (one vectorized expression)

# (b)
w_l2 = ...  # YOUR CODE HERE

# (c)
max_anchor_gap = ...  # YOUR CODE HERE (checker MAY loop)

# (d)
zeros_l1 = ...      # YOUR CODE HERE
zeros_l2 = ...      # YOUR CODE HERE
shrink_check = ...  # YOUR CODE HERE

# %% [markdown]
# *Your (d) sentence here.*
