# %% [markdown]
# # C6-pytorch — Practice p01
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** torch tensors
#
# Consider
#
# ```python
# t = torch.arange(6).reshape(2, 3)
# u = t.sum(dim=0)
# ```
#
# Which statement is true?
#
# A. `u` is `tensor([3, 12])` and its dtype is `torch.int64`.
#
# B. `u` is `tensor([3, 5, 7])` and its dtype is `torch.float32`.
#
# C. `u` is `tensor([3, 12])` and its dtype is `torch.float32`.
#
# D. `u` is `tensor([3, 5, 7])` and its dtype is `torch.int64`.
#
# E. The second line raises a `RuntimeError` because `sum` is not defined
# for integer tensors.
#
# Reasoning is not required. Record your choice below.

# %%
import torch

answer_p01 = "?"  # replace with "A".."E"
