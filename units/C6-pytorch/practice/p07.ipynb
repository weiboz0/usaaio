# %% [markdown]
# # C6-pytorch — Practice p07
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** nn.Module
#
# A parameter-free module from an exact contract.
#
# **(a)** Implement `Window(nn.Module)`:
#
# - the constructor takes two plain floats `lo` and `hi` (with
#   `lo <= hi`) and stores them as ordinary attributes;
# - `forward(x)` returns, elementwise, `1.0` where
#   `lo <= x <= hi` and `0.0` elsewhere, with the output dtype equal to
#   `x`'s dtype.
#
# **(b)** For `t = torch.tensor([-2.0, -0.5, 0.0, 0.7, 1.0, 3.0])` and
# `w = Window(-0.5, 1.0)`, compute `inside = w(t)` — **calling the
# module, not `w.forward`** — and `n_inside`, the number of entries
# inside the window, as a plain `int`.
#
# **(c)** For the seeded standard-normal vector `v` below, compute
# `frac_inside` — the fraction of its 200 entries inside the same
# window, as a plain `float`.
#
# **Banned (zero points): `torch.clamp`/`clip`; `torch.where`; loops and
# comprehensions; importing NumPy.**
# Comparisons, `&`, and `.to(...)` are the intended tools; the module
# must subclass `nn.Module` and call `super().__init__()`.

# %%
import torch
import torch.nn as nn

torch.set_default_dtype(torch.float64)   # course convention (Session 1)


# (a) YOUR CODE HERE — class Window


t = torch.tensor([-2.0, -0.5, 0.0, 0.7, 1.0, 3.0])

# (b) YOUR CODE HERE
inside = ...
n_inside = ...

# (c)
torch.manual_seed(20260804)
v = torch.randn(200)
frac_inside = ...  # YOUR CODE HERE
