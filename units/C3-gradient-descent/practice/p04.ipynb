# %% [markdown]
# # C3-gradient-descent — Practice p04
#
# **Type:** multiple choice (numeric, normal form) · **Difficulty:** core · **Concepts:** gradient descent, learning rate
#
# Let $L(w) = (w - 4)^2$.
# Starting from $w_0 = 0$, take **two** gradient-descent steps
# $w \leftarrow w - \eta\, L'(w)$ with learning rate $\eta = 0.3$.
#
# The resulting $w_2$ is a positive rational number.
# Write it in lowest terms as $w_2 = p/q$ with $\gcd(p, q) = 1$ and $q > 0$.
# What is $p + q$?
#
# A. 17
#
# B. 105
#
# C. 109
#
# D. 113
#
# E. 436
#
# Reasoning is not required. Record your choice below.

# %%
import numpy as np

answer_p04 = "?"  # replace with "A".."E"
