# %% [markdown]
# # C3-gradient-descent — Practice p11
#
# **Type:** proof · **Difficulty:** advanced · **Concepts:** gradient descent, learning rate
#
# **Reasoning is required.**
#
# Consider the quadratic loss $L(w) = w^2$ with a single parameter $w$, minimized by gradient descent
# $$w_{t+1} = w_t - \eta\, L'(w_t), \qquad \eta > 0 .$$
#
# **(a)** Show that the update is exactly
# $w_{t+1} = (1 - 2\eta)\, w_t$, and deduce the closed form
# $w_t = (1 - 2\eta)^t\, w_0$ for every $t \ge 0$ (say why the deduction holds for all $t$, not just the first few).
#
# **(b)** Determine **exactly** the set of learning rates $\eta > 0$ for which $w_t \to 0$ for **every** starting point $w_0$, and justify it from the closed form.
# Then describe the behavior of the iterates in each regime:
# $0 < \eta < \tfrac12$, $\;\eta = \tfrac12$, $\;\tfrac12 < \eta < 1$, $\;\eta = 1$, $\;\eta > 1$
# (monotone or alternating in sign? shrinking, constant, or growing in size?).
#
# **(c) Concrete anchor:** for $\eta = 0.8$, $w_0 = 5$, compute `w10_loop` by running the update 10 times in a loop and `w10_formula` $= (1 - 2\eta)^{10}\, w_0$ directly, then `anchor_gap = abs(w10_loop - w10_formula)`.
# The two must agree to floating-point precision, and their common value must match the sign and size your (b) analysis predicts for this $\eta$.

# %% [markdown]
# *Your derivation for (a) and analysis for (b) here.*

# %%
import numpy as np

# (c) YOUR CODE HERE
w10_loop = ...
w10_formula = ...
anchor_gap = ...
