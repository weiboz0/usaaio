# %% [markdown]
# # C3-gradient-descent — Practice p09
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** gradient descent
#
# End to end: fit the C2 linear model by gradient descent.
#
# As covered in C2-linear-models, the model and loss are
# $$\hat y_i = \sum_{k} X_{ik} w_k + b, \qquad
# L(w, b) = \frac{1}{n} \sum_{i=1}^{n} (\hat y_i - y_i)^2 ,$$
# with gradients
# $$\frac{\partial L}{\partial w_k} = \frac{2}{n} \sum_i (\hat y_i - y_i)\, X_{ik}, \qquad
# \frac{\partial L}{\partial b} = \frac{2}{n} \sum_i (\hat y_i - y_i).$$
#
# **(a)** Write `mse_loss(X, y, w, b)` and `mse_gradients(X, y, w, b)` (returning `(grad_w, grad_b)`).
#
# **(b)** Write `fit(X, y, eta, steps)` that starts from `w = np.zeros(d)`, `b = 0.0` and repeats the descent step
# $w \leftarrow w - \eta\, \mathrm{grad}_w$, $\;b \leftarrow b - \eta\, \mathrm{grad}_b$ for `steps` iterations, returning `(w, b, losses)` where `losses` holds the loss value **after** each step (shape `(steps,)`).
#
# **(c)** Run `fit(X, y, eta=0.1, steps=500)` on the seeded data below.
# Store `w_fit`, `b_fit`, `final_loss = losses[-1]`, and
# `param_gap` = the largest absolute difference between the fitted parameters and the generating parameters (`w_true`, `b_true`), over all four numbers.
# If your implementation is right, `param_gap` is below `0.05` and `final_loss` is close to the noise level ($0.1^2$).
#
# **Banned (zero points): `@`, `np.matmul`, `np.dot`, `np.einsum`, `.T`.**
# The **only** loop allowed anywhere is the loop over the `steps` descent iterations — loss and gradients use broadcasting and axis sums only.

# %%
import numpy as np

SEED = 20260804
rng = np.random.default_rng(SEED)
X = rng.normal(0, 1, (120, 3))
w_true = np.array([3.0, -2.0, 1.0])
b_true = -0.5
y = (X * w_true).sum(axis=1) + b_true + rng.normal(0, 0.1, 120)


def mse_loss(X, y, w, b):
    # YOUR CODE HERE
    ...


def mse_gradients(X, y, w, b):
    # YOUR CODE HERE
    ...


def fit(X, y, eta, steps):
    # YOUR CODE HERE (only loop allowed: over the steps)
    ...


w_fit, b_fit, losses = ...  # YOUR CODE HERE
final_loss = ...            # YOUR CODE HERE
param_gap = ...             # YOUR CODE HERE
