# %% [markdown]
# # C3-gradient-descent — Practice p15
#
# **Type:** scenario analysis · **Difficulty:** core · **Concepts:** learning rate
#
# A teammate fits the C2 linear model on $n = 500$ points with the mean-MSE loss
# $L_{\text{mean}} = \frac{1}{n}\sum_i (\hat y_i - y_i)^2$ and $\eta = 0.05$; the loss decreases nicely.
# They then switch to the **sum** loss $L_{\text{sum}} = \sum_i (\hat y_i - y_i)^2$ — "same minimizer, so nothing changes" — keep $\eta = 0.05$, and the loss explodes within a few steps.
#
# Work the effect on a 1-D proxy: all $x_i = 1$ and all $y_i = 4$, so
# $L_{\text{mean}}(w) = (w - 4)^2$ while $L_{\text{sum}}(w) = 500\,(w - 4)^2$.
#
# **(a)** By hand: `scale` = the factor by which switching to the sum loss multiplies **every gradient**; `factor_mean` $= 1 - 2\eta$ and `factor_sum` $= 1 - 2 \cdot 500 \cdot \eta$, the per-step error multipliers of the two runs at $\eta = 0.05$.
#
# **(b)** Simulate both from $w_0 = 0$: `trace_mean` and `trace_sum`, each the array of the first 4 iterates $(w_1, \dots, w_4)$.
# Then set `eta_fixed` = the corrected learning rate for the sum loss that reproduces the mean-loss run exactly, and `trace_fixed` = the first 4 iterates of the sum loss with `eta_fixed` (it must equal `trace_mean`).
#
# **(c)** In the markdown cell (2–3 sentences): explain to the teammate why the same $\eta$ diverges — same minimizer, but an $n$-times-steeper surface — and add one sentence on why raw **sum**-loss values are also not comparable between datasets of different sizes, while mean-MSE values are.
#
# Loops over the 4 steps are allowed.

# %%
import numpy as np

eta = 0.05
n = 500

# (a) YOUR CODE HERE
scale = ...
factor_mean = ...
factor_sum = ...

# (b) YOUR CODE HERE
trace_mean = ...
trace_sum = ...
eta_fixed = ...
trace_fixed = ...

# %% [markdown]
# *Your (c) explanation here (2–3 sentences).*
