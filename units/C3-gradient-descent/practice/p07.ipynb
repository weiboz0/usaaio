# %% [markdown]
# # C3-gradient-descent — Practice p07
#
# **Type:** constrained coding · **Difficulty:** core · **Concepts:** gradient descent, learning rate
#
# One learning rate, two curvatures.
#
# Consider the elongated bowl
# $$L(w_1, w_2) = w_1^2 + 10\, w_2^2, \qquad \nabla L = (2 w_1,\; 20 w_2).$$
#
# **(a)** Write `run_descent(w0, eta, steps)` that runs `steps` descent steps
# $w \leftarrow w - \eta\, \nabla L(w)$ from the shape-`(2,)` start `w0` and returns the full history as an array of shape `(steps + 1, 2)` (row 0 is `w0`).
# Run it from `w0 = np.array([8.0, 3.0])` with `eta = 0.09`, `steps = 40`; store the history in `hist_a` and its last row in `final_a`.
#
# **(b)** Repeat with `eta = 0.11` (same start, same steps): `hist_b`, `final_b`.
# Set `diverged_b = bool(np.abs(final_b).max() > 100)`.
#
# **(c)** In the markdown cell: in 2–3 sentences, explain which coordinate sets the upper limit on the usable learning rate here, using the per-coordinate update factors ($1 - 2\eta$ for $w_1$, $1 - 20\eta$ for $w_2$).
#
# **Banned (zero points): `@`, `np.matmul`, `np.dot`, `np.einsum`, `.T`.**
# The **only** loop allowed is the loop over descent steps; compute each gradient with elementwise array arithmetic.

# %%
import numpy as np


def run_descent(w0, eta, steps):
    # YOUR CODE HERE (only loop allowed: over the steps)
    ...


hist_a = ...      # YOUR CODE HERE — eta = 0.09
final_a = ...     # YOUR CODE HERE

hist_b = ...      # YOUR CODE HERE — eta = 0.11
final_b = ...     # YOUR CODE HERE
diverged_b = ...  # YOUR CODE HERE

# %% [markdown]
# *Your (c) explanation here (2–3 sentences).*
