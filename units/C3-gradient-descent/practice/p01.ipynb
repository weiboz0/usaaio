# %% [markdown]
# # C3-gradient-descent — Practice p01
#
# **Type:** multiple choice · **Difficulty:** intro · **Concepts:** loss surfaces
#
# Consider the loss surface
# $$L(w_1, w_2) = (w_1 - 2)^2 + 4\,(w_2 + 1)^2 .$$
#
# Which statement is true?
#
# A. The minimum is at $(-2, 1)$ and the contour lines are circles.
#
# B. The minimum is at $(2, -1)$; the contour lines are ellipses, and the surface climbs more steeply along the $w_2$ direction than along the $w_1$ direction.
#
# C. The minimum is at $(2, -1)$ and the contour lines are circles — the surface is equally steep in every direction.
#
# D. The minimum is at $(2, -1)$; the contour lines are ellipses, and the surface climbs more steeply along the $w_1$ direction than along the $w_2$ direction.
#
# E. The minimum is at $(-2, 1)$; the contour lines are ellipses, and the surface climbs more steeply along the $w_2$ direction.
#
# Reasoning is not required. Record your choice below.

# %%
import numpy as np

answer_p01 = "?"  # replace with "A".."E"
